# %% [markdown]
# # Leisure Walking Recommendation
#
# Analysing the POIs in the description - both verbal descriptions of POIs and the geometric and thematic characterisitics

# %% [markdown]
# ## Setup
#
# Loading libraries and models

# %%
# working with files
import os.path
# IO
import json
# calling Webservices
import requests
# systematic thread stops for polite crawling
import time

# set random seed for reproducibility of results
from umap import UMAP

# dataframe 
import numpy as np
import pandas as pd
import geopandas as gpd

# geocoding
from geopy.geocoders import Nominatim

# getting data from OSM
import osmnx as ox

# topic modelling
from bertopic import BERTopic
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.representation import KeyBERTInspired

# nlp
from sentence_transformers import SentenceTransformer, util
import spacy
from nltk.corpus import stopwords

# en_core_web_lg must be downloaded, if not run: 'python -m spacy download en_core_web_lg' first!
nlp = spacy.load('en_core_web_lg')

umap_model = UMAP(random_state=42)

stopword_removal = False

# %% [markdown]
# ## Dataset
#
# Reading the dataset crawled from WalkingMap website.

# %%
with open('dataset/walkingmaps.json', 'r', encoding='utf-8') as fp:
    dataset = json.load(fp)

# %%
dataset[1]
# Out:
# {'markers': [{'markerId': 1581,
#    'snapToRoad': False,
#    'lat': -38.46876091,
#    'lng': 144.08441126},
#   {'markerId': 1582,
#    'snapToRoad': False,
#    'lat': -38.46847531,
#    'lng': 144.09128845},
#   {'markerId': 1583,
#    'snapToRoad': False,
#    'lat': -38.46838291,
#    'lng': 144.09777939},
#   {'markerId': 1584,
#    'snapToRoad': False,
#    'lat': -38.46883651,
#    'lng': 144.10096586},
#   {'markerId': 1585,
#    'snapToRoad': False,
#    'lat': -38.46712287,
#    'lng': 144.1010946},
#   {'markerId': 1586,
#    'snapToRoad': False,
#    'lat': -38.46678686,
#    'lng': 144.10134137},
#   {'markerId': 1587,
#    'snapToRoad': False,
#    'lat': -38.46640884,
#    'lng': 144.0987128},
#   {'markerId': 1588,
#    'snapToRoad': False,
#    'lat': -38.46572001,
#    'lng': 144.09890592},
#   {'markerId': 1589,
#    'snapToRoad': False,
#    'lat': -38.46549319,
#    'lng': 144.09875572},
#   {'markerId': 1590,
#    'snapToRoad': False,
#    'lat': -38.46572841,
#    'lng': 144.09900248},
#   {'markerId': 1591,
#    'snapToRoad': False,
#    'lat': -38.46635844,
#    'lng': 144.09876913},
#   {'markerId': 1592,
#    'snapToRoad': False,
#    'lat': -38.46675746,
#    'lng': 144.10141915},
#   {'markerId': 1593,
#    'snapToRoad': False,
#    'lat': -38.46716487,
#    'lng': 144.10118312},
#   {'markerId': 1594,
#    'snapToRoad': False,
#    'lat': -38.4681309,
#    'lng': 144.1040799}],
#  'pathDetails': [{'lat': -38.46876091, 'lng': 144.08441126},
#   {'lat': -38.46847531, 'lng': 144.09128845},
#   {'lat': -38.46838291, 'lng': 144.09777939},
#   {'lat': -38.46883651, 'lng': 144.10096586},
#   {'lat': -38.46712287, 'lng': 144.1010946},
#   {'lat': -38.46678686, 'lng': 144.10134137},
#   {'lat': -38.46640884, 'lng': 144.0987128},
#   {'lat': -38.46572001, 'lng': 144.09890592},
#   {'lat': -38.46549319, 'lng': 144.09875572},
#   {'lat': -38.46572841, 'lng': 144.09900248},
#   {'lat': -38.46635844, 'lng': 144.09876913},
#   {'lat': -38.46675746, 'lng': 144.10141915},
#   {'lat': -38.46716487, 'lng': 144.10118312},
#   {'lat': -38.4681309, 'lng': 144.1040799}],
#  'pois': [{'title': 'Fairhaven Surf Life Saving Club',
#    'summary': 'Fairhaven is a well known surf beach. The beach is patrolled during December to the Easter. The Fairhaven SLSC was established in 1958.',
#    'poiId': 372,
#    'hasImage': True,
#    'isHazard': False,
#    'lat': -38.46875894,
#    'lng': 144.08445884},
#   {'title': 'Beach walk',
#    'summary': 'From Sprout Creek, Eastern View, Moggs Creek, Fairhaven to the bottom of the light house there is approx 6 km of beach, featuring rolling surf and spectacular views of the Otway Ranges and Lorne.',
#    'poiId': 373,
#    'hasImage': True,
#    'isHazard': False,
#    'lat': -38.46854155,
#    'lng': 144.08969344},
#   {'title': 'Rock pools',
#    'summary': 'See what sort of shells and stones you can collect. Can you find a bright red sea star? You can see all sorts of sea vegetation, small fish and crabs. Look at the bird life, gulls and cormorants.',
#    'poiId': 374,
#    'hasImage': True,
#    'isHazard': False,
#    'lat': -38.4684592,
#    'lng': 144.09241977},
#   {'title': 'Sand dunes',
#    'summary': 'The beautiful rolling sand dunes shape the beach. 2011 has seen significant erosion due to winter storms that have bought strong winds and big waves (up to 10 feet).',
#    'poiId': 375,
#    'hasImage': True,
#    'isHazard': False,
#    'lat': -38.46841795,
#    'lng': 144.09531794},
#   {'title': 'Painkalac Creek',
#    'summary': 'The creek separates Aireys Inlet from Fairhaven and forms an inlet behind the sand dunes before it cuts through to the ocean. A great place to shelter from the wind and for younger children to swim.',
#    'poiId': 376,
#    'hasImage': True,
#    'isHazard': False,
#    'lat': -38.46838956,
#    'lng': 144.09731206},
#   {'title': 'Rocks and caves under the light house',
#    'summary': 'There are more rockpools and rocky outcrops to explore under the light house. This area is part of the marine national park. This means that all wildlife is protected and cannot be removed.',
#    'poiId': 377,
#    'hasImage': True,
#    'isHazard': False,
#    'lat': -38.46882153,
#    'lng': 144.10086059},
#   {'title': 'Aireys Inlet playground and picnic ground',
#    'summary': 'There is small skateboard ramp for children to ride their scooters or skateboards. There are also swings and other play equipment for children and a picnic area.',
#    'poiId': 378,
#    'hasImage': True,
#    'isHazard': False,
#    'lat': -38.46619881,
#    'lng': 144.09877169},
#   {'title': 'Aireys Inlet lower shops',
#    'summary': 'Pick up a coffee, newspaper or Fish and Chips! To the left of the shops, on the other side of the river, kangaroos can be seen in the early morning or at dusk.',
#    'poiId': 379,
#    'hasImage': True,
#    'isHazard': False,
#    'lat': -38.46553592,
#    'lng': 144.09880054},
#   {'title': 'Loutit Bay lookout',
#    'summary': 'Return to Painkalac Creek inlet and walk to the grassed area on the left. At the light house bollard turn right and walk up the signed (steep) walking track. Enjoy panaromic views on your walk up.',
#    'poiId': 380,
#    'hasImage': True,
#    'isHazard': False,
#    'lat': -38.46791596,
#    'lng': 144.10343538},
#   {'title': 'Historical homestead and building',
#    'summary': 'At the lighthouse is the original homestead for the lighthouse keeper. The Aireys Inlet area was first settled in the 1840s. The first tourists arrived in 1919.',
#    'poiId': 381,
#    'hasImage': True,
#    'isHazard': False,
#    'lat': -38.46804821,
#    'lng': 144.10383193},
#   {'title': 'Split Point Lighthouse',
#    'summary': 'Follow the signs and continue up the walking track. Shipping along the Victorian coast was much safer once the combination of this and other lighthouses at Cape Otway and Point Lonsdale were built.',
#    'poiId': 382,
#    'hasImage': True,
#    'isHazard': False,
#    'lat': -38.46811382,
#    'lng': 144.10402869}],
#  'title': 'Fairhaven to Aireys Inlet Walk created by tedmcrae',
#  'description': 'Apart from the points of interested listed, here are a few things to keep in mind when taking this walk. 1. Crossing the Great Ocean Road, particularly during summer can be a little perilous. The speed restriction is lowered to 60 kms between November to April. 2. Dogs are prohibited on the beach between December and April. However, this is not well policed by the Surf Coast Shire. Dogs off leash often jump on unsuspecting walkers. 3. Horses on the beach. During the busy summer months, a local horse riding company allows tourists to take horses on the beach to canter. These are inexperienced riders. The horses also defecate so there is a need to be mindful where you step after they have been on the beach.'}

# %% [markdown]
# ### Dataset Transformation
#
# Aim: Transforming the dataset into pandas and geopandas dataframes, with a focus on POIs
#
# A basic preprocessing step to create a dataset of POI descriptions, also including A preliminary analysis their location.

# %%
counter = 0
total = 0
for record in dataset:
    if 'pois' in record.keys() and len(record['pois']) > 0:
        counter+=1
        total += len(record['pois'])
print('records: {0} total POIs: {1} - average per record: {2}'.format(counter, total, round(total/counter)))
# Out:
# records: 386 total POIs: 4392 - average per record: 11

# %%
data_structure = {'record_title':[], 'record_description':[], 'poi_title':[], 'poi_summary':[], 'latitude': [], 'longitude': []}
for record in dataset:
    if 'pois' in record.keys() and len(record['pois']) > 0:
        for poi in record['pois']:
            data_structure['record_title'].append(record['title'])
            data_structure['record_description'].append(record['description'])
            data_structure['poi_title'].append(poi['title'])
            data_structure['poi_summary'].append(poi['summary'])
            data_structure['latitude'].append(poi['lat'])
            data_structure['longitude'].append(poi['lng'])

# %%
df = pd.DataFrame(data_structure)

gdf = gpd.GeoDataFrame(df[['poi_title', 'poi_summary', 'latitude', 'longitude']], geometry=gpd.points_from_xy(df.longitude, df.latitude), crs="EPSG:4326")

# %%
gdf.explore()

# %%
gdf.head()
# Out:
#                          poi_title  \
# 0  Fairhaven Surf Life Saving Club
# 1                       Beach walk
# 2                       Rock pools
# 3                       Sand dunes
# 4                  Painkalac Creek
#
#                                          poi_summary   latitude   longitude  \
# 0  Fairhaven is a well known surf beach. The beac... -38.468759  144.084459
# 1  From Sprout Creek, Eastern View, Moggs Creek, ... -38.468542  144.089693
# 2  See what sort of shells and stones you can col... -38.468459  144.092420
# 3  The beautiful rolling sand dunes shape the bea... -38.468418  144.095318
# 4  The creek separates Aireys Inlet from Fairhave... -38.468390  144.097312
#
#                       geometry
# 0  POINT (144.08446 -38.46876)
# 1  POINT (144.08969 -38.46854)
# 2  POINT (144.09242 -38.46846)
# 3  POINT (144.09532 -38.46842)
# 4  POINT (144.09731 -38.46839)

# %%
df.head()
# Out:
#                                         record_title  \
# 0  Fairhaven to Aireys Inlet Walk created by tedm...
# 1  Fairhaven to Aireys Inlet Walk created by tedm...
# 2  Fairhaven to Aireys Inlet Walk created by tedm...
# 3  Fairhaven to Aireys Inlet Walk created by tedm...
# 4  Fairhaven to Aireys Inlet Walk created by tedm...
#
#                                   record_description  \
# 0  Apart from the points of interested listed, he...
# 1  Apart from the points of interested listed, he...
# 2  Apart from the points of interested listed, he...
# 3  Apart from the points of interested listed, he...
# 4  Apart from the points of interested listed, he...
#
#                          poi_title  \
# 0  Fairhaven Surf Life Saving Club
# 1                       Beach walk
# 2                       Rock pools
# 3                       Sand dunes
# 4                  Painkalac Creek
#
#                                          poi_summary   latitude   longitude
# 0  Fairhaven is a well known surf beach. The beac... -38.468759  144.084459
# 1  From Sprout Creek, Eastern View, Moggs Creek, ... -38.468542  144.089693
# 2  See what sort of shells and stones you can col... -38.468459  144.092420
# 3  The beautiful rolling sand dunes shape the bea... -38.468418  144.095318
# 4  The creek separates Aireys Inlet from Fairhave... -38.468390  144.097312

# %% [markdown]
# ## Topic Modelling
#
# **Aim**: Findings topics describing the POIs using BERT embeddings
#
# **Approach**: Using raw textual description (title + summary) and feed it BERTopic for categorisation. Manunally investigating the categories to find out the categories are coherent and meaningful.

# %%
gdf['description'] = gdf['poi_title']+': '+gdf['poi_summary']

# %%
def remove_stopwords(row):
    return ' '.join([w for w in row['description'].split() if w.lower() not in stopwords.words('english')])

# %%
if stopword_removal:
    gdf['description'] = gdf.apply(remove_stopwords, axis=1)

# %%
gdf.head()
# Out:
#                          poi_title  \
# 0  Fairhaven Surf Life Saving Club
# 1                       Beach walk
# 2                       Rock pools
# 3                       Sand dunes
# 4                  Painkalac Creek
#
#                                          poi_summary   latitude   longitude  \
# 0  Fairhaven is a well known surf beach. The beac... -38.468759  144.084459
# 1  From Sprout Creek, Eastern View, Moggs Creek, ... -38.468542  144.089693
# 2  See what sort of shells and stones you can col... -38.468459  144.092420
# 3  The beautiful rolling sand dunes shape the bea... -38.468418  144.095318
# 4  The creek separates Aireys Inlet from Fairhave... -38.468390  144.097312
#
#                       geometry  \
# 0  POINT (144.08446 -38.46876)
# 1  POINT (144.08969 -38.46854)
# 2  POINT (144.09242 -38.46846)
# 3  POINT (144.09532 -38.46842)
# 4  POINT (144.09731 -38.46839)
#
#                                          description
# 0  Fairhaven Surf Life Saving Club: Fairhaven is ...
# 1  Beach walk: From Sprout Creek, Eastern View, M...
# 2  Rock pools: See what sort of shells and stones...
# 3  Sand dunes: The beautiful rolling sand dunes s...
# 4  Painkalac Creek: The creek separates Aireys In...

# %%
docs = list(gdf['description'])

ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)
topic_model = BERTopic(umap_model=umap_model, ctfidf_model=ctfidf_model)
topics, probs = topic_model.fit_transform(docs)

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                    Name  \
# 0      -1   1454          -1_reserve_street_through_hall
# 1       0    328            0_track_steep_signage_gravel
# 2       1    165                   1_beach_bay_sand_tide
# 3       2    161  2_bridge_pedestrian_footbridge_railway
# 4       3    148           3_sculpture_artists_mural_art
# ..    ...    ...                                     ...
# 59     58     12    58_boydys_anthills_center_mornington
# 60     59     11          59_brummys_weeks_burnt_bremner
# 61     60     11   60_tramway_formation_grub_lysterfield
# 62     61     10  61_wisteria_emblem_riceflower_dilwinia
# 63     62     10  62_pickering_koonung_viaduct_doncaster
#
#                                        Representation  \
# 0   [reserve, street, through, hall, water, centre...
# 1   [track, steep, signage, gravel, top, path, wal...
# 2   [beach, bay, sand, tide, breakwater, surf, coa...
# 3   [bridge, pedestrian, footbridge, railway, unde...
# 4   [sculpture, artists, mural, art, wall, artwork...
# ..                                                ...
# 59  [boydys, anthills, center, mornington, ice, di...
# 60  [brummys, weeks, burnt, bremner, elms, smoke, ...
# 61  [tramway, formation, grub, lysterfield, expens...
# 62  [wisteria, emblem, riceflower, dilwinia, flowe...
# 63  [pickering, koonung, viaduct, doncaster, cable...
#
#                                   Representative_Docs
# 0   [Boroondara Shops: A great little shopping str...
# 1   [The walking route: The route is flat and acce...
# 2   [Beach walkers: If the tide is out, walking al...
# 3   [Overhead Railway Bridge : The Overhead Bridge...
# 4   [Three Businessmen Who Brought Their Own Lunch...
# ..                                                ...
# 59  [Boydys Take Away: Excellent place for a meal ...
# 60  [As weeks go by - Laurens Tan, 2004: As Weeks ...
# 61  [incline tramway: This is the only incline fir...
# 62  [Wisteria heaven: Come in spring time for an e...
# 63  [Right fork please!: Take the gravel path head...
#
# [64 rows x 5 columns]

# %%
topic_model.visualize_topics()

# %%
topic_model.visualize_hierarchy()

# %%
# what happen when merging topics as well
hierarchical_topics = topic_model.hierarchical_topics(docs)
topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# 100%|██████████| 62/62 [00:00<00:00, 228.09it/s]

# %%
topic_model.visualize_barchart()

# %%
topic_model.visualize_heatmap()

# %%
# topic outlier reduction - if necessary (todo)
topics = topic_model.reduce_outliers(docs, topics, strategy="c-tf-idf")

# %%
topic_df = pd.DataFrame({'topic': topics, 'document': docs})

# %%
topic_df.head()
# Out:
#    topic                                           document
# 0      1  Fairhaven Surf Life Saving Club: Fairhaven is ...
# 1      1  Beach walk: From Sprout Creek, Eastern View, M...
# 2     12  Rock pools: See what sort of shells and stones...
# 3      1  Sand dunes: The beautiful rolling sand dunes s...
# 4     35  Painkalac Creek: The creek separates Aireys In...

# %% [markdown]
# ### Conclusions
# Some categories are not atomic, several biases toward famous geographic names including LGAs and suburbs. Removing the geographic names from the POI descriptions will help to understand 'what' categories they belong rather than 'where' they are.
#
# #### Work ToDo:
# 1. **Classification**: Analysing the hierarchical organization of topics to define classes describing what POIs are described.
# 2. **Space and Classes/Topics**: LGA? SA2/SA3? Question: Is there a relationship between categories and location - how it changes before and after removing place names?
# 3. **Walks and Classes/Topics**: Type of the walk - finding a categorization of leisure walks and check the association of topics to leisure walk purpose. Question: Is there a association between walks/categories of walks and certian POIs selected based on their classification/topics.

# %% [markdown]
# ### Possible Future Work: Multimodel Topic Modelling
#
# Using both text and images for topic modelling.
#
# Could be a good future work or an extension to the work - I need change the crawler information for this to capture links for description and also for images.
#
# See: https://maartengr.github.io/BERTopic/getting_started/multimodal/multimodal.html#text-images

# %% [markdown]
# ## OSM Points of Interests

# %%
# bounding box of each path
paths = []
for record in dataset:
    min_lat = 90
    max_lat = -90
    min_lng = 180
    max_lng = -180
    for latlng in record['pathDetails']:
        if min_lat > latlng['lat']:
            min_lat = latlng['lat']
        if max_lat < latlng['lat']:
            max_lat = latlng['lat']
        if min_lng > latlng['lng']:
            min_lng = latlng['lng']
        if max_lng < latlng['lng']:
            max_lng = latlng['lng']
    paths.append({'min_lat': min_lat, 'max_lat': max_lat, 'min_lng': min_lng, 'max_lng': max_lng})

# %%
paths
# Out:
# [{'min_lat': -37.82326007,
#   'max_lat': -37.81401352,
#   'min_lng': 144.96751249,
#   'max_lng': 144.97828424},
#  {'min_lat': -38.46883651,
#   'max_lat': -38.46549319,
#   'min_lng': 144.08441126,
#   'max_lng': 144.1040799},
#  {'min_lat': -37.80922028,
#   'max_lat': -37.79740113,
#   'min_lng': 144.96275961,
#   'max_lng': 144.97345358},
#  {'min_lat': -34.190259657952346,
#   'max_lat': -34.1828022667217,
#   'min_lng': 142.15728521325218,
#   'max_lng': 142.16644227499273},
#  {'min_lat': -37.81905011,
#   'max_lat': -37.81639942,
#   'min_lng': 144.9672094,
#   'max_lng': 144.98397186},
#  {'min_lat': -38.34566157,
#   'max_lat': -38.31852415,
#   'min_lng': 144.69141662000004,
#   'max_lng': 144.73630071000002},
#  {'min_lat': -37.57328182,
#   'max_lat': -37.54903468,
#   'min_lng': 149.75053489,
#   'max_lng': 149.76544261},
#  {'min_lat': -37.80127748,
#   'max_lat': -37.79937006,
#   'min_lng': 145.00765997,
#   'max_lng': 145.01382369},
#  {'min_lat': -36.39264513,
#   'max_lat': -36.38615029,
#   'min_lng': 145.39311469,
#   'max_lng': 145.39760202},
#  {'min_lat': -37.77030766,
#   'max_lat': -37.76252183,
#   'min_lng': 145.34911036,
#   'max_lng': 145.35765052},
#  {'min_lat': -37.47563881424965,
#   'max_lat': -37.44667788682738,
#   'min_lng': 146.9557374715805,
#   'max_lng': 146.98676},
#  {'min_lat': -37.833470000000005,
#   'max_lat': -37.82213,
#   'min_lng': 144.97139000000004,
#   'max_lng': 144.98472000000004},
#  {'min_lat': -36.77832054,
#   'max_lat': -36.73403483,
#   'min_lng': 142.17737675,
#   'max_lng': 142.20587254},
#  {'min_lat': -37.81656258,
#   'max_lat': -37.80660315,
#   'min_lng': 144.95981187000007,
#   'max_lng': 144.97541024999998},
#  {'min_lat': -37.90205877,
#   'max_lat': -37.89545521,
#   'min_lng': 145.19418061,
#   'max_lng': 145.20620763},
#  {'min_lat': -38.15949771,
#   'max_lat': -38.12814273,
#   'min_lng': 145.85812926,
#   'max_lng': 145.92358589},
#  {'min_lat': -37.97109813,
#   'max_lat': -37.95291168,
#   'min_lng': 145.29331075999994,
#   'max_lng': 145.30562747},
#  {'min_lat': -37.75961965815255,
#   'max_lat': -37.75234363033979,
#   'min_lng': 145.00031826464692,
#   'max_lng': 145.00741957410355},
#  {'min_lat': -37.79920474721049,
#   'max_lat': -37.79450380455811,
#   'min_lng': 144.91437524557114,
#   'max_lng': 144.92595970630646},
#  {'min_lat': -39.03399,
#   'max_lat': -39.02333470246017,
#   'min_lng': 146.30323112010956,
#   'max_lng': 146.32160999999996},
#  {'min_lat': -38.49336905,
#   'max_lat': -38.48623103,
#   'min_lng': 144.88888621,
#   'max_lng': 144.91354107999996},
#  {'min_lat': -37.81792766,
#   'max_lat': -37.80907459,
#   'min_lng': 144.96033020000004,
#   'max_lng': 144.97045554},
#  {'min_lat': -26.406630000000003,
#   'max_lat': -26.37696,
#   'min_lng': 153.09897512197495,
#   'max_lng': 153.11913000000004},
#  {'min_lat': -37.79243513,
#   'max_lat': -37.77893218,
#   'min_lng': 144.9488765,
#   'max_lng': 144.9705863},
#  {'min_lat': -36.63023047332152,
#   'max_lat': -36.62004211117345,
#   'min_lng': 142.62932762503624,
#   'max_lng': 142.64019593596458},
#  {'min_lat': -37.9180803,
#   'max_lat': -37.9123992,
#   'min_lng': 144.99473691,
#   'max_lng': 145.00374913},
#  {'min_lat': -38.168394,
#   'max_lat': -38.14955624,
#   'min_lng': 144.31948543,
#   'max_lng': 144.33172435000006},
#  {'min_lat': -37.75156341501005,
#   'max_lat': -37.740291,
#   'min_lng': 144.75722895700835,
#   'max_lng': 144.76306799999998},
#  {'min_lat': -37.96251299532802,
#   'max_lat': -37.95525079248291,
#   'min_lng': 144.40851598978043,
#   'max_lng': 144.41449731588364},
#  {'min_lat': -37.786928256787704,
#   'max_lat': -37.782070000000004,
#   'min_lng': 144.94908571243286,
#   'max_lng': 144.95477000000005},
#  {'min_lat': -37.957480000000004,
#   'max_lat': -37.94429903109217,
#   'min_lng': 145.24626,
#   'max_lng': 145.26274999999998},
#  {'min_lat': -36.72654964,
#   'max_lat': -36.72270142,
#   'min_lng': 146.96243243,
#   'max_lng': 146.97173433},
#  {'min_lat': -37.9510674,
#   'max_lat': -37.94613501,
#   'min_lng': 145.22268739000003,
#   'max_lng': 145.22676997999997},
#  {'min_lat': -38.573032,
#   'max_lat': -38.526174,
#   'min_lng': 145.447635,
#   'max_lng': 145.50888800000007},
#  {'min_lat': -38.064129529790065,
#   'max_lat': -38.053924794265704,
#   'min_lng': 145.4639357328415,
#   'max_lng': 145.46857327222824},
#  {'min_lat': -35.279250000000005,
#   'max_lat': -35.27087,
#   'min_lng': 149.10294,
#   'max_lng': 149.10884857177734},
#  {'min_lat': -37.78625735733004,
#   'max_lat': -37.783117933282725,
#   'min_lng': 144.84796307981014,
#   'max_lng': 144.8562403768301},
#  {'min_lat': -37.4579291,
#   'max_lat': -37.44825367,
#   'min_lng': 144.64526652999996,
#   'max_lng': 144.65226172999996},
#  {'min_lat': -34.193559701128514,
#   'max_lat': -34.18683882282585,
#   'min_lng': 142.15947031974792,
#   'max_lng': 142.1657520532608},
#  {'min_lat': -39.030190000000005,
#   'max_lat': -39.02758,
#   'min_lng': 146.31654000000003,
#   'max_lng': 146.32418000000007},
#  {'min_lat': -37.985610229820345,
#   'max_lat': -37.972970000000004,
#   'min_lng': 145.14829874038696,
#   'max_lng': 145.15700000000004},
#  {'min_lat': -37.90971138,
#   'max_lat': -37.88588747,
#   'min_lng': 145.35495222,
#   'max_lng': 145.37969291},
#  {'min_lat': -37.78272258,
#   'max_lat': -37.77451404,
#   'min_lng': 144.7962749,
#   'max_lng': 144.8233223},
#  {'min_lat': -37.819354708967964,
#   'max_lat': -37.81159246271351,
#   'min_lng': 147.62725049244182,
#   'max_lng': 147.64710956798808},
#  {'min_lat': -34.23269399729047,
#   'max_lat': -34.21643340730008,
#   'min_lng': 142.2231325507164,
#   'max_lng': 142.22811877727509},
#  {'min_lat': -37.160145539952296,
#   'max_lat': -37.13725,
#   'min_lng': 142.50087797641754,
#   'max_lng': 142.51747999999998},
#  {'min_lat': -37.84754478,
#   'max_lat': -37.84072451,
#   'min_lng': 144.94513214,
#   'max_lng': 144.95560348},
#  {'min_lat': -37.98884039,
#   'max_lat': -37.98375832,
#   'min_lng': 145.47986805000005,
#   'max_lng': 145.49339712000005},
#  {'min_lat': -37.77801634978228,
#   'max_lat': -37.731124236671704,
#   'min_lng': 144.96462106704712,
#   'max_lng': 144.98890042304993},
#  {'min_lat': -37.845155637957674,
#   'max_lat': -37.826640000000005,
#   'min_lng': 144.88378,
#   'max_lng': 144.89707},
#  {'min_lat': -37.11096933,
#   'max_lat': -37.1083469,
#   'min_lng': 142.40560098000003,
#   'max_lng': 142.41196833000004},
#  {'min_lat': -37.92660525,
#   'max_lat': -37.91313109,
#   'min_lng': 144.78929042999994,
#   'max_lng': 144.79909657999997},
#  {'min_lat': -37.53234372,
#   'max_lat': -37.52199719,
#   'min_lng': 145.76146245,
#   'max_lng': 145.77365041},
#  {'min_lat': -28.64304592,
#   'max_lat': -28.63639575,
#   'min_lng': 153.60286832,
#   'max_lng': 153.62883478},
#  {'min_lat': -35.945349899503626,
#   'max_lat': -35.94194064090243,
#   'min_lng': 142.41522833704948,
#   'max_lng': 142.41943404078484},
#  {'min_lat': -38.401242816263405,
#   'max_lat': -38.38699257075828,
#   'min_lng': 142.44878850360692,
#   'max_lng': 142.47234366252087},
#  {'min_lat': -37.85474561,
#   'max_lat': -37.84934929,
#   'min_lng': 144.98619138999993,
#   'max_lng': 144.99374449000004},
#  {'min_lat': -37.5632,
#   'max_lat': -37.55765943715888,
#   'min_lng': 143.85484999999994,
#   'max_lng': 143.86327000000006},
#  {'min_lat': -27.6031846,
#   'max_lat': -27.5969474,
#   'min_lng': 153.14425349,
#   'max_lng': 153.1498754},
#  {'min_lat': -37.68639,
#   'max_lat': -37.68517883584943,
#   'min_lng': 145.57339131832123,
#   'max_lng': 145.58344999999997},
#  {'min_lat': -37.97119962600511,
#   'max_lat': -37.93895157575608,
#   'min_lng': 145.28479099273682,
#   'max_lng': 145.30500411987305},
#  {'min_lat': -38.85511157,
#   'max_lat': -38.85255075,
#   'min_lng': 143.5388875,
#   'max_lng': 143.54587197},
#  {'min_lat': -37.79662753165606,
#   'max_lat': -37.79021377439333,
#   'min_lng': 144.91483390331268,
#   'max_lng': 144.92780774831772},
#  {'min_lat': -37.89995077,
#   'max_lat': -37.89564148,
#   'min_lng': 145.56822538000006,
#   'max_lng': 145.58373392},
#  {'min_lat': -37.6809419,
#   'max_lat': -37.67833085,
#   'min_lng': 145.05836426999997,
#   'max_lng': 145.06574571},
#  {'min_lat': -33.8515,
#   'max_lat': -33.84096,
#   'min_lng': 151.20741999999996,
#   'max_lng': 151.22045000000003},
#  {'min_lat': -36.76598165,
#   'max_lat': -36.74526555,
#   'min_lng': 144.26927178999995,
#   'max_lng': 144.29370135},
#  {'min_lat': -36.640330496851995,
#   'max_lat': -36.62570952954824,
#   'min_lng': 142.6262349843455,
#   'max_lng': 142.6315135716868},
#  {'min_lat': -37.0509857903596,
#   'max_lat': -37.040395156591345,
#   'min_lng': 143.7376056611538,
#   'max_lng': 143.75074043869972},
#  {'min_lat': -37.80768815,
#   'max_lat': -37.80601825,
#   'min_lng': 144.95574832,
#   'max_lng': 144.95957181},
#  {'min_lat': -37.490639,
#   'max_lat': -37.489288,
#   'min_lng': 145.840012,
#   'max_lng': 145.841049},
#  {'min_lat': -37.770932,
#   'max_lat': -37.74221,
#   'min_lng': 144.25908000000004,
#   'max_lng': 144.28757999999993},
#  {'min_lat': -34.18561246,
#   'max_lat': -34.17457015,
#   'min_lng': 142.15838885,
#   'max_lng': 142.16539083},
#  {'min_lat': -35.0591584434034,
#   'max_lat': -35.028309569210975,
#   'min_lng': 141.69857025146484,
#   'max_lng': 141.7181396484375},
#  {'min_lat': -36.257441706966326,
#   'max_lat': -36.246241682615576,
#   'min_lng': 142.38544642925262,
#   'max_lng': 142.39459812641144},
#  {'min_lat': -37.84010599902733,
#   'max_lat': -37.83592029800687,
#   'min_lng': 145.22777795791626,
#   'max_lng': 145.26916980743408},
#  {'min_lat': -37.81183731311794,
#   'max_lat': -37.80859,
#   'min_lng': 144.95348,
#   'max_lng': 144.9562257528305},
#  {'min_lat': -37.49673321,
#   'max_lat': -37.48487061,
#   'min_lng': 148.15376902,
#   'max_lng': 148.16145229},
#  {'min_lat': -37.91939874616854,
#   'max_lat': -37.91276712110228,
#   'min_lng': 145.23715496063232,
#   'max_lng': 145.24286270141602},
#  {'min_lat': -38.43068154,
#   'max_lat': -38.4228817,
#   'min_lng': 146.56624398,
#   'max_lng': 146.57433352},
#  {'min_lat': -37.81887848,
#   'max_lat': -37.81119948,
#   'min_lng': 145.22066474,
#   'max_lng': 145.2374661},
#  {'min_lat': -36.822160000000004,
#   'max_lat': -36.75977385237353,
#   'min_lng': 144.22859000000003,
#   'max_lng': 144.27831083536148},
#  {'min_lat': -38.179382,
#   'max_lat': -38.175995,
#   'min_lng': 146.27888499999995,
#   'max_lng': 146.284225},
#  {'min_lat': -37.519211,
#   'max_lat': -37.51487,
#   'min_lng': 145.743423,
#   'max_lng': 145.747345},
#  {'min_lat': -37.92277146201673,
#   'max_lat': -37.91967381661647,
#   'min_lng': 144.66351628303528,
#   'max_lng': 144.66766834259033},
#  {'min_lat': -36.13955563,
#   'max_lat': -36.11967693,
#   'min_lng': 144.73775983,
#   'max_lng': 144.7459352},
#  {'min_lat': -38.15155898,
#   'max_lat': -38.14563601,
#   'min_lng': 144.37481536999996,
#   'max_lng': 144.38409447999993},
#  {'min_lat': -37.87658948640064,
#   'max_lat': -37.86734961428255,
#   'min_lng': 145.26187419891357,
#   'max_lng': 145.28609991073608},
#  {'min_lat': -37.714594302882475,
#   'max_lat': -37.710465147732066,
#   'min_lng': 142.83884210562974,
#   'max_lng': 142.84247167073772},
#  {'min_lat': -38.1772992697859,
#   'max_lat': -38.163156550672554,
#   'min_lng': 146.2665845300204,
#   'max_lng': 146.33637999999996},
#  {'min_lat': -38.15071528614556,
#   'max_lat': -38.14894454218717,
#   'min_lng': 144.3759647011757,
#   'max_lng': 144.37921285629272},
#  {'min_lat': -38.23841678888687,
#   'max_lat': -38.23211363165673,
#   'min_lng': 146.42340588559819,
#   'max_lng': 146.4247314333261},
#  {'min_lat': -37.64500740550136,
#   'max_lat': -37.63198524509537,
#   'min_lng': 145.05997963249683,
#   'max_lng': 145.06885640323162},
#  {'min_lat': -36.72454171,
#   'max_lat': -36.71893472,
#   'min_lng': 142.19594836,
#   'max_lng': 142.20418811000002},
#  {'min_lat': -37.96886525,
#   'max_lat': -37.96558346,
#   'min_lng': 146.97067872000002,
#   'max_lng': 146.97411194000006},
#  {'min_lat': -37.832022468119085,
#   'max_lat': -37.82937860542196,
#   'min_lng': 144.90670680999756,
#   'max_lng': 144.911470413208},
#  {'min_lat': -37.81105963,
#   'max_lat': -37.80633825,
#   'min_lng': 144.95843589,
#   'max_lng': 144.96140778},
#  {'min_lat': -37.817810592269204,
#   'max_lat': -37.80989,
#   'min_lng': 144.93303537368774,
#   'max_lng': 144.93800282478333},
#  {'min_lat': -36.044032944453235,
#   'max_lat': -35.938770115570605,
#   'min_lng': 136.6540002822876,
#   'max_lng': 136.9357395172119},
#  {'min_lat': -37.83206483694232,
#   'max_lat': -37.82910743466058,
#   'min_lng': 144.90583777427673,
#   'max_lng': 144.91090178489685},
#  {'min_lat': -38.63603106206255,
#   'max_lat': -38.63331569814947,
#   'min_lng': 145.74130296707153,
#   'max_lng': 145.75619459152222},
#  {'min_lat': -37.25482402,
#   'max_lat': -37.2458398,
#   'min_lng': 144.44085538,
#   'max_lng': 144.4536294},
#  {'min_lat': -37.934204537042916,
#   'max_lat': -37.928560154470645,
#   'min_lng': 145.45737504959106,
#   'max_lng': 145.4605507850647},
#  {'min_lat': -37.845496645573455,
#   'max_lat': -37.835361056807564,
#   'min_lng': 144.68983948230743,
#   'max_lng': 144.7062787413597},
#  {'min_lat': -34.20848383,
#   'max_lat': -34.20612809,
#   'min_lng': 142.11742401,
#   'max_lng': 142.12396324},
#  {'min_lat': -37.983242,
#   'max_lat': -37.964294,
#   'min_lng': 146.82783500000005,
#   'max_lng': 146.97848},
#  {'min_lat': -38.22307,
#   'max_lat': -38.212460867268966,
#   'min_lng': 145.03271,
#   'max_lng': 145.04832000000002},
#  {'min_lat': -36.39372035,
#   'max_lat': -36.38843478,
#   'min_lng': 145.36628723,
#   'max_lng': 145.38208008},
#  {'min_lat': -38.62365186,
#   'max_lat': -38.60375223,
#   'min_lng': 145.59089005,
#   'max_lng': 145.60295463},
#  {'min_lat': -37.78804747,
#   'max_lat': -37.78459651,
#   'min_lng': 145.01166736999994,
#   'max_lng': 145.02057230000003},
#  {'min_lat': -38.367584,
#   'max_lat': -38.356102,
#   'min_lng': 146.38293499999997,
#   'max_lng': 146.38987700000007},
#  {'min_lat': -37.94682032,
#   'max_lat': -37.93373912,
#   'min_lng': 144.65852952,
#   'max_lng': 144.66535306000003},
#  {'min_lat': -37.71582,
#   'max_lat': -37.70803,
#   'min_lng': 145.06543,
#   'max_lng': 145.07304999999997},
#  {'min_lat': -36.500317371414056,
#   'max_lat': -36.48853582908591,
#   'min_lng': 144.60138285750872,
#   'max_lng': 144.61565896868706},
#  {'min_lat': -36.7230626,
#   'max_lat': -36.7131209,
#   'min_lng': 142.19962835,
#   'max_lng': 142.19980001},
#  {'min_lat': -36.14529,
#   'max_lat': -36.136618339837035,
#   'min_lng': 146.84555999999998,
#   'max_lng': 146.86227000000008},
#  {'min_lat': -37.814510000000006,
#   'max_lat': -37.810410000000005,
#   'min_lng': 144.97431000000006,
#   'max_lng': 144.98308999999995},
#  {'min_lat': -37.87223,
#   'max_lat': -37.855940000000004,
#   'min_lng': 144.8674,
#   'max_lng': 144.9084},
#  {'min_lat': -37.93244103142638,
#   'max_lat': -37.927530000000004,
#   'min_lng': 144.66675639152527,
#   'max_lng': 144.6751356124878},
#  {'min_lat': -37.880813102457594,
#   'max_lat': -37.8714191966321,
#   'min_lng': 145.24364858865738,
#   'max_lng': 145.2520975470543},
#  {'min_lat': -36.13738949872306,
#   'max_lat': -36.128386396383334,
#   'min_lng': 146.9148552417755,
#   'max_lng': 146.9366991519928},
#  {'min_lat': -36.11428610444692,
#   'max_lat': -36.111607889481135,
#   'min_lng': 146.88645601272583,
#   'max_lng': 146.89233005046844},
#  {'min_lat': -37.31795663111293,
#   'max_lat': -37.297219877833555,
#   'min_lng': 144.11543905735016,
#   'max_lng': 144.12453711032867},
#  {'min_lat': -37.80586779,
#   'max_lat': -37.79871305,
#   'min_lng': 144.97863829,
#   'max_lng': 144.98364329},
#  {'min_lat': -37.792366,
#   'max_lat': -37.787502,
#   'min_lng': 145.05711399999996,
#   'max_lng': 145.06013499999995},
#  {'min_lat': -36.39260195,
#   'max_lat': -36.38591493,
#   'min_lng': 145.39296314,
#   'max_lng': 145.39734051},
#  {'min_lat': -37.74613753,
#   'max_lat': -37.74222435,
#   'min_lng': 144.79761332,
#   'max_lng': 144.80142877},
#  {'min_lat': -37.72715,
#   'max_lat': -37.71441,
#   'min_lng': 145.10636,
#   'max_lng': 145.11343},
#  {'min_lat': -38.144703,
#   'max_lat': -38.136578,
#   'min_lng': 146.47489900000005,
#   'max_lng': 146.47905000000003},
#  {'min_lat': -37.69501389771473,
#   'max_lat': -37.68258850510687,
#   'min_lng': 144.9026259520906,
#   'max_lng': 144.9189635298785},
#  {'min_lat': -37.98626980240955,
#   'max_lat': -37.96511,
#   'min_lng': 145.22632,
#   'max_lng': 145.23181},
#  {'min_lat': -37.82157,
#   'max_lat': -37.809720000000006,
#   'min_lng': 144.95388686656952,
#   'max_lng': 144.96841},
#  {'min_lat': -37.82623465820838,
#   'max_lat': -37.81754785443027,
#   'min_lng': 144.96651999999995,
#   'max_lng': 144.98532},
#  {'min_lat': -37.78570304,
#   'max_lat': -37.77890674,
#   'min_lng': 144.98966753000002,
#   'max_lng': 144.99946295999996},
#  {'min_lat': -37.93406068,
#   'max_lat': -37.92823646,
#   'min_lng': 144.66680333,
#   'max_lng': 144.67205912},
#  {'min_lat': -36.759507393716255,
#   'max_lat': -36.70481,
#   'min_lng': 144.27781000000002,
#   'max_lng': 144.31322},
#  {'min_lat': -37.42437112870223,
#   'max_lat': -37.42004350615701,
#   'min_lng': 143.37793462872014,
#   'max_lng': 143.38874301931355},
#  {'min_lat': -37.974520000000005,
#   'max_lat': -37.965230000000005,
#   'min_lng': 144.6847915649414,
#   'max_lng': 144.70686999999998},
#  {'min_lat': -38.658319975717326,
#   'max_lat': -38.65188539228618,
#   'min_lng': 145.75070142745972,
#   'max_lng': 145.7623314857483},
#  {'min_lat': -37.82019214,
#   'max_lat': -37.80518964,
#   'min_lng': 144.96566176,
#   'max_lng': 144.97164845},
#  {'min_lat': -37.803920000000005,
#   'max_lat': -37.76104,
#   'min_lng': 144.88908,
#   'max_lng': 144.91619},
#  {'min_lat': -37.82506,
#   'max_lat': -37.81755124480881,
#   'min_lng': 144.94753000000003,
#   'max_lng': 144.9686293612467},
#  {'min_lat': -37.67915451,
#   'max_lat': -37.67098331,
#   'min_lng': 145.00621139999998,
#   'max_lng': 145.01023203},
#  {'min_lat': -38.22625506914308,
#   'max_lat': -38.216060000000006,
#   'min_lng': 145.02964586019516,
#   'max_lng': 145.03613412380219},
#  {'min_lat': -37.84253766361694,
#   'max_lat': -37.836098237499385,
#   'min_lng': 144.87089,
#   'max_lng': 144.88304000000002},
#  {'min_lat': -37.87180455,
#   'max_lat': -37.8650797,
#   'min_lng': 144.9883887,
#   'max_lng': 144.99449015},
#  {'min_lat': -36.630252,
#   'max_lat': -36.61637156,
#   'min_lng': 145.21709204,
#   'max_lng': 145.22335768},
#  {'min_lat': -37.97272200654509,
#   'max_lat': -37.96395942871063,
#   'min_lng': 146.89200282096863,
#   'max_lng': 146.98443174362183},
#  {'min_lat': -37.159510000000004,
#   'max_lat': -37.135020000000004,
#   'min_lng': 142.84210000000002,
#   'max_lng': 142.85935},
#  {'min_lat': -37.40362063590243,
#   'max_lat': -37.38721684475389,
#   'min_lng': 144.31752741336823,
#   'max_lng': 144.3360722064972},
#  {'min_lat': -37.981422,
#   'max_lat': -37.96270767007331,
#   'min_lng': 146.96975366811182,
#   'max_lng': 147.08183133589046},
#  {'min_lat': -38.14820950734723,
#   'max_lat': -38.14746237852481,
#   'min_lng': 146.47630038855823,
#   'max_lng': 146.47677299373754},
#  {'min_lat': -38.35298597,
#   'max_lat': -38.34019619,
#   'min_lng': 144.72886026,
#   'max_lng': 144.73656625},
#  {'min_lat': -38.067846132872624,
#   'max_lat': -38.06583686777575,
#   'min_lng': 145.44723361730576,
#   'max_lng': 145.45377284288406},
#  {'min_lat': -38.375750000000004,
#   'max_lat': -38.36661,
#   'min_lng': 145.00895000000003,
#   'max_lng': 145.01397999999995},
#  {'min_lat': -36.63652260478989,
#   'max_lat': -36.62864054917885,
#   'min_lng': 142.63080418142636,
#   'max_lng': 142.63150386210327},
#  {'min_lat': -38.192905,
#   'max_lat': -38.187649,
#   'min_lng': 146.26097100000004,
#   'max_lng': 146.26637299999993},
#  {'min_lat': -38.238605,
#   'max_lat': -38.236935,
#   'min_lng': 146.42218000000003,
#   'max_lng': 146.424713},
#  {'min_lat': -37.85674,
#   'max_lat': -37.85008632754947,
#   'min_lng': 144.69298839569092,
#   'max_lng': 144.70513343811035},
#  {'min_lat': -37.94033078,
#   'max_lat': -37.93576999,
#   'min_lng': 145.48958838,
#   'max_lng': 145.49261391},
#  {'min_lat': -38.42957213,
#   'max_lat': -38.42499985,
#   'min_lng': 146.56622453,
#   'max_lng': 146.57789576000005},
#  {'min_lat': -39.021767,
#   'max_lat': -39.01389,
#   'min_lng': 146.32017700000006,
#   'max_lng': 146.33198600000003},
#  {'min_lat': -38.44760632,
#   'max_lat': -38.44158982,
#   'min_lng': 146.53727854,
#   'max_lng': 146.54157007000003},
#  {'min_lat': -36.18096065252005,
#   'max_lat': -36.156510081759365,
#   'min_lng': 147.00815320014954,
#   'max_lng': 147.02375292778015},
#  {'min_lat': -38.13755,
#   'max_lat': -38.135193,
#   'min_lng': 146.44064300000002,
#   'max_lng': 146.44424400000003},
#  {'min_lat': -37.57494846,
#   'max_lat': -37.56302601,
#   'min_lng': 144.70079362,
#   'max_lng': 144.7387737},
#  {'min_lat': -37.10908273,
#   'max_lat': -37.10112511,
#   'min_lng': 147.57674968,
#   'max_lng': 147.58179331},
#  {'min_lat': -38.2833679950393,
#   'max_lat': -38.27385931043831,
#   'min_lng': 144.49731051921844,
#   'max_lng': 144.5076034963131},
#  {'min_lat': -36.13815198545098,
#   'max_lat': -36.12719919224624,
#   'min_lng': 146.85617923736572,
#   'max_lng': 146.87328100204468},
#  {'min_lat': -38.1822,
#   'max_lat': -38.163180000000004,
#   'min_lng': 144.33056000000002,
#   'max_lng': 144.36536},
#  {'min_lat': -38.55112733,
#   'max_lat': -38.53963981,
#   'min_lng': 145.43896973,
#   'max_lng': 145.47742188},
#  {'min_lat': -36.10623384935248,
#   'max_lat': -36.09153137081497,
#   'min_lng': 146.89872980117798,
#   'max_lng': 146.9125485420227},
#  {'min_lat': -34.19253582374011,
#   'max_lat': -34.19068771022454,
#   'min_lng': 142.1453619003296,
#   'max_lng': 142.14763909578323},
#  {'min_lat': -37.84503703,
#   'max_lat': -37.83526785,
#   'min_lng': 144.92536426,
#   'max_lng': 144.93719816},
#  {'min_lat': -38.15197239,
#   'max_lat': -38.14053108,
#   'min_lng': 146.78434029,
#   'max_lng': 146.79326668},
#  {'min_lat': -36.7751925,
#   'max_lat': -36.76969233,
#   'min_lng': 144.30390716,
#   'max_lng': 144.31259751},
#  {'min_lat': -37.25133977,
#   'max_lat': -37.2326348,
#   'min_lng': 144.44544196,
#   'max_lng': 144.45273757},
#  {'min_lat': -37.759407,
#   'max_lat': -37.756237,
#   'min_lng': 145.08131400000002,
#   'max_lng': 145.08425899999997},
#  {'min_lat': -35.078667,
#   'max_lat': -35.07092572912096,
#   'min_lng': 138.49569302186865,
#   'max_lng': 138.49815778778623},
#  {'min_lat': -34.184603958064386,
#   'max_lat': -34.17369559272904,
#   'min_lng': 142.15856105089188,
#   'max_lng': 142.17001140117645},
#  {'min_lat': -37.81367,
#   'max_lat': -37.809740000000005,
#   'min_lng': 144.95371,
#   'max_lng': 144.96433000000002},
#  {'min_lat': -36.43997972,
#   'max_lat': -36.43992793,
#   'min_lng': 145.22249937,
#   'max_lng': 145.23290634},
#  {'min_lat': -37.09108672237929,
#   'max_lat': -37.085963638517704,
#   'min_lng': 143.47063794062706,
#   'max_lng': 143.47318325089873},
#  {'min_lat': -37.99415461810887,
#   'max_lat': -37.975648271577604,
#   'min_lng': 145.0149017572403,
#   'max_lng': 145.03145098686218},
#  {'min_lat': -38.22728331,
#   'max_lat': -38.21889469,
#   'min_lng': 145.30614209,
#   'max_lng': 145.3126756},
#  {'min_lat': -37.785931974199165,
#   'max_lat': -37.780789246658195,
#   'min_lng': 144.85105868428946,
#   'max_lng': 144.8594694212079},
#  {'min_lat': -36.624488884412564,
#   'max_lat': -36.61857677484572,
#   'min_lng': 142.4614986688357,
#   'max_lng': 142.46606510283527},
#  {'min_lat': -37.149460000000005,
#   'max_lat': -37.14797,
#   'min_lng': 142.44823999999994,
#   'max_lng': 142.45888000000002},
#  {'min_lat': -38.39207945452429,
#   'max_lat': -38.37246653428025,
#   'min_lng': 142.4346532630807,
#   'max_lng': 142.47288839389512},
#  {'min_lat': -36.129088311550326,
#   'max_lat': -36.11381807346601,
#   'min_lng': 146.79536819458008,
#   'max_lng': 146.82772636413574},
#  {'min_lat': -38.05491745,
#   'max_lat': -38.04521839,
#   'min_lng': 147.56591454,
#   'max_lng': 147.58183613000006},
#  {'min_lat': -37.445553353823655,
#   'max_lat': -37.439854280722685,
#   'min_lng': 143.37965848477324,
#   'max_lng': 143.38541471945064},
#  {'min_lat': -37.63637578,
#   'max_lat': -37.62411902,
#   'min_lng': 145.09752720999995,
#   'max_lng': 145.11487841999997},
#  {'min_lat': -37.95459,
#   'max_lat': -37.93994,
#   'min_lng': 145.26792526245117,
#   'max_lng': 145.28368},
#  {'min_lat': -36.13702150930486,
#   'max_lat': -36.12266460035196,
#   'min_lng': 146.87215361576818,
#   'max_lng': 146.87861688100384},
#  {'min_lat': -38.238887976513794,
#   'max_lat': -38.22938189699613,
#   'min_lng': 146.42328679561615,
#   'max_lng': 146.4253306388855},
#  {'min_lat': -37.82480246534096,
#   'max_lat': -37.81990398615678,
#   'min_lng': 145.11624097824097,
#   'max_lng': 145.1192021369934},
#  {'min_lat': -37.7485426,
#   'max_lat': -37.7419571,
#   'min_lng': 144.96341541,
#   'max_lng': 144.97690558},
#  {'min_lat': -37.86255560356931,
#   'max_lat': -37.85969260038823,
#   'min_lng': 145.28378248214722,
#   'max_lng': 145.28697967529297},
#  {'min_lat': -36.71655248,
#   'max_lat': -36.71176198,
#   'min_lng': 142.19830871,
#   'max_lng': 142.20242858},
#  {'min_lat': -36.14787234860844,
#   'max_lat': -36.137122929887454,
#   'min_lng': 146.86249991660588,
#   'max_lng': 146.87994800809975},
#  {'min_lat': -37.8673,
#   'max_lat': -37.855070000000005,
#   'min_lng': 144.82638,
#   'max_lng': 144.84253},
#  {'min_lat': -34.22904828,
#   'max_lat': -34.2156283,
#   'min_lng': 142.2271229,
#   'max_lng': 142.23428249},
#  {'min_lat': -36.12785,
#   'max_lat': -36.115950192010736,
#   'min_lng': 144.7490519285202,
#   'max_lng': 144.7733634710312},
#  {'min_lat': -37.818670000000004,
#   'max_lat': -37.810320000000004,
#   'min_lng': 144.96737000000007,
#   'max_lng': 144.98158999999998},
#  {'min_lat': -37.82320922404997,
#   'max_lat': -37.81860515665624,
#   'min_lng': 144.9681656062603,
#   'max_lng': 144.97804686427116},
#  {'min_lat': -38.6591534,
#   'max_lat': -38.65079615,
#   'min_lng': 146.1989838,
#   'max_lng': 146.20634437},
#  {'min_lat': -37.8356661,
#   'max_lat': -37.82048029,
#   'min_lng': 145.15037477,
#   'max_lng': 145.16648412},
#  {'min_lat': -38.11180175,
#   'max_lat': -38.11042577,
#   'min_lng': 147.04394996,
#   'max_lng': 147.04799473},
#  {'min_lat': -38.400597,
#   'max_lat': -38.369907,
#   'min_lng': 146.16262800000004,
#   'max_lng': 146.2739961144689},
#  {'min_lat': -37.79650884,
#   'max_lat': -37.78438453,
#   'min_lng': 144.99889970000004,
#   'max_lng': 145.01424193000003},
#  {'min_lat': -37.8449,
#   'max_lat': -37.84076,
#   'min_lng': 144.65273916721344,
#   'max_lng': 144.66087000000005},
#  {'min_lat': -37.93099736232602,
#   'max_lat': -37.92820472157481,
#   'min_lng': 145.23348569869995,
#   'max_lng': 145.25078058242798},
#  {'min_lat': -38.61006328,
#   'max_lat': -38.60043823,
#   'min_lng': 145.56194043000005,
#   'max_lng': 145.57391273999997},
#  {'min_lat': -37.817130000000006,
#   'max_lat': -37.80677903622832,
#   'min_lng': 144.95237999999995,
#   'max_lng': 144.96025443077087},
#  {'min_lat': -37.6749214765168,
#   'max_lat': -37.66460324831077,
#   'min_lng': 145.04703998565674,
#   'max_lng': 145.0674569606781},
#  {'min_lat': -37.849500000000006,
#   'max_lat': -37.844930000000005,
#   'min_lng': 144.65166999999997,
#   'max_lng': 144.6671},
#  {'min_lat': -37.7125581,
#   'max_lat': -37.70075958,
#   'min_lng': 145.04473329,
#   'max_lng': 145.05102575},
#  {'min_lat': -37.02970883,
#   'max_lat': -37.02245386,
#   'min_lng': 147.23662412,
#   'max_lng': 147.23969257},
#  {'min_lat': -38.0069,
#   'max_lat': -37.996027401514496,
#   'min_lng': 145.15117406845093,
#   'max_lng': 145.16027212142944},
#  {'min_lat': -36.86028296481222,
#   'max_lat': -36.85504,
#   'min_lng': 143.72746000000006,
#   'max_lng': 143.73541999999998},
#  {'min_lat': -38.00789712,
#   'max_lat': -37.99124177,
#   'min_lng': 145.12440562,
#   'max_lng': 145.13347149},
#  {'min_lat': -36.12188688374149,
#   'max_lat': -36.10772474895031,
#   'min_lng': 144.7272402048111,
#   'max_lng': 144.7470000386238},
#  {'min_lat': -37.957399498060155,
#   'max_lat': -37.949506503219965,
#   'min_lng': 145.14080196619034,
#   'max_lng': 145.15288531780243},
#  {'min_lat': -27.4768,
#   'max_lat': -27.47342,
#   'min_lng': 153.02790000000005,
#   'max_lng': 153.03102},
#  {'min_lat': -38.402611774560874,
#   'max_lat': -38.38836294592741,
#   'min_lng': 142.47205495965318,
#   'max_lng': 142.5097882780392},
#  {'min_lat': -37.82461602,
#   'max_lat': -37.81414065,
#   'min_lng': 144.9397954,
#   'max_lng': 144.94756308},
#  {'min_lat': -36.465299320751285,
#   'max_lat': -36.45833596033623,
#   'min_lng': 142.024227976799,
#   'max_lng': 142.0322746038437},
#  {'min_lat': -38.20651334,
#   'max_lat': -38.19310538,
#   'min_lng': 144.70478877000005,
#   'max_lng': 144.71105576000002},
#  {'min_lat': -34.18858884312198,
#   'max_lat': -34.182828338268585,
#   'min_lng': 142.1554470062256,
#   'max_lng': 142.1634242534583},
#  {'min_lat': -38.11526692,
#   'max_lat': -38.10836596,
#   'min_lng': 144.62040514,
#   'max_lng': 144.63187426},
#  {'min_lat': -37.8240228,
#   'max_lat': -37.81410675,
#   'min_lng': 144.93943062,
#   'max_lng': 144.96799078},
#  {'min_lat': -38.3643,
#   'max_lat': -38.356693,
#   'min_lng': 146.38734399999998,
#   'max_lng': 146.39376800000002},
#  {'min_lat': -37.74636658,
#   'max_lat': -37.73217217,
#   'min_lng': 144.96578246,
#   'max_lng': 144.98217076},
#  {'min_lat': -35.81869374925295,
#   'max_lat': -35.81514748941008,
#   'min_lng': 144.91041448069154,
#   'max_lng': 144.91472640016582},
#  {'min_lat': -37.93597308,
#   'max_lat': -37.9315051,
#   'min_lng': 145.44836283,
#   'max_lng': 145.45943499},
#  {'min_lat': -37.05551531310214,
#   'max_lat': -37.04921757626379,
#   'min_lng': 144.2141819000244,
#   'max_lng': 144.21876043081284},
#  {'min_lat': -35.34348502,
#   'max_lat': -35.32941139,
#   'min_lng': 143.56143951,
#   'max_lng': 143.5653019},
#  {'min_lat': -37.82432789,
#   'max_lat': -37.81354734,
#   'min_lng': 144.93623428,
#   'max_lng': 144.94760685},
#  {'min_lat': -34.19220969,
#   'max_lat': -34.18376081,
#   'min_lng': 142.16023274,
#   'max_lng': 142.17237778},
#  {'min_lat': -37.8080251,
#   'max_lat': -37.80107826,
#   'min_lng': 144.97147679,
#   'max_lng': 144.98542964},
#  {'min_lat': -38.23742169424233,
#   'max_lat': -38.23459016893573,
#   'min_lng': 146.39155626296997,
#   'max_lng': 146.39930248260498},
#  {'min_lat': -37.759788536251335,
#   'max_lat': -37.75579550037444,
#   'min_lng': 144.92341294884682,
#   'max_lng': 144.92789290845394},
#  {'min_lat': -35.07442046,
#   'max_lat': -35.06922221,
#   'min_lng': 150.67522377,
#   'max_lng': 150.69676995},
#  {'min_lat': -37.76916168,
#   'max_lat': -37.76069293,
#   'min_lng': 145.0538414,
#   'max_lng': 145.06525688},
#  {'min_lat': -37.87395,
#   'max_lat': -37.863220000000005,
#   'min_lng': 144.67177000000004,
#   'max_lng': 144.67826000000002},
#  {'min_lat': -38.169044,
#   'max_lat': -37.976238,
#   'min_lng': 146.56527700000004,
#   'max_lng': 146.78694199999995},
#  {'min_lat': -37.93563460414499,
#   'max_lat': -37.922805315344064,
#   'min_lng': 145.3108835220337,
#   'max_lng': 145.336332321167},
#  {'min_lat': -37.515362,
#   'max_lat': -37.510387,
#   'min_lng': 145.73053000000004,
#   'max_lng': 145.739243},
#  {'min_lat': -37.830400000000004,
#   'max_lat': -37.82343,
#   'min_lng': 144.98906,
#   'max_lng': 144.99701000000002},
#  {'min_lat': -38.14669915,
#   'max_lat': -38.13711352,
#   'min_lng': 144.70057368,
#   'max_lng': 144.71912384},
#  {'min_lat': -34.71452466,
#   'max_lat': -34.70083629,
#   'min_lng': 142.33448982,
#   'max_lng': 142.35938072},
#  {'min_lat': -36.77484875,
#   'max_lat': -36.76054744,
#   'min_lng': 144.29494858,
#   'max_lng': 144.31717873},
#  {'min_lat': -38.305946,
#   'max_lat': -38.301796,
#   'min_lng': 146.42396499999995,
#   'max_lng': 146.427734},
#  {'min_lat': -36.13699958787405,
#   'max_lat': -36.1325674650459,
#   'min_lng': 146.8724924325943,
#   'max_lng': 146.87862932682037},
#  {'min_lat': -30.30545426,
#   'max_lat': -30.30166806,
#   'min_lng': 153.14048231,
#   'max_lng': 153.15393358},
#  {'min_lat': -37.78805595,
#   'max_lat': -37.77481933,
#   'min_lng': 144.89343256000006,
#   'max_lng': 144.90361690999998},
#  {'min_lat': -37.78817,
#   'max_lat': -37.78188735290587,
#   'min_lng': 144.85300000000007,
#   'max_lng': 144.8596192896366},
#  {'min_lat': -37.532734,
#   'max_lat': -37.529758,
#   'min_lng': 145.772339,
#   'max_lng': 145.77359},
#  {'min_lat': -37.80736,
#   'max_lat': -37.801170000000006,
#   'min_lng': 144.96897161006927,
#   'max_lng': 144.97348308563232},
#  {'min_lat': -37.84923491758845,
#   'max_lat': -37.83989417775849,
#   'min_lng': 144.91279006004333,
#   'max_lng': 144.91697430610657},
#  {'min_lat': -37.864140000000006,
#   'max_lat': -37.839580000000005,
#   'min_lng': 144.91732835769653,
#   'max_lng': 144.97212000000002},
#  {'min_lat': -37.89287289224261,
#   'max_lat': -37.88081521949764,
#   'min_lng': 145.30388832092285,
#   'max_lng': 145.3165054321289},
#  {'min_lat': -38.15145774,
#   'max_lat': -38.1460585,
#   'min_lng': 144.36480403,
#   'max_lng': 144.37205672},
#  {'min_lat': -37.794694560984574,
#   'max_lat': -37.780150000000006,
#   'min_lng': 145.08488059043884,
#   'max_lng': 145.10026000000005},
#  {'min_lat': -37.33286990277341,
#   'max_lat': -37.32960254554808,
#   'min_lng': 144.5932987332344,
#   'max_lng': 144.59705114364624},
#  {'min_lat': -36.365930000000006,
#   'max_lat': -36.347018652855226,
#   'min_lng': 146.67393000000004,
#   'max_lng': 146.69238},
#  {'min_lat': -37.88896961,
#   'max_lat': -37.88219552,
#   'min_lng': 144.9799633,
#   'max_lng': 145.00059485},
#  {'min_lat': -37.832550000000005,
#   'max_lat': -37.81889,
#   'min_lng': 144.9539351463318,
#   'max_lng': 144.96006},
#  {'min_lat': -37.65444497,
#   'max_lat': -37.65163337,
#   'min_lng': 145.51342249,
#   'max_lng': 145.52193046},
#  {'min_lat': -37.80028986,
#   'max_lat': -37.79699208,
#   'min_lng': 144.95963752,
#   'max_lng': 144.96430457},
#  {'min_lat': -37.25893788,
#   'max_lat': -37.24425976,
#   'min_lng': 144.44892347,
#   'max_lng': 144.45394456},
#  {'min_lat': -37.50232744999928,
#   'max_lat': -37.49897,
#   'min_lng': 145.8313734129639,
#   'max_lng': 145.840866},
#  {'min_lat': -37.86251,
#   'max_lat': -37.84276642236187,
#   'min_lng': 144.88361835479736,
#   'max_lng': 144.90553736686707},
#  {'min_lat': -34.18845572,
#   'max_lat': -34.17570163,
#   'min_lng': 142.1549109,
#   'max_lng': 142.16697011},
#  {'min_lat': -37.84210556182947,
#   'max_lat': -37.83610671079786,
#   'min_lng': 144.9293553829193,
#   'max_lng': 144.9374234676361},
#  {'min_lat': -36.7625931,
#   'max_lat': -36.75734131,
#   'min_lng': 144.27710384,
#   'max_lng': 144.28207263000002},
#  {'min_lat': -36.6967091,
#   'max_lat': -36.68285785,
#   'min_lng': 142.23482966,
#   'max_lng': 142.24817634},
#  {'min_lat': -36.759507393716255,
#   'max_lat': -36.755368570241544,
#   'min_lng': 144.27621871232986,
#   'max_lng': 144.28335},
#  {'min_lat': -38.07907503978339,
#   'max_lat': -38.07160900113221,
#   'min_lng': 144.38631534576416,
#   'max_lng': 144.40584182739258},
#  {'min_lat': -36.83199296016174,
#   'max_lat': -36.82402350690828,
#   'min_lng': 144.21433210372925,
#   'max_lng': 144.2302429676056},
#  {'min_lat': -38.12156795,
#   'max_lat': -38.11485752,
#   'min_lng': 144.64666665,
#   'max_lng': 144.65137124},
#  {'min_lat': -37.2847,
#   'max_lat': -37.276970000000006,
#   'min_lng': 142.92497000000003,
#   'max_lng': 142.93624877929688},
#  {'min_lat': -37.94077923084092,
#   'max_lat': -37.93089581361178,
#   'min_lng': 145.21887302398682,
#   'max_lng': 145.22595405578613},
#  {'min_lat': -38.76267125,
#   'max_lat': -38.75451835,
#   'min_lng': 143.66935953000007,
#   'max_lng': 143.67962837000005},
#  {'min_lat': -37.95687078696719,
#   'max_lat': -37.94463746453946,
#   'min_lng': 145.24632811546326,
#   'max_lng': 145.26267886161804},
#  {'min_lat': -37.716181,
#   'max_lat': -37.706944,
#   'min_lng': 144.813536,
#   'max_lng': 144.818623},
#  {'min_lat': -37.81924631085864,
#   'max_lat': -37.81420761240515,
#   'min_lng': 144.9408996105194,
#   'max_lng': 144.9458885192871},
#  {'min_lat': -36.76083968,
#   'max_lat': -36.75444021,
#   'min_lng': 144.27665323,
#   'max_lng': 144.28272039},
#  {'min_lat': -37.530853,
#   'max_lat': -37.510597,
#   'min_lng': 145.74858100000006,
#   'max_lng': 145.77392599999996},
#  {'min_lat': -36.61766327,
#   'max_lat': -36.61566542,
#   'min_lng': 145.21595478,
#   'max_lng': 145.22192001},
#  {'min_lat': -37.77906,
#   'max_lat': -37.77306,
#   'min_lng': 145.03255000000001,
#   'max_lng': 145.03735721111298},
#  {'min_lat': -37.79440723884532,
#   'max_lat': -37.78709537624587,
#   'min_lng': 144.92748856544495,
#   'max_lng': 144.9304625986042},
#  {'min_lat': -36.49680760842929,
#   'max_lat': -36.49340259041285,
#   'min_lng': 144.60704357917166,
#   'max_lng': 144.61419238970848},
#  {'min_lat': -37.99016369666814,
#   'max_lat': -37.9842276449606,
#   'min_lng': 145.21055281162262,
#   'max_lng': 145.21653413772583},
#  {'min_lat': -38.06775744340718,
#   'max_lat': -38.0658421470522,
#   'min_lng': 145.44727720320225,
#   'max_lng': 145.4536870121956},
#  {'min_lat': -37.99386714,
#   'max_lat': -37.98563137,
#   'min_lng': 145.63343525000005,
#   'max_lng': 145.64477563000003},
#  {'min_lat': -36.13701691728627,
#   'max_lat': -36.11169456453467,
#   'min_lng': 146.87215983867645,
#   'max_lng': 146.88708499073982},
#  {'min_lat': -37.73168851,
#   'max_lat': -37.72081595,
#   'min_lng': 145.23523182,
#   'max_lng': 145.2448985},
#  {'min_lat': -37.79195397970005,
#   'max_lat': -37.78558857155609,
#   'min_lng': 144.85290974378586,
#   'max_lng': 144.85790200531483},
#  {'min_lat': -36.73021279,
#   'max_lat': -36.71167597,
#   'min_lng': 142.17576474,
#   'max_lng': 142.21835822},
#  {'min_lat': -38.08447984098634,
#   'max_lat': -38.07366983908321,
#   'min_lng': 144.35400009155273,
#   'max_lng': 144.36378479003906},
#  {'min_lat': -37.865553,
#   'max_lat': -37.863251,
#   'min_lng': 144.848924,
#   'max_lng': 144.85734300000001},
#  {'min_lat': -38.11899358,
#   'max_lat': -38.11122772,
#   'min_lng': 147.06936187999997,
#   'max_lng': 147.07946844000003},
#  {'min_lat': -37.5647184,
#   'max_lat': -37.5533727,
#   'min_lng': 143.85587096,
#   'max_lng': 143.86363864},
#  {'min_lat': -37.809784631261465,
#   'max_lat': -37.78671000000001,
#   'min_lng': 144.96813999999995,
#   'max_lng': 144.97532844543457},
#  {'min_lat': -37.88394837,
#   'max_lat': -37.86245396,
#   'min_lng': 144.77390528,
#   'max_lng': 144.83063935999996},
#  {'min_lat': -38.47327000000001,
#   'max_lat': -38.417,
#   'min_lng': 144.92773,
#   'max_lng': 144.9493},
#  {'min_lat': -38.09986,
#   'max_lat': -38.095760000000006,
#   'min_lng': 144.35905000000002,
#   'max_lng': 144.36518999999998},
#  {'min_lat': -38.129845,
#   'max_lat': -38.128078,
#   'min_lng': 146.440109,
#   'max_lng': 146.44126900000003},
#  {'min_lat': -37.74506434,
#   'max_lat': -37.73895579,
#   'min_lng': 145.64165354,
#   'max_lng': 145.70452451999995},
#  {'min_lat': -37.81448939712067,
#   'max_lat': -37.806020000000004,
#   'min_lng': 144.95549000000005,
#   'max_lng': 144.97212648377172},
#  {'min_lat': -36.362680000000005,
#   'max_lat': -36.355970000000006,
#   'min_lng': 146.68706059455872,
#   'max_lng': 146.69507},
#  {'min_lat': -37.66380490584766,
#   'max_lat': -37.653926830841904,
#   'min_lng': 144.35259997844696,
#   'max_lng': 144.3644043803215},
#  {'min_lat': -38.15158429544816,
#   'max_lat': -38.147728515037606,
#   'min_lng': 144.30033177137375,
#   'max_lng': 144.31076020002365},
#  {'min_lat': -37.73222838,
#   'max_lat': -37.72756137,
#   'min_lng': 145.02992749,
#   'max_lng': 145.03898263},
#  {'min_lat': -37.78282,
#   'max_lat': -37.77322,
#   'min_lng': 145.04881,
#   'max_lng': 145.06705},
#  {'min_lat': -37.767272,
#   'max_lat': -37.74895685332546,
#   'min_lng': 144.78046100000006,
#   'max_lng': 144.80070999999998},
#  {'min_lat': -36.36101223502869,
#   'max_lat': -36.35793852851784,
#   'min_lng': 146.6849698126316,
#   'max_lng': 146.6889502108097},
#  {'min_lat': -38.1822,
#   'max_lat': -38.163180000000004,
#   'min_lng': 144.32997,
#   'max_lng': 144.36536},
#  {'min_lat': -37.756840000000004,
#   'max_lat': -37.74936,
#   'min_lng': 145.07425999999998,
#   'max_lng': 145.08713},
#  {'min_lat': -37.86958558329152,
#   'max_lat': -37.863530000000004,
#   'min_lng': 145.24212999999997,
#   'max_lng': 145.2609086036682},
#  {'min_lat': -37.95919708730817,
#   'max_lat': -37.94592349742364,
#   'min_lng': 144.41977590322495,
#   'max_lng': 144.42754358053207},
#  {'min_lat': -37.882090000000005,
#   'max_lat': -37.867391962810814,
#   'min_lng': 144.79636000000002,
#   'max_lng': 144.83058},
#  {'min_lat': -37.81771736,
#   'max_lat': -37.81297098,
#   'min_lng': 144.93792858,
#   'max_lng': 144.95166149},
#  {'min_lat': -37.89987458095476,
#   'max_lat': -37.89722468520369,
#   'min_lng': 145.27511358261108,
#   'max_lng': 145.28144359588623},
#  {'min_lat': -37.83776745850651,
#   'max_lat': -37.83117,
#   'min_lng': 144.65476999999998,
#   'max_lng': 144.67615},
#  {'min_lat': -37.68387152451519,
#   'max_lat': -37.673657205573015,
#   'min_lng': 144.87435741524678,
#   'max_lng': 144.9030129206585},
#  {'min_lat': -34.21771095,
#   'max_lat': -34.2137718,
#   'min_lng': 142.12829232,
#   'max_lng': 142.13313103},
#  {'min_lat': -37.6424800402399,
#   'max_lat': -37.637415493674645,
#   'min_lng': 145.06667912006378,
#   'max_lng': 145.07313385605812},
#  {'min_lat': -37.69609694947432,
#   'max_lat': -37.68994297326633,
#   'min_lng': 145.04434302449226,
#   'max_lng': 145.0552073121071},
#  {'min_lat': -37.82864983,
#   'max_lat': -37.82442111,
#   'min_lng': 145.15965521,
#   'max_lng': 145.1647836},
#  {'min_lat': -34.1832105351268,
#   'max_lat': -34.17784963611233,
#   'min_lng': 142.1550714969635,
#   'max_lng': 142.16021060943604},
#  {'min_lat': -38.14748,
#   'max_lat': -38.143040000000006,
#   'min_lng': 144.36183,
#   'max_lng': 144.37466},
#  {'min_lat': -37.82437,
#   'max_lat': -37.82058199574018,
#   'min_lng': 144.95176000000004,
#   'max_lng': 144.95774388313293},
#  {'min_lat': -37.87144,
#   'max_lat': -37.85654,
#   'min_lng': 144.83017,
#   'max_lng': 144.85731},
#  {'min_lat': -37.86164,
#   'max_lat': -37.851820000000004,
#   'min_lng': 144.67192,
#   'max_lng': 144.6843},
#  {'min_lat': -34.18431551,
#   'max_lat': -34.17745909,
#   'min_lng': 142.15506881,
#   'max_lng': 142.16134518},
#  {'min_lat': -37.12133623838971,
#   'max_lat': -37.110890184342814,
#   'min_lng': 143.79474475979805,
#   'max_lng': 143.80149319767952},
#  {'min_lat': -34.21341691,
#   'max_lat': -34.20874113,
#   'min_lng': 142.12422609,
#   'max_lng': 142.12786317},
#  {'min_lat': -37.81882540841619,
#   'max_lat': -37.811364452130015,
#   'min_lng': 147.63027715085627,
#   'max_lng': 147.6470882177091},
#  {'min_lat': -37.6716457,
#   'max_lat': -37.66815747,
#   'min_lng': 145.08533925,
#   'max_lng': 145.09118378},
#  {'min_lat': -37.83114203851823,
#   'max_lat': -37.82611,
#   'min_lng': 144.9753971089376,
#   'max_lng': 144.98350596441014},
#  {'min_lat': -37.92732459,
#   'max_lat': -37.88474434,
#   'min_lng': 144.97955829,
#   'max_lng': 144.98789191000003},
#  {'min_lat': -37.90612090162848,
#   'max_lat': -37.900686659903585,
#   'min_lng': 144.64958830340038,
#   'max_lng': 144.65965829118545},
#  {'min_lat': -37.66732094551782,
#   'max_lat': -37.66417859913336,
#   'min_lng': 144.7660081833601,
#   'max_lng': 144.7720954567194},
#  {'min_lat': -38.17781844,
#   'max_lat': -38.17388814,
#   'min_lng': 144.70606685000007,
#   'max_lng': 144.71585155000002},
#  {'min_lat': -36.891127,
#   'max_lat': -36.884585,
#   'min_lng': 142.36871900000006,
#   'max_lng': 142.375808},
#  {'min_lat': -37.390549888436325,
#   'max_lat': -37.369270418948766,
#   'min_lng': 144.15781259536743,
#   'max_lng': 144.17304754257202},
#  {'min_lat': -37.85618,
#   'max_lat': -37.84554536081841,
#   'min_lng': 145.31615,
#   'max_lng': 145.34591999999998},
#  {'min_lat': -37.98435872,
#   'max_lat': -37.98163576,
#   'min_lng': 146.77841744,
#   'max_lng': 146.78144296999994},
#  {'min_lat': -37.846443410004056,
#   'max_lat': -37.83771,
#   'min_lng': 144.6756237745285,
#   'max_lng': 144.68852788209915},
#  {'min_lat': -38.13055642762072,
#   'max_lat': -38.12683457273544,
#   'min_lng': 145.26749074459076,
#   'max_lng': 145.272758603096},
#  {'min_lat': -38.063789,
#   'max_lat': -38.055496,
#   'min_lng': 146.62046799999996,
#   'max_lng': 146.62629700000002},
#  {'min_lat': -38.2001521921522,
#   'max_lat': -38.19240762011026,
#   'min_lng': 144.32219177484512,
#   'max_lng': 144.33084458112717},
#  {'min_lat': -39.07645,
#   'max_lat': -39.030819244968264,
#   'min_lng': 146.32054000000005,
#   'max_lng': 146.4710408449173},
#  {'min_lat': -37.73359343,
#   'max_lat': -37.71208068,
#   'min_lng': 145.13992488,
#   'max_lng': 145.14834702},
#  {'min_lat': -37.847002567179814,
#   'max_lat': -37.83466623607848,
#   'min_lng': 144.99197959899902,
#   'max_lng': 145.00536918640137},
#  {'min_lat': -37.72924895,
#   'max_lat': -37.7238774,
#   'min_lng': 144.82741803,
#   'max_lng': 144.83703643},
#  {'min_lat': -37.81975143314222,
#   'max_lat': -37.81631043477293,
#   'min_lng': 144.5828890800476,
#   'max_lng': 144.5869982242791},
#  {'min_lat': -36.3276421,
#   'max_lat': -36.28685089,
#   'min_lng': 145.68791628,
#   'max_lng': 145.69649935},
#  {'min_lat': -37.8677011,
#   'max_lat': -37.86383037,
#   'min_lng': 144.97011423,
#   'max_lng': 144.9784382},
#  {'min_lat': -37.83115,
#   'max_lat': -37.81814,
#   'min_lng': 144.9676439166069,
#   'max_lng': 144.98416999999995},
#  {'min_lat': -37.35266,
#   'max_lat': -37.34532379926192,
#   'min_lng': 144.13508892059326,
#   'max_lng': 144.14048000000003},
#  {'min_lat': -34.177354978385466,
#   'max_lat': -34.16678753419204,
#   'min_lng': 142.158043384552,
#   'max_lng': 142.16001749038696},
#  {'min_lat': -36.61838231169463,
#   'max_lat': -36.61550825532965,
#   'min_lng': 142.46342226862907,
#   'max_lng': 142.46626004576683},
#  {'min_lat': -36.08159740543335,
#   'max_lat': -36.08021873282375,
#   'min_lng': 146.9082248210907,
#   'max_lng': 146.9100970029831},
#  {'min_lat': -38.067825016342994,
#   'max_lat': -38.06581786237739,
#   'min_lng': 145.44715080410242,
#   'max_lng': 145.4536883533001},
#  {'min_lat': -37.81561856721983,
#   'max_lat': -37.806742713676655,
#   'min_lng': 147.62439581750186,
#   'max_lng': 147.63741566237513},
#  {'min_lat': -37.851710000000004,
#   'max_lat': -37.84544369418374,
#   'min_lng': 144.89585000000002,
#   'max_lng': 144.90526},
#  {'min_lat': -36.751693726737834,
#   'max_lat': -36.748710741883826,
#   'min_lng': 144.27346676588058,
#   'max_lng': 144.2758458852768},
#  {'min_lat': -37.81390333,
#   'max_lat': -37.81244547,
#   'min_lng': 145.23535287,
#   'max_lng': 145.24062073},
#  {'min_lat': -37.64885138,
#   'max_lat': -37.6405388,
#   'min_lng': 145.03089040999998,
#   'max_lng': 145.03499418},
#  {'min_lat': -38.319077,
#   'max_lat': -38.301743,
#   'min_lng': 146.42311100000006,
#   'max_lng': 146.42765800000006},
#  {'min_lat': -37.71898072,
#   'max_lat': -37.71526343,
#   'min_lng': 145.05114712,
#   'max_lng': 145.05637541},
#  {'min_lat': -36.73381127,
#   'max_lat': -36.72980435,
#   'min_lng': 142.16854692,
#   'max_lng': 142.176615},
#  {'min_lat': -37.39235700106203,
#   'max_lat': -37.38521353748777,
#   'min_lng': 144.26027566194534,
#   'max_lng': 144.32356774806976},
#  {'min_lat': -37.86878945,
#   'max_lat': -37.85808317,
#   'min_lng': 144.98830497,
#   'max_lng': 144.99567568},
#  {'min_lat': -37.79690306063769,
#   'max_lat': -37.78774223089043,
#   'min_lng': 144.92427796125412,
#   'max_lng': 144.9305972456932},
#  {'min_lat': -37.217290000000006,
#   'max_lat': -37.21169510256055,
#   'min_lng': 150.00941999999998,
#   'max_lng': 150.01735000000008},
#  {'min_lat': -37.82607364382899,
#   'max_lat': -37.80972673782494,
#   'min_lng': 144.96338993310928,
#   'max_lng': 144.97260332107544},
#  {'min_lat': -37.79957776,
#   'max_lat': -37.73800553,
#   'min_lng': 144.97831106,
#   'max_lng': 145.0061202},
#  {'min_lat': -37.85605862850264,
#   'max_lat': -37.85325,
#   'min_lng': 144.99000549316406,
#   'max_lng': 144.99406999999997},
#  {'min_lat': -37.64213597,
#   'max_lat': -37.630989,
#   'min_lng': 144.84163642,
#   'max_lng': 144.85327721},
#  {'min_lat': -38.21573867053175,
#   'max_lat': -38.21158980243556,
#   'min_lng': 146.41767615074968,
#   'max_lng': 146.4267361164093},
#  {'min_lat': -37.8438509,
#   'max_lat': -37.84208862,
#   'min_lng': 144.93763804,
#   'max_lng': 144.94768023},
#  {'min_lat': -37.657107833372606,
#   'max_lat': -37.65044838238024,
#   'min_lng': 145.05444288253784,
#   'max_lng': 145.05951762199402}]

# %%
tags = {'amenity': True, 'natural': True, 'animal': True, 'leisure': True}

# %%
path = paths[0]
feature_gdf = ox.features_from_bbox(north=path['max_lat'], south=path['min_lat'], east=path['max_lng'], west=path['min_lng'], tags=tags)

# %%
feature_gdf.explore()

# %%
feature_gdf.head()
# Out:
#                         addr:city addr:housenumber addr:postcode  \
# element_type osmid
# node         176729780  Melbourne              191          3000
#              243097159        NaN              NaN           NaN
#              247024808        NaN              NaN           NaN
#              247689970        NaN              NaN           NaN
#              266733834        NaN              NaN           NaN
#
#                            addr:street           amenity  \
# element_type osmid
# node         176729780  Collins Street           theatre
#              243097159             NaN      loading_dock
#              247024808             NaN  parking_entrance
#              247689970             NaN  parking_entrance
#              266733834             NaN           parking
#
#                                          name        operator  \
# element_type osmid
# node         176729780         Regent Theatre  Marriner Group
#              243097159                    NaN             NaN
#              247024808                    NaN             NaN
#              247689970                    NaN             NaN
#              266733834  Sofitel Hotel Carpark  Wilson Parking
#
#                                                                   website  \
# element_type osmid
# node         176729780  https://www.marrinergroup.com.au/theatre-regen...
#              243097159                                                NaN
#              247024808                                                NaN
#              247689970                                                NaN
#              266733834                                                NaN
#
#                         wikidata                     geometry  ...  bus  \
# element_type osmid                                             ...
# node         176729780  Q7308110  POINT (144.96760 -37.81550)  ...  NaN
#              243097159       NaN  POINT (144.96796 -37.82161)  ...  NaN
#              247024808       NaN  POINT (144.97019 -37.81548)  ...  NaN
#              247689970       NaN  POINT (144.97070 -37.81789)  ...  NaN
#              266733834       NaN  POINT (144.97302 -37.81451)  ...  NaN
#
#                        motor_vehicle building:part not:operator:wikidata  \
# element_type osmid
# node         176729780           NaN           NaN                   NaN
#              243097159           NaN           NaN                   NaN
#              247024808           NaN           NaN                   NaN
#              247689970           NaN           NaN                   NaN
#              266733834           NaN           NaN                   NaN
#
#                        water unisex ways type intermittent salt
# element_type osmid
# node         176729780   NaN    NaN  NaN  NaN          NaN  NaN
#              243097159   NaN    NaN  NaN  NaN          NaN  NaN
#              247024808   NaN    NaN  NaN  NaN          NaN  NaN
#              247689970   NaN    NaN  NaN  NaN          NaN  NaN
#              266733834   NaN    NaN  NaN  NaN          NaN  NaN
#
# [5 rows x 132 columns]

# %%
list(feature_gdf.columns)
# Out:
# ['addr:city',
#  'addr:housenumber',
#  'addr:postcode',
#  'addr:street',
#  'amenity',
#  'name',
#  'operator',
#  'website',
#  'wikidata',
#  'geometry',
#  'parking',
#  'level',
#  'capacity:disabled',
#  'fee',
#  'layer',
#  'barrier',
#  'created_by',
#  'wheelchair',
#  'check_date',
#  'addr:housename',
#  'food',
#  'outdoor_seating',
#  'phone',
#  'smoking',
#  'access',
#  'male',
#  'operator:wikidata',
#  'toilets:disposal',
#  'tourism',
#  'maxheight',
#  'internet_access',
#  'source',
#  'collection_times',
#  'covered',
#  'brand',
#  'brand:wikidata',
#  'brand:wikipedia',
#  'operator:wikipedia',
#  'addr:state',
#  'addr:suburb',
#  'building',
#  'opening_hours',
#  'cuisine',
#  'takeaway',
#  'note',
#  'atm',
#  'bicycle_parking',
#  'capacity',
#  'brewery',
#  'leisure',
#  'natural',
#  'backrest',
#  'name:en',
#  'email',
#  'fountain',
#  'mapillary',
#  'survey:date',
#  'changing_table',
#  'source:geometry',
#  'official_name',
#  'healthcare',
#  'payment:credit_cards',
#  'addr:unit',
#  'payment:card',
#  'payment:cash',
#  'alt_name',
#  'payment:cards',
#  'payment:coins',
#  'payment:notes',
#  'vending',
#  'service:bicycle:pump',
#  'fuel',
#  'denotation',
#  'leaf_cycle',
#  'leaf_type',
#  'check_date:capacity',
#  'ref',
#  'ferry',
#  'public_transport',
#  'recycling_type',
#  'highway',
#  'traffic_signals',
#  'traffic_signals:direction',
#  'toilets',
#  'operator:type',
#  'nodes',
#  'description',
#  'name:fr',
#  'name:vi',
#  'name:zh',
#  'start_date',
#  'wikipedia',
#  'area',
#  'sport',
#  'surface',
#  'denomination',
#  'height',
#  'identifiable_factor:age',
#  'identifiable_factor:cultural_significance',
#  'identifiable_factor:historical_significance',
#  'identifiable_factor:shape',
#  'identifiable_factor:size',
#  'identifiable_factor:type',
#  'identifiable_factor:visibility',
#  'image',
#  'landmark:name',
#  'name:ko',
#  'religion',
#  'roof:height',
#  'roof:shape',
#  'landmark:property',
#  'old_name',
#  'theatre:type',
#  'addr:country',
#  'toilets:wheelchair',
#  'garden:type',
#  'owner',
#  'owner:wikidata',
#  'building:levels',
#  'historic',
#  'phone:AU',
#  'name:pronunciation',
#  'bus',
#  'motor_vehicle',
#  'building:part',
#  'not:operator:wikidata',
#  'water',
#  'unisex',
#  'ways',
#  'type',
#  'intermittent',
#  'salt']

# %%
feature_gdf.amenity = feature_gdf.amenity.astype(str)
feature_gdf.natural = feature_gdf.natural.astype(str)
feature_gdf.leisure = feature_gdf.leisure.astype(str)
feature_gdf.name = feature_gdf.name.astype(str)

# %%
feature_gdf = feature_gdf[['name', 'amenity', 'natural', 'leisure', 'geometry']].dropna(how='all')
feature_gdf
# Out:
#                                           name           amenity natural  \
# element_type osmid
# node         176729780          Regent Theatre           theatre     nan
#              243097159                     nan      loading_dock     nan
#              247024808                     nan  parking_entrance     nan
#              247689970                     nan  parking_entrance     nan
#              266733834   Sofitel Hotel Carpark           parking     nan
# ...                                        ...               ...     ...
# way          1239949234                    nan               nan     nan
# relation     954522                        nan               nan   water
#              1718900                   Court 3               nan     nan
#              1718902                1573 Arena               nan     nan
#              13628081                      nan               nan   water
#
#                          leisure  \
# element_type osmid
# node         176729780       nan
#              243097159       nan
#              247024808       nan
#              247689970       nan
#              266733834       nan
# ...                          ...
# way          1239949234    pitch
# relation     954522          nan
#              1718900     stadium
#              1718902     stadium
#              13628081        nan
#
#                                                                   geometry
# element_type osmid
# node         176729780                         POINT (144.96760 -37.81550)
#              243097159                         POINT (144.96796 -37.82161)
#              247024808                         POINT (144.97019 -37.81548)
#              247689970                         POINT (144.97070 -37.81789)
#              266733834                         POINT (144.97302 -37.81451)
# ...                                                                    ...
# way          1239949234  POLYGON ((144.97781 -37.82089, 144.97757 -37.8...
# relation     954522      POLYGON ((144.96548 -37.81920, 144.96554 -37.8...
#              1718900     POLYGON ((144.97799 -37.82051, 144.97797 -37.8...
#              1718902     POLYGON ((144.97677 -37.82102, 144.97673 -37.8...
#              13628081    MULTIPOLYGON (((144.96814 -37.82217, 144.96825...
#
# [1416 rows x 5 columns]

# %%
for idx, path in enumerate(paths):
    
    if os.path.isfile('dataset/features-osm-{}.geojson'.format(idx)):
        print('features for path {0} out of {1} is already loaded and saved.'.format(idx, len(paths)))
        continue;
    try:
        feature_gdf = ox.features_from_bbox(north=path['max_lat'], south=path['min_lat'], east=path['max_lng'], west=path['min_lng'], tags=tags)
        cols = feature_gdf.columns
        #preprocess
        if 'amenity' not in cols:
            feature_gdf['amenity'] = np.nan
        feature_gdf.amenity = feature_gdf.amenity.astype(str)    
        if 'natural' not in cols:
            feature_gdf['natural'] = np.nan
        feature_gdf.natural = feature_gdf.natural.astype(str)    
        if 'leisure' not in cols:
            feature_gdf['leisure'] = np.nan
        feature_gdf.leisure = feature_gdf.leisure.astype(str)
        if 'name' not in cols:
            feature_gdf['name'] = np.nan
        feature_gdf.name = feature_gdf.name.astype(str)
        feature_gdf = feature_gdf[['name', 'amenity', 'natural', 'leisure', 'geometry']].dropna(how='all')
    
        feature_gdf.to_file("dataset/features-osm-{}.geojson".format(idx), driver='GeoJSON')
        print('features for path {0} out of {1} is loaded from OSM and saved ...'.format(idx, len(paths)))
    except Exception as e:
        print('error in writing path {0} out of {1}...'.format(idx, len(paths)))
        print(e)
# Out:
# features for path 0 out of 387 is already loaded and saved.
# features for path 1 out of 387 is already loaded and saved.
# features for path 2 out of 387 is already loaded and saved.
# features for path 3 out of 387 is already loaded and saved.
# features for path 4 out of 387 is already loaded and saved.
# features for path 5 out of 387 is already loaded and saved.
# features for path 6 out of 387 is already loaded and saved.
# features for path 7 out of 387 is already loaded and saved.
# features for path 8 out of 387 is already loaded and saved.
# features for path 9 out of 387 is already loaded and saved.
# features for path 10 out of 387 is already loaded and saved.
# features for path 11 out of 387 is already loaded and saved.
# features for path 12 out of 387 is already loaded and saved.
# features for path 13 out of 387 is already loaded and saved.
# features for path 14 out of 387 is already loaded and saved.
# features for path 15 out of 387 is already loaded and saved.
# features for path 16 out of 387 is already loaded and saved.
# features for path 17 out of 387 is already loaded and saved.
# features for path 18 out of 387 is already loaded and saved.
# features for path 19 out of 387 is already loaded and saved.
# features for path 20 out of 387 is already loaded and saved.
# features for path 21 out of 387 is already loaded and saved.
# features for path 22 out of 387 is already loaded and saved.
# features for path 23 out of 387 is already loaded and saved.
# features for path 24 out of 387 is already loaded and saved.
# features for path 25 out of 387 is already loaded and saved.
# features for path 26 out of 387 is already loaded and saved.
# features for path 27 out of 387 is already loaded and saved.
# features for path 28 out of 387 is already loaded and saved.
# features for path 29 out of 387 is already loaded and saved.
# features for path 30 out of 387 is already loaded and saved.
# features for path 31 out of 387 is already loaded and saved.
# features for path 32 out of 387 is already loaded and saved.
# features for path 33 out of 387 is already loaded and saved.
# features for path 34 out of 387 is already loaded and saved.
# features for path 35 out of 387 is already loaded and saved.
# features for path 36 out of 387 is already loaded and saved.
# features for path 37 out of 387 is already loaded and saved.
# features for path 38 out of 387 is already loaded and saved.
# features for path 39 out of 387 is already loaded and saved.
# features for path 40 out of 387 is already loaded and saved.
# features for path 41 out of 387 is already loaded and saved.
# features for path 42 out of 387 is already loaded and saved.
# features for path 43 out of 387 is already loaded and saved.
# features for path 44 out of 387 is already loaded and saved.
# features for path 45 out of 387 is already loaded and saved.
# features for path 46 out of 387 is already loaded and saved.
# features for path 47 out of 387 is already loaded and saved.
# features for path 48 out of 387 is already loaded and saved.
# features for path 49 out of 387 is already loaded and saved.
# features for path 50 out of 387 is already loaded and saved.
# features for path 51 out of 387 is already loaded and saved.
# features for path 52 out of 387 is already loaded and saved.
# features for path 53 out of 387 is already loaded and saved.
# features for path 54 out of 387 is already loaded and saved.
# features for path 55 out of 387 is already loaded and saved.
# features for path 56 out of 387 is already loaded and saved.
# features for path 57 out of 387 is already loaded and saved.
# features for path 58 out of 387 is already loaded and saved.
# C:\Users\Ehsan\AppData\Local\Temp\ipykernel_26476\2411664283.py:7: FutureWarning:
#
# The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead.
# error in writing path 59 out of 387...
# No data elements in server response. Check log and query location/tags.
# features for path 60 out of 387 is already loaded and saved.
# features for path 61 out of 387 is already loaded and saved.
# features for path 62 out of 387 is already loaded and saved.
# features for path 63 out of 387 is already loaded and saved.
# features for path 64 out of 387 is already loaded and saved.
# features for path 65 out of 387 is already loaded and saved.
# features for path 66 out of 387 is already loaded and saved.
# features for path 67 out of 387 is already loaded and saved.
# features for path 68 out of 387 is already loaded and saved.
# features for path 69 out of 387 is already loaded and saved.
# features for path 70 out of 387 is already loaded and saved.
# features for path 71 out of 387 is already loaded and saved.
# features for path 72 out of 387 is already loaded and saved.
# features for path 73 out of 387 is already loaded and saved.
# features for path 74 out of 387 is already loaded and saved.
# features for path 75 out of 387 is already loaded and saved.
# features for path 76 out of 387 is already loaded and saved.
# features for path 77 out of 387 is already loaded and saved.
# features for path 78 out of 387 is already loaded and saved.
# features for path 79 out of 387 is already loaded and saved.
# features for path 80 out of 387 is already loaded and saved.
# features for path 81 out of 387 is already loaded and saved.
# features for path 82 out of 387 is already loaded and saved.
# features for path 83 out of 387 is already loaded and saved.
# features for path 84 out of 387 is already loaded and saved.
# features for path 85 out of 387 is already loaded and saved.
# features for path 86 out of 387 is already loaded and saved.
# features for path 87 out of 387 is already loaded and saved.
# features for path 88 out of 387 is already loaded and saved.
# features for path 89 out of 387 is already loaded and saved.
# features for path 90 out of 387 is already loaded and saved.
# features for path 91 out of 387 is already loaded and saved.
# features for path 92 out of 387 is already loaded and saved.
# features for path 93 out of 387 is already loaded and saved.
# features for path 94 out of 387 is already loaded and saved.
# features for path 95 out of 387 is already loaded and saved.
# features for path 96 out of 387 is already loaded and saved.
# features for path 97 out of 387 is already loaded and saved.
# features for path 98 out of 387 is already loaded and saved.
# features for path 99 out of 387 is already loaded and saved.
# features for path 100 out of 387 is already loaded and saved.
# features for path 101 out of 387 is already loaded and saved.
# features for path 102 out of 387 is already loaded and saved.
# features for path 103 out of 387 is already loaded and saved.
# features for path 104 out of 387 is already loaded and saved.
# features for path 105 out of 387 is already loaded and saved.
# features for path 106 out of 387 is already loaded and saved.
# features for path 107 out of 387 is already loaded and saved.
# features for path 108 out of 387 is already loaded and saved.
# features for path 109 out of 387 is already loaded and saved.
# features for path 110 out of 387 is already loaded and saved.
# features for path 111 out of 387 is already loaded and saved.
# features for path 112 out of 387 is already loaded and saved.
# features for path 113 out of 387 is already loaded and saved.
# features for path 114 out of 387 is already loaded and saved.
# features for path 115 out of 387 is already loaded and saved.
# features for path 116 out of 387 is already loaded and saved.
# features for path 117 out of 387 is already loaded and saved.
# features for path 118 out of 387 is already loaded and saved.
# features for path 119 out of 387 is already loaded and saved.
# features for path 120 out of 387 is already loaded and saved.
# features for path 121 out of 387 is already loaded and saved.
# features for path 122 out of 387 is already loaded and saved.
# features for path 123 out of 387 is already loaded and saved.
# features for path 124 out of 387 is already loaded and saved.
# features for path 125 out of 387 is already loaded and saved.
# features for path 126 out of 387 is already loaded and saved.
# features for path 127 out of 387 is already loaded and saved.
# C:\Users\Ehsan\AppData\Local\Temp\ipykernel_26476\2411664283.py:7: FutureWarning:
#
# The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead.
# error in writing path 128 out of 387...
# No data elements in server response. Check log and query location/tags.
# features for path 129 out of 387 is already loaded and saved.
# features for path 130 out of 387 is already loaded and saved.
# features for path 131 out of 387 is already loaded and saved.
# features for path 132 out of 387 is already loaded and saved.
# features for path 133 out of 387 is already loaded and saved.
# features for path 134 out of 387 is already loaded and saved.
# features for path 135 out of 387 is already loaded and saved.
# features for path 136 out of 387 is already loaded and saved.
# features for path 137 out of 387 is already loaded and saved.
# features for path 138 out of 387 is already loaded and saved.
# features for path 139 out of 387 is already loaded and saved.
# features for path 140 out of 387 is already loaded and saved.
# features for path 141 out of 387 is already loaded and saved.
# features for path 142 out of 387 is already loaded and saved.
# features for path 143 out of 387 is already loaded and saved.
# features for path 144 out of 387 is already loaded and saved.
# features for path 145 out of 387 is already loaded and saved.
# features for path 146 out of 387 is already loaded and saved.
# features for path 147 out of 387 is already loaded and saved.
# features for path 148 out of 387 is already loaded and saved.
# features for path 149 out of 387 is already loaded and saved.
# features for path 150 out of 387 is already loaded and saved.
# C:\Users\Ehsan\AppData\Local\Temp\ipykernel_26476\2411664283.py:7: FutureWarning:
#
# The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead.
# error in writing path 151 out of 387...
# No data elements in server response. Check log and query location/tags.
# features for path 152 out of 387 is already loaded and saved.
# features for path 153 out of 387 is already loaded and saved.
# features for path 154 out of 387 is already loaded and saved.
# features for path 155 out of 387 is already loaded and saved.
# features for path 156 out of 387 is already loaded and saved.
# features for path 157 out of 387 is already loaded and saved.
# features for path 158 out of 387 is already loaded and saved.
# features for path 159 out of 387 is already loaded and saved.
# features for path 160 out of 387 is already loaded and saved.
# features for path 161 out of 387 is already loaded and saved.
# features for path 162 out of 387 is already loaded and saved.
# features for path 163 out of 387 is already loaded and saved.
# features for path 164 out of 387 is already loaded and saved.
# features for path 165 out of 387 is already loaded and saved.
# features for path 166 out of 387 is already loaded and saved.
# features for path 167 out of 387 is already loaded and saved.
# features for path 168 out of 387 is already loaded and saved.
# features for path 169 out of 387 is already loaded and saved.
# features for path 170 out of 387 is already loaded and saved.
# features for path 171 out of 387 is already loaded and saved.
# features for path 172 out of 387 is already loaded and saved.
# features for path 173 out of 387 is already loaded and saved.
# features for path 174 out of 387 is already loaded and saved.
# features for path 175 out of 387 is already loaded and saved.
# features for path 176 out of 387 is already loaded and saved.
# features for path 177 out of 387 is already loaded and saved.
# features for path 178 out of 387 is already loaded and saved.
# features for path 179 out of 387 is already loaded and saved.
# features for path 180 out of 387 is already loaded and saved.
# features for path 181 out of 387 is already loaded and saved.
# features for path 182 out of 387 is already loaded and saved.
# features for path 183 out of 387 is already loaded and saved.
# features for path 184 out of 387 is already loaded and saved.
# features for path 185 out of 387 is already loaded and saved.
# features for path 186 out of 387 is already loaded and saved.
# features for path 187 out of 387 is already loaded and saved.
# features for path 188 out of 387 is already loaded and saved.
# features for path 189 out of 387 is already loaded and saved.
# features for path 190 out of 387 is already loaded and saved.
# features for path 191 out of 387 is already loaded and saved.
# features for path 192 out of 387 is already loaded and saved.
# features for path 193 out of 387 is already loaded and saved.
# features for path 194 out of 387 is already loaded and saved.
# features for path 195 out of 387 is already loaded and saved.
# features for path 196 out of 387 is already loaded and saved.
# features for path 197 out of 387 is already loaded and saved.
# features for path 198 out of 387 is already loaded and saved.
# features for path 199 out of 387 is already loaded and saved.
# features for path 200 out of 387 is already loaded and saved.
# features for path 201 out of 387 is already loaded and saved.
# features for path 202 out of 387 is already loaded and saved.
# features for path 203 out of 387 is already loaded and saved.
# features for path 204 out of 387 is already loaded and saved.
# features for path 205 out of 387 is already loaded and saved.
# features for path 206 out of 387 is already loaded and saved.
# features for path 207 out of 387 is already loaded and saved.
# features for path 208 out of 387 is already loaded and saved.
# features for path 209 out of 387 is already loaded and saved.
# features for path 210 out of 387 is already loaded and saved.
# features for path 211 out of 387 is already loaded and saved.
# features for path 212 out of 387 is already loaded and saved.
# features for path 213 out of 387 is already loaded and saved.
# features for path 214 out of 387 is already loaded and saved.
# features for path 215 out of 387 is already loaded and saved.
# features for path 216 out of 387 is already loaded and saved.
# features for path 217 out of 387 is already loaded and saved.
# features for path 218 out of 387 is already loaded and saved.
# features for path 219 out of 387 is already loaded and saved.
# features for path 220 out of 387 is already loaded and saved.
# features for path 221 out of 387 is already loaded and saved.
# features for path 222 out of 387 is already loaded and saved.
# features for path 223 out of 387 is already loaded and saved.
# features for path 224 out of 387 is already loaded and saved.
# features for path 225 out of 387 is already loaded and saved.
# features for path 226 out of 387 is already loaded and saved.
# features for path 227 out of 387 is already loaded and saved.
# features for path 228 out of 387 is already loaded and saved.
# features for path 229 out of 387 is already loaded and saved.
# features for path 230 out of 387 is already loaded and saved.
# features for path 231 out of 387 is already loaded and saved.
# features for path 232 out of 387 is already loaded and saved.
# features for path 233 out of 387 is already loaded and saved.
# features for path 234 out of 387 is already loaded and saved.
# features for path 235 out of 387 is already loaded and saved.
# features for path 236 out of 387 is already loaded and saved.
# features for path 237 out of 387 is already loaded and saved.
# features for path 238 out of 387 is already loaded and saved.
# features for path 239 out of 387 is already loaded and saved.
# features for path 240 out of 387 is already loaded and saved.
# features for path 241 out of 387 is already loaded and saved.
# features for path 242 out of 387 is already loaded and saved.
# features for path 243 out of 387 is already loaded and saved.
# features for path 244 out of 387 is already loaded and saved.
# features for path 245 out of 387 is already loaded and saved.
# features for path 246 out of 387 is already loaded and saved.
# features for path 247 out of 387 is already loaded and saved.
# features for path 248 out of 387 is already loaded and saved.
# features for path 249 out of 387 is already loaded and saved.
# features for path 250 out of 387 is already loaded and saved.
# features for path 251 out of 387 is already loaded and saved.
# features for path 252 out of 387 is already loaded and saved.
# features for path 253 out of 387 is already loaded and saved.
# features for path 254 out of 387 is already loaded and saved.
# features for path 255 out of 387 is already loaded and saved.
# features for path 256 out of 387 is already loaded and saved.
# features for path 257 out of 387 is already loaded and saved.
# features for path 258 out of 387 is already loaded and saved.
# features for path 259 out of 387 is already loaded and saved.
# features for path 260 out of 387 is already loaded and saved.
# features for path 261 out of 387 is already loaded and saved.
# features for path 262 out of 387 is already loaded and saved.
# features for path 263 out of 387 is already loaded and saved.
# features for path 264 out of 387 is already loaded and saved.
# features for path 265 out of 387 is already loaded and saved.
# features for path 266 out of 387 is already loaded and saved.
# features for path 267 out of 387 is already loaded and saved.
# features for path 268 out of 387 is already loaded and saved.
# features for path 269 out of 387 is already loaded and saved.
# features for path 270 out of 387 is already loaded and saved.
# features for path 271 out of 387 is already loaded and saved.
# features for path 272 out of 387 is already loaded and saved.
# features for path 273 out of 387 is already loaded and saved.
# features for path 274 out of 387 is already loaded and saved.
# features for path 275 out of 387 is already loaded and saved.
# features for path 276 out of 387 is already loaded and saved.
# features for path 277 out of 387 is already loaded and saved.
# features for path 278 out of 387 is already loaded and saved.
# features for path 279 out of 387 is already loaded and saved.
# features for path 280 out of 387 is already loaded and saved.
# features for path 281 out of 387 is already loaded and saved.
# features for path 282 out of 387 is already loaded and saved.
# features for path 283 out of 387 is already loaded and saved.
# features for path 284 out of 387 is already loaded and saved.
# features for path 285 out of 387 is already loaded and saved.
# features for path 286 out of 387 is already loaded and saved.
# features for path 287 out of 387 is already loaded and saved.
# features for path 288 out of 387 is already loaded and saved.
# features for path 289 out of 387 is already loaded and saved.
# features for path 290 out of 387 is already loaded and saved.
# features for path 291 out of 387 is already loaded and saved.
# features for path 292 out of 387 is already loaded and saved.
# features for path 293 out of 387 is already loaded and saved.
# features for path 294 out of 387 is already loaded and saved.
# features for path 295 out of 387 is already loaded and saved.
# features for path 296 out of 387 is already loaded and saved.
# features for path 297 out of 387 is already loaded and saved.
# features for path 298 out of 387 is already loaded and saved.
# features for path 299 out of 387 is already loaded and saved.
# features for path 300 out of 387 is already loaded and saved.
# features for path 301 out of 387 is already loaded and saved.
# features for path 302 out of 387 is already loaded and saved.
# features for path 303 out of 387 is already loaded and saved.
# features for path 304 out of 387 is already loaded and saved.
# features for path 305 out of 387 is already loaded and saved.
# features for path 306 out of 387 is already loaded and saved.
# features for path 307 out of 387 is already loaded and saved.
# features for path 308 out of 387 is already loaded and saved.
# C:\Users\Ehsan\AppData\Local\Temp\ipykernel_26476\2411664283.py:7: FutureWarning:
#
# The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead.
# error in writing path 309 out of 387...
# No data elements in server response. Check log and query location/tags.
# features for path 310 out of 387 is already loaded and saved.
# features for path 311 out of 387 is already loaded and saved.
# features for path 312 out of 387 is already loaded and saved.
# features for path 313 out of 387 is already loaded and saved.
# features for path 314 out of 387 is already loaded and saved.
# features for path 315 out of 387 is already loaded and saved.
# features for path 316 out of 387 is already loaded and saved.
# features for path 317 out of 387 is already loaded and saved.
# features for path 318 out of 387 is already loaded and saved.
# features for path 319 out of 387 is already loaded and saved.
# features for path 320 out of 387 is already loaded and saved.
# features for path 321 out of 387 is already loaded and saved.
# features for path 322 out of 387 is already loaded and saved.
# features for path 323 out of 387 is already loaded and saved.
# features for path 324 out of 387 is already loaded and saved.
# features for path 325 out of 387 is already loaded and saved.
# features for path 326 out of 387 is already loaded and saved.
# features for path 327 out of 387 is already loaded and saved.
# features for path 328 out of 387 is already loaded and saved.
# features for path 329 out of 387 is already loaded and saved.
# features for path 330 out of 387 is already loaded and saved.
# features for path 331 out of 387 is already loaded and saved.
# features for path 332 out of 387 is already loaded and saved.
# features for path 333 out of 387 is already loaded and saved.
# features for path 334 out of 387 is already loaded and saved.
# features for path 335 out of 387 is already loaded and saved.
# features for path 336 out of 387 is already loaded and saved.
# features for path 337 out of 387 is already loaded and saved.
# C:\Users\Ehsan\AppData\Local\Temp\ipykernel_26476\2411664283.py:7: FutureWarning:
#
# The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead.
# error in writing path 338 out of 387...
# No data elements in server response. Check log and query location/tags.
# features for path 339 out of 387 is already loaded and saved.
# features for path 340 out of 387 is already loaded and saved.
# features for path 341 out of 387 is already loaded and saved.
# features for path 342 out of 387 is already loaded and saved.
# features for path 343 out of 387 is already loaded and saved.
# features for path 344 out of 387 is already loaded and saved.
# features for path 345 out of 387 is already loaded and saved.
# features for path 346 out of 387 is already loaded and saved.
# features for path 347 out of 387 is already loaded and saved.
# features for path 348 out of 387 is already loaded and saved.
# features for path 349 out of 387 is already loaded and saved.
# features for path 350 out of 387 is already loaded and saved.
# features for path 351 out of 387 is already loaded and saved.
# features for path 352 out of 387 is already loaded and saved.
# features for path 353 out of 387 is already loaded and saved.
# features for path 354 out of 387 is already loaded and saved.
# features for path 355 out of 387 is already loaded and saved.
# features for path 356 out of 387 is already loaded and saved.
# features for path 357 out of 387 is already loaded and saved.
# features for path 358 out of 387 is already loaded and saved.
# features for path 359 out of 387 is already loaded and saved.
# features for path 360 out of 387 is already loaded and saved.
# features for path 361 out of 387 is already loaded and saved.
# features for path 362 out of 387 is already loaded and saved.
# features for path 363 out of 387 is already loaded and saved.
# features for path 364 out of 387 is already loaded and saved.
# features for path 365 out of 387 is already loaded and saved.
# features for path 366 out of 387 is already loaded and saved.
# features for path 367 out of 387 is already loaded and saved.
# features for path 368 out of 387 is already loaded and saved.
# features for path 369 out of 387 is already loaded and saved.
# features for path 370 out of 387 is already loaded and saved.
# features for path 371 out of 387 is already loaded and saved.
# features for path 372 out of 387 is already loaded and saved.
# features for path 373 out of 387 is already loaded and saved.
# features for path 374 out of 387 is already loaded and saved.
# features for path 375 out of 387 is already loaded and saved.
# features for path 376 out of 387 is already loaded and saved.
# features for path 377 out of 387 is already loaded and saved.
# features for path 378 out of 387 is already loaded and saved.
# features for path 379 out of 387 is already loaded and saved.
# features for path 380 out of 387 is already loaded and saved.
# features for path 381 out of 387 is already loaded and saved.
# features for path 382 out of 387 is already loaded and saved.
# features for path 383 out of 387 is already loaded and saved.
# features for path 384 out of 387 is already loaded and saved.
# features for path 385 out of 387 is already loaded and saved.
# features for path 386 out of 387 is already loaded and saved.

# %%
feature_gdf.head()
# Out:
#                                          name           amenity natural  \
# element_type osmid
# node         176729780         Regent Theatre           theatre     nan
#              243097159                    nan      loading_dock     nan
#              247024808                    nan  parking_entrance     nan
#              247689970                    nan  parking_entrance     nan
#              266733834  Sofitel Hotel Carpark           parking     nan
#
#                        leisure                     geometry
# element_type osmid
# node         176729780     nan  POINT (144.96760 -37.81550)
#              243097159     nan  POINT (144.96796 -37.82161)
#              247024808     nan  POINT (144.97019 -37.81548)
#              247689970     nan  POINT (144.97070 -37.81789)
#              266733834     nan  POINT (144.97302 -37.81451)

# %% [markdown]
# ## Matching POIs to OSM POIs
#
# - spatial criteria: defining containment
# - semantic criteria: defining semantic similarity using word embeddings

# %% [markdown]
# ### Semantic Matching
#
# Ranking the relevance of textual descriptions in OSM POIs and LW POIS
#
# Example to test how it works

# %%
sbert_model = SentenceTransformer('bert-base-nli-mean-tokens') # symmetric semantic search
msmarco_model = SentenceTransformer('sentence-transformers/msmarco-distilbert-dot-v5')  # asymmetric semantic search

# embedding derived from BERT for the pois
def embed_texts(sentences, model=sbert_model):
    sentence_embeddings = model.encode(sentences)
    return sentence_embeddings


def compute_similarities(query, sentences, sentence_embeddings, model=sbert_model):
    query_vec = embed_texts(query)
    scores = util.dot_score(query_vec, sentence_embeddings)[0].cpu().tolist()
    doc_score_pairs = list(zip(sentences, scores))
    doc_score_pairs = sorted(doc_score_pairs, key=lambda x: x[1], reverse=True)
    print("Query:", query)
    for doc, score in doc_score_pairs:
        print('\t', score, '\t', doc)
    return doc_score_pairs
# Out:
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\ipywidgets\widgets\widget.py:528: DeprecationWarning:
#
# The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
# Downloading modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading README.md:   0%|          | 0.00/3.99k [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/399 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading README.md:   0%|          | 0.00/6.51k [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/546 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/265M [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/320 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
def only_noun_phrases(sentence):
    doc = nlp(sentence)
    phrases = set() 
    for nc in doc.noun_chunks:
        phrases.add(nc.text)
        phrases.add(doc[nc.root.left_edge.i:nc.root.right_edge.i+1].text)
    return ' '.join(phrases)

# %%
example_poi_osm = "Gaswork park theatre"
example_sentences = ["Gasworks Park: There are artists studios, a theatre and a cafe. Every 3rd Saturday there is a Farmers' Market.  In the park you'll also come across various wonderful sculptures and installations.",
                                                 "Australia's Number One university and world leader in education, teaching and research excellence.",
                                                 "Completed in 1870, the Melbourne Town Hall is at the heart of the city's cultural and civic activity",
                                                 "The magnificent octagonal domed reading room is both a quiet space for study and an iconic Melbourne location to take an unforgettable selfie.?"]
example_sentence_embeddings = embed_texts(example_sentences)
compute_similarities(example_poi_osm, example_sentences, example_sentence_embeddings)
# Out:
# Query: Gaswork park theatre
# 	 112.5803451538086 	 Completed in 1870, the Melbourne Town Hall is at the heart of the city's cultural and civic activity
# 	 92.63168334960938 	 Gasworks Park: There are artists studios, a theatre and a cafe. Every 3rd Saturday there is a Farmers' Market.  In the park you'll also come across various wonderful sculptures and installations.
# 	 84.31318664550781 	 The magnificent octagonal domed reading room is both a quiet space for study and an iconic Melbourne location to take an unforgettable selfie.?
# 	 62.57233810424805 	 Australia's Number One university and world leader in education, teaching and research excellence.
# [("Completed in 1870, the Melbourne Town Hall is at the heart of the city's cultural and civic activity",
#   112.5803451538086),
#  ("Gasworks Park: There are artists studios, a theatre and a cafe. Every 3rd Saturday there is a Farmers' Market.  In the park you'll also come across various wonderful sculptures and installations.",
#   92.63168334960938),
#  ('The magnificent octagonal domed reading room is both a quiet space for study and an iconic Melbourne location to take an unforgettable selfie.?',
#   84.31318664550781),
#  ("Australia's Number One university and world leader in education, teaching and research excellence.",
#   62.57233810424805)]

# %%
# with preprocessing
only_noun_example_sentences = [only_noun_phrases(sentence) for sentence in example_sentences]
example_sentence_embeddings = embed_texts(only_noun_example_sentences)
compute_similarities(example_poi_osm, only_noun_example_sentences, example_sentence_embeddings)
# Out:
# Query: Gaswork park theatre
# 	 133.74261474609375 	 Gasworks Park artists studios, a theatre and a cafe installations various wonderful sculptures a theatre and a cafe a theatre you artists studios the park a cafe various wonderful sculptures and installations a Farmers' Market Gasworks Park:
# 	 121.1363296508789 	 the Melbourne Town Hall the heart of the city's cultural and civic activity the city's cultural and civic activity the heart
# 	 75.88065338134766 	 The magnificent octagonal domed reading room an unforgettable selfie study an iconic Melbourne location to take an unforgettable selfie an iconic Melbourne location a quiet space a quiet space for study and an iconic Melbourne location to take an unforgettable selfie
# 	 58.85948181152344 	 excellence Australia's Number One university and world leader in education, teaching and research excellence. teaching and research excellence research education, teaching and research excellence Australia's Number One university and world leader teaching education
# [("Gasworks Park artists studios, a theatre and a cafe installations various wonderful sculptures a theatre and a cafe a theatre you artists studios the park a cafe various wonderful sculptures and installations a Farmers' Market Gasworks Park:",
#   133.74261474609375),
#  ("the Melbourne Town Hall the heart of the city's cultural and civic activity the city's cultural and civic activity the heart",
#   121.1363296508789),
#  ('The magnificent octagonal domed reading room an unforgettable selfie study an iconic Melbourne location to take an unforgettable selfie an iconic Melbourne location a quiet space a quiet space for study and an iconic Melbourne location to take an unforgettable selfie',
#   75.88065338134766),
#  ("excellence Australia's Number One university and world leader in education, teaching and research excellence. teaching and research excellence research education, teaching and research excellence Australia's Number One university and world leader teaching education",
#   58.85948181152344)]

# %%
example_sentence_embeddings = embed_texts(example_sentences, model=msmarco_model)
compute_similarities(example_poi_osm, example_sentences, example_sentence_embeddings, model=msmarco_model)
# Out:
# Query: Gaswork park theatre
# 	 42.83140182495117 	 Gasworks Park: There are artists studios, a theatre and a cafe. Every 3rd Saturday there is a Farmers' Market.  In the park you'll also come across various wonderful sculptures and installations.
# 	 30.71784019470215 	 Completed in 1870, the Melbourne Town Hall is at the heart of the city's cultural and civic activity
# 	 25.08165740966797 	 The magnificent octagonal domed reading room is both a quiet space for study and an iconic Melbourne location to take an unforgettable selfie.?
# 	 18.95928382873535 	 Australia's Number One university and world leader in education, teaching and research excellence.
# [("Gasworks Park: There are artists studios, a theatre and a cafe. Every 3rd Saturday there is a Farmers' Market.  In the park you'll also come across various wonderful sculptures and installations.",
#   42.83140182495117),
#  ("Completed in 1870, the Melbourne Town Hall is at the heart of the city's cultural and civic activity",
#   30.71784019470215),
#  ('The magnificent octagonal domed reading room is both a quiet space for study and an iconic Melbourne location to take an unforgettable selfie.?',
#   25.08165740966797),
#  ("Australia's Number One university and world leader in education, teaching and research excellence.",
#   18.95928382873535)]

# %%
example_sentence_embeddings = embed_texts(only_noun_example_sentences, model=msmarco_model)
compute_similarities(example_poi_osm, only_noun_example_sentences, example_sentence_embeddings, model=msmarco_model)
# Out:
# Query: Gaswork park theatre
# 	 44.30448913574219 	 Gasworks Park artists studios, a theatre and a cafe installations various wonderful sculptures a theatre and a cafe a theatre you artists studios the park a cafe various wonderful sculptures and installations a Farmers' Market Gasworks Park:
# 	 30.507658004760742 	 the Melbourne Town Hall the heart of the city's cultural and civic activity the city's cultural and civic activity the heart
# 	 23.770713806152344 	 The magnificent octagonal domed reading room an unforgettable selfie study an iconic Melbourne location to take an unforgettable selfie an iconic Melbourne location a quiet space a quiet space for study and an iconic Melbourne location to take an unforgettable selfie
# 	 17.956480026245117 	 excellence Australia's Number One university and world leader in education, teaching and research excellence. teaching and research excellence research education, teaching and research excellence Australia's Number One university and world leader teaching education
# [("Gasworks Park artists studios, a theatre and a cafe installations various wonderful sculptures a theatre and a cafe a theatre you artists studios the park a cafe various wonderful sculptures and installations a Farmers' Market Gasworks Park:",
#   44.30448913574219),
#  ("the Melbourne Town Hall the heart of the city's cultural and civic activity the city's cultural and civic activity the heart",
#   30.507658004760742),
#  ('The magnificent octagonal domed reading room an unforgettable selfie study an iconic Melbourne location to take an unforgettable selfie an iconic Melbourne location a quiet space a quiet space for study and an iconic Melbourne location to take an unforgettable selfie',
#   23.770713806152344),
#  ("excellence Australia's Number One university and world leader in education, teaching and research excellence. teaching and research excellence research education, teaching and research excellence Australia's Number One university and world leader teaching education",
#   17.956480026245117)]

# %%
topic_df[topic_df.document.str.contains('Gasworks', na=False)]
# Out:
#       topic                                           document
# 673      58  Gasworks Park: There are artists studios, a th...
# 4373     31  The Weighbridge: This is where the coal was br...
# 4374      3  Brick Wall: I love the patterning of this bric...
# 4375     39  Solar!: Note the solar panels appearing on hou...

# %%
topic_model.get_topic(-1)
# Out:
# [('reserve', 0.11792720130243667),
#  ('street', 0.1142422991259655),
#  ('through', 0.11406649920539602),
#  ('hall', 0.1136732770113999),
#  ('water', 0.1098914926540999),
#  ('centre', 0.10860185819207639),
#  ('town', 0.10813687336068976),
#  ('stop', 0.10793617779580789),
#  ('shopping', 0.1066996453060482),
#  ('spot', 0.10664274791347784)]

# %%
topic_df.head()
# Out:
#    topic                                           document
# 0      1  Fairhaven Surf Life Saving Club: Fairhaven is ...
# 1      1  Beach walk: From Sprout Creek, Eastern View, M...
# 2     12  Rock pools: See what sort of shells and stones...
# 3      1  Sand dunes: The beautiful rolling sand dunes s...
# 4     35  Painkalac Creek: The creek separates Aireys In...

# %% [markdown]
# ## Case Investigation
#
# Checking the POIs in description with respect to OSM POIs

# %%
def get_case(idx):
    record = dataset[idx]  
    pois = {'title': [], 'summary': [], 'lat': [], 'lng': []}
    for poi in record['pois']:
        pois['title'].append(poi['title'])
        pois['summary'].append(poi['summary'])
        pois['lat'].append(poi['lat'])
        pois['lng'].append(poi['lng'])
        
    df = pd.DataFrame(pois)
    gdf = gpd.GeoDataFrame(df[['title', 'summary', 'lat', 'lng']],
                           geometry=gpd.points_from_xy(df.lng, df.lat), crs="EPSG:4326")
    
    if os.path.isfile('dataset/features-osm-{}.geojson'.format(idx)):
        osm_pois = gpd.read_file('dataset/features-osm-{}.geojson'.format(idx))
    else:
        print('OSM features are not loaded - potentially empty dataframe')
        osm_pois = None
    return gdf, osm_pois

# %%
lw_poi, osm_poi = get_case(1)

# %%
lw_poi
# Out:
#                                         title  \
# 0             Fairhaven Surf Life Saving Club
# 1                                  Beach walk
# 2                                  Rock pools
# 3                                  Sand dunes
# 4                             Painkalac Creek
# 5       Rocks and caves under the light house
# 6   Aireys Inlet playground and picnic ground
# 7                    Aireys Inlet lower shops
# 8                          Loutit Bay lookout
# 9           Historical homestead and building
# 10                     Split Point Lighthouse
#
#                                               summary        lat         lng  \
# 0   Fairhaven is a well known surf beach. The beac... -38.468759  144.084459
# 1   From Sprout Creek, Eastern View, Moggs Creek, ... -38.468542  144.089693
# 2   See what sort of shells and stones you can col... -38.468459  144.092420
# 3   The beautiful rolling sand dunes shape the bea... -38.468418  144.095318
# 4   The creek separates Aireys Inlet from Fairhave... -38.468390  144.097312
# 5   There are more rockpools and rocky outcrops to... -38.468822  144.100861
# 6   There is small skateboard ramp for children to... -38.466199  144.098772
# 7   Pick up a coffee, newspaper or Fish and Chips!... -38.465536  144.098801
# 8   Return to Painkalac Creek inlet and walk to th... -38.467916  144.103435
# 9   At the lighthouse is the original homestead fo... -38.468048  144.103832
# 10  Follow the signs and continue up the walking t... -38.468114  144.104029
#
#                        geometry
# 0   POINT (144.08446 -38.46876)
# 1   POINT (144.08969 -38.46854)
# 2   POINT (144.09242 -38.46846)
# 3   POINT (144.09532 -38.46842)
# 4   POINT (144.09731 -38.46839)
# 5   POINT (144.10086 -38.46882)
# 6   POINT (144.09877 -38.46620)
# 7   POINT (144.09880 -38.46554)
# 8   POINT (144.10344 -38.46792)
# 9   POINT (144.10383 -38.46805)
# 10  POINT (144.10403 -38.46811)

# %%
osm_poi
# Out:
#    element_type       osmid                                 name  \
# 0          node   831201200                                  nan
# 1          node   831201305                                  nan
# 2          node   831201411                                  nan
# 3          node   831201826                                  nan
# 4          node  5315720235                                  nan
# 5          node  8568393481                                  nan
# 6           way    30501938              Painkalac Creek Estuary
# 7           way    69366065                                  nan
# 8           way    69366070                                  nan
# 9           way    69366078                                  nan
# 10          way    69366081              Aireys Inlet Skate Park
# 11          way    69366092                     Bark Hut Reserve
# 12          way    69366108                                  nan
# 13          way    69366116                                  nan
# 14          way    69560073                 Aireys Inlet Reserve
# 15          way    95186468                                  nan
# 16          way   161748270                Allen Noble Sanctuary
# 17          way   283542690                                  nan
# 18          way   865565686                                  nan
# 19          way   865569273                                  nan
# 20          way  1007494584                            Fairhaven
# 21          way  1009404376                           Table Rock
# 22     relation     9212148  Lorne - Queenscliff Coastal Reserve
# 23     relation     9212157          Eagle Rock Marine Sanctuary
# 24     relation     9457256                          Bass Strait
#
#          amenity    natural         leisure  \
# 0        toilets        nan             nan
# 1        toilets        nan             nan
# 2            bbq        nan             nan
# 3        shelter        nan             nan
# 4            nan        nan    picnic_table
# 5   waste_basket        nan             nan
# 6            nan      water             nan
# 7        parking        nan             nan
# 8        parking        nan             nan
# 9            nan        nan      playground
# 10           nan        nan           pitch
# 11           nan        nan            park
# 12           nan        nan      playground
# 13       parking        nan             nan
# 14           nan        nan            park
# 15           nan  coastline             nan
# 16           nan    wetland             nan
# 17       parking        nan             nan
# 18           nan        nan   swimming_pool
# 19           nan        nan   swimming_pool
# 20           nan      beach             nan
# 21           nan      beach             nan
# 22           nan        nan  nature_reserve
# 23           nan        nan  nature_reserve
# 24           nan     strait             nan
#
#                                              geometry
# 0                         POINT (144.09837 -38.46594)
# 1                         POINT (144.10104 -38.46734)
# 2                         POINT (144.09857 -38.46592)
# 3                         POINT (144.09864 -38.46595)
# 4                         POINT (144.10073 -38.46681)
# 5                         POINT (144.10029 -38.46666)
# 6   POLYGON ((144.09591 -38.46359, 144.09625 -38.4...
# 7   POLYGON ((144.10000 -38.46659, 144.09998 -38.4...
# 8   POLYGON ((144.09836 -38.46586, 144.09836 -38.4...
# 9   POLYGON ((144.10198 -38.46581, 144.10217 -38.4...
# 10  POLYGON ((144.09837 -38.46610, 144.09862 -38.4...
# 11  POLYGON ((144.10218 -38.46611, 144.10185 -38.4...
# 12  POLYGON ((144.09846 -38.46595, 144.09868 -38.4...
# 13  POLYGON ((144.09880 -38.46545, 144.09894 -38.4...
# 14  POLYGON ((144.09882 -38.46563, 144.09879 -38.4...
# 15  LINESTRING (143.86352 -38.66725, 143.86349 -38...
# 16  POLYGON ((144.10274 -38.46564, 144.10266 -38.4...
# 17  POLYGON ((144.09879 -38.46604, 144.09885 -38.4...
# 18  POLYGON ((144.08774 -38.46745, 144.08774 -38.4...
# 19  POLYGON ((144.10330 -38.46597, 144.10337 -38.4...
# 20  POLYGON ((144.06686 -38.46862, 144.06692 -38.4...
# 21  POLYGON ((144.10310 -38.46865, 144.10247 -38.4...
# 22  MULTIPOLYGON (((143.94680 -38.57970, 143.94656...
# 23  POLYGON ((144.10158 -38.46903, 144.10159 -38.4...
# 24  POLYGON ((143.51178 -38.85797, 143.51209 -38.8...

# %%
# projection 

lw_projected = lw_poi.to_crs("EPSG:32755")
osm_projected = osm_poi.to_crs("EPSG:32755")

# %%
poi_case = 6

lw_poi.iloc[poi_case]
# Out:
# title               Aireys Inlet playground and picnic ground
# summary     There is small skateboard ramp for children to...
# lat                                                -38.466199
# lng                                                144.098772
# geometry                    POINT (144.09877169 -38.46619881)
# Name: 6, dtype: object

# %%
osm_projected.distance(lw_projected.iloc[poi_case]['geometry'])
# Out:
# 0      45.318589
# 1     235.344292
# 2      35.687710
# 3      30.304774
# 4     184.116072
# 5     142.141188
# 6      51.867211
# 7     115.908134
# 8      37.170695
# 9     283.902017
# 10     13.688306
# 11    271.562240
# 12     15.267822
# 13     78.705460
# 14      8.479294
# 15    277.569933
# 16    279.422113
# 17      0.902516
# 18    968.728085
# 19    394.194319
# 20    242.844765
# 21    148.460931
# 22     79.652279
# 23    388.207314
# 24    277.569933
# dtype: float64

# %% [markdown]
# ## Enrich the OSM Description of POIs
# - using hierarchy (contained by)
# - combining names, types and extratags

# %%
# todo - maybe creating a dataset as well! the task is actually difficult!
def generate_req_id(row):
    return row['element_type'][0].upper()+str(row['osmid'])

osm_poi['req_id'] = osm_poi.apply(generate_req_id, axis=1)
osm_poi.req_id.tolist()
# Out:
# ['N831201200',
#  'N831201305',
#  'N831201411',
#  'N831201826',
#  'N5315720235',
#  'N8568393481',
#  'W30501938',
#  'W69366065',
#  'W69366070',
#  'W69366078',
#  'W69366081',
#  'W69366092',
#  'W69366108',
#  'W69366116',
#  'W69560073',
#  'W95186468',
#  'W161748270',
#  'W283542690',
#  'W865565686',
#  'W865569273',
#  'W1007494584',
#  'W1009404376',
#  'R9212148',
#  'R9212157',
#  'R9457256']

# %%
req_ids = set()

# read all osm ids and save in a file
for idx, path in enumerate(paths):
    if os.path.isfile('dataset/features-osm-{}.geojson'.format(idx)):
        osm_poi = gpd.read_file('dataset/features-osm-{}.geojson'.format(idx))
        osm_poi['req_id'] = osm_poi.apply(generate_req_id, axis=1)
        req_ids.update(osm_poi.req_id.tolist())

# %%
headers = {"Content-Type": "application/json; charset=utf-8"}
address_endpoint_template = "https://nominatim.openstreetmap.org/lookup?osm_ids={}&format=json&extratags=1"

def download_osm_details(rids):
    resp = requests.get(address_endpoint_template.format(','.join(rids), headers=headers))
    return resp.json()

# %%
req_ids = list(req_ids)

all_osm_info = []

if os.path.isfile('dataset/osm-detailed-pois.json'):
    with open('dataset/osm-detailed-pois.json', 'r') as fp:
        all_osm_info = json.load(fp)
else:
    bucket_size = 50  # maximum value for OSM lookup!
    for i in range(0, len(req_ids), bucket_size):
        try:
            all_osm_info.append(download_osm_details(req_ids[i:i+bucket_size]))
            print('bucket done: {}'.format(i))
            time.sleep(0.5)
        except Exception as e:
            print(e)
            print('bucket: {}'.format(i))

# %%
all_osm_list = []
for bucket in all_osm_info:
    all_osm_list.extend(bucket)

# %%
with open('dataset/osm-detailed-pois.json', 'w', encoding='utf-8') as fp:
    json.dump(all_osm_info, fp)

with open('dataset/processed-osm-detailed-pois.json', 'w', encoding='utf-8') as fp:
    json.dump(all_osm_list, fp)
    
print('Detailed information about OSM pois are stored in `dataset/osm-detailed-pois.json`')
# Out:
# Detailed information about OSM pois are stored in `dataset/osm-detailed-pois.json`

# %%
print(len(req_ids))
print(len(all_osm_info))
print(len(all_osm_list))
osm_poi_details_df = pd.DataFrame(all_osm_list)
osm_poi_details_df.head()
# Out:
# 84203
# 1685
# 27900
#    place_id                                            licence osm_type  \
# 0  50105769  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
# 1  50264145  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
# 2  49748802  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
# 3  50013438  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
# 4  50156137  Data © OpenStreetMap contributors, ODbL 1.0. h...     node
#
#        osm_id                  lat                 lon    class  \
# 0   210529635         -37.77131895  144.88922947664923  amenity
# 1  1005592702           -37.755842  144.79434671579116  amenity
# 2   948227337  -38.338870549999996  144.72523383795718  leisure
# 3   542417354  -37.985324399999996   145.2116291306154  amenity
# 4   678349689           -37.800412          144.966749  amenity
#
#             type  place_rank  importance addresstype                 name  \
# 0        parking          30     0.00001     amenity  David Jones Carpark
# 1        parking          30     0.00001     amenity
# 2  swimming_pool          30     0.00001     leisure
# 3        parking          30     0.00001     amenity
# 4     restaurant          30     0.00001     amenity         Il Cantuccio
#
#                                         display_name  \
# 0  David Jones Carpark, Primary Place, Maribyrnon...
# 1  Ken Jordan Road, Cairnlea, Melbourne, City of ...
# 2  Stonecutters Road, Portsea, Melbourne, Shire o...
# 3  Robinson Street, Dandenong, Melbourne, City of...
# 4  Il Cantuccio, 209, Lygon Street, Little Italy,...
#
#                                              address  \
# 0  {'amenity': 'David Jones Carpark', 'road': 'Pr...
# 1  {'road': 'Ken Jordan Road', 'suburb': 'Cairnle...
# 2  {'road': 'Stonecutters Road', 'suburb': 'Ports...
# 3  {'road': 'Robinson Street', 'suburb': 'Dandeno...
# 4  {'amenity': 'Il Cantuccio', 'house_number': '2...
#
#                                            extratags  \
# 0  {'parking': 'multi-storey', 'building': 'parki...
# 1                         {'parking': 'street_side'}
# 2                                               None
# 3                                               None
# 4  {'phone': '+61 3 9347 9959', 'cuisine': 'itali...
#
#                                          boundingbox
# 0  [-37.7716973, -37.7708987, 144.8879962, 144.89...
# 1  [-37.7559597, -37.7557312, 144.7942967, 144.79...
# 2  [-38.3389150, -38.3388240, 144.7251718, 144.72...
# 3  [-37.9856572, -37.9849960, 145.2114001, 145.21...
# 4  [-37.8004620, -37.8003620, 144.9666990, 144.96...

# %%
osm_poi_details_df[(osm_poi_details_df['osm_type'] == 'way') & (osm_poi_details_df['osm_id'] == 542417354)]['display_name'].values[0]
# Out:
# 'Robinson Street, Dandenong, Melbourne, City of Greater Dandenong, Victoria, 3177, Australia'

# %%
def enrich(row):
    info = osm_poi_details_df[(osm_poi_details_df['osm_type'] == row['element_type']) & 
    (osm_poi_details_df['osm_id'] == row['osmid'])]
    if len(info) > 0:
        t_name = ' '.join(info['display_name'].values[0].split(',')[:2])
        if info['extratags'].values[0] is not None:
            t_name += ' '.join([k+' '+v for (k,v) in info['extratags'].values[0].items()])
    else:
        t_name = ''
    h_name = ''
    parents = osm_poi.loc[(osm_poi.geometry.contains(row.geometry)) & (osm_poi.id != row.id)]['name'].values.tolist()
    if len(parents) > 0:
        h_name += ' in '+ ', '.join([p for p in parents if p != 'nan'])
    p_name = ''
    if row['amenity'] != 'nan':
        p_name += 'amenity {} '.format(row['amenity']).replace('_', ' ')
    if row['natural'] != 'nan':
        p_name += 'natural {} '.format(row['natural']).replace('_', ' ')
    if row['leisure'] != 'nan':
        p_name += 'leisure {} '.format(row['leisure']).replace('_', ' ')
    if row['name'] == 'nan':
        return p_name+ t_name + h_name
    return row['name'] + ' ' + p_name + t_name + h_name

# %%
osm_poi.reset_index(inplace=True)
osm_poi = osm_poi.rename(columns= {'index': 'id'})
osm_poi
# Out:
#     id element_type        osmid name amenity natural leisure  \
# 0    0         node  10889194475  nan     nan    tree     nan
# 1    1         node  10889194476  nan     nan    tree     nan
# 2    2         node  10889194477  nan     nan    tree     nan
# 3    3         node  10889194478  nan     nan    tree     nan
# 4    4         node  10889194481  nan     nan    tree     nan
# ..  ..          ...          ...  ...     ...     ...     ...
# 69  69          way   1171940505  nan     nan     nan   pitch
# 70  70          way   1171940506  nan     nan     nan   pitch
# 71  71          way   1171940507  nan     nan     nan   pitch
# 72  72          way   1171940508  nan     nan     nan   pitch
# 73  73          way   1171940509  nan     nan     nan   pitch
#
#                                              geometry        req_id
# 0                         POINT (145.05762 -37.65706)  N10889194475
# 1                         POINT (145.05774 -37.65697)  N10889194476
# 2                         POINT (145.05782 -37.65706)  N10889194477
# 3                         POINT (145.05787 -37.65710)  N10889194478
# 4                         POINT (145.05794 -37.65696)  N10889194481
# ..                                                ...           ...
# 69  POLYGON ((145.05668 -37.65476, 145.05677 -37.6...   W1171940505
# 70  POLYGON ((145.05469 -37.65574, 145.05475 -37.6...   W1171940506
# 71  POLYGON ((145.05555 -37.65548, 145.05560 -37.6...   W1171940507
# 72  POLYGON ((145.05563 -37.65674, 145.05557 -37.6...   W1171940508
# 73  POLYGON ((145.05677 -37.65641, 145.05675 -37.6...   W1171940509
#
# [74 rows x 9 columns]

# %%
osm_poi['full_name'] = osm_poi.apply(enrich, axis=1)
osm_poi
# Out:
#     id element_type        osmid name amenity natural leisure  \
# 0    0         node  10889194475  nan     nan    tree     nan
# 1    1         node  10889194476  nan     nan    tree     nan
# 2    2         node  10889194477  nan     nan    tree     nan
# 3    3         node  10889194478  nan     nan    tree     nan
# 4    4         node  10889194481  nan     nan    tree     nan
# ..  ..          ...          ...  ...     ...     ...     ...
# 69  69          way   1171940505  nan     nan     nan   pitch
# 70  70          way   1171940506  nan     nan     nan   pitch
# 71  71          way   1171940507  nan     nan     nan   pitch
# 72  72          way   1171940508  nan     nan     nan   pitch
# 73  73          way   1171940509  nan     nan     nan   pitch
#
#                                              geometry        req_id  \
# 0                         POINT (145.05762 -37.65706)  N10889194475
# 1                         POINT (145.05774 -37.65697)  N10889194476
# 2                         POINT (145.05782 -37.65706)  N10889194477
# 3                         POINT (145.05787 -37.65710)  N10889194478
# 4                         POINT (145.05794 -37.65696)  N10889194481
# ..                                                ...           ...
# 69  POLYGON ((145.05668 -37.65476, 145.05677 -37.6...   W1171940505
# 70  POLYGON ((145.05469 -37.65574, 145.05475 -37.6...   W1171940506
# 71  POLYGON ((145.05555 -37.65548, 145.05560 -37.6...   W1171940507
# 72  POLYGON ((145.05563 -37.65674, 145.05557 -37.6...   W1171940508
# 73  POLYGON ((145.05677 -37.65641, 145.05675 -37.6...   W1171940509
#
#                                             full_name
# 0                                       natural tree
# 1                                       natural tree
# 2                                       natural tree
# 3                                       natural tree
# 4                                       natural tree
# ..                                                ...
# 69  leisure pitch Gilroy Crescent  Mill Parksport ...
# 70  leisure pitch Lady Penrhyn Avenue  Mill Parksp...
# 71  leisure pitch Gilroy Crescent  Mill Parksport ...
# 72  leisure pitch Lady Penrhyn Avenue  Mill Parksp...
# 73  leisure pitch Morang Drive  Mill Parksport sof...
#
# [74 rows x 10 columns]

# %%
osm_poi.loc[(osm_poi.geometry.contains(osm_poi.loc[70].geometry)) & (osm_poi.index != 70)]['name'].values.tolist()
# Out:
# ['Mill Park Recreation Reserve']

# %%
osm_poi.iloc[70]['full_name']
# Out:
# 'leisure pitch Lady Penrhyn Avenue  Mill Parksport softball in Mill Park Recreation Reserve'

# %%
for idx, path in enumerate(paths):
    if os.path.isfile('dataset/features-osm-{}.geojson'.format(idx)):
        if os.path.isfile("dataset/features-osm-poi-{}.geojson".format(idx)):
            continue
        osm_poi = gpd.read_file('dataset/features-osm-{}.geojson'.format(idx))
        print('analysing: {0} - number of features: {1}'.format(idx, len(osm_pois)))
        osm_poi.reset_index(inplace=True)
        osm_poi = osm_poi.rename(columns= {'index': 'id'})
        osm_poi['full_name'] = osm_poi.apply(enrich, axis=1)
        osm_poi.to_file("dataset/features-osm-poi-{}.geojson".format(idx), driver='GeoJSON')
        print('enriched features for path {0} out of {1} is loaded from OSM and saved ...'.format(idx, len(paths)))

# %%
osm_poi
# Out:
#     id element_type        osmid name amenity natural leisure  \
# 0    0         node  10889194475  nan     nan    tree     nan
# 1    1         node  10889194476  nan     nan    tree     nan
# 2    2         node  10889194477  nan     nan    tree     nan
# 3    3         node  10889194478  nan     nan    tree     nan
# 4    4         node  10889194481  nan     nan    tree     nan
# ..  ..          ...          ...  ...     ...     ...     ...
# 69  69          way   1171940505  nan     nan     nan   pitch
# 70  70          way   1171940506  nan     nan     nan   pitch
# 71  71          way   1171940507  nan     nan     nan   pitch
# 72  72          way   1171940508  nan     nan     nan   pitch
# 73  73          way   1171940509  nan     nan     nan   pitch
#
#                                              geometry        req_id  \
# 0                         POINT (145.05762 -37.65706)  N10889194475
# 1                         POINT (145.05774 -37.65697)  N10889194476
# 2                         POINT (145.05782 -37.65706)  N10889194477
# 3                         POINT (145.05787 -37.65710)  N10889194478
# 4                         POINT (145.05794 -37.65696)  N10889194481
# ..                                                ...           ...
# 69  POLYGON ((145.05668 -37.65476, 145.05677 -37.6...   W1171940505
# 70  POLYGON ((145.05469 -37.65574, 145.05475 -37.6...   W1171940506
# 71  POLYGON ((145.05555 -37.65548, 145.05560 -37.6...   W1171940507
# 72  POLYGON ((145.05563 -37.65674, 145.05557 -37.6...   W1171940508
# 73  POLYGON ((145.05677 -37.65641, 145.05675 -37.6...   W1171940509
#
#                                             full_name
# 0                                       natural tree
# 1                                       natural tree
# 2                                       natural tree
# 3                                       natural tree
# 4                                       natural tree
# ..                                                ...
# 69  leisure pitch Gilroy Crescent  Mill Parksport ...
# 70  leisure pitch Lady Penrhyn Avenue  Mill Parksp...
# 71  leisure pitch Gilroy Crescent  Mill Parksport ...
# 72  leisure pitch Lady Penrhyn Avenue  Mill Parksp...
# 73  leisure pitch Morang Drive  Mill Parksport sof...
#
# [74 rows x 10 columns]

# %% [markdown]
# ## Matching LW POIs to OSM POIs
#
# Using:
#
# - *Spatial criterion*: nearby or contained
# - *Thematic criterion*: topic representation of POI with types in OSM POIs
# - *Linguistic criterion*: description of the POI with detailed contextual information from OSM (name, type, hierarchy)
#
# **Note** The POIs might be missing in OSM data

# %%
def get_case_with_details(idx):
    record = dataset[idx]  
    pois = {'title': [], 'summary': [], 'lat': [], 'lng': []}
    for poi in record['pois']:
        pois['title'].append(poi['title'])
        pois['summary'].append(poi['summary'])
        pois['lat'].append(poi['lat'])
        pois['lng'].append(poi['lng'])
        
    df = pd.DataFrame(pois)
    gdf = gpd.GeoDataFrame(df[['title', 'summary', 'lat', 'lng']],
                           geometry=gpd.points_from_xy(df.lng, df.lat), crs="EPSG:4326")
    
    if os.path.isfile('dataset/features-osm-poi-{}.geojson'.format(idx)):
        osm_pois = gpd.read_file('dataset/features-osm-poi-{}.geojson'.format(idx))
    else:
        print('OSM features are not loaded - potentially empty dataframe')
        osm_pois = None
    return gdf, osm_pois

# %%
test_case_idx = 2
test_case_gdf, test_case_pois = get_case_with_details(test_case_idx)

# %%
test_case_gdf = test_case_gdf.to_crs("EPSG:32755")
test_case_gdf
# Out:
#                                              title  \
# 0                            1. Tramway signal box
# 1                                    2. City Baths
# 2                             3. Magistrates Court
# 3                            4. Old Melbourne Gaol
# 4                       5. Eight Hour Day Monument
# 5                                   6. Trades Hall
# 6                                   7. Medley Hall
# 7                             8. Lygon shop corner
# 8                                9. Matthais House
# 9                 10. Sacred Heart Catholic Church
# 10                                11. IMAX Theatre
# 11                            12. Melbourne Museum
# 12                   13. Royal Exhibition Building
# 13                             14. Carlton Gardens
# 14                                  15. Playground
# 15              16. Carlton Gardens Primary School
# 16  17. Terrace Houses (201 - 205 Drummond Street)
# 17                              18. Museo Italiano
# 18                             19. La Mama Theatre
# 19                  19. Underground public toilets
# 20                     21. 313-315 Drummond Street
# 21                         22. Carlton Court House
#
#                                               summary        lat         lng  \
# 0   Built in 1928 soon after the electrification o... -37.806953  144.962813
# 1   Built in 1903, the design reflected the social... -37.807382  144.962990
# 2   Built on the site of the earlier Supreme Court... -37.808828  144.966112
# 3   Built between 1851 - 1864. As the oldest survi... -37.807569  144.965710
# 4   Built in 1923, the monument commemorates the E... -37.807126  144.965808
# 5   Built in stages from 1873 - 1926, Trades Hall ... -37.806905  144.965989
# 6   Built in 1893 as a private residence, the buil... -37.805803  144.967618
# 7   Lygon Buildings is architecturally significant... -37.804863  144.966279
# 8   A two storeyed stucco faced bluestone house of... -37.803827  144.967759
# 9   Built in 1855-56. In the 1930s and 1940s the C... -37.803051  144.969378
# 10  IMAX is the world's largest cinema format, wit... -37.803371  144.969616
# 11  The museum has eight galleries, including one ... -37.803674  144.969564
# 12  The Royal Exhibition Building is the only surv... -37.805135  144.971235
# 13  Developed in 19th-century Gardenesque style, t... -37.805630  144.971385
# 14  Wonderful playground with swings, slides and m... -37.802505  144.970700
# 15  The school is an Italian Gothic style building... -37.801938  144.969625
# 16  Built in 1884, Holcombe Terrace is a fine exam... -37.800896  144.968340
# 17  Museo Italiano displays and interprets the exp... -37.798813  144.968136
# 18  Built in 1883, the building was used for vario... -37.798753  144.967652
# 19  The underground public toilets, built in 1939,... -37.798724  144.967416
# 20  Built in 1889, the buliding is architecturally... -37.798425  144.968750
# 21  The Carlton Court House is historically signif... -37.797703  144.968867
#
#                           geometry
# 0   POINT (320663.065 5813648.747)
# 1   POINT (320679.723 5813601.482)
# 2   POINT (320958.059 5813447.052)
# 3   POINT (320919.660 5813585.973)
# 4   POINT (320927.197 5813635.299)
# 5   POINT (320942.628 5813660.156)
# 6   POINT (321083.333 5813785.590)
# 7   POINT (320963.170 5813887.275)
# 8   POINT (321091.019 5814005.140)
# 9   POINT (321231.646 5814094.295)
# 10  POINT (321253.423 5814059.312)
# 11  POINT (321249.542 5814025.589)
# 12  POINT (321400.230 5813866.625)
# 13  POINT (321414.635 5813812.021)
# 14  POINT (321346.754 5814157.403)
# 15  POINT (321250.714 5814218.329)
# 16  POINT (321135.071 5814331.466)
# 17  POINT (321112.101 5814562.205)
# 18  POINT (321069.304 5814567.889)
# 19  POINT (321048.512 5814570.650)
# 20  POINT (321165.248 5814606.489)
# 21  POINT (321173.746 5814686.735)

# %%
test_case_pois = test_case_pois.to_crs("EPSG:32755")
test_case_pois
# Out:
#         id element_type       osmid  \
# 0        0         node   242538793
# 1        1         node   242540159
# 2        2         node   242823091
# 3        3         node   242823102
# 4        4         node   242823114
# ...    ...          ...         ...
# 2375  2375          way  1201832429
# 2376  2376          way  1217340419
# 2377  2377          way  1232632180
# 2378  2378     relation     6614802
# 2379  2379     relation    15629064
#
#                                                name       amenity natural  \
# 0                                               nan      post_box     nan
# 1                                               nan     telephone     nan
# 2                                               nan     telephone     nan
# 3                                               nan      post_box     nan
# 4                                               nan       toilets     nan
# ...                                             ...           ...     ...
# 2375                                            nan           nan     nan
# 2376                 Melbourne Sexual Health Centre        clinic     nan
# 2377                   Lemon Tree Children's Centre  kindergarten     nan
# 2378                                Carlton Gardens           nan     nan
# 2379  The University of Melbourne, Parkville Campus    university     nan
#
#      leisure                                          full_name  \
# 0        nan       amenity post box Queensberry Street  Carlton
# 1        nan  amenity telephone Swanston Street  East End Th...
# 2        nan  amenity telephone Swanston Street  East End Th...
# 3        nan            amenity post box Pelham Street  Carlton
# 4        nan  amenity toilets Rathdowne Street  Carltonfee n...
# ...      ...                                                ...
# 2375  garden  leisure garden Porters Lane  Parkville in The ...
# 2376     nan  Melbourne Sexual Health Centre amenity clinic ...
# 2377     nan  Lemon Tree Children's Centre amenity kindergar...
# 2378    park  Carlton Gardens leisure park Carlton Gardens  ...
# 2379     nan  The University of Melbourne, Parkville Campus ...
#
#                                                geometry
# 0                        POINT (320727.351 5813899.378)
# 1                        POINT (320749.536 5813412.933)
# 2                        POINT (320730.759 5813422.172)
# 3                        POINT (321220.734 5814072.447)
# 4                        POINT (321272.049 5814137.476)
# ...                                                 ...
# 2375  POLYGON ((320637.296 5814510.471, 320647.393 5...
# 2376  POLYGON ((320778.428 5814047.124, 320780.211 5...
# 2377  POLYGON ((321255.627 5814355.303, 321255.375 5...
# 2378  MULTIPOLYGON (((321219.805 5813634.926, 321210...
# 2379  MULTIPOLYGON (((320414.684 5813964.264, 320412...
#
# [2380 rows x 9 columns]

# %%
test_row_id = 6
test_row = test_case_gdf.loc[test_row_id]
test_row
# Out:
# title                                          7. Medley Hall
# summary     Built in 1893 as a private residence, the buil...
# lat                                                -37.805803
# lng                                                144.967618
# geometry         POINT (321083.33274179127 5813785.590421503)
# Name: 6, dtype: object

# %%
test_case_pois.loc[test_row.geometry.distance(test_case_pois.geometry) < 100]
# Out:
#         id element_type      osmid                           name  \
# 2153  2153          way  265141186  Lygon Street Christian Chapel
# 2231  2231          way  710777495                            nan
# 2232  2232          way  710777496                            nan
# 2254  2254          way  743141724                            nan
# 2283  2283          way  831017470                            nan
# 2284  2284          way  831017484                            nan
# 2285  2285          way  831017485                            nan
#
#                amenity natural leisure  \
# 2153  place_of_worship     nan     nan
# 2231           parking     nan     nan
# 2232           parking     nan     nan
# 2254           parking     nan     nan
# 2283           parking     nan     nan
# 2284           parking     nan     nan
# 2285           parking     nan     nan
#
#                                               full_name  \
# 2153  Lygon Street Christian Chapel amenity place of...
# 2231  amenity parking McDonald Lane  Carltonaccess p...
# 2232  amenity parking Elm Tree Place  Carltonaccess ...
# 2254  amenity parking McDonald Lane  Carltonaccess c...
# 2283  amenity parking Hudson Place  Carltonaccess pr...
# 2284  amenity parking Trades Hall Place  Carltonacce...
# 2285  amenity parking Trades Hall Place  Carltonacce...
#
#                                                geometry
# 2153  POLYGON ((321008.928 5813761.985, 320994.084 5...
# 2231  POLYGON ((321000.885 5813812.657, 320997.612 5...
# 2232  POLYGON ((321135.119 5813776.077, 321133.814 5...
# 2254  POLYGON ((320978.251 5813859.025, 321001.671 5...
# 2283  POLYGON ((321146.543 5813801.593, 321159.873 5...
# 2284  POLYGON ((321003.601 5813711.301, 321007.125 5...
# 2285  POLYGON ((321009.308 5813760.340, 321010.362 5...

# %%
# missing tags - tourisms * - historic * - monument *

# %%
# geocoding results for all POIs
titles = [pt for pt in data_structure['poi_title']]

# %%
geocoder = Nominatim(user_agent='research_app')

# %%
paths[test_case_idx]
# Out:
# {'min_lat': -37.80922028,
#  'max_lat': -37.79740113,
#  'min_lng': 144.96275961,
#  'max_lng': 144.97345358}

# %%
result = geocoder.geocode("Medley Hall", viewbox=[(paths[test_case_idx]['max_lat'], paths[test_case_idx]['max_lng']), 
                                                         (paths[test_case_idx]['min_lat'], paths[test_case_idx]['min_lng'])],
                          bounded=True)

# %%
result
# Out:
# Location(Medley Hall, 48-56, Drummond Street, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia, (-37.80576115, 144.9679888773678, 0.0))

# %%
def geocode_by_name(name, path):
    name = name.lstrip('0123456789.- ')
    return geocoder.geocode(name, viewbox=[(path['max_lat'], path['max_lng']), 
                                                         (path['min_lat'], path['min_lng'])],
                          bounded=True)

# %%
if os.path.isfile('dataset/nominatim-geocoding.json'):
    with open('dataset/nominatim-geocoding.json') as fp:
        nominatim_output = json.load(fp)
     
    print('nominatim dump file is already loaded')
else:
    geocoding_results = []
    for idx, path in enumerate(paths):
        record = dataset[idx]
        for poi in record['pois']:
            name = poi['title']
            result = geocode_by_name(name, path)
            geocoding_results.append(result)
            if result is not None:
                print(name, path)
        if idx%10 == 0:
            time.sleep(1)
            print('idx: {}'.format(idx))

    nominatim_output = {}
    counter = 0
    for idx, path in enumerate(paths):
        record = dataset[idx]
        for poi in record['pois']:
            geocoding_result = geocoding_results[counter]
        
            name = poi['title']
            description = poi['summary']
            lat = poi['lat']
            lng = poi['lng']

            nominatim_output[counter] = {'walk_id': idx, 'title': name, 'summary': description, 'lat': lat, 'lng': lng}
            if geocoding_result is not None:
                nominatim_output[counter]['osm'] = geocoding_result.raw
            else:
                nominatim_output[counter]['osm'] = None
            counter += 1
# Out:
# nominatim dump file is already loaded

# %%
nominatim_output
# Out:
# {'0': {'walk_id': 1,
#   'title': 'Fairhaven Surf Life Saving Club',
#   'summary': 'Fairhaven is a well known surf beach. The beach is patrolled during December to the Easter. The Fairhaven SLSC was established in 1958.',
#   'lat': -38.46875894,
#   'lng': 144.08445884,
#   'osm': None},
#  '1': {'walk_id': 1,
#   'title': 'Beach walk',
#   'summary': 'From Sprout Creek, Eastern View, Moggs Creek, Fairhaven to the bottom of the light house there is approx 6 km of beach, featuring rolling surf and spectacular views of the Otway Ranges and Lorne.',
#   'lat': -38.46854155,
#   'lng': 144.08969344,
#   'osm': None},
#  '2': {'walk_id': 1,
#   'title': 'Rock pools',
#   'summary': 'See what sort of shells and stones you can collect. Can you find a bright red sea star? You can see all sorts of sea vegetation, small fish and crabs. Look at the bird life, gulls and cormorants.',
#   'lat': -38.4684592,
#   'lng': 144.09241977,
#   'osm': None},
#  '3': {'walk_id': 1,
#   'title': 'Sand dunes',
#   'summary': 'The beautiful rolling sand dunes shape the beach. 2011 has seen significant erosion due to winter storms that have bought strong winds and big waves (up to 10 feet).',
#   'lat': -38.46841795,
#   'lng': 144.09531794,
#   'osm': None},
#  '4': {'walk_id': 1,
#   'title': 'Painkalac Creek',
#   'summary': 'The creek separates Aireys Inlet from Fairhaven and forms an inlet behind the sand dunes before it cuts through to the ocean. A great place to shelter from the wind and for younger children to swim.',
#   'lat': -38.46838956,
#   'lng': 144.09731206,
#   'osm': None},
#  '5': {'walk_id': 1,
#   'title': 'Rocks and caves under the light house',
#   'summary': 'There are more rockpools and rocky outcrops to explore under the light house. This area is part of the marine national park. This means that all wildlife is protected and cannot be removed.',
#   'lat': -38.46882153,
#   'lng': 144.10086059,
#   'osm': None},
#  '6': {'walk_id': 1,
#   'title': 'Aireys Inlet playground and picnic ground',
#   'summary': 'There is small skateboard ramp for children to ride their scooters or skateboards. There are also swings and other play equipment for children and a picnic area.',
#   'lat': -38.46619881,
#   'lng': 144.09877169,
#   'osm': None},
#  '7': {'walk_id': 1,
#   'title': 'Aireys Inlet lower shops',
#   'summary': 'Pick up a coffee, newspaper or Fish and Chips! To the left of the shops, on the other side of the river, kangaroos can be seen in the early morning or at dusk.',
#   'lat': -38.46553592,
#   'lng': 144.09880054,
#   'osm': None},
#  '8': {'walk_id': 1,
#   'title': 'Loutit Bay lookout',
#   'summary': 'Return to Painkalac Creek inlet and walk to the grassed area on the left. At the light house bollard turn right and walk up the signed (steep) walking track. Enjoy panaromic views on your walk up.',
#   'lat': -38.46791596,
#   'lng': 144.10343538,
#   'osm': {'place_id': 16991282,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'node',
#    'osm_id': 3621405496,
#    'lat': '-38.4681858',
#    'lon': '144.1024762',
#    'class': 'tourism',
#    'type': 'viewpoint',
#    'place_rank': 30,
#    'importance': 9.99999999995449e-06,
#    'addresstype': 'tourism',
#    'name': 'Loutit Bay Lookout',
#    'display_name': 'Loutit Bay Lookout, Surf Coast Walk, Aireys Inlet, Surf Coast Shire, Victoria, 3231, Australia',
#    'boundingbox': ['-38.4682358',
#     '-38.4681358',
#     '144.1024262',
#     '144.1025262']}},
#  '9': {'walk_id': 1,
#   'title': 'Historical homestead and building',
#   'summary': 'At the lighthouse is the original homestead for the lighthouse keeper. The Aireys Inlet area was first settled in the 1840s. The first tourists arrived in 1919.',
#   'lat': -38.46804821,
#   'lng': 144.10383193,
#   'osm': None},
#  '10': {'walk_id': 1,
#   'title': 'Split Point Lighthouse',
#   'summary': 'Follow the signs and continue up the walking track. Shipping along the Victorian coast was much safer once the combination of this and other lighthouses at Cape Otway and Point Lonsdale were built.',
#   'lat': -38.46811382,
#   'lng': 144.10402869,
#   'osm': None},
#  '11': {'walk_id': 2,
#   'title': '1. Tramway signal box',
#   'summary': 'Built in 1928 soon after the electrification of the Swanston St and St Kilda Rd cable tramways. Originally included female public toilets, roofed passenger waiting area, small store and staff toilets.',
#   'lat': -37.80695293,
#   'lng': 144.96281264,
#   'osm': None},
#  '12': {'walk_id': 2,
#   'title': '2. City Baths',
#   'summary': 'Built in 1903, the design reflected the social conventions of the time. Men and women were segregated for all facilities; second class baths were in the basement, first class on the main floor. ',
#   'lat': -37.80738194,
#   'lng': 144.96299006,
#   'osm': {'place_id': 17615927,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 26564416,
#    'lat': '-37.80710775',
#    'lon': '144.96329504904304',
#    'class': 'leisure',
#    'type': 'sports_centre',
#    'place_rank': 30,
#    'importance': 0.1708812954247281,
#    'addresstype': 'leisure',
#    'name': 'Melbourne City Baths',
#    'display_name': 'Melbourne City Baths, Victoria Street, East End Theatre District, Melbourne, City of Melbourne, Victoria, 3000, Australia',
#    'boundingbox': ['-37.8072635',
#     '-37.8068026',
#     '144.9629880',
#     '144.9640602']}},
#  '13': {'walk_id': 2,
#   'title': '3. Magistrates Court',
#   'summary': 'Built on the site of the earlier Supreme Court, the building retains fittings from the earlier court including the Gothic canopy that judge Sir Redmond Barry sat under during Ned Kelly trial in 1880.',
#   'lat': -37.80882759,
#   'lng': 144.96611185,
#   'osm': None},
#  '14': {'walk_id': 2,
#   'title': '4. Old Melbourne Gaol',
#   'summary': 'Built between 1851 - 1864. As the oldest surviving penal establishment, it was the site where Ned Kelly was imprisoned, executed and buried, amongst many other criminals.',
#   'lat': -37.80756873,
#   'lng': 144.96571024,
#   'osm': {'place_id': 17681983,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 26564392,
#    'lat': '-37.80781855',
#    'lon': '144.96526819735215',
#    'class': 'tourism',
#    'type': 'attraction',
#    'place_rank': 30,
#    'importance': 0.35295936752470625,
#    'addresstype': 'tourism',
#    'name': 'Old Melbourne Gaol',
#    'display_name': 'Old Melbourne Gaol, 377, Russell Street, East End Theatre District, Melbourne, City of Melbourne, Victoria, 3000, Australia',
#    'boundingbox': ['-37.8079826',
#     '-37.8076406',
#     '144.9647851',
#     '144.9654652']}},
#  '15': {'walk_id': 2,
#   'title': '5. Eight Hour Day Monument',
#   'summary': 'Built in 1923, the monument commemorates the Eight Hour Day movement started by stonemasons in 1856 to improve working conditions - eight hours labour, eight hours rest and eight hours recreation.',
#   'lat': -37.8071259,
#   'lng': 144.965808,
#   'osm': None},
#  '16': {'walk_id': 2,
#   'title': '6. Trades Hall',
#   'summary': 'Built in stages from 1873 - 1926, Trades Hall is of historical and social significance as a centre of radical and working class politics and activism in Victoria for over 100 years.',
#   'lat': -37.80690503,
#   'lng': 144.96598933,
#   'osm': {'place_id': 17644820,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 32710391,
#    'lat': '-37.8064311',
#    'lon': '144.9664008365221',
#    'class': 'building',
#    'type': 'yes',
#    'place_rank': 30,
#    'importance': 0.21360161928091015,
#    'addresstype': 'building',
#    'name': 'Victorian Trades Hall',
#    'display_name': 'Victorian Trades Hall, 54, Victoria Street, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia',
#    'boundingbox': ['-37.8068946',
#     '-37.8059780',
#     '144.9661460',
#     '144.9667004']}},
#  '17': {'walk_id': 2,
#   'title': '7. Medley Hall',
#   'summary': "Built in 1893 as a private residence, the building has since housed the Italian Club, Italian Consulate and for short time was used for a 'less reputable purpose'. ",
#   'lat': -37.80580276,
#   'lng': 144.96761773,
#   'osm': {'place_id': 369250915,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 435967756,
#    'lat': '-37.80576115',
#    'lon': '144.9679888773678',
#    'class': 'building',
#    'type': 'residential',
#    'place_rank': 30,
#    'importance': 0.22735449175290195,
#    'addresstype': 'building',
#    'name': 'Medley Hall',
#    'display_name': 'Medley Hall, 48-56, Drummond Street, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia',
#    'boundingbox': ['-37.8059463',
#     '-37.8055910',
#     '144.9678002',
#     '144.9681965']}},
#  '18': {'walk_id': 2,
#   'title': '8. Lygon shop corner',
#   'summary': 'Lygon Buildings is architecturally significant as the largest and most intact terrace of nineteenth century shops in Melbourne. There are no other comparable retail structures in Melbourne.',
#   'lat': -37.80486328,
#   'lng': 144.96627867,
#   'osm': None},
#  '19': {'walk_id': 2,
#   'title': '9. Matthais House',
#   'summary': 'A two storeyed stucco faced bluestone house of 1865-6 with many charming and unusual features - a tower and weathervane, a cantilevered cast iron balcony and delicately glazed arched windows.',
#   'lat': -37.80382667,
#   'lng': 144.96775921,
#   'osm': None},
#  '20': {'walk_id': 2,
#   'title': '10. Sacred Heart Catholic Church',
#   'summary': "Built in 1855-56. In the 1930s and 1940s the Church of the Sacred Heart became a primary focus for Carlton's Italian community, and this continued into the 1960s.",
#   'lat': -37.80305114,
#   'lng': 144.96937767,
#   'osm': None},
#  '21': {'walk_id': 2,
#   'title': '11. IMAX Theatre',
#   'summary': "IMAX is the world's largest cinema format, with a screen up to eight storeys high. Films, from documentaries to latest release movies, can be experienced in 2D or 3D.",
#   'lat': -37.80337052,
#   'lng': 144.96961626,
#   'osm': None},
#  '22': {'walk_id': 2,
#   'title': '12. Melbourne Museum',
#   'summary': 'The museum has eight galleries, including one just for children. Highlights include a complete skeleton of a blue whale, the Bunjilaka Aboriginal Cultural Centre, a living rainforest and Phar Lap.',
#   'lat': -37.80367352,
#   'lng': 144.96956388,
#   'osm': {'place_id': 17611003,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 4817074,
#    'lat': '-37.80322985',
#    'lon': '144.97234880717411',
#    'class': 'tourism',
#    'type': 'museum',
#    'place_rank': 30,
#    'importance': 0.379989495490236,
#    'addresstype': 'tourism',
#    'name': 'Melbourne Museum',
#    'display_name': 'Melbourne Museum, 11, Nicholson Street, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia',
#    'boundingbox': ['-37.8038879',
#     '-37.8025869',
#     '144.9703120',
#     '144.9730882']}},
#  '23': {'walk_id': 2,
#   'title': '13. Royal Exhibition Building',
#   'summary': 'The Royal Exhibition Building is the only surviving Great Hall that once housed a 19th-century international exhibition and is still used for exhibitions. ',
#   'lat': -37.80513488,
#   'lng': 144.97123539,
#   'osm': {'place_id': 17546919,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 4817059,
#    'lat': '-37.804666850000004',
#    'lon': '144.9714669305319',
#    'class': 'historic',
#    'type': 'building',
#    'place_rank': 30,
#    'importance': 0.39044459367468287,
#    'addresstype': 'historic',
#    'name': 'Royal Exhibition Building',
#    'display_name': 'Royal Exhibition Building, 9, Nicholson Street, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia',
#    'boundingbox': ['-37.8051500',
#     '-37.8041865',
#     '144.9705305',
#     '144.9724671']}},
#  '24': {'walk_id': 2,
#   'title': '14. Carlton Gardens',
#   'summary': 'Developed in 19th-century Gardenesque style, the Gardens feature symmetrically-placed garden beds, significant avenues, the path system, specimen and clusters of trees, 2 small lakes and 3 fountains.',
#   'lat': -37.80562954,
#   'lng': 144.97138546,
#   'osm': {'place_id': 17689989,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 6614802,
#    'lat': '-37.80624775',
#    'lon': '144.97123179005268',
#    'class': 'leisure',
#    'type': 'park',
#    'place_rank': 24,
#    'importance': 0.4080931175367518,
#    'addresstype': 'park',
#    'name': 'Carlton Gardens',
#    'display_name': 'Carlton Gardens, East End Theatre District, Carlton, Melbourne, City of Melbourne, Victoria, 3000, Australia',
#    'boundingbox': ['-37.8075948',
#     '-37.8008940',
#     '144.9690310',
#     '144.9741029']}},
#  '25': {'walk_id': 2,
#   'title': '15. Playground',
#   'summary': 'Wonderful playground with swings, slides and many opportunities to climb and clamber, plus small hills to roll down!',
#   'lat': -37.80250522,
#   'lng': 144.97069999,
#   'osm': None},
#  '26': {'walk_id': 2,
#   'title': '16. Carlton Gardens Primary School',
#   'summary': 'The school is an Italian Gothic style building built in 1884 with a hipped roof central pavilion buttressed either end by slightly projecting gables.',
#   'lat': -37.80193764,
#   'lng': 144.96962474,
#   'osm': {'place_id': 17331284,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 30066634,
#    'lat': '-37.80194335',
#    'lon': '144.96929402743143',
#    'class': 'amenity',
#    'type': 'school',
#    'place_rank': 30,
#    'importance': 0.1626514353057295,
#    'addresstype': 'amenity',
#    'name': 'Carlton Gardens Primary School',
#    'display_name': 'Carlton Gardens Primary School, 201-231, Rathdowne Street, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia',
#    'boundingbox': ['-37.8022553',
#     '-37.8016314',
#     '144.9689812',
#     '144.9696069']}},
#  '27': {'walk_id': 2,
#   'title': '17. Terrace Houses (201 - 205 Drummond Street)',
#   'summary': 'Built in 1884, Holcombe Terrace is a fine example of boom style terrace architecture and notable among the works of Norman Hitchcock.',
#   'lat': -37.80089591,
#   'lng': 144.96833986,
#   'osm': None},
#  '28': {'walk_id': 2,
#   'title': '18. Museo Italiano',
#   'summary': 'Museo Italiano displays and interprets the experience of Italian migration, and the culture created by Italians in Australia.',
#   'lat': -37.79881302,
#   'lng': 144.96813606,
#   'osm': {'place_id': 17581463,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'node',
#    'osm_id': 6515021014,
#    'lat': '-37.7989059',
#    'lon': '144.968043',
#    'class': 'tourism',
#    'type': 'museum',
#    'place_rank': 30,
#    'importance': 9.99999999995449e-06,
#    'addresstype': 'tourism',
#    'name': 'Museo Italiano',
#    'display_name': 'Museo Italiano, 199, Faraday Street, Little Italy, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia',
#    'boundingbox': ['-37.7989559',
#     '-37.7988559',
#     '144.9679930',
#     '144.9680930']}},
#  '29': {'walk_id': 2,
#   'title': '19. La Mama Theatre',
#   'summary': 'Built in 1883, the building was used for various industrial purposes. In 1967, it was leased by Betty Burstall, teacher and theatre-lover, for use as a small theatre to nurture new Australian drama.',
#   'lat': -37.79875344,
#   'lng': 144.96765164,
#   'osm': {'place_id': 17638475,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'node',
#    'osm_id': 331165028,
#    'lat': '-37.7990994',
#    'lon': '144.9676917',
#    'class': 'amenity',
#    'type': 'theatre',
#    'place_rank': 30,
#    'importance': 0.2940287400552381,
#    'addresstype': 'amenity',
#    'name': 'La Mama Theatre',
#    'display_name': 'La Mama Theatre, 205, Faraday Street, Little Italy, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia',
#    'boundingbox': ['-37.7991494',
#     '-37.7990494',
#     '144.9676417',
#     '144.9677417']}},
#  '30': {'walk_id': 2,
#   'title': '19. Underground public toilets',
#   'summary': 'The underground public toilets, built in 1939, are one of eleven built in Melbourne in response to public demand for public toilet facilities in Melbourne that were both sanitary and discreet.',
#   'lat': -37.7987245,
#   'lng': 144.9674163,
#   'osm': None},
#  '31': {'walk_id': 2,
#   'title': '21. 313-315 Drummond Street',
#   'summary': 'Built in 1889, the buliding is architecturally significant for its highly unusual grotesque Gothic facade. The kangaroo-gryphon grotesques on the parapet are highly unusual and distinctive.',
#   'lat': -37.79842454,
#   'lng': 144.9687503,
#   'osm': {'place_id': 17674429,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 1123830491,
#    'lat': '-37.7985566',
#    'lon': '144.9687403',
#    'class': 'highway',
#    'type': 'residential',
#    'place_rank': 26,
#    'importance': 0.10000999999999993,
#    'addresstype': 'road',
#    'name': 'Drummond Street',
#    'display_name': 'Drummond Street, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia',
#    'boundingbox': ['-37.7987658',
#     '-37.7984704',
#     '144.9687040',
#     '144.9687550']}},
#  '32': {'walk_id': 2,
#   'title': '22. Carlton Court House',
#   'summary': 'The Carlton Court House is historically significant as part of the civic core of Drummond Street. It is directly opposite the 1878 Carlton Police Station. ',
#   'lat': -37.79770339,
#   'lng': 144.96886656,
#   'osm': {'place_id': 17513744,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 668210311,
#    'lat': '-37.7976963',
#    'lon': '144.9686731571162',
#    'class': 'boundary',
#    'type': 'protected_area',
#    'place_rank': 25,
#    'importance': 0.12500999999999995,
#    'addresstype': 'protected_area',
#    'name': 'Carlton Court House Historic Reserve',
#    'display_name': 'Carlton Court House Historic Reserve, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia',
#    'boundingbox': ['-37.7977901',
#     '-37.7975994',
#     '144.9685467',
#     '144.9688001']}},
#  '33': {'walk_id': 3,
#   'title': 'The Mildura Wharf',
#   'summary': 'Mildura Wharf has been a vital part of the town and inland river transport system since the 1880s. It was established by the Mildura Progress Committee in 1888 to assist the burgeoning river trade.',
#   'lat': -34.1831733,
#   'lng': 142.16634149,
#   'osm': None},
#  '34': {'walk_id': 3,
#   'title': 'Railway overpass',
#   'summary': 'A short walk across the railway overpass leads to Deakin Ave or head left down to the Hugh King Drive underpass to avoid the stairs.',
#   'lat': -34.18308684,
#   'lng': 142.16521185,
#   'osm': None},
#  '35': {'walk_id': 3,
#   'title': 'Prince and Princess of Wales Fountain Plaza',
#   'summary': 'This fountain is very special as it was opened by the Prince and Princess of Wales on the 29th October 1985. Many Mildura residence crowded around to see the Princess Diana.',
#   'lat': -34.18332571,
#   'lng': 142.16467286,
#   'osm': None},
#  '36': {'walk_id': 3,
#   'title': 'War Memorial ',
#   'summary': 'To the left is a War Memorial commemorating those who served in Vietnam, Korea\nand South East Asia.',
#   'lat': -34.18334912,
#   'lng': 142.16461225,
#   'osm': None},
#  '37': {'walk_id': 3,
#   'title': 'Sculpture commemorating Alfred Deakin, Primie Minister of Australia and the initiator of the Mildura',
#   'summary': 'Sculpted by Michael Meszaros and presented to the city to mark the centenary of the irrigation colony in 1987. The memorial represents  fruit blocks and irrigation channels as seen from the air. ',
#   'lat': -34.1833602,
#   'lng': 142.16458121,
#   'osm': None},
#  '38': {'walk_id': 3,
#   'title': 'The Grand Hotel (to the right)',
#   'summary': 'Enter the Grand Hotel’s main entrance and turn left. To your right, you will see a display of historical photos. Through the glass doors are one of Mildura’s original Chaffey fountains.',
#   'lat': -34.18351713,
#   'lng': 142.1641636,
#   'osm': None},
#  '39': {'walk_id': 3,
#   'title': 'Commodore Motel former site of the Warren boarding house',
#   'summary': 'Back in 1888, this site was a early boarding house called the Warren. A plaque marking the site can be found at the entrance to the motel’s restaurant. The Warren was demolished in 1965.\n',
#   'lat': -34.18392536,
#   'lng': 142.16451843,
#   'osm': None},
#  '40': {'walk_id': 3,
#   'title': 'WIN TV',
#   'summary': 'Originally STV8, opening in 1966 and next door is the Sunraysia Daily, the local newspaper.\n',
#   'lat': -34.184552,
#   'lng': 142.16377931,
#   'osm': None},
#  '41': {'walk_id': 3,
#   'title': 'The Cultivator',
#   'summary': 'Mildura’s earliest newspaper was the Cultivator, begun in 1888. It was a\ntwice-weekly publication that moved to the current Sunraysia Daily site at\n22 Deakin Avenue in 1912.',
#   'lat': -34.18457895,
#   'lng': 142.16374769,
#   'osm': None},
#  '42': {'walk_id': 3,
#   'title': 'Sunraysia Daily',
#   'summary': 'Local identity, C.J De Garis bought The Cultivator along with the Mildura\nTelegraph and Merbein Irrigationist and merged them into one paper, the\nSunraysia Daily, in 1920.',
#   'lat': -34.18459018,
#   'lng': 142.16373453,
#   'osm': {'place_id': 16755843,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 686511908,
#    'lat': '-34.18460785',
#    'lon': '142.16416188135207',
#    'class': 'office',
#    'type': 'newspaper',
#    'place_rank': 30,
#    'importance': 9.99999999995449e-06,
#    'addresstype': 'office',
#    'name': 'Sunraysia Daily',
#    'display_name': 'Sunraysia Daily, Midgley Lane, Mildura, Rural City of Mildura, Victoria, 3500, Australia',
#    'boundingbox': ['-34.1847835',
#     '-34.1843766',
#     '142.1638680',
#     '142.1643746']}},
#  '43': {'walk_id': 3,
#   'title': 'George and William Chaffey Building',
#   'summary': 'Across the road is a single story late Victorian, red brick building, with\na brick and iron palisade fence. The building was gifted to La Trobe Uni in 2009 by Don Carrazza.',
#   'lat': -34.18467124,
#   'lng': 142.16363945,
#   'osm': None},
#  '44': {'walk_id': 3,
#   'title': 'Electric Supply Department Substation No.1',
#   'summary': 'In the centre plantation, stands the Electric Supply Department Substation No.1, dating back to 1936, when the production of electricity was considered a local responsibility, rather than a state one.',
#   'lat': -34.18488305,
#   'lng': 142.16339103,
#   'osm': None},
#  '45': {'walk_id': 3,
#   'title': 'Queen Elizabeth II visit to Mildura, March 25th, 1954',
#   'summary': 'When Queen Elizabeth toured Mildura in 1954, a decorative dais was erected in this area of the plantation.  Pics of this day are displayed at the Carnegie Centre. Visit to Barclays Block in Red Cliffs',
#   'lat': -34.18503122,
#   'lng': 142.16321607,
#   'osm': None},
#  '46': {'walk_id': 3,
#   'title': "Bowring's Store, corner Deakin Avenue and 8th Street - Circa 1937",
#   'summary': 'The site of the ANZ Bank was previously known as Bowring Corner and was the site of Bowring’s Store, opened in 1888. It extended into Langtree Avenue in 1961 but ceased business two decades later.\n',
#   'lat': -34.18505972,
#   'lng': 142.16272952,
#   'osm': None},
#  '47': {'walk_id': 3,
#   'title': 'Old Mildura Post Office (LHS of Deakin Ave)',
#   'summary': 'This corner building was for over a century, the Mildura Post Office. The earliest Post Office on this site was built in 1890, with much of the current building being erected in 1923. ',
#   'lat': -34.18539044,
#   'lng': 142.1627847,
#   'osm': None},
#  '48': {'walk_id': 3,
#   'title': 'George V Memorial Fountain (in centre plantation)',
#   'summary': 'Crossing into the centre plantation, you will find the George V Memorial Fountain, originally erected in the gardens of the Rio Vista, home of W.B Chaffey, it was moved to its current position in 1936',
#   'lat': -34.18544392,
#   'lng': 142.16272763,
#   'osm': None},
#  '49': {'walk_id': 3,
#   'title': 'Mildura Law Courts (LHS of Deakin Ave)',
#   'summary': 'Opened by Robert Hulls, Victoria’s Attorney General, on Nov 23 2004. This complex was built on the site that began as Washington Stores, before becoming Maples, before it all went up in flames in 1996',
#   'lat': -34.18576121,
#   'lng': 142.16236065,
#   'osm': None},
#  '50': {'walk_id': 3,
#   'title': '70 Deakin Avenue (LHS of Deakin Ave)',
#   'summary': 'Once the site of the Shire Offices, beginning as a modest, timber, two roomed building before the current building was erected in 1922. In 1971, the Shire Offices were relocated to Irymple. ',
#   'lat': -34.18614633,
#   'lng': 142.16188736,
#   'osm': None},
#  '51': {'walk_id': 3,
#   'title': 'Carnegie Centre - Home to the Historical and Genealogical Societies (LHS of Deakin Ave)',
#   'summary': 'Constructed in 1908, as the Carnegie Library, courtesy of a 2000 pound grant made by Andrew Carnegie, in 1906, after a request from Lord Hopetoun. The tower was added in 1922 as a soldier memorial.',
#   'lat': -34.186245,
#   'lng': 142.16176521,
#   'osm': None},
#  '52': {'walk_id': 3,
#   'title': 'Civic Buildings  (LHS of Deakin Ave)',
#   'summary': 'The Civic Buildings, opened in 1958 and it’s also the site of the original Shire Hall, also known as the Mildura Town Hall.',
#   'lat': -34.18656212,
#   'lng': 142.16137632,
#   'osm': None},
#  '53': {'walk_id': 3,
#   'title': 'Statue of W.B. Chaffey (in center  plantation)',
#   'summary': 'In the center  plantation is a statue of W.B. Chaffey, who died in 1926. The Paul Mountford sculpture was unveiled in 1929. A similar sculpture can be found in Renmark, SA. ',
#   'lat': -34.18670405,
#   'lng': 142.16120554,
#   'osm': None},
#  '54': {'walk_id': 3,
#   'title': 'Desailly Rotunda (in center  plantation)',
#   'summary': 'The centre  plantation is home to the Desailly Rotunda, named for Cr George Desailly, former Shire President, who died whilst in office in 1913.',
#   'lat': -34.18660603,
#   'lng': 142.16132206,
#   'osm': None},
#  '55': {'walk_id': 3,
#   'title': "61 Deakin Ave - Mildura's earliest surviving building (RHS of Deakin Ave)",
#   'summary': 'On the RHS of Deakin Ave is the earliest surviving building in Mildura. It started out as Mildura’s first general store, owned by H.B Williams, in 1887. A bank altered the building appearance in 1937.',
#   'lat': -34.18604765,
#   'lng': 142.1620095,
#   'osm': None},
#  '56': {'walk_id': 3,
#   'title': '69 Deakin Ave (RHS of Deakin Ave)',
#   'summary': 'Built in 1914, this  Edwardian building has been a restaurant, a bank, a real estate agency and other businesses, which although altered over the years, still retains some of its original charm.\n',
#   'lat': -34.18629834,
#   'lng': 142.16170105,
#   'osm': None},
#  '57': {'walk_id': 3,
#   'title': 'Mildura Club (RHS of Deakin Ave)',
#   'summary': 'The Mildura "Gentlemen\'s Club" began in 1890 with Lord Ranfurly as the first President. Meetings were originally held at the Coffee Palace, until this building was completed in 1920. ',
#   'lat': -34.18682464,
#   'lng': 142.16109258,
#   'osm': None},
#  '58': {'walk_id': 3,
#   'title': 'Deakin Cinema Complex  (RHS of Deakin Ave)',
#   'summary': 'The Deakin Cinema complex was  established in 1975. A point of interest is that the cinema includes the original site of the Masonic Temple, built in 1907, with the façade still remaining. ',
#   'lat': -34.18717927,
#   'lng': 142.16062025,
#   'osm': None},
#  '59': {'walk_id': 3,
#   'title': 'Mildura Workingmans Club (LHS of Deakin Ave)',
#   'summary': 'An iconic landmark, once famous for having the world’s longest bar (which was removed in recent renovations.). Begun in 1908, it was originally a 1 story structure with a 2nd level added in 1935. ',
#   'lat': -34.18744262,
#   'lng': 142.1602677,
#   'osm': None},
#  '60': {'walk_id': 3,
#   'title': 'Mildura Workingmans Club  War Memorial (LHS of Deakin Ave)',
#   'summary': 'Has stood at the front of the club, since 1920, honoring Mildura’s war dead. The marble soldier is the work of A.D Thomson and the three-sided list of soldiers’ names underpins the heavy losses of WW1',
#   'lat': -34.18746532,
#   'lng': 142.16024187,
#   'osm': None},
#  '61': {'walk_id': 3,
#   'title': 'Methodist Church (LHS of Deakin Ave)',
#   'summary': 'Opened in 1912, this unique church had a number of architectural influences, including Byzantine, Queen Anne, Masonic and Art Nouveau . Image: Methodist Church under construction 1911.',
#   'lat': -34.18831339,
#   'lng': 142.15927694,
#   'osm': None},
#  '62': {'walk_id': 3,
#   'title': 'The Church of Christ  (RHS of Deakin Ave)',
#   'summary': 'Built in 1908, the Church of Christ was first organised by Reuben Mansell in 1890 and members met in a variety of venues until this building was completed using all voluntary labour. ',
#   'lat': -34.18787876,
#   'lng': 142.15878865,
#   'osm': None},
#  '63': {'walk_id': 3,
#   'title': 'War Memorial (centre plantation)',
#   'summary': 'Commemorates those who died or were killed in World War One. Erected by the Mildura Branch R. S. & S. I. L. A.',
#   'lat': -34.18839149,
#   'lng': 142.15819056,
#   'osm': None},
#  '64': {'walk_id': 3,
#   'title': 'Uniting Church / St Andrew’s  (RHS of Deakin Ave)',
#   'summary': 'The Uniting Church, known as St Andrew’s, started out as a Presbyterian church and was built in 1914, at a cost of 2097 pounds. It replaced a wooden structure that had been there since 1891. ',
#   'lat': -34.18920549,
#   'lng': 142.15729784,
#   'osm': None},
#  '65': {'walk_id': 3,
#   'title': 'St Margaret’s Anglican Church (LSH of Deakin Ave)',
#   'summary': 'This church opened in 1902, with the addition of the sanctuary in 1934 and the vestry and bell tower in 1957 that honours the lost soldiers of World War II.',
#   'lat': -34.18952039,
#   'lng': 142.15768978,
#   'osm': None},
#  '66': {'walk_id': 3,
#   'title': 'Madden Avenue ',
#   'summary': 'Madden Ave was originally planned to be the principal retail district of Mildura due to easy access to the wharf. However,  Langtree, with it’s proximity to the railway proved to be more significant',
#   'lat': -34.19026169,
#   'lng': 142.15861732,
#   'osm': {'place_id': 16812379,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 1160145426,
#    'lat': '-34.1846268',
#    'lon': '142.1654735',
#    'class': 'highway',
#    'type': 'residential',
#    'place_rank': 26,
#    'importance': 0.10000999999999993,
#    'addresstype': 'road',
#    'name': 'Madden Avenue',
#    'display_name': 'Madden Avenue, Mildura, Rural City of Mildura, Victoria, 3500, Australia',
#    'boundingbox': ['-34.1846268',
#     '-34.1845342',
#     '142.1654735',
#     '142.1655323']}},
#  '67': {'walk_id': 3,
#   'title': 'Mildura RSL Sub Branch',
#   'summary': 'The Returned and Services League with some 1500 Sub Branches Australia wide and with a membership of 240,000 is the largest service association in Australia.',
#   'lat': -34.18913686,
#   'lng': 142.15997189,
#   'osm': None},
#  '68': {'walk_id': 3,
#   'title': 'Mildura Water Tower',
#   'summary': "As you cross over 10th street, to your right you will see one of  Mildura's Water Towers. Built in 1957, the tower provides water pressure for thousands of homes across the urban area.",
#   'lat': -34.18891499,
#   'lng': 142.16024011,
#   'osm': None},
#  '69': {'walk_id': 3,
#   'title': 'Mecure Hotel ',
#   'summary': 'Commercial Hotel, commonly remembered as the Wintersun and now the Mecure Hotel was built in 1925',
#   'lat': -34.18593745,
#   'lng': 142.16383964,
#   'osm': None},
#  '70': {'walk_id': 3,
#   'title': 'Disused water tower',
#   'summary': 'Behind the hotel is a disused water tower, which from 1912 until 1957 operated as Mildura’s sole source of water storage. Instigated by the former First Mildura Irrigation Trust. 180000 litre capacity',
#   'lat': -34.18570226,
#   'lng': 142.16412395,
#   'osm': None},
#  '71': {'walk_id': 4,
#   'title': 'Under the Clocks',
#   'summary': "Melbourne's well known and iconic meeting place is under the clocks at Flinders Street Station. Sit on the steps and see the world go by. ",
#   'lat': -37.81775223,
#   'lng': 144.96721165,
#   'osm': None},
#  '72': {'walk_id': 4,
#   'title': 'Mirka Mora mosaic',
#   'summary': 'Mirka Mora made this mosaic in about 1985, it is brilliant. Do not be one of the thousands who walk past it every day without stopping. ',
#   'lat': -37.81867716,
#   'lng': 144.9678153,
#   'osm': None},
#  '73': {'walk_id': 4,
#   'title': 'To Birrarung Marr',
#   'summary': 'The slope down to Birrarung Marr, always fills with expectation. The sculpture of hundreds of red poles is a cracker. Go up and push the poles firmly, what a noise!',
#   'lat': -37.81862957,
#   'lng': 144.96835377,
#   'osm': None},
#  '74': {'walk_id': 4,
#   'title': 'Federation Square',
#   'summary': 'There always seems to be something happening at Fed Square whether it is concerts, buskers, festivals or people lolling about. The pavers are great to sit on on a sunny afternoon. ',
#   'lat': -37.81803095,
#   'lng': 144.96819109,
#   'osm': {'place_id': 17680987,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 1098427843,
#    'lat': '-37.817775499999996',
#    'lon': '144.96918237308262',
#    'class': 'tourism',
#    'type': 'attraction',
#    'place_rank': 30,
#    'importance': 0.37985987946060773,
#    'addresstype': 'tourism',
#    'name': 'Federation Square',
#    'display_name': 'Federation Square, Swanston Street, Melbourne, City of Melbourne, Victoria, 3000, Australia',
#    'boundingbox': ['-37.8187282',
#     '-37.8168338',
#     '144.9676713',
#     '144.9709395']}},
#  '75': {'walk_id': 4,
#   'title': 'The Art Centre from Fed Square',
#   'summary': 'Looking over to the Art Centre spire from Fed Square.',
#   'lat': -37.81826778,
#   'lng': 144.96948266,
#   'osm': None},
#  '76': {'walk_id': 4,
#   'title': 'Birrarung Marr playground',
#   'summary': 'The playground is always open. Watch kids play and enjoy the tube slides, sand pits, swinging hammocks, activity panels, rock and rope climbing features and balance beams.',
#   'lat': -37.81817384,
#   'lng': 144.97133444,
#   'osm': None},
#  '77': {'walk_id': 4,
#   'title': 'Art Play',
#   'summary': 'Art Play is a great place for children it has lots of shows and creative activities for kids.',
#   'lat': -37.81842082,
#   'lng': 144.97142583,
#   'osm': None},
#  '78': {'walk_id': 4,
#   'title': 'Mosaic outside art play',
#   'summary': 'I do not know what the story is behind this brightly coloured mosaic outside Art Play, but it is wonderful. ',
#   'lat': -37.81843198,
#   'lng': 144.97162369,
#   'osm': None},
#  '79': {'walk_id': 4,
#   'title': 'Textured path',
#   'summary': 'The winding, textured pathway of cast iron acknowledges the significance of the eel as a traditional food source for groups camped by the river.',
#   'lat': -37.81842658,
#   'lng': 144.971528,
#   'osm': None},
#  '80': {'walk_id': 4,
#   'title': 'Watching rowers from Birrarung Marr',
#   'summary': 'Sit on the seats under a shady tree watching rowers go by.',
#   'lat': -37.81861151,
#   'lng': 144.97173697,
#   'osm': None},
#  '81': {'walk_id': 4,
#   'title': 'To Princes Bridge',
#   'summary': 'The gravel path on the river bank is a bit quieter. More seats and looking back to Princess Bridge. ',
#   'lat': -37.8186351,
#   'lng': 144.97185557,
#   'osm': None},
#  '82': {'walk_id': 4,
#   'title': 'West along the river',
#   'summary': "From 'Angel' you can get a good look along the Yarra River ",
#   'lat': -37.81896412,
#   'lng': 144.97277994,
#   'osm': None},
#  '83': {'walk_id': 4,
#   'title': 'Angel',
#   'summary': 'Angel (ceramic, steel and concrete) by Deborah Halpern is an artwork commissioned by the National Gallery of Victoria. It is even more impressive than the photo suggests. ',
#   'lat': -37.81895244,
#   'lng': 144.97301726,
#   'osm': {'place_id': 17737906,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'node',
#    'osm_id': 6741658224,
#    'lat': '-37.8189411',
#    'lon': '144.9729364',
#    'class': 'tourism',
#    'type': 'artwork',
#    'place_rank': 30,
#    'importance': 9.99999999995449e-06,
#    'addresstype': 'tourism',
#    'name': 'Angel',
#    'display_name': 'Angel, Capital City Trail Main Yarra Trail, East End Theatre District, Melbourne, City of Melbourne, Victoria, 3000, Australia',
#    'boundingbox': ['-37.8189911',
#     '-37.8188911',
#     '144.9728864',
#     '144.9729864']}},
#  '84': {'walk_id': 4,
#   'title': 'Grassy hill for rolling',
#   'summary': 'There should be more grassy hills like this one in the centre of cities. Watch the number of kids who are immediately drawn to it and roll down laughing.',
#   'lat': -37.81803458,
#   'lng': 144.97380556,
#   'osm': None},
#  '85': {'walk_id': 4,
#   'title': 'Walking up the slope to the bridge',
#   'summary': 'The trees and shrubs set in the stone fence as you walk up the slope to the William Barak bridge. ',
#   'lat': -37.81848684,
#   'lng': 144.97440371,
#   'osm': None},
#  '86': {'walk_id': 4,
#   'title': 'William Barak bridge',
#   'summary': 'A purpose built walking (and cycling) space, William Barak bridge is one of true delights of Melbourne. Beautiful and functional.   ',
#   'lat': -37.81832709,
#   'lng': 144.97679175,
#   'osm': {'place_id': 17652749,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 8038239,
#    'lat': '-37.8182656',
#    'lon': '144.9765041',
#    'class': 'highway',
#    'type': 'cycleway',
#    'place_rank': 27,
#    'importance': 0.07500999999999991,
#    'addresstype': 'road',
#    'name': 'William Barak Bridge',
#    'display_name': 'William Barak Bridge, East End Theatre District, Melbourne, City of Melbourne, Victoria, 3000, Australia',
#    'boundingbox': ['-37.8186320',
#     '-37.8182656',
#     '144.9765041',
#     '144.9797687']}},
#  '87': {'walk_id': 4,
#   'title': 'Listening to Proximities',
#   'summary': 'Proximities is a public art installation commissioned for the 2006 Commonwealth Games.  The stories and songs from 53 Commonwealth nations come out of the many, many speakers across the bridge. ',
#   'lat': -37.81834507,
#   'lng': 144.9769408,
#   'osm': None},
#  '88': {'walk_id': 4,
#   'title': 'Sit and watch Melbourne',
#   'summary': 'Sit on the bridge and look south to the Yarra and Tennis Centre or north to the city and listen to the trains go by underneath.',
#   'lat': -37.81840969,
#   'lng': 144.97780994,
#   'osm': None},
#  '89': {'walk_id': 4,
#   'title': "Off the bridge to the 'G'",
#   'summary': 'Coming off the bridge and walk to the MCG under the shade of magnificent old Elm trees.',
#   'lat': -37.81866569,
#   'lng': 144.98000985,
#   'osm': None},
#  '90': {'walk_id': 4,
#   'title': 'The MCG',
#   'summary': "The MCG, what a collosseum. You don't realise how massive it is until you actually see it. Even if you don't like sport, the sound of the crowd cheering will grab your attention.",
#   'lat': -37.81885613,
#   'lng': 144.98111314,
#   'osm': None},
#  '91': {'walk_id': 4,
#   'title': 'Dennis Lillee',
#   'summary': 'Bronze statues do around the MCG, none more impressive than the great Dennis Lillee.',
#   'lat': -37.81904332,
#   'lng': 144.98187585,
#   'osm': None},
#  '92': {'walk_id': 4,
#   'title': 'Aussie Rules',
#   'summary': 'Statue commemorating the first game of Australian Rules Football said to be played nearby on 7 August 1858.',
#   'lat': -37.81880752,
#   'lng': 144.98220433,
#   'osm': None},
#  '93': {'walk_id': 4,
#   'title': 'Jolimont Station',
#   'summary': 'Its a beautiful the old train bridge. Catch a train (or tram) back to Flinders St or keep going. ',
#   'lat': -37.81648432,
#   'lng': 144.98350297,
#   'osm': {'place_id': 17771516,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 413591726,
#    'lat': '-37.81650195',
#    'lon': '144.9838372088187',
#    'class': 'railway',
#    'type': 'station',
#    'place_rank': 30,
#    'importance': 0.35570776425552836,
#    'addresstype': 'railway',
#    'name': 'Jolimont',
#    'display_name': 'Jolimont, Wellington Parade, East Melbourne, Melbourne, City of Melbourne, Victoria, 3002, Australia',
#    'boundingbox': ['-37.8166744',
#     '-37.8163224',
#     '144.9829825',
#     '144.9846868']}},
#  '94': {'walk_id': 5,
#   'title': "Watt's Cottage",
#   'summary': 'Home to early settlers in Sorrento, this house was built in 1869. The Pioneer Memorial Garden is well tended with blooms all year round. Tours available (at limited times).',
#   'lat': -38.34054845,
#   'lng': 144.73584164,
#   'osm': None},
#  '95': {'walk_id': 5,
#   'title': 'Information boards and cafe',
#   'summary': 'Check out the information boards here for details about the history, local environment and features of the area. All Smiles Cafe located a short walk away from here.',
#   'lat': -38.34551199,
#   'lng': 144.72681889,
#   'osm': None},
#  '96': {'walk_id': 5,
#   'title': "Surf's up",
#   'summary': 'A good spot to watch the surf, have a picnic, go for a swim, read a book or do whatever you please.',
#   'lat': -38.34548235,
#   'lng': 144.72660135,
#   'osm': None},
#  '97': {'walk_id': 5,
#   'title': 'Uphill climb towards the top',
#   'summary': 'Definitely a steep climb uphill but the scenery from the top is very worthwhile. Get your heart rate up!',
#   'lat': -38.34538353,
#   'lng': 144.72625773,
#   'osm': None},
#  '98': {'walk_id': 5,
#   'title': 'Panoramic views',
#   'summary': 'A perfect spot to watch the sunset, or simply enjoy the sweeping panoramic views.',
#   'lat': -38.34505623,
#   'lng': 144.72526604,
#   'osm': None},
#  '99': {'walk_id': 5,
#   'title': 'Heading down to the beach',
#   'summary': 'Follow the track, which will eventually take you towards the beach.',
#   'lat': -38.34316437,
#   'lng': 144.72111073,
#   'osm': None},
#  '100': {'walk_id': 5,
#   'title': 'Fine sandy beach',
#   'summary': 'Enjoy the salty sea breezes as you feel the sand under your feet on this beautiful stretch of coastline. ',
#   'lat': -38.34156282,
#   'lng': 144.71668977,
#   'osm': None},
#  '101': {'walk_id': 5,
#   'title': 'Portsea Surf Lifesaving Club',
#   'summary': 'You can take a detour here if you need a toilet stop.',
#   'lat': -38.33542809,
#   'lng': 144.70425765,
#   'osm': {'place_id': 17095668,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 471789660,
#    'lat': '-38.33488585',
#    'lon': '144.70478867460818',
#    'class': 'building',
#    'type': 'yes',
#    'place_rank': 30,
#    'importance': 9.99999999995449e-06,
#    'addresstype': 'building',
#    'name': 'Portsea Surf Lifesaving Club',
#    'display_name': 'Portsea Surf Lifesaving Club, Back Beach Road, Portsea, Melbourne, Shire of Mornington Peninsula, Victoria, 3943, Australia',
#    'boundingbox': ['-38.3350665',
#     '-38.3347053',
#     '144.7045074',
#     '144.7050700']}},
#  '102': {'walk_id': 5,
#   'title': "'London Bridge'",
#   'summary': "A great spot to explore the rockpools and wander under the 'London Bridge' (but not during high tide of course). You can continue along the beach all the way to Point Nepean if you like.",
#   'lat': -38.33035347,
#   'lng': 144.69404522,
#   'osm': {'place_id': 16619305,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 147610651,
#    'lat': '-38.3280757',
#    'lon': '144.696334',
#    'class': 'highway',
#    'type': 'tertiary',
#    'place_rank': 26,
#    'importance': 0.10000999999999993,
#    'addresstype': 'road',
#    'name': 'London Bridge Road',
#    'display_name': 'London Bridge Road, Portsea, Melbourne, Shire of Mornington Peninsula, Victoria, 3943, Australia',
#    'boundingbox': ['-38.3288501',
#     '-38.3277430',
#     '144.6951016',
#     '144.6979794']}},
#  '103': {'walk_id': 5,
#   'title': 'Public toilets and drinking fountain',
#   'summary': "Phew! It's a pretty steep ramp that leads you up here. A convenient toilet stop and a chance to top up your water bottle before heading off again. ",
#   'lat': -38.3295251,
#   'lng': 144.69499469,
#   'osm': None},
#  '104': {'walk_id': 5,
#   'title': "Start of Wilson's Folly Track",
#   'summary': "There's a sign a near the car park marking the start of the track. Apparently Capt R Wilson simply lit a match wherever he thought the bush needed to be cleared for the army\\'s weapons training areas.",
#   'lat': -38.32825967,
#   'lng': 144.69577002,
#   'osm': None},
#  '105': {'walk_id': 5,
#   'title': 'Looking out to the sea',
#   'summary': 'Listen out for the twitter of small birds in this fabulous bit of coastal bushland overlooking the sea.',
#   'lat': -38.32624464,
#   'lng': 144.69165766,
#   'osm': None},
#  '106': {'walk_id': 5,
#   'title': 'Unexploded bombs',
#   'summary': 'A former weapons training area. "All large unexploded ordinance has been removed but you may come across small arms such as rifle and pistol shells," which of course, you shouldn\'t touch.',
#   'lat': -38.32144469,
#   'lng': 144.69648537,
#   'osm': None},
#  '107': {'walk_id': 5,
#   'title': 'Point Nepean Visitor Centre',
#   'summary': 'The visitor centre has plenty of local information and maps of the area. You can take a tour to the historical Fort Nepean (a buggy can transport you there). Public toilets and BBQ available here.',
#   'lat': -38.31870845,
#   'lng': 144.70297928,
#   'osm': {'place_id': 17008126,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 36897615,
#    'lat': '-38.3188995',
#    'lon': '144.70298929696781',
#    'class': 'tourism',
#    'type': 'information',
#    'place_rank': 30,
#    'importance': 9.99999999995449e-06,
#    'addresstype': 'tourism',
#    'name': 'Point Nepean Visitor Centre',
#    'display_name': 'Point Nepean Visitor Centre, Defence Road, Portsea, Melbourne, Shire of Mornington Peninsula, Victoria, 3943, Australia',
#    'boundingbox': ['-38.3190342',
#     '-38.3187783',
#     '144.7028241',
#     '144.7031502']}},
#  '108': {'walk_id': 5,
#   'title': 'Mighty high fences',
#   'summary': "You can take a short detour down to the beach via Cove Ave. Clearly residents here like their privacy but it's such a shame that the street is marred by these enormously high walls and fences.",
#   'lat': -38.31894485,
#   'lng': 144.70458036,
#   'osm': None},
#  '109': {'walk_id': 5,
#   'title': 'Nature strip plantings',
#   'summary': 'Thankfully, there are patches of wonderful plants to enjoy as you walk down the street.',
#   'lat': -38.31901562,
#   'lng': 144.70505969,
#   'osm': None},
#  '110': {'walk_id': 5,
#   'title': 'A little bit arty',
#   'summary': '... and even a bit of art to give some of these high walls a little bit of character.',
#   'lat': -38.3191189,
#   'lng': 144.70575917,
#   'osm': None},
#  '111': {'walk_id': 5,
#   'title': 'On the other side',
#   'summary': 'Across the road are a row of charming cottages that reminds us of how the area used to look before the high walls and fences came along.',
#   'lat': -38.31923424,
#   'lng': 144.70654032,
#   'osm': None},
#  '112': {'walk_id': 5,
#   'title': 'Bus stop',
#   'summary': 'You can catch bus number 788 back to Sorrento, or all the way back to Frankston along point Nepean Road. ',
#   'lat': -38.31931725,
#   'lng': 144.70710254,
#   'osm': None},
#  '113': {'walk_id': 6,
#   'title': 'Boardwalk near fishing platforms',
#   'summary': 'The boardwalks starts along the path just past the carpark on Lakeside Drive. A few fishing platforms go off the boardwalk.',
#   'lat': -37.54919735,
#   'lng': 149.7570991,
#   'osm': None},
#  '114': {'walk_id': 6,
#   'title': 'Wetlands',
#   'summary': 'The inlet is on one side of the boardwalk and wetlands on the other, both have an abundance of birdlife and aquatic life.',
#   'lat': -37.54939497,
#   'lng': 149.75700563,
#   'osm': None},
#  '115': {'walk_id': 6,
#   'title': 'The shared path',
#   'summary': 'The shared path is very popular with walkers and bike riders alike and is in pretty good condition.',
#   'lat': -37.55145333,
#   'lng': 149.75589918,
#   'osm': None},
#  '116': {'walk_id': 6,
#   'title': 'Pelicans and piers',
#   'summary': 'There are many little jetties dotted along the path and it is hard not to spot a pelican or two perched on many of them.',
#   'lat': -37.55366176,
#   'lng': 149.7536224,
#   'osm': None},
#  '117': {'walk_id': 6,
#   'title': 'Raised boardwalks',
# ...
#   'summary': 'The first free dispensary for women in 1896 was set up here. In the first 3 months the clinic treated 2,000 women and children. This led to the establishment of the Queen Victoria Hospital.',
#   'lat': -37.81072759,
#   'lng': 144.96005122,
#   'osm': None},
#  '956': {'walk_id': 69,
#   'title': 'Republic Tower - corner Queen and LaTrobe Street',
#   'summary': 'Public art where you would normally expect a billboard. Designed by Melbourne architect Nonda Katsilidis, various international artworks have featured here. Cross the street for a close-up.',
#   'lat': -37.81105963,
#   'lng': 144.95894015,
#   'osm': None},
#  '957': {'walk_id': 69,
#   'title': 'Laneway street art',
#   'summary': 'Step into this laneway to see a fantastic public gallery of street art. A hidden treasure trove of quirky, odd and creative pieces guaranteed to raise your eyebrows in surprise and wonder.',
#   'lat': -37.80837336,
#   'lng': 144.95940158,
#   'osm': None},
#  '958': {'walk_id': 69,
#   'title': 'Queen Victoria Market',
#   'summary': 'The Queen Victoria Market, established in 1878 is the largest market in Australia and one of the largest in the world. Many of the buildings are still used in trade today. ',
#   'lat': -37.80638432,
#   'lng': 144.95942469,
#   'osm': {'place_id': 17611364,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 25467961,
#    'lat': '-37.806999399999995',
#    'lon': '144.9569322479119',
#    'class': 'amenity',
#    'type': 'marketplace',
#    'place_rank': 30,
#    'importance': 0.34412427439762555,
#    'addresstype': 'amenity',
#    'name': 'Queen Victoria Market',
#    'display_name': 'Queen Victoria Market, Victoria Street, Melbourne, City of Melbourne, Victoria, 3000, Australia',
#    'boundingbox': ['-37.8080057',
#     '-37.8060326',
#     '144.9558726',
#     '144.9580023']}},
#  '959': {'walk_id': 69,
#   'title': 'WCTU drinking fountain',
#   'summary': 'The fountain was erected in 1901 by the Woman\x9ds Christian Temperance Union who agitated for the provision of clean drinking water in public places as part of its temperance concerns.',
#   'lat': -37.80670318,
#   'lng': 144.95958526,
#   'osm': None},
#  '960': {'walk_id': 70,
#   'title': 'The Beeches Rainforest Walk',
#   'summary': 'Taggarty Cascades is part of a longer network of walks called The Beeches Rainforest Walk. Our 20 minute walk is to the timber footbridge and back, to see the waterfall tumbling down the rocks.',
#   'lat': -37.489306,
#   'lng': 145.84103823,
#   'osm': None},
#  '961': {'walk_id': 70,
#   'title': 'A picnic spot',
#   'summary': "There's a table near the carpark that's perfect for having a picnic if the sun is out. Watch for lyrebirds that are known to frequent the area.",
#   'lat': -37.48948903,
#   'lng': 145.84092557,
#   'osm': None},
#  '962': {'walk_id': 70,
#   'title': 'Fabulous fungi',
#   'summary': 'Keep an eye out for the different varieties of fungi as you descend into the rainforest understorey. ',
#   'lat': -37.48992745,
#   'lng': 145.84058762,
#   'osm': None},
#  '963': {'walk_id': 70,
#   'title': 'Viewing platform',
#   'summary': "There's a viewing point half way down the path that gives you a taste of the rambunctious river that's flowing at your side. Your ears will already know about this. It's very loud.",
#   'lat': -37.49003812,
#   'lng': 145.84047496,
#   'osm': None},
#  '964': {'walk_id': 70,
#   'title': 'A lush staircase',
#   'summary': 'As you descend into the rainforest, take care on the steps in case they are wet or slippery. Admire the lush tree ferns and Myrtle Beech that thrive in this cool dark world.',
#   'lat': -37.49020837,
#   'lng': 145.8403033,
#   'osm': None},
#  '965': {'walk_id': 70,
#   'title': 'Viewing bridge',
#   'summary': 'This timber bridge takes you across the Taggarty River, giving you the perfect viewing platform to watch the waves of fresh water gush beneath your feet. ',
#   'lat': -37.49054889,
#   'lng': 145.84001362,
#   'osm': None},
#  '966': {'walk_id': 70,
#   'title': 'Stunning waterfall',
#   'summary': 'The Taggarty Cascades is an impressive site! Such a steady flow of clear gushing water tumbling over the granite boulders and down into the rainforest below.',
#   'lat': -37.49062976,
#   'lng': 145.84004581,
#   'osm': None},
#  '967': {'walk_id': 71,
#   'title': 'Hooded Orchid',
#   'summary': 'Orchid',
#   'lat': -37.74628599,
#   'lng': 144.27700996,
#   'osm': None},
#  '968': {'walk_id': 71,
#   'title': 'Orchid',
#   'summary': 'Orchid',
#   'lat': -37.7466932,
#   'lng': 144.27975655,
#   'osm': None},
#  '969': {'walk_id': 71,
#   'title': 'Orchid',
#   'summary': 'Orchid',
#   'lat': -37.74302821,
#   'lng': 144.27194595,
#   'osm': None},
#  '970': {'walk_id': 71,
#   'title': 'Boar Gully Camp Ground',
#   'summary': 'Boar Gully',
#   'lat': -37.76772944,
#   'lng': 144.26250458,
#   'osm': None},
#  '971': {'walk_id': 71,
#   'title': 'Grevillea',
#   'summary': 'Grevillea',
#   'lat': -37.74479286,
#   'lng': 144.28310394,
#   'osm': None},
#  '972': {'walk_id': 71,
#   'title': 'Brisbane Ranges National Park',
#   'summary': 'Brisbane Ranges National Park',
#   'lat': -37.75320829,
#   'lng': 144.25932884,
#   'osm': {'place_id': 17703166,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 9216331,
#    'lat': '-37.747618149999994',
#    'lon': '144.2698778160718',
#    'class': 'leisure',
#    'type': 'nature_reserve',
#    'place_rank': 30,
#    'importance': 0.31653158036886236,
#    'addresstype': 'leisure',
#    'name': 'Brisbane Ranges National Park',
#    'display_name': 'Brisbane Ranges National Park, Staughton Vale, City of Greater Geelong, Victoria, Australia',
#    'boundingbox': ['-37.9172798',
#     '-37.7317115',
#     '144.1489128',
#     '144.3258703']}},
#  '973': {'walk_id': 71,
#   'title': 'Brisbane Ranges National Park',
#   'summary': 'Brisbane Ranges National Park',
#   'lat': -37.75062947,
#   'lng': 144.26293373,
#   'osm': {'place_id': 17703166,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 9216331,
#    'lat': '-37.747618149999994',
#    'lon': '144.2698778160718',
#    'class': 'leisure',
#    'type': 'nature_reserve',
#    'place_rank': 30,
#    'importance': 0.31653158036886236,
#    'addresstype': 'leisure',
#    'name': 'Brisbane Ranges National Park',
#    'display_name': 'Brisbane Ranges National Park, Staughton Vale, City of Greater Geelong, Victoria, Australia',
#    'boundingbox': ['-37.9172798',
#     '-37.7317115',
#     '144.1489128',
#     '144.3258703']}},
#  '974': {'walk_id': 71,
#   'title': 'Common Rice-flower',
#   'summary': 'Common Rice-flower',
#   'lat': -37.74465712,
#   'lng': 144.26679611,
#   'osm': None},
#  '975': {'walk_id': 71,
#   'title': 'Brisbane Ranges National Park',
#   'summary': 'Brisbane Ranges National Park',
#   'lat': -37.75307256,
#   'lng': 144.28619384,
#   'osm': {'place_id': 17703166,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 9216331,
#    'lat': '-37.747618149999994',
#    'lon': '144.2698778160718',
#    'class': 'leisure',
#    'type': 'nature_reserve',
#    'place_rank': 30,
#    'importance': 0.31653158036886236,
#    'addresstype': 'leisure',
#    'name': 'Brisbane Ranges National Park',
#    'display_name': 'Brisbane Ranges National Park, Staughton Vale, City of Greater Geelong, Victoria, Australia',
#    'boundingbox': ['-37.9172798',
#     '-37.7317115',
#     '144.1489128',
#     '144.3258703']}},
#  '976': {'walk_id': 71,
#   'title': 'Echidna',
#   'summary': 'Echidna',
#   'lat': -37.75524413,
#   'lng': 144.26370621,
#   'osm': None},
#  '977': {'walk_id': 71,
#   'title': 'Grass Tree',
#   'summary': 'Grass Tree',
#   'lat': -37.74520008,
#   'lng': 144.26885605,
#   'osm': None},
#  '978': {'walk_id': 71,
#   'title': 'Sundews',
#   'summary': 'Sundews',
#   'lat': -37.7466932,
#   'lng': 144.28190231,
#   'osm': None},
#  '979': {'walk_id': 72,
#   'title': 'Langtree Mall ',
#   'summary': 'The recently refurbished Mall has lots of shade, seating and shops. ',
#   'lat': -34.1848712,
#   'lng': 142.16065709,
#   'osm': {'place_id': 16834079,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 222608315,
#    'lat': '-34.18488225',
#    'lon': '142.16066220415223',
#    'class': 'highway',
#    'type': 'pedestrian',
#    'place_rank': 26,
#    'importance': 0.10000999999999993,
#    'addresstype': 'road',
#    'name': 'Langtree Mall',
#    'display_name': 'Langtree Mall, Mildura, Rural City of Mildura, Victoria, 3500, Australia',
#    'boundingbox': ['-34.1856281',
#     '-34.1841238',
#     '142.1597326',
#     '142.1615527']}},
#  '980': {'walk_id': 72,
#   'title': 'Langtree Restaurants "Feast Street"',
#   'summary': "Large and diverse selection of restaurants including the Mildura Brewery and Stefano\\\\'s Pizza Caf\x9d. Lots of pedestrian priority here. ",
#   'lat': -34.18415164,
#   'lng': 142.16154141,
#   'osm': None},
#  '981': {'walk_id': 72,
#   'title': '8th St footpaths',
#   'summary': 'Like many of the streets around the CBD, 8th St has wide footpaths and seating available. ',
#   'lat': -34.18455535,
#   'lng': 142.1620713,
#   'osm': None},
#  '982': {'walk_id': 72,
#   'title': 'Fountain at Deakin Ave and 7th',
#   'summary': 'As you cross over 7th Ave at Deakin to access the footbridge to the river, you pass this lovely fountain. ',
#   'lat': -34.18330033,
#   'lng': 142.16453654,
#   'osm': None},
#  '983': {'walk_id': 72,
#   'title': 'Riverfront at rowing club',
#   'summary': 'Terrific spot to relax, picnic or walk the dog. Lots of lovely sights along the river. heading right you would hit the marina. ',
#   'lat': -34.18178055,
#   'lng': 142.16505412,
#   'osm': None},
#  '984': {'walk_id': 72,
#   'title': 'Locks',
#   'summary': 'From the riverbank you can see the locks. If you continue along the river, beyond this route, you would come to the Mildura Weir. ',
#   'lat': -34.17677683,
#   'lng': 142.16328455,
#   'osm': None},
#  '985': {'walk_id': 72,
#   'title': 'Rio Vista Park ',
#   'summary': 'Mildura West Primary School spent five years rejuvenating this area of the park. There is lots of native bush and many signs indicating types of plants, trees, etc. Take your time to wander. ',
#   'lat': -34.1758614,
#   'lng': 142.15976,
#   'osm': {'place_id': 16734532,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 579485279,
#    'lat': '-34.1764455',
#    'lon': '142.16116276960724',
#    'class': 'leisure',
#    'type': 'park',
#    'place_rank': 24,
#    'importance': 0.15000999999999998,
#    'addresstype': 'park',
#    'name': 'Rio Vista Park',
#    'display_name': 'Rio Vista Park, Mildura, Rural City of Mildura, Victoria, 3500, Australia',
#    'boundingbox': ['-34.1796385',
#     '-34.1731477',
#     '142.1580634',
#     '142.1634544']}},
#  '986': {'walk_id': 72,
#   'title': 'The Hut Sculpture',
#   'summary': 'Sculpture from 1988 Mildura Sculpture Triennial ',
#   'lat': -34.1754821,
#   'lng': 142.15928038,
#   'osm': None},
#  '987': {'walk_id': 72,
#   'title': 'More public art',
#   'summary': 'Art on both sides of the road here. ',
#   'lat': -34.17668925,
#   'lng': 142.15933592,
#   'osm': None},
#  '988': {'walk_id': 72,
#   'title': 'Mildura Arts Centre and public art',
#   'summary': 'Several pieces of public art on the grounds of the Arts Centre. Visit the Rio Vista House, built in 1889 by W.B. Chaffey, in Queen Anne style, the house features original furniture and fittings. ',
#   'lat': -34.17731553,
#   'lng': 142.15889507,
#   'osm': None},
#  '989': {'walk_id': 72,
#   'title': 'Mildura Bowls Club ',
#   'summary': 'Lovely setting for a game! If entering the park from here, be aware this street does not have footpaths all the way, but you can walk along the grass. ',
#   'lat': -34.17773814,
#   'lng': 142.16001539,
#   'osm': {'place_id': 16774390,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 1168157799,
#    'lat': '-34.17813405',
#    'lon': '142.16094503843408',
#    'class': 'leisure',
#    'type': 'sports_centre',
#    'place_rank': 30,
#    'importance': 9.99999999995449e-06,
#    'addresstype': 'leisure',
#    'name': 'Mildura Bowls Club',
#    'display_name': 'Mildura Bowls Club, 176, Cureton Avenue, Mildura, Rural City of Mildura, Victoria, 3500, Australia',
#    'boundingbox': ['-34.1789766',
#     '-34.1772930',
#     '142.1599295',
#     '142.1619592']}},
#  '990': {'walk_id': 72,
#   'title': 'Jaycee Park ',
#   'summary': 'Lots to see and do in this Park. Playgrounds, picnic areas, open fields, enough for everyone! ',
#   'lat': -34.17943109,
#   'lng': 142.16228902,
#   'osm': {'place_id': 16897283,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 295344837,
#    'lat': '-34.1799862',
#    'lon': '142.1625155293292',
#    'class': 'leisure',
#    'type': 'park',
#    'place_rank': 24,
#    'importance': 0.15000999999999998,
#    'addresstype': 'park',
#    'name': 'Jaycee Park',
#    'display_name': 'Jaycee Park, Mildura, Rural City of Mildura, Victoria, 3500, Australia',
#    'boundingbox': ['-34.1812028',
#     '-34.1790394',
#     '142.1607847',
#     '142.1638908']}},
#  '991': {'walk_id': 72,
#   'title': 'Outdoor cafe',
#   'summary': 'Before heading back to the CBD you can relax at this outdoor caf\x9d with your favourite pooch. ',
#   'lat': -34.1808315,
#   'lng': 142.16334084,
#   'osm': None},
#  '992': {'walk_id': 73,
#   'title': 'North shore',
#   'summary': "There are remains of structures, small 'make-ups' across water channels and other items. The barren hills to the north overlook 100 km of uninhabited country",
#   'lat': -35.0285907,
#   'lng': 141.71728134,
#   'osm': None},
#  '993': {'walk_id': 73,
#   'title': 'slipways',
#   'summary': 'The cordwood slipways were built out from the lake shore to make salt extraction easier. Several are still in relatively good order considering their age',
#   'lat': -35.03112088,
#   'lng': 141.71813965,
#   'osm': None},
#  '994': {'walk_id': 73,
#   'title': 'interpretive trail',
#   'summary': 'This signposted interpretive trail is the most accessible part of the former tramway. Relics include a former skip frame from the Sailor Salt Co. ',
#   'lat': -35.03407266,
#   'lng': 141.71813965,
#   'osm': None},
#  '995': {'walk_id': 73,
#   'title': 'Lake Becking',
#   'summary': "The lake's east shore is a vast lunette dune. From this point, the tramway formation veers away from the lake shore and out into the wilderness",
#   'lat': -35.03646211,
#   'lng': 141.71642303,
#   'osm': {'place_id': 16860118,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 76027059,
#    'lat': '-35.03291',
#    'lon': '141.71258815401214',
#    'class': 'natural',
#    'type': 'water',
#    'place_rank': 22,
#    'importance': 0.2000000999999999,
#    'addresstype': 'water',
#    'name': 'Lake Becking',
#    'display_name': 'Lake Becking, Murray-Sunset, Rural City of Mildura, Victoria, 3490, Australia',
#    'boundingbox': ['-35.0383214',
#     '-35.0274527',
#     '141.7054685',
#     '141.7172975']}},
#  '996': {'walk_id': 73,
#   'title': 'Remote area',
#   'summary': 'This section is several kms from the nearest track and feels very remote. Decaying sleepers and dogspikes are everywhere. If unsure of navigation or conditions, do not attempt this section',
#   'lat': -35.045176,
#   'lng': 141.70560837,
#   'osm': None},
#  '997': {'walk_id': 73,
#   'title': 'Grub Track',
#   'summary': 'Return is possible via Grub track and Ring road, but return via the tramway is more direct. The tramway formation continues south, but is soon out of the park and on private property',
#   'lat': -35.05965024,
#   'lng': 141.69857025,
#   'osm': None},
#  '998': {'walk_id': 74,
#   'title': 'Playground for the kids',
#   'summary': 'A great activity for the kids in the flora and fauna park',
#   'lat': -36.24640974,
#   'lng': 142.39330859,
#   'osm': None},
#  '999': {'walk_id': 74,
#   'title': 'Public Toilets in the Lions Park',
#   'summary': 'There are clean public toilets in the park',
#   'lat': -36.24632481,
#   'lng': 142.39317107,
#   'osm': None},
#  ...}

# %%
topic_df.iloc[23]
# Out:
# topic                                                      15
# document    13. Royal Exhibition Building: The Royal Exhib...
# Name: 23, dtype: object

# %%
nominatim_output['23']
# Out:
# {'walk_id': 2,
#  'title': '13. Royal Exhibition Building',
#  'summary': 'The Royal Exhibition Building is the only surviving Great Hall that once housed a 19th-century international exhibition and is still used for exhibitions. ',
#  'lat': -37.80513488,
#  'lng': 144.97123539,
#  'osm': {'place_id': 17546919,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 4817059,
#   'lat': '-37.804666850000004',
#   'lon': '144.9714669305319',
#   'class': 'historic',
#   'type': 'building',
#   'place_rank': 30,
#   'importance': 0.39044459367468287,
#   'addresstype': 'historic',
#   'name': 'Royal Exhibition Building',
#   'display_name': 'Royal Exhibition Building, 9, Nicholson Street, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia',
#   'boundingbox': ['-37.8051500', '-37.8041865', '144.9705305', '144.9724671']}}

# %%
topic_df.reset_index(inplace=True)

# %%
def is_found(row):
    idx = str(row['index'])
    if idx not in nominatim_output:
        print('index not found')
        return None
    if nominatim_output[idx]['osm'] is not None:
        return True
    return False

def which_class_type(row):
    idx = str(row['index'])
    if idx not in nominatim_output:
        print('index not found')
        return None
    if nominatim_output[idx]['osm'] is not None:
        return nominatim_output[idx]['osm']['class'] + ' ' + nominatim_output[idx]['osm']['type']
    return None

# %%
topic_df['is_found'] = topic_df.apply(is_found, axis=1)
topic_df['class'] = topic_df.apply(which_class_type, axis=1)

# %%
topic_df.head(50)
# Out:
#     index  topic                                           document  is_found  \
# 0       0      1  Fairhaven Surf Life Saving Club: Fairhaven is ...     False
# 1       1      1  Beach walk: From Sprout Creek, Eastern View, M...     False
# 2       2     12  Rock pools: See what sort of shells and stones...     False
# 3       3      1  Sand dunes: The beautiful rolling sand dunes s...     False
# 4       4     35  Painkalac Creek: The creek separates Aireys In...     False
# 5       5     14  Rocks and caves under the light house: There a...     False
# 6       6      8  Aireys Inlet playground and picnic ground: The...     False
# 7       7      7  Aireys Inlet lower shops: Pick up a coffee, ne...     False
# 8       8      1  Loutit Bay lookout: Return to Painkalac Creek ...      True
# 9       9     13  Historical homestead and building: At the ligh...     False
# 10     10     26  Split Point Lighthouse: Follow the signs and c...     False
# 11     11     60  1. Tramway signal box: Built in 1928 soon afte...     False
# 12     12     40  2. City Baths: Built in 1903, the design refle...      True
# 13     13     44  3. Magistrates Court: Built on the site of the...     False
# 14     14     44  4. Old Melbourne Gaol: Built between 1851 - 18...      True
# 15     15     42  5. Eight Hour Day Monument: Built in 1923, the...     False
# 16     16     15  6. Trades Hall: Built in stages from 1873 - 19...      True
# 17     17     15  7. Medley Hall: Built in 1893 as a private res...      True
# 18     18     11  8. Lygon shop corner: Lygon Buildings is archi...     False
# 19     19     13  9. Matthais House: A two storeyed stucco faced...     False
# 20     20     19  10. Sacred Heart Catholic Church: Built in 185...     False
# 21     21     15  11. IMAX Theatre: IMAX is the world's largest ...     False
# 22     22     40  12. Melbourne Museum: The museum has eight gal...      True
# 23     23     15  13. Royal Exhibition Building: The Royal Exhib...      True
# 24     24      6  14. Carlton Gardens: Developed in 19th-century...      True
# 25     25      8  15. Playground: Wonderful playground with swin...     False
# 26     26     15  16. Carlton Gardens Primary School: The school...      True
# 27     27     15  17. Terrace Houses (201 - 205 Drummond Street)...     False
# 28     28     11  18. Museo Italiano: Museo Italiano displays an...      True
# 29     29     15  19. La Mama Theatre: Built in 1883, the buildi...      True
# 30     30     39  19. Underground public toilets: The undergroun...     False
# 31     31     15  21. 313-315 Drummond Street: Built in 1889, th...      True
# 32     32     15  22. Carlton Court House: The Carlton Court Hou...      True
# 33     33     25  The Mildura Wharf: Mildura Wharf has been a vi...     False
# 34     34      2  Railway overpass: A short walk across the rail...     False
# 35     35     47  Prince and Princess of Wales Fountain Plaza: T...     False
# 36     36     20  War Memorial : To the left is a War Memorial c...     False
# 37     37      3  Sculpture commemorating Alfred Deakin, Primie ...     False
# 38     38     36  The Grand Hotel (to the right): Enter the Gran...     False
# 39     39     15  Commodore Motel former site of the Warren boar...     False
# 40     40     25  WIN TV: Originally STV8, opening in 1966 and n...     False
# 41     41     25  The Cultivator: Mildura’s earliest newspaper w...     False
# 42     42     25  Sunraysia Daily: Local identity, C.J De Garis ...      True
# 43     43     50  George and William Chaffey Building: Across th...     False
# 44     44     55  Electric Supply Department Substation No.1: In...     False
# 45     45     49  Queen Elizabeth II visit to Mildura, March 25t...     False
# 46     46     15  Bowring's Store, corner Deakin Avenue and 8th ...     False
# 47     47     25  Old Mildura Post Office (LHS of Deakin Ave): T...     False
# 48     48     50  George V Memorial Fountain (in centre plantati...     False
# 49     49     25  Mildura Law Courts (LHS of Deakin Ave): Opened...     False
#
#                       class
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# 5                      None
# 6                      None
# 7                      None
# 8         tourism viewpoint
# 9                      None
# 10                     None
# 11                     None
# 12    leisure sports_centre
# 13                     None
# 14       tourism attraction
# 15                     None
# 16             building yes
# 17     building residential
# 18                     None
# 19                     None
# 20                     None
# 21                     None
# 22           tourism museum
# 23        historic building
# 24             leisure park
# 25                     None
# 26           amenity school
# 27                     None
# 28           tourism museum
# 29          amenity theatre
# 30                     None
# 31      highway residential
# 32  boundary protected_area
# 33                     None
# 34                     None
# 35                     None
# 36                     None
# 37                     None
# 38                     None
# 39                     None
# 40                     None
# 41                     None
# 42         office newspaper
# 43                     None
# 44                     None
# 45                     None
# 46                     None
# 47                     None
# 48                     None
# 49                     None

# %%
topic_agg_df = topic_df.groupby(['topic']).agg({'is_found': ['sum', 'count']})

# %%
topic_agg_df[('is_found', 'ratio')] = topic_agg_df[('is_found', 'sum')] / topic_agg_df[('is_found', 'count')]

# %%
topic_agg_df.reset_index(inplace=True)
topic_agg_df
# Out:
#    topic is_found
#               sum count     ratio
# 0     -1        2     4  0.500000
# 1      0       13   406  0.032020
# 2      1       32   209  0.153110
# 3      2       27   198  0.136364
# 4      3       19   176  0.107955
# ..   ...      ...   ...       ...
# 59    58        5    36  0.138889
# 60    59        4    24  0.166667
# 61    60        3    19  0.157895
# 62    61        2    40  0.050000
# 63    62        4    24  0.166667
#
# [64 rows x 4 columns]

# %%
def add_represenation(row):
    return '-'.join(topic_model.get_topic_info(row['topic'])['Representation'].values[0])

topic_agg_df.sort_values(by=('is_found', 'ratio'), inplace=True)

# %%
topic_agg_df.head(20)
# Out:
#    topic is_found
#               sum count     ratio
# 58    57        0    23  0.000000
# 54    53        1    39  0.025641
# 13    12        3   107  0.028037
# 19    18        2    71  0.028169
# 8      7        3   104  0.028846
# 47    46        1    33  0.030303
# 1      0       13   406  0.032020
# 39    38        2    56  0.035714
# 33    32        2    55  0.036364
# 22    21        4    86  0.046512
# 62    61        2    40  0.050000
# 10     9        6   118  0.050847
# 40    39        2    39  0.051282
# 55    54        1    19  0.052632
# 38    37        2    34  0.058824
# 9      8        8   115  0.069565
# 11    10        8   114  0.070175
# 36    35        4    56  0.071429
# 56    55        2    25  0.080000
# 57    56        2    25  0.080000

# %%
topic_agg_df.tail(20)
# Out:
#    topic is_found
#               sum count     ratio
# 14    13       16    83  0.192771
# 42    41        7    36  0.194444
# 26    25       10    50  0.200000
# 29    28       10    45  0.222222
# 53    52        6    26  0.230769
# 5      4       33   132  0.250000
# 50    49        8    31  0.258065
# 16    15       23    88  0.261364
# 20    19       16    60  0.266667
# 52    51       10    36  0.277778
# 7      6       37   127  0.291339
# 27    26       17    57  0.298246
# 31    30       12    40  0.300000
# 37    36       13    42  0.309524
# 51    50       13    39  0.333333
# 45    44       11    32  0.343750
# 25    24       24    56  0.428571
# 28    27       23    53  0.433962
# 12    11       48   101  0.475248
# 0     -1        2     4  0.500000

# %%
not_founds = list(topic_agg_df.head(20)['topic'])
for idx in not_founds:
    print(topic_model.get_topic_info(idx)['Representation'].values[0])
# Out:
# ['fungi', 'mushrooms', 'mushroom', 'spider', 'descend', 'did', 'darker', 'ask', 'thirty', 'wasnt']
# ['crusoe', 'reservoir', 'gate', 'millers', 'spillover', 'tank', 'crest', 'bass', 'gravel', 'mitigation']
# ['bird', 'hide', 'birdlife', 'nesting', 'birds', 'peter', 'feeding', 'parrots', 'ostrich', 'rump']
# ['ducks', 'pelicans', 'swans', 'pelican', 'cormorants', 'duck', 'seagulls', 'black', 'waterbirds', 'bread']
# ['kangaroos', 'animals', 'wildlife', 'echidna', 'lizard', 'zoo', 'constellation', 'wallaby', 'insects', 'wombat']
# ['wildflowers', 'wildflower', 'daisies', 'yam', 'meadow', 'daisy', 'feathery', 'dainty', 'bumpy', 'edgars']
# ['track', 'steep', 'signage', 'gravel', 'top', 'path', 'walking', 'markers', 'valley', 'lookout']
# ['car', 'parking', 'carpark', 'thunder', 'dee', 'bike', 'decide', 'endeavour', 'wonderland', 'board']
# ['gum', 'gums', 'red', 'gumtree', 'twisting', 'stabilising', 'flowering', 'plays', 'greet', 'trees']
# ['seat', 'seats', 'seating', 'rest', 'plenty', 'sit', 'tired', 'legs', 'chair', 'serenity']
# ['wisteria', 'emblem', 'riceflower', 'dilwinia', 'flowers', 'heath', 'veronica', 'floral', 'aborigines', 'borne']
# ['fallen', 'teal', 'canopy', 'heathland', 'logs', 'tea', 'chestnut', 'trees', 'conservation', 'tree']
# ['toilets', 'toilet', 'block', 'public', 'showers', 'clean', 'crofton', 'lakewood', 'brand', 'amenities']
# ['orchid', 'orchids', 'waxlip', 'glossodia', '43', 'cinnamon', 'nodding', 'fringing', 'thelymitra', 'hyacinth']
# ['gym', 'equipment', 'exercise', 'outdoor', 'consists', 'fitness', 'ups', 'gear', 'exoskeleton', 'equipments']
# ['playground', 'childrens', 'kids', 'bayswater', 'wallace', 'children', 'marie', 'slides', 'play', 'slide']
# ['trees', 'tree', 'eucalypts', 'native', 'revegetation', 'grass', 'bunya', 'bark', 'indigenous', 'shrubs']
# ['creek', 'yarriambiack', 'wimmera', 'stony', 'hidden', 'toomuc', 'gem', 'blowhole', 'impacted', 'countryside']
# ['tower', 'towns', 'pumped', 'supply', 'towers', 'water', 'electricity', 'gasholders', '18x15', 'pump']
# ['wild', 'notforprofit', 'engagement', 'nature', 'website', 'connecting', 'specialising', 'dedicated', 'completed', 'please']

# %%
founds = list(topic_agg_df.tail(20)['topic'])
for idx in founds:
    print(topic_model.get_topic_info(idx)['Representation'].values[0])
# Out:
# ['homestead', 'house', 'houses', 'prefabricated', 'imported', 'housing', 'ruins', 'flats', 'architecture', 'desbrowe']
# ['rowing', 'boat', 'rowers', 'clubs', 'apex', 'band', 'ramp', 'blackbird', 'canoe', 'piers']
# ['mildura', 'milduras', 'wharf', 'shillidays', 'ave', 'langtree', 'deakin', 'earliest', 'daily', 'sunraysia']
# ['skate', 'bmx', 'incredibly', 'bigger', 'jumps', 'velodrome', 'skaters', 'ramp', 'park', 'better']
# ['ringwood', 'maroondah', 'nswwestpac', 'finnish', 'savings', 'operates', 'trading', 'wares', 'bank', 'northwestern']
# ['cafe', 'bakery', 'restaurant', 'coffee', 'shop', 'vietnamese', 'shops', 'caf', 'cake', 'rolls']
# ['elmore', 'preschool', 'emr', 'station', 'kathleen', 'railway', 'kindergarten', '1972', 'miniature', 'progress']
# ['ballarat', 'civic', 'hall', 'cinema', 'building', 'imax', 'nash', 'coburn', 'theatre', 'sturt']
# ['church', 'uniting', 'cathedral', 'sacred', 'anglican', 'presbyterian', 'heart', 'andrews', 'catholic', 'christ']
# ['lonsdale', 'womens', 'lt', 'clinic', '364378', 'court', 'women', 'county', 'hospital', 'qv']
# ['garden', 'gardens', 'pool', 'botanic', 'swimming', 'flagstaff', 'aquamoves', '21st', 'weir', 'pools']
# ['pier', 'princes', 'yacht', 'altona', 'port', 'hobsons', 'terminal', 'melbourne', 'ferguson', 'dukes']
# ['yarra', 'como', 'river', 'mcec', 'yalam', 'yorta', 'punt', 'bolte', 'woodside', 'polly']
# ['hotel', 'tinamba', 'grand', 'morgala', 'hardiman', 'hal', 'tanswells', 'tanswell', 'langi', '78']
# ['chaffey', 'avenue', 'cureton', 'bungalow', 'gatehouse', 'chauncy', 'valetta', 'lapthorne', '37', 'edmunds']
# ['gaol', 'beechworth', 'ned', 'precinct', 'prisoners', 'courthouse', 'police', 'prisoner', 'charged', 'cell']
# ['braybrook', 'library', 'community', 'primary', 'school', 'programs', 'classes', 'hub', 'maidstone', 'neighbourhood']
# ['play', 'jaycee', 'space', 'michie', 'snowgum', 'goddard', 'boxironbark', 'mimosa', 'prosthetic', 'moorookyle']
# ['federation', 'flinders', 'square', 'argus', 'arena', 'melbourne', 'college', 'boronia', 'enterprize', 'canberra']
# ['reserve', 'street', 'through', 'hall', 'water', 'centre', 'town', 'stop', 'shopping', 'spot']

# %% [markdown]
# ## Analyzing Topics
#
# Finding better solutions for the topic modelling part:
#
# - many topics are biased toward geographic areas (place names of suburbs and LGAs) rather than what is captured as POI - Topics 3, 12, 14, 20, 44, 45, 57, 59, 64, 69, 78
# - topics with mixed themes: 53, 63, 74, 75
# - not so clear topics: 17, 34, 35, 37, 46, 52, 55, 72, 76, 77, 78

# %%
topic_model.visualize_barchart(top_n_topics=79)
# Out:
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\plotly\io\_renderers.py:395: DeprecationWarning:
#
# distutils Version classes are deprecated. Use packaging.version instead.

# %% [markdown]
# ## Refining Topic Models
#
# Due to frequency of famous place names: LGAs and suburbs, several clusters are just defined by their location, while we are more interested to identify their characteristics.
#
# Source:
# https://public.opendatasoft.com/explore/dataset/georef-australia-local-government-area/table/?disjunctive.ste_code&disjunctive.ste_name&disjunctive.lga_code&disjunctive.lga_name
#
# https://public.opendatasoft.com/explore/dataset/georef-australia-state-suburb/table/?disjunctive.ste_code&disjunctive.ste_name&disjunctive.lga_code&disjunctive.lga_name&disjunctive.scc_code&disjunctive.scc_name

# %%
with open('dataset/georef-australia-state-suburb.json', 'r') as fp:
    suburbs = json.load(fp)
with open('dataset/georef-australia-local-government-area.json', 'r') as fp:
    lgas = json.load(fp)

# %%
suburb_names = [suburb['scc_name'][0] for suburb in suburbs]

# %%
lga_names = [lga['lga_name'][0] for lga in lgas]

# %%
lga_names_lower = [lga.lower() for lga in lga_names]
suburb_names_lower = [suburb.lower() for suburb in suburb_names]

# %%
def replace_by_list(desc, names):
    for n in names:
        if n in desc:
            desc = desc.replace(n, '')
    return desc

def refined_description(row):
    desc = row['description']
    desc = replace_by_list(desc, lga_names)
    desc = replace_by_list(desc, lga_names_lower)
    desc = replace_by_list(desc, suburb_names)
    return replace_by_list(desc, suburb_names_lower)

# %%
gdf['refined_description'] = gdf.apply(refined_description, axis=1)

# %%
gdf.head()
# Out:
#                          poi_title  \
# 0  Fairhaven Surf Life Saving Club
# 1                       Beach walk
# 2                       Rock pools
# 3                       Sand dunes
# 4                  Painkalac Creek
#
#                                          poi_summary   latitude   longitude  \
# 0  Fairhaven is a well known surf beach. The beac... -38.468759  144.084459
# 1  From Sprout Creek, Eastern View, Moggs Creek, ... -38.468542  144.089693
# 2  See what sort of shells and stones you can col... -38.468459  144.092420
# 3  The beautiful rolling sand dunes shape the bea... -38.468418  144.095318
# 4  The creek separates Aireys Inlet from Fairhave... -38.468390  144.097312
#
#                       geometry  \
# 0  POINT (144.08446 -38.46876)
# 1  POINT (144.08969 -38.46854)
# 2  POINT (144.09242 -38.46846)
# 3  POINT (144.09532 -38.46842)
# 4  POINT (144.09731 -38.46839)
#
#                                          description  \
# 0  Fairhaven Surf Life Saving Club: Fairhaven is ...
# 1  Beach walk: From Sprout Creek, Eastern View, M...
# 2  Rock pools: See what sort of shells and stones...
# 3  Sand dunes: The beautiful rolling sand dunes s...
# 4  Painkalac Creek: The creek separates Aireys In...
#
#                                  refined_description
# 0   Surf Life Saving Club:  is a well known surf ...
# 1  Beach walk: From Sprout Creek, , ,  to the bot...
# 2  Rock pools: See what sort of shells and stones...
# 3  Sand dunes: The beautiful rolling sand dunes s...
# 4  Painkalac Creek: The creek setes  from  and fo...

# %%
refined_docs = list(gdf['refined_description'])

refined_topic_model = BERTopic(umap_model=umap_model, ctfidf_model=ctfidf_model)
refined_topics, refined_probs = refined_topic_model.fit_transform(refined_docs)
# Out:
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\umap\umap_.py:1943: UserWarning:
#
# n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\hdbscan\hdbscan_.py:1170: DeprecationWarning:
#
# `alltrue` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `all` instead.

# %%
refined_topic_model.get_topic_info()
# Out:
#     Topic  Count                                     Name  \
# 0      -1   1590               -1_reserve_street_up_birds
# 1       0    234             0_building_office_post_court
# 2       1    160                    1_beach_bay_sand_tide
# 3       2    144               2_sculpture_art_mural_wall
# 4       3    138     3_bridge_footbridge_pedestrian_cross
# ..    ...    ...                                      ...
# 66     65     13                65_market_meat_queen_1878
# 67     66     12  66_library_kensington_neighbourhood_knh
# 68     67     11        67_weir_turbine_generation_diving
# 69     68     11        68_jk_crofton_reservecherry_booth
# 70     69     10    69_felltimber_wetland_ducks_swamphens
#
#                                        Representation  \
# 0   [reserve, street, up, birds, information, path...
# 1   [building, office, post, court, offices, civic...
# 2   [beach, bay, sand, tide, foreshore, surf, coas...
# 3   [sculpture, art, mural, wall, sculptures, arti...
# 4   [bridge, footbridge, pedestrian, cross, railwa...
# ..                                                ...
# 66  [market, meat, queen, 1878, largest, class, vi...
# 67  [library, kensington, neighbourhood, knh, broo...
# 68  [weir, turbine, generation, diving, picturevie...
# 69  [jk, crofton, reservecherry, booth, turnstile,...
# 70  [felltimber, wetland, ducks, swamphens, ibis, ...
#
#                                   Representative_Docs
# 0   [While the cars slog away above its peaceful d...
# 1   [70  Avenue (LHS of  Ave): Once the site of th...
# 2   [Coastal walking path: The narrow unsealed coa...
# 3   [9. Mural, Civic /Library Car Park, off Market...
# 4   [Overhead Railway Bridge: The Overhead Bridge ...
# ..                                                ...
# 66  [Queen Victoria Market: The Queen Victoria Mar...
# 67  [State Library Victoria: The State Library is ...
# 68  [ 11: Completed in 1928. Paddle steamers still...
# 69  [ Reserve: If you're in need of more space,  R...
# 70  [Birdlife: Keep an eye out for Purple Swamphen...
#
# [71 rows x 5 columns]

# %%
refined_topic_model.visualize_topics()
# Out:
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\umap\umap_.py:1943: UserWarning:
#
# n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\plotly\io\_renderers.py:395: DeprecationWarning:
#
# distutils Version classes are deprecated. Use packaging.version instead.

# %%
refined_topic_model.visualize_hierarchy()
# Out:
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\plotly\figure_factory\_dendrogram.py:350: DeprecationWarning:
#
# scipy.array is deprecated and will be removed in SciPy 2.0.0, use numpy.array instead
#
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\plotly\figure_factory\_dendrogram.py:351: DeprecationWarning:
#
# scipy.array is deprecated and will be removed in SciPy 2.0.0, use numpy.array instead
#
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\plotly\figure_factory\_dendrogram.py:352: DeprecationWarning:
#
# scipy.array is deprecated and will be removed in SciPy 2.0.0, use numpy.array instead
#
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\plotly\figure_factory\_dendrogram.py:353: DeprecationWarning:
#
# scipy.array is deprecated and will be removed in SciPy 2.0.0, use numpy.array instead

# %%
# what happen when merging topics as well
hierarchical_refined_topics = refined_topic_model.hierarchical_topics(refined_docs)
refined_topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_refined_topics)
# Out:
# 100%|██████████| 69/69 [00:00<00:00, 252.80it/s]
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\plotly\figure_factory\_dendrogram.py:350: DeprecationWarning:
#
# scipy.array is deprecated and will be removed in SciPy 2.0.0, use numpy.array instead
#
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\plotly\figure_factory\_dendrogram.py:351: DeprecationWarning:
#
# scipy.array is deprecated and will be removed in SciPy 2.0.0, use numpy.array instead
#
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\plotly\figure_factory\_dendrogram.py:352: DeprecationWarning:
#
# scipy.array is deprecated and will be removed in SciPy 2.0.0, use numpy.array instead
#
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\plotly\figure_factory\_dendrogram.py:353: DeprecationWarning:
#
# scipy.array is deprecated and will be removed in SciPy 2.0.0, use numpy.array instead
#
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\plotly\io\_renderers.py:395: DeprecationWarning:
#
# distutils Version classes are deprecated. Use packaging.version instead.

# %%
# topic outlier reduction - if necessary (todo)
refined_topics = refined_topic_model.reduce_outliers(refined_docs, refined_topics, strategy="c-tf-idf")

refined_topic_df = pd.DataFrame({'topic': refined_topics, 'document': refined_docs})

# %%
refined_topic_df
# Out:
#       topic                                           document
# 0         1   Surf Life Saving Club:  is a well known surf ...
# 1         1  Beach walk: From Sprout Creek, , ,  to the bot...
# 2        62  Rock pools: See what sort of shells and stones...
# 3         1  Sand dunes: The beautiful rolling sand dunes s...
# 4        20  Painkalac Creek: The creek setes  from  and fo...
# ...     ...                                                ...
# 4387      9  Lots of native flora: There are many native tr...
# 4388      6  Continue the loop or go elsewhere: There are p...
# 4389      6  Residential Street: This section of the walk t...
# 4390      4  The Stables Playground: This playground is hug...
# 4391     12  Plenty of seats: There are plenty of seats alo...
#
# [4392 rows x 2 columns]

# %%
refined_topic_model.visualize_barchart(top_n_topics=65)
# Out:
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\plotly\io\_renderers.py:395: DeprecationWarning:
#
# distutils Version classes are deprecated. Use packaging.version instead.

# %%
refined_topic_df.reset_index(inplace=True)

refined_topic_df['is_found'] = refined_topic_df.apply(is_found, axis=1)
refined_topic_df['class'] = refined_topic_df.apply(which_class_type, axis=1)

refined_topic_agg_df = refined_topic_df.groupby(['topic']).agg({'is_found': ['sum', 'count']})

refined_topic_agg_df[('is_found', 'ratio')] = refined_topic_agg_df[('is_found', 'sum')] / refined_topic_agg_df[('is_found', 'count')]

refined_topic_agg_df.reset_index(inplace=True)

refined_topic_agg_df.sort_values(by=('is_found', 'ratio'), inplace=True)

# %%
not_founds = list(refined_topic_agg_df.head(20)['topic'])
for idx in not_founds:
    print(refined_topic_model.get_topic_info(idx)['Representation'].values[0])
# Out:
# ['smoking', 'aboriginal', 'interpretive', 'ceremony', 'gippslands', 'yorta', 'gippsland', 'stories', 'welcomes', 'walker']
# ['ducks', 'pelicans', 'duck', 'pacific', 'ducklings', 'pelican', 'black', 'seagull', 'waterbirds', 'bread']
# ['olive', 'strip', 'moments', 'poinciana', 'dobsons', 'iramoo', 'vas', 'agricultural', 'grasslands', 'nature']
# ['echidna', 'zoo', 'wildlife', 'animals', 'koala', 'insects', 'creatures', 'rustle', 'safari', 'doing']
# ['wildflowers', 'wildflower', 'daisies', 'yam', 'flowers', 'daisy', 'fingernail', 'edgars', 'bumpy', 'peculiar']
# ['gym', 'exercise', 'equipment', 'outdoor', 'consists', 'fitness', 'ups', 'gear', 'crunches', 'equipments']
# ['bird', 'birdlife', 'nesting', 'hide', 'parrots', 'birds', 'heron', 'loads', 'cormorants', 'feng']
# ['orchid', 'orchids', 'waxlip', '43', 'hyacinth', 'roseum', 'specimens', 'sp', 'fringing', 'nodding']
# ['toilets', 'toilet', 'public', 'showers', 'clean', 'amenities', 'basll', 'rules', 'stables', 'unisex']
# ['fishing', 'trout', 'fish', 'lagoon', 'anglers', 'spit', 'steampacket', 'azure', 'kingfisher', 'buoys']
# ['loop', 'shared', 'footpath', 'turn', 'left', 'steps', 'precincts', 'grateful', 'koolamara', 'start']
# ['tree', 'trees', 'oak', 'eucalypts', 'leaves', 'ferns', 'cedar', 'shrub', 'silver', 'shrubs']
# ['blind', 'spring', 'goat', 'trail', 'creek', 'crosses', 'group', 'friends', 'shared', 'deck']
# ['lookout', 'mt', 'rock', 'strezlecki', 'cliffs', 'ranges', 'height', 'massive', 'rails', 'pardalot']
# ['boardwalk', 'boardwalks', 'allows', 'wet', 'ish', 'slipways', 'feet', 'relatively', 'jawbone', 'schnapper']
# ['gum', 'gums', 'gumtree', 'flowering', 'brushes', 'red', 'trees', 'magnificent', 'greet', 'bottle']
# ['canopy', 'spinebill', 'transition', 'heathlands', 'sprayed', 'schlerophyll', 'rebushing', 'rejuvenating', 'parklandwide', 'spent']
# ['tramway', 'formation', 'grub', 'tramline', 'expensive', 'shows', 'hopper', 'materials', 'branch', 'cutting']
# ['wild', 'notforprofit', 'engagement', 'website', 'nature', 'connecting', 'specialising', 'dcated', 'completed', 'please']
# ['cng', 'trucks', 'careful', 'busy', 'semi', 'cars', 'highway', 'road', 'trailer', 'traffic']

# %%
founds = list(refined_topic_agg_df.tail(20)['topic'])
for idx in founds:
    print(refined_topic_model.get_topic_info(idx)['Representation'].values[0])
# Out:
# ['tennis', 'courts', 'netball', 'basketball', 'cricket', 'wanting', 'tucked', 'football', 'anyone', 'tournaments']
# ['skate', 'bmx', 'incrbly', 'newport', 'bigger', 'jumps', 'scooters', 'facility', 'skaters', 'ramp']
# ['shops', 'store', 'shopping', 'shillidays', 'general', 'shop', 'preston', 'clothes', 'strath', 'fashion']
# ['pool', 'aquamoves', 'swimming', 'swim', 'sadler', 'creche', 'olympic', 'pools', 'waterworld', 'swimland']
# ['bakery', 'vietnamese', 'bun', 'rolls', 'grocery', 'pho', 'salad', 'savoury', 'crust', 'sweet']
# ['boat', 'ramp', 'marina', 'ship', 'yacht', 'altona', 'rowing', 'paddlesteamer', 'canoe', 'te']
# ['coffee', 'cafe', 'caf', 'restaurant', 'chai', 'cafes', 'bakery', 'british', 'harbour', 'salingers']
# ['jk', 'crofton', 'reservecherry', 'booth', 'turnstile', 'hut', 'reserve', 'exit', 'cubbyh', 'subdivisions']
# ['conservatory', 'ford', 'recital', 'sites', 'sub', 'ngv', 'potter', 'headlines', 'leachs', 'bitten']
# ['weir', 'turbine', 'generation', 'diving', 'pictureview', 'contraption', 'aug', 'waterslide', 'weirs', 'collects']
# ['gardens', 'botanic', 'garden', 'royal', 'japanese', 'botanical', 'grow', 'sensory', 'com', 'village']
# ['building', 'office', 'post', 'court', 'offices', 'civic', 'historic', 'ave', 'original', 'bell']
# ['church', 'uniting', 'cathedral', 'anglican', 'presbyterian', 'methodist', 'sacred', 'cic', 'christ', 'heart']
# ['railway', 'station', 'magic', 'train', 'travelled', '1278', 'radio', 'renamed', 'runnymede', 'signal']
# ['gallery', 'arts', 'galleries', 'spire', 'aka', 'lap', 'phar', 'museum', 'ceiling', 'skel']
# ['coal', 'miner', 'mine', 'miners', 'noisy', 'mining', 'charcoal', 'mines', '1909', 'kiln']
# ['reserve', 'street', 'up', 'birds', 'information', 'path', 'avenue', 'through', 'back', 'where']
# ['market', 'meat', 'queen', '1878', 'largest', 'class', 'victoria', 'trades', 'qv', 'trade']
# ['primary', 'school', 'preschool', 'kindergarten', 'kathleen', 'dinjerra', 'schools', 'students', 'holy', 'ballet']
# ['square', 'bowl', 'albanian', 'music', 'outing', 'events', 'myer', 'sidney', 'carols', 'arts']

# %%
refined_topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_refined_topics)
# Out:
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\plotly\figure_factory\_dendrogram.py:350: DeprecationWarning:
#
# scipy.array is deprecated and will be removed in SciPy 2.0.0, use numpy.array instead
#
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\plotly\figure_factory\_dendrogram.py:351: DeprecationWarning:
#
# scipy.array is deprecated and will be removed in SciPy 2.0.0, use numpy.array instead
#
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\plotly\figure_factory\_dendrogram.py:352: DeprecationWarning:
#
# scipy.array is deprecated and will be removed in SciPy 2.0.0, use numpy.array instead
#
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\plotly\figure_factory\_dendrogram.py:353: DeprecationWarning:
#
# scipy.array is deprecated and will be removed in SciPy 2.0.0, use numpy.array instead
#
# d:\Programming\leisure-walking-analysis\.conda\Lib\site-packages\plotly\io\_renderers.py:395: DeprecationWarning:
#
# distutils Version classes are deprecated. Use packaging.version instead.

# %%
# TODO: Outdated topic ids
labelled_topics = {'cultural, historical and social': [46,14,0,17,41,25,6,1,50,34],
                   'affordance, function': [55,19,24,29,36,62,7,31,40,44,32,53,54,51,21,8,58,61,48,52,56,37],
                   'signs': [26,28,35,45],
                   'natural features': [39,23,57,49,13,15,5,2,3,4,11,10],
                   'species': [59,43,47,38,9,22,18,27,16,12,29,69],
                   'unknown': [-1]
                  }

# %%
def labelled_stats(topic_ids, labelled_topics = labelled_topics):
    stat_topics = {}
    for idx in topic_ids:
        for key, values in labelled_topics.items():
            if idx in values:
                if key not in stat_topics.keys():
                    stat_topics[key] = 1
                else:
                    stat_topics[key] += 1
    return stat_topics

# %%
not_found_topics = labelled_stats(not_founds)
not_found_topics
# Out:
# {'affordance, function': 6,
#  'natural features': 2,
#  'cultural, historical and social': 2,
#  'species': 4,
#  'signs': 2}

# %%
found_topics = labelled_stats(founds)
found_topics
# Out:
# {'affordance, function': 8,
#  'species': 4,
#  'cultural, historical and social': 3,
#  'natural features': 1,
#  'unknown': 1,
#  'signs': 1}

# %%
refined_topic_agg_df
# Out:
#    topic is_found
#               sum count     ratio
# 65    64        0    26  0.000000
# 32    31        0    49  0.000000
# 38    37        0    40  0.000000
# 12    11        1    75  0.013333
# 45    44        1    33  0.030303
# ..   ...      ...   ...       ...
# 52    51       10    31  0.322581
# 0     -1        3     9  0.333333
# 66    65       12    28  0.428571
# 36    35       18    40  0.450000
# 47    46       16    33  0.484848
#
# [71 rows x 4 columns]

# %% [markdown]
# ## Labelling Process:
#
# - label if the geocoding was correct - if geocoding was successful
# - find 10 most likely using textual and spatial criteria and record the element as a match

# %%
classes_found = list(refined_topic_df['class'].unique())
sup_classes = set([c.split(' ')[0] for c in classes_found if c is not None])
sup_classes
# Out:
# {'amenity',
#  'boundary',
#  'bridge',
#  'building',
#  'club',
#  'highway',
#  'historic',
#  'landuse',
#  'leisure',
#  'man_made',
#  'natural',
#  'office',
#  'place',
#  'railway',
#  'shop',
#  'tourism',
#  'waterway'}

# %%
tags = dict([(k, True) for k in sup_classes])
tags['animal'] = True
tags
# Out:
# {'landuse': True,
#  'tourism': True,
#  'leisure': True,
#  'railway': True,
#  'man_made': True,
#  'bridge': True,
#  'natural': True,
#  'place': True,
#  'club': True,
#  'amenity': True,
#  'highway': True,
#  'historic': True,
#  'office': True,
#  'shop': True,
#  'waterway': True,
#  'boundary': True,
#  'building': True,
#  'animal': True}

# %%
def get_feature_from_osm(lat, lng, dist=200, tags=tags):
    return ox.features_from_point((lat, lng), tags, dist)

# %%
case_id = 23
test_case = nominatim_output[str(case_id)]

# %%
test_case
# Out:
# {'walk_id': 2,
#  'title': '13. Royal Exhibition Building',
#  'summary': 'The Royal Exhibition Building is the only surviving Great Hall that once housed a 19th-century international exhibition and is still used for exhibitions. ',
#  'lat': -37.80513488,
#  'lng': 144.97123539,
#  'osm': {'place_id': 17546919,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 4817059,
#   'lat': '-37.804666850000004',
#   'lon': '144.9714669305319',
#   'class': 'historic',
#   'type': 'building',
#   'place_rank': 30,
#   'importance': 0.39044459367468287,
#   'addresstype': 'historic',
#   'name': 'Royal Exhibition Building',
#   'display_name': 'Royal Exhibition Building, 9, Nicholson Street, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia',
#   'boundingbox': ['-37.8051500', '-37.8041865', '144.9705305', '144.9724671']}}

# %%
dist_threshold = 200
features = get_feature_from_osm(test_case['lat'], test_case['lng'], dist=dist_threshold)
features
# Out:
#                            highway traffic_signals:direction  \
# element_type osmid
# node         319157917         NaN                       NaN
#              368393200         NaN                       NaN
#              371974432         NaN                       NaN
#              493873180    crossing                       NaN
#              501027469    crossing                       NaN
# ...                            ...                       ...
# relation     13238592   pedestrian                       NaN
#              16464561          NaN                       NaN
#              16505481   pedestrian                       NaN
#              17205856          NaN                       NaN
#              17205857          NaN                       NaN
#
#                                                                  geometry  \
# element_type osmid
# node         319157917                        POINT (144.96920 -37.80626)
#              368393200                        POINT (144.97064 -37.80351)
#              371974432                        POINT (144.97138 -37.80545)
#              493873180                        POINT (144.96961 -37.80495)
#              501027469                        POINT (144.97350 -37.80553)
# ...                                                                   ...
# relation     13238592   POLYGON ((144.97319 -37.80469, 144.97316 -37.8...
#              16464561   POLYGON ((144.96877 -37.80399, 144.96879 -37.8...
#              16505481   POLYGON ((144.97232 -37.80461, 144.97205 -37.8...
#              17205856   POLYGON ((144.97222 -37.80608, 144.97215 -37.8...
#              17205857   POLYGON ((144.97004 -37.80614, 144.97007 -37.8...
#
#                        access   amenity  fee                operator  \
# element_type osmid
# node         319157917    yes   toilets   no  Melbourne City Council
#              368393200    NaN    cinema  NaN        Melbourne museum
#              371974432    NaN  fountain  NaN                     NaN
#              493873180    NaN       NaN  NaN                     NaN
#              501027469    NaN       NaN  NaN                     NaN
# ...                       ...       ...  ...                     ...
# relation     13238592     NaN       NaN  NaN                     NaN
#              16464561     NaN       NaN  NaN                     NaN
#              16505481     NaN       NaN  NaN                     NaN
#              17205856     NaN       NaN  NaN                     NaN
#              17205857     NaN       NaN  NaN                     NaN
#
#                        toilets:disposal unisex wheelchair  ... name:mk  \
# element_type osmid                                         ...
# node         319157917            flush    yes        yes  ...     NaN
#              368393200              NaN    NaN        NaN  ...     NaN
#              371974432              NaN    NaN        NaN  ...     NaN
#              493873180              NaN    NaN        NaN  ...     NaN
#              501027469              NaN    NaN        NaN  ...     NaN
# ...                                 ...    ...        ...  ...     ...
# relation     13238592               NaN    NaN        NaN  ...     NaN
#              16464561               NaN    NaN        NaN  ...     NaN
#              16505481               NaN    NaN        NaN  ...     NaN
#              17205856               NaN    NaN        NaN  ...     NaN
#              17205857               NaN    NaN        NaN  ...     NaN
#
#                        short_name political_division heritage  \
# element_type osmid
# node         319157917        NaN                NaN      NaN
#              368393200        NaN                NaN      NaN
#              371974432        NaN                NaN      NaN
#              493873180        NaN                NaN      NaN
#              501027469        NaN                NaN      NaN
# ...                           ...                ...      ...
# relation     13238592         NaN                NaN      NaN
#              16464561         NaN                NaN      NaN
#              16505481         NaN                NaN      NaN
#              17205856         NaN                NaN      NaN
#              17205857         NaN                NaN      NaN
#
#                        heritage:operator heritage:website area intermittent  \
# element_type osmid
# node         319157917               NaN              NaN  NaN          NaN
#              368393200               NaN              NaN  NaN          NaN
#              371974432               NaN              NaN  NaN          NaN
#              493873180               NaN              NaN  NaN          NaN
#              501027469               NaN              NaN  NaN          NaN
# ...                                  ...              ...  ...          ...
# relation     13238592                NaN              NaN  yes          NaN
#              16464561                NaN              NaN  NaN          NaN
#              16505481                NaN              NaN  NaN          NaN
#              17205856                NaN              NaN  NaN           no
#              17205857                NaN              NaN  NaN          NaN
#
#                        salt water
# element_type osmid
# node         319157917  NaN   NaN
#              368393200  NaN   NaN
#              371974432  NaN   NaN
#              493873180  NaN   NaN
#              501027469  NaN   NaN
# ...                     ...   ...
# relation     13238592   NaN   NaN
#              16464561   NaN   NaN
#              16505481   NaN   NaN
#              17205856    no  pond
#              17205857   NaN  pond
#
# [449 rows x 145 columns]

# %%
list(features.columns)
# Out:
# ['highway',
#  'traffic_signals:direction',
#  'geometry',
#  'access',
#  'amenity',
#  'fee',
#  'operator',
#  'toilets:disposal',
#  'unisex',
#  'wheelchair',
#  'crossing',
#  'check_date',
#  'name',
#  'payment:mastercard',
#  'payment:visa',
#  'phone',
#  'screen',
#  'website',
#  'wikidata',
#  'bicycle',
#  'artist',
#  'covered',
#  'drinking_water',
#  'indoor',
#  'tactile_paving',
#  'button_operated',
#  'crossing:markings',
#  'foot',
#  'traffic_signals:sound',
#  'traffic_signals:vibration',
#  'backrest',
#  'source',
#  'railway',
#  'parking',
#  'crossing:island',
#  'kerb',
#  'bicycle_parking',
#  'fountain',
#  'leisure',
#  'brand',
#  'brand:wikidata',
#  'brand:wikipedia',
#  'operator:wikidata',
#  'operator:wikipedia',
#  'payment:cash',
#  'payment:credit_cards',
#  'toilets:wheelchair',
#  'place',
#  'network',
#  'public_transport',
#  'ref',
#  'tram',
#  'natural',
#  'bench',
#  'bin',
#  'bus',
#  'lit',
#  'network:wikidata',
#  'network:wikipedia',
#  'ref:ptv_website',
#  'route_ref',
#  'shelter',
#  'capacity',
#  'location',
#  'historic',
#  'traffic_signals',
#  'material',
#  'memorial',
#  'image',
#  'survey:date',
#  'artwork_type',
#  'tourism',
#  'inscription',
#  'artist_name',
#  'year_of_construction',
#  'nodes',
#  'addr:country',
#  'addr:housenumber',
#  'addr:postcode',
#  'addr:state',
#  'addr:street',
#  'addr:suburb',
#  'building',
#  'building:colour',
#  'height',
#  'layer',
#  'name:fr',
#  'name:vi',
#  'name:zh',
#  'wikipedia',
#  'addr:city',
#  'atm',
#  'internet_access',
#  'name:el',
#  'opening_hours',
#  'operator:type',
#  'motorcar',
#  'noname',
#  'surface',
#  'cycleway:both',
#  'oneway',
#  'source:name',
#  'service',
#  'lane_markings',
#  'footway',
#  'segregated',
#  'cycleway:left',
#  'cycleway:left:buffer:right',
#  'cycleway:left:lane',
#  'cycleway:right',
#  'lanes',
#  'maxspeed',
#  'sidewalk:left',
#  'sidewalk:right',
#  'electrified',
#  'frequency',
#  'gauge',
#  'voltage',
#  'office',
#  'building:levels',
#  'landuse',
#  'passenger_information_display',
#  'shoulder',
#  'leaf_type',
#  'ways',
#  'admin_level',
#  'boundary',
#  'population',
#  'population:date',
#  'postal_code',
#  'ref:psma:loc_pid',
#  'ref:vicmap:pfi',
#  'type',
#  'ref:psma:lga_pid',
#  'source:population',
#  'name:mk',
#  'short_name',
#  'political_division',
#  'heritage',
#  'heritage:operator',
#  'heritage:website',
#  'area',
#  'intermittent',
#  'salt',
#  'water']

# %%
for key, value in nominatim_output.items():
    print('key: {}'.format(key))
    if os.path.isfile('dataset/osm-poi-{0}-dist-{1}-features.geojson'.format(key, dist_threshold)):
        print('already investigated...')
        continue;
    try:
        features = get_feature_from_osm(value['lat'], value['lng'])
        cols = list(features.columns)
        cols.remove('geometry')
        features[cols] = features[cols].astype(str)
        features.to_file('dataset/osm-poi-{0}-dist-{1}-features.geojson'.format(key, dist_threshold), driver="GeoJSON") 
        print('done')
    except Exception as e:
        print(e)
# Out:
# key: 0
# already investigated...
# key: 1
# already investigated...
# key: 2
# already investigated...
# key: 3
# already investigated...
# key: 4
# already investigated...
# key: 5
# already investigated...
# key: 6
# already investigated...
# key: 7
# already investigated...
# key: 8
# already investigated...
# key: 9
# already investigated...
# key: 10
# already investigated...
# key: 11
# already investigated...
# key: 12
# already investigated...
# key: 13
# already investigated...
# key: 14
# already investigated...
# key: 15
# already investigated...
# key: 16
# already investigated...
# key: 17
# already investigated...
# key: 18
# already investigated...
# key: 19
# already investigated...
# key: 20
# already investigated...
# key: 21
# already investigated...
# key: 22
# already investigated...
# key: 23
# already investigated...
# key: 24
# already investigated...
# key: 25
# already investigated...
# key: 26
# already investigated...
# key: 27
# already investigated...
# key: 28
# already investigated...
# key: 29
# already investigated...
# key: 30
# already investigated...
# key: 31
# already investigated...
# key: 32
# already investigated...
# key: 33
# already investigated...
# key: 34
# already investigated...
# key: 35
# already investigated...
# key: 36
# already investigated...
# key: 37
# already investigated...
# key: 38
# already investigated...
# key: 39
# already investigated...
# key: 40
# already investigated...
# key: 41
# already investigated...
# key: 42
# already investigated...
# key: 43
# already investigated...
# key: 44
# already investigated...
# key: 45
# already investigated...
# key: 46
# already investigated...
# key: 47
# already investigated...
# key: 48
# already investigated...
# key: 49
# already investigated...
# key: 50
# already investigated...
# key: 51
# already investigated...
# key: 52
# already investigated...
# key: 53
# already investigated...
# key: 54
# already investigated...
# key: 55
# already investigated...
# key: 56
# already investigated...
# key: 57
# already investigated...
# key: 58
# already investigated...
# key: 59
# already investigated...
# key: 60
# already investigated...
# key: 61
# already investigated...
# key: 62
# already investigated...
# key: 63
# already investigated...
# key: 64
# already investigated...
# key: 65
# already investigated...
# key: 66
# already investigated...
# key: 67
# already investigated...
# key: 68
# already investigated...
# key: 69
# already investigated...
# key: 70
# already investigated...
# key: 71
# already investigated...
# key: 72
# already investigated...
# key: 73
# already investigated...
# key: 74
# already investigated...
# key: 75
# already investigated...
# key: 76
# already investigated...
# key: 77
# already investigated...
# key: 78
# already investigated...
# key: 79
# already investigated...
# key: 80
# already investigated...
# key: 81
# already investigated...
# key: 82
# already investigated...
# key: 83
# already investigated...
# key: 84
# already investigated...
# key: 85
# already investigated...
# key: 86
# already investigated...
# key: 87
# already investigated...
# key: 88
# already investigated...
# key: 89
# already investigated...
# key: 90
# already investigated...
# key: 91
# already investigated...
# key: 92
# already investigated...
# key: 93
# already investigated...
# key: 94
# already investigated...
# key: 95
# already investigated...
# key: 96
# already investigated...
# key: 97
# already investigated...
# key: 98
# already investigated...
# key: 99
# already investigated...
# key: 100
# already investigated...
# key: 101
# already investigated...
# key: 102
# already investigated...
# key: 103
# already investigated...
# key: 104
# already investigated...
# key: 105
# already investigated...
# key: 106
# already investigated...
# key: 107
# already investigated...
# key: 108
# already investigated...
# key: 109
# already investigated...
# key: 110
# already investigated...
# key: 111
# already investigated...
# key: 112
# already investigated...
# key: 113
# already investigated...
# key: 114
# already investigated...
# key: 115
# already investigated...
# key: 116
# already investigated...
# key: 117
# already investigated...
# key: 118
# already investigated...
# key: 119
# already investigated...
# key: 120
# already investigated...
# key: 121
# already investigated...
# key: 122
# already investigated...
# key: 123
# already investigated...
# key: 124
# already investigated...
# key: 125
# already investigated...
# key: 126
# already investigated...
# key: 127
# already investigated...
# key: 128
# already investigated...
# key: 129
# already investigated...
# key: 130
# already investigated...
# key: 131
# already investigated...
# key: 132
# already investigated...
# key: 133
# already investigated...
# key: 134
# already investigated...
# key: 135
# already investigated...
# key: 136
# already investigated...
# key: 137
# already investigated...
# key: 138
# already investigated...
# key: 139
# already investigated...
# key: 140
# already investigated...
# key: 141
# already investigated...
# key: 142
# already investigated...
# key: 143
# already investigated...
# key: 144
# already investigated...
# key: 145
# already investigated...
# key: 146
# already investigated...
# key: 147
# already investigated...
# key: 148
# already investigated...
# key: 149
# already investigated...
# key: 150
# already investigated...
# key: 151
# already investigated...
# key: 152
# already investigated...
# key: 153
# already investigated...
# key: 154
# already investigated...
# key: 155
# already investigated...
# key: 156
# already investigated...
# key: 157
# already investigated...
# key: 158
# already investigated...
# key: 159
# already investigated...
# key: 160
# already investigated...
# key: 161
# already investigated...
# key: 162
# already investigated...
# key: 163
# already investigated...
# key: 164
# already investigated...
# key: 165
# already investigated...
# key: 166
# already investigated...
# key: 167
# already investigated...
# key: 168
# already investigated...
# key: 169
# already investigated...
# key: 170
# already investigated...
# key: 171
# already investigated...
# key: 172
# already investigated...
# key: 173
# already investigated...
# key: 174
# already investigated...
# key: 175
# already investigated...
# key: 176
# already investigated...
# key: 177
# already investigated...
# key: 178
# already investigated...
# key: 179
# already investigated...
# key: 180
# already investigated...
# key: 181
# already investigated...
# key: 182
# already investigated...
# key: 183
# already investigated...
# key: 184
# already investigated...
# key: 185
# already investigated...
# key: 186
# already investigated...
# key: 187
# already investigated...
# key: 188
# already investigated...
# key: 189
# already investigated...
# key: 190
# already investigated...
# key: 191
# already investigated...
# key: 192
# already investigated...
# key: 193
# already investigated...
# key: 194
# already investigated...
# key: 195
# already investigated...
# key: 196
# already investigated...
# key: 197
# already investigated...
# key: 198
# already investigated...
# key: 199
# already investigated...
# key: 200
# already investigated...
# key: 201
# already investigated...
# key: 202
# already investigated...
# key: 203
# already investigated...
# key: 204
# already investigated...
# key: 205
# already investigated...
# key: 206
# already investigated...
# key: 207
# already investigated...
# key: 208
# already investigated...
# key: 209
# already investigated...
# key: 210
# already investigated...
# key: 211
# already investigated...
# key: 212
# already investigated...
# key: 213
# already investigated...
# key: 214
# already investigated...
# key: 215
# already investigated...
# key: 216
# already investigated...
# key: 217
# already investigated...
# key: 218
# already investigated...
# key: 219
# already investigated...
# key: 220
# already investigated...
# key: 221
# already investigated...
# key: 222
# already investigated...
# key: 223
# already investigated...
# key: 224
# already investigated...
# key: 225
# already investigated...
# key: 226
# already investigated...
# key: 227
# already investigated...
# key: 228
# already investigated...
# key: 229
# already investigated...
# key: 230
# already investigated...
# key: 231
# already investigated...
# key: 232
# already investigated...
# key: 233
# already investigated...
# key: 234
# already investigated...
# key: 235
# already investigated...
# key: 236
# already investigated...
# key: 237
# already investigated...
# key: 238
# already investigated...
# key: 239
# already investigated...
# key: 240
# already investigated...
# key: 241
# already investigated...
# key: 242
# already investigated...
# key: 243
# already investigated...
# key: 244
# already investigated...
# key: 245
# already investigated...
# key: 246
# already investigated...
# key: 247
# already investigated...
# key: 248
# already investigated...
# key: 249
# already investigated...
# key: 250
# already investigated...
# key: 251
# already investigated...
# key: 252
# already investigated...
# key: 253
# already investigated...
# key: 254
# already investigated...
# key: 255
# already investigated...
# key: 256
# already investigated...
# key: 257
# already investigated...
# key: 258
# already investigated...
# key: 259
# already investigated...
# key: 260
# already investigated...
# key: 261
# already investigated...
# key: 262
# already investigated...
# key: 263
# already investigated...
# key: 264
# already investigated...
# key: 265
# already investigated...
# key: 266
# already investigated...
# key: 267
# already investigated...
# key: 268
# already investigated...
# key: 269
# already investigated...
# key: 270
# already investigated...
# key: 271
# already investigated...
# key: 272
# already investigated...
# key: 273
# already investigated...
# key: 274
# already investigated...
# key: 275
# already investigated...
# key: 276
# already investigated...
# key: 277
# already investigated...
# key: 278
# already investigated...
# key: 279
# already investigated...
# key: 280
# already investigated...
# key: 281
# already investigated...
# key: 282
# already investigated...
# key: 283
# already investigated...
# key: 284
# already investigated...
# key: 285
# already investigated...
# key: 286
# already investigated...
# key: 287
# already investigated...
# key: 288
# already investigated...
# key: 289
# already investigated...
# key: 290
# already investigated...
# key: 291
# already investigated...
# key: 292
# already investigated...
# key: 293
# already investigated...
# key: 294
# already investigated...
# key: 295
# already investigated...
# key: 296
# already investigated...
# key: 297
# already investigated...
# key: 298
# already investigated...
# key: 299
# already investigated...
# key: 300
# already investigated...
# key: 301
# already investigated...
# key: 302
# already investigated...
# key: 303
# already investigated...
# key: 304
# already investigated...
# key: 305
# already investigated...
# key: 306
# already investigated...
# key: 307
# already investigated...
# key: 308
# already investigated...
# key: 309
# already investigated...
# key: 310
# already investigated...
# key: 311
# already investigated...
# key: 312
# already investigated...
# key: 313
# already investigated...
# key: 314
# already investigated...
# key: 315
# already investigated...
# key: 316
# already investigated...
# key: 317
# already investigated...
# key: 318
# already investigated...
# key: 319
# already investigated...
# key: 320
# already investigated...
# key: 321
# already investigated...
# key: 322
# already investigated...
# key: 323
# already investigated...
# key: 324
# already investigated...
# key: 325
# already investigated...
# key: 326
# already investigated...
# key: 327
# already investigated...
# key: 328
# already investigated...
# key: 329
# already investigated...
# key: 330
# already investigated...
# key: 331
# already investigated...
# key: 332
# already investigated...
# key: 333
# already investigated...
# key: 334
# already investigated...
# key: 335
# already investigated...
# key: 336
# already investigated...
# key: 337
# already investigated...
# key: 338
# already investigated...
# key: 339
# already investigated...
# key: 340
# already investigated...
# key: 341
# already investigated...
# key: 342
# already investigated...
# key: 343
# already investigated...
# key: 344
# already investigated...
# key: 345
# already investigated...
# key: 346
# already investigated...
# key: 347
# already investigated...
# key: 348
# already investigated...
# key: 349
# already investigated...
# key: 350
# already investigated...
# key: 351
# already investigated...
# key: 352
# already investigated...
# key: 353
# already investigated...
# key: 354
# already investigated...
# key: 355
# already investigated...
# key: 356
# already investigated...
# key: 357
# already investigated...
# key: 358
# already investigated...
# key: 359
# already investigated...
# key: 360
# already investigated...
# key: 361
# already investigated...
# key: 362
# already investigated...
# key: 363
# already investigated...
# key: 364
# already investigated...
# key: 365
# already investigated...
# key: 366
# already investigated...
# key: 367
# already investigated...
# key: 368
# already investigated...
# key: 369
# already investigated...
# key: 370
# already investigated...
# key: 371
# already investigated...
# key: 372
# already investigated...
# key: 373
# already investigated...
# key: 374
# already investigated...
# key: 375
# already investigated...
# key: 376
# already investigated...
# key: 377
# already investigated...
# key: 378
# already investigated...
# key: 379
# already investigated...
# key: 380
# already investigated...
# key: 381
# already investigated...
# key: 382
# already investigated...
# key: 383
# already investigated...
# key: 384
# already investigated...
# key: 385
# already investigated...
# key: 386
# already investigated...
# key: 387
# already investigated...
# key: 388
# already investigated...
# key: 389
# already investigated...
# key: 390
# already investigated...
# key: 391
# already investigated...
# key: 392
# already investigated...
# key: 393
# already investigated...
# key: 394
# already investigated...
# key: 395
# already investigated...
# key: 396
# already investigated...
# key: 397
# already investigated...
# key: 398
# already investigated...
# key: 399
# already investigated...
# key: 400
# already investigated...
# key: 401
# already investigated...
# key: 402
# already investigated...
# key: 403
# already investigated...
# key: 404
# already investigated...
# key: 405
# already investigated...
# key: 406
# already investigated...
# key: 407
# already investigated...
# key: 408
# already investigated...
# key: 409
# already investigated...
# key: 410
# already investigated...
# key: 411
# already investigated...
# key: 412
# already investigated...
# key: 413
# already investigated...
# key: 414
# already investigated...
# key: 415
# already investigated...
# key: 416
# already investigated...
# key: 417
# already investigated...
# key: 418
# already investigated...
# key: 419
# already investigated...
# key: 420
# already investigated...
# key: 421
# already investigated...
# key: 422
# already investigated...
# key: 423
# already investigated...
# key: 424
# already investigated...
# key: 425
# already investigated...
# key: 426
# already investigated...
# key: 427
# already investigated...
# key: 428
# already investigated...
# key: 429
# already investigated...
# key: 430
# already investigated...
# key: 431
# already investigated...
# key: 432
# already investigated...
# key: 433
# already investigated...
# key: 434
# already investigated...
# key: 435
# already investigated...
# key: 436
# already investigated...
# key: 437
# already investigated...
# key: 438
# already investigated...
# key: 439
# already investigated...
# key: 440
# already investigated...
# key: 441
# already investigated...
# key: 442
# already investigated...
# key: 443
# already investigated...
# key: 444
# already investigated...
# key: 445
# already investigated...
# key: 446
# already investigated...
# key: 447
# already investigated...
# key: 448
# already investigated...
# key: 449
# already investigated...
# key: 450
# already investigated...
# key: 451
# already investigated...
# key: 452
# already investigated...
# key: 453
# already investigated...
# key: 454
# already investigated...
# key: 455
# already investigated...
# key: 456
# already investigated...
# key: 457
# already investigated...
# key: 458
# already investigated...
# key: 459
# already investigated...
# key: 460
# already investigated...
# key: 461
# already investigated...
# key: 462
# already investigated...
# key: 463
# already investigated...
# key: 464
# already investigated...
# key: 465
# already investigated...
# key: 466
# already investigated...
# key: 467
# already investigated...
# key: 468
# already investigated...
# key: 469
# already investigated...
# key: 470
# already investigated...
# key: 471
# already investigated...
# key: 472
# already investigated...
# key: 473
# already investigated...
# key: 474
# already investigated...
# key: 475
# already investigated...
# key: 476
# already investigated...
# key: 477
# already investigated...
# key: 478
# already investigated...
# key: 479
# already investigated...
# key: 480
# already investigated...
# key: 481
# already investigated...
# key: 482
# already investigated...
# key: 483
# already investigated...
# key: 484
# already investigated...
# key: 485
# already investigated...
# key: 486
# already investigated...
# key: 487
# already investigated...
# key: 488
# already investigated...
# key: 489
# already investigated...
# key: 490
# already investigated...
# key: 491
# already investigated...
# key: 492
# already investigated...
# key: 493
# already investigated...
# key: 494
# already investigated...
# key: 495
# already investigated...
# key: 496
# already investigated...
# key: 497
# already investigated...
# key: 498
# already investigated...
# key: 499
# already investigated...
# key: 500
# already investigated...
# key: 501
# already investigated...
# key: 502
# already investigated...
# key: 503
# already investigated...
# key: 504
# already investigated...
# key: 505
# already investigated...
# key: 506
# already investigated...
# key: 507
# already investigated...
# key: 508
# already investigated...
# key: 509
# already investigated...
# key: 510
# already investigated...
# key: 511
# already investigated...
# key: 512
# already investigated...
# key: 513
# already investigated...
# key: 514
# already investigated...
# key: 515
# already investigated...
# key: 516
# already investigated...
# key: 517
# already investigated...
# key: 518
# already investigated...
# key: 519
# already investigated...
# key: 520
# already investigated...
# key: 521
# already investigated...
# key: 522
# already investigated...
# key: 523
# already investigated...
# key: 524
# already investigated...
# key: 525
# already investigated...
# key: 526
# already investigated...
# key: 527
# already investigated...
# key: 528
# already investigated...
# key: 529
# already investigated...
# key: 530
# already investigated...
# key: 531
# already investigated...
# key: 532
# already investigated...
# key: 533
# already investigated...
# key: 534
# already investigated...
# key: 535
# already investigated...
# key: 536
# already investigated...
# key: 537
# already investigated...
# key: 538
# already investigated...
# key: 539
# already investigated...
# key: 540
# already investigated...
# key: 541
# already investigated...
# key: 542
# already investigated...
# key: 543
# already investigated...
# key: 544
# already investigated...
# key: 545
# already investigated...
# key: 546
# already investigated...
# key: 547
# already investigated...
# key: 548
# already investigated...
# key: 549
# already investigated...
# key: 550
# already investigated...
# key: 551
# already investigated...
# key: 552
# already investigated...
# key: 553
# already investigated...
# key: 554
# already investigated...
# key: 555
# already investigated...
# key: 556
# already investigated...
# key: 557
# already investigated...
# key: 558
# already investigated...
# key: 559
# already investigated...
# key: 560
# already investigated...
# key: 561
# already investigated...
# key: 562
# already investigated...
# key: 563
# already investigated...
# key: 564
# already investigated...
# key: 565
# already investigated...
# key: 566
# already investigated...
# key: 567
# already investigated...
# key: 568
# already investigated...
# key: 569
# already investigated...
# key: 570
# already investigated...
# key: 571
# already investigated...
# key: 572
# already investigated...
# key: 573
# already investigated...
# key: 574
# already investigated...
# key: 575
# already investigated...
# key: 576
# already investigated...
# key: 577
# already investigated...
# key: 578
# already investigated...
# key: 579
# already investigated...
# key: 580
# already investigated...
# key: 581
# already investigated...
# key: 582
# already investigated...
# key: 583
# already investigated...
# key: 584
# already investigated...
# key: 585
# already investigated...
# key: 586
# already investigated...
# key: 587
# already investigated...
# key: 588
# already investigated...
# key: 589
# already investigated...
# key: 590
# already investigated...
# key: 591
# already investigated...
# key: 592
# already investigated...
# key: 593
# already investigated...
# key: 594
# already investigated...
# key: 595
# already investigated...
# key: 596
# already investigated...
# key: 597
# already investigated...
# key: 598
# already investigated...
# key: 599
# already investigated...
# key: 600
# already investigated...
# key: 601
# already investigated...
# key: 602
# already investigated...
# key: 603
# already investigated...
# key: 604
# already investigated...
# key: 605
# already investigated...
# key: 606
# already investigated...
# key: 607
# already investigated...
# key: 608
# already investigated...
# key: 609
# already investigated...
# key: 610
# already investigated...
# key: 611
# already investigated...
# key: 612
# already investigated...
# key: 613
# already investigated...
# key: 614
# already investigated...
# key: 615
# already investigated...
# key: 616
# already investigated...
# key: 617
# already investigated...
# key: 618
# already investigated...
# key: 619
# already investigated...
# key: 620
# already investigated...
# key: 621
# already investigated...
# key: 622
# already investigated...
# key: 623
# already investigated...
# key: 624
# already investigated...
# key: 625
# already investigated...
# key: 626
# already investigated...
# key: 627
# already investigated...
# key: 628
# already investigated...
# key: 629
# already investigated...
# key: 630
# already investigated...
# key: 631
# already investigated...
# key: 632
# already investigated...
# key: 633
# already investigated...
# key: 634
# already investigated...
# key: 635
# already investigated...
# key: 636
# already investigated...
# key: 637
# already investigated...
# key: 638
# already investigated...
# key: 639
# already investigated...
# key: 640
# already investigated...
# key: 641
# already investigated...
# key: 642
# already investigated...
# key: 643
# already investigated...
# key: 644
# already investigated...
# key: 645
# already investigated...
# key: 646
# already investigated...
# key: 647
# already investigated...
# key: 648
# already investigated...
# key: 649
# already investigated...
# key: 650
# already investigated...
# key: 651
# already investigated...
# key: 652
# already investigated...
# key: 653
# already investigated...
# key: 654
# already investigated...
# key: 655
# already investigated...
# key: 656
# already investigated...
# key: 657
# already investigated...
# key: 658
# already investigated...
# key: 659
# already investigated...
# key: 660
# already investigated...
# key: 661
# already investigated...
# key: 662
# already investigated...
# key: 663
# already investigated...
# key: 664
# already investigated...
# key: 665
# already investigated...
# key: 666
# already investigated...
# key: 667
# already investigated...
# key: 668
# already investigated...
# key: 669
# already investigated...
# key: 670
# already investigated...
# key: 671
# already investigated...
# key: 672
# already investigated...
# key: 673
# already investigated...
# key: 674
# already investigated...
# key: 675
# already investigated...
# key: 676
# already investigated...
# key: 677
# already investigated...
# key: 678
# already investigated...
# key: 679
# already investigated...
# key: 680
# already investigated...
# key: 681
# already investigated...
# key: 682
# already investigated...
# key: 683
# already investigated...
# key: 684
# already investigated...
# key: 685
# already investigated...
# key: 686
# already investigated...
# key: 687
# already investigated...
# key: 688
# already investigated...
# key: 689
# already investigated...
# key: 690
# already investigated...
# key: 691
# already investigated...
# key: 692
# already investigated...
# key: 693
# already investigated...
# key: 694
# already investigated...
# key: 695
# already investigated...
# key: 696
# already investigated...
# key: 697
# already investigated...
# key: 698
# already investigated...
# key: 699
# already investigated...
# key: 700
# already investigated...
# key: 701
# already investigated...
# key: 702
# already investigated...
# key: 703
# already investigated...
# key: 704
# already investigated...
# key: 705
# already investigated...
# key: 706
# already investigated...
# key: 707
# already investigated...
# key: 708
# already investigated...
# key: 709
# already investigated...
# key: 710
# already investigated...
# key: 711
# already investigated...
# key: 712
# already investigated...
# key: 713
# already investigated...
# key: 714
# already investigated...
# key: 715
# already investigated...
# key: 716
# already investigated...
# key: 717
# already investigated...
# key: 718
# already investigated...
# key: 719
# already investigated...
# key: 720
# already investigated...
# key: 721
# already investigated...
# key: 722
# already investigated...
# key: 723
# already investigated...
# key: 724
# already investigated...
# key: 725
# already investigated...
# key: 726
# already investigated...
# key: 727
# already investigated...
# key: 728
# already investigated...
# key: 729
# already investigated...
# key: 730
# already investigated...
# key: 731
# already investigated...
# key: 732
# already investigated...
# key: 733
# already investigated...
# key: 734
# already investigated...
# key: 735
# already investigated...
# key: 736
# already investigated...
# key: 737
# already investigated...
# key: 738
# already investigated...
# key: 739
# already investigated...
# key: 740
# already investigated...
# key: 741
# already investigated...
# key: 742
# already investigated...
# key: 743
# already investigated...
# key: 744
# already investigated...
# key: 745
# already investigated...
# key: 746
# already investigated...
# key: 747
# already investigated...
# key: 748
# already investigated...
# key: 749
# already investigated...
# key: 750
# already investigated...
# key: 751
# already investigated...
# key: 752
# already investigated...
# key: 753
# already investigated...
# key: 754
# already investigated...
# key: 755
# already investigated...
# key: 756
# already investigated...
# key: 757
# already investigated...
# key: 758
# already investigated...
# key: 759
# already investigated...
# key: 760
# already investigated...
# key: 761
# already investigated...
# key: 762
# already investigated...
# key: 763
# already investigated...
# key: 764
# already investigated...
# key: 765
# already investigated...
# key: 766
# already investigated...
# key: 767
# already investigated...
# key: 768
# already investigated...
# key: 769
# already investigated...
# key: 770
# already investigated...
# key: 771
# already investigated...
# key: 772
# already investigated...
# key: 773
# already investigated...
# key: 774
# already investigated...
# key: 775
# already investigated...
# key: 776
# already investigated...
# key: 777
# already investigated...
# key: 778
# already investigated...
# key: 779
# already investigated...
# key: 780
# already investigated...
# key: 781
# already investigated...
# key: 782
# already investigated...
# key: 783
# already investigated...
# key: 784
# already investigated...
# key: 785
# already investigated...
# key: 786
# already investigated...
# key: 787
# already investigated...
# key: 788
# already investigated...
# key: 789
# already investigated...
# key: 790
# already investigated...
# key: 791
# already investigated...
# key: 792
# already investigated...
# key: 793
# already investigated...
# key: 794
# already investigated...
# key: 795
# already investigated...
# key: 796
# already investigated...
# key: 797
# already investigated...
# key: 798
# already investigated...
# key: 799
# already investigated...
# key: 800
# already investigated...
# key: 801
# already investigated...
# key: 802
# already investigated...
# key: 803
# already investigated...
# key: 804
# already investigated...
# key: 805
# already investigated...
# key: 806
# already investigated...
# key: 807
# already investigated...
# key: 808
# already investigated...
# key: 809
# already investigated...
# key: 810
# already investigated...
# key: 811
# already investigated...
# key: 812
# already investigated...
# key: 813
# already investigated...
# key: 814
# already investigated...
# key: 815
# already investigated...
# key: 816
# already investigated...
# key: 817
# already investigated...
# key: 818
# already investigated...
# key: 819
# already investigated...
# key: 820
# already investigated...
# key: 821
# already investigated...
# key: 822
# already investigated...
# key: 823
# already investigated...
# key: 824
# already investigated...
# key: 825
# already investigated...
# key: 826
# already investigated...
# key: 827
# already investigated...
# key: 828
# already investigated...
# key: 829
# already investigated...
# key: 830
# already investigated...
# key: 831
# already investigated...
# key: 832
# already investigated...
# key: 833
# already investigated...
# key: 834
# already investigated...
# key: 835
# already investigated...
# key: 836
# already investigated...
# key: 837
# already investigated...
# key: 838
# already investigated...
# key: 839
# already investigated...
# key: 840
# already investigated...
# key: 841
# already investigated...
# key: 842
# already investigated...
# key: 843
# already investigated...
# key: 844
# already investigated...
# key: 845
# already investigated...
# key: 846
# already investigated...
# key: 847
# already investigated...
# key: 848
# already investigated...
# key: 849
# already investigated...
# key: 850
# already investigated...
# key: 851
# already investigated...
# key: 852
# already investigated...
# key: 853
# already investigated...
# key: 854
# already investigated...
# key: 855
# already investigated...
# key: 856
# already investigated...
# key: 857
# already investigated...
# key: 858
# already investigated...
# key: 859
# already investigated...
# key: 860
# already investigated...
# key: 861
# already investigated...
# key: 862
# already investigated...
# key: 863
# already investigated...
# key: 864
# already investigated...
# key: 865
# already investigated...
# key: 866
# already investigated...
# key: 867
# already investigated...
# key: 868
# already investigated...
# key: 869
# already investigated...
# key: 870
# already investigated...
# key: 871
# already investigated...
# key: 872
# already investigated...
# key: 873
# already investigated...
# key: 874
# already investigated...
# key: 875
# already investigated...
# key: 876
# already investigated...
# key: 877
# already investigated...
# key: 878
# already investigated...
# key: 879
# already investigated...
# key: 880
# already investigated...
# key: 881
# already investigated...
# key: 882
# already investigated...
# key: 883
# already investigated...
# key: 884
# already investigated...
# key: 885
# already investigated...
# key: 886
# already investigated...
# key: 887
# already investigated...
# key: 888
# already investigated...
# key: 889
# already investigated...
# key: 890
# already investigated...
# key: 891
# already investigated...
# key: 892
# already investigated...
# key: 893
# already investigated...
# key: 894
# already investigated...
# key: 895
# already investigated...
# key: 896
# already investigated...
# key: 897
# already investigated...
# key: 898
# already investigated...
# key: 899
# already investigated...
# key: 900
# already investigated...
# key: 901
# already investigated...
# key: 902
# already investigated...
# key: 903
# already investigated...
# key: 904
# already investigated...
# key: 905
# already investigated...
# key: 906
# already investigated...
# key: 907
# already investigated...
# key: 908
# already investigated...
# key: 909
# already investigated...
# key: 910
# already investigated...
# key: 911
# already investigated...
# key: 912
# already investigated...
# key: 913
# already investigated...
# key: 914
# already investigated...
# key: 915
# already investigated...
# key: 916
# already investigated...
# key: 917
# already investigated...
# key: 918
# already investigated...
# key: 919
# already investigated...
# key: 920
# already investigated...
# key: 921
# already investigated...
# key: 922
# already investigated...
# key: 923
# already investigated...
# key: 924
# already investigated...
# key: 925
# already investigated...
# key: 926
# already investigated...
# key: 927
# already investigated...
# key: 928
# already investigated...
# key: 929
# already investigated...
# key: 930
# already investigated...
# key: 931
# already investigated...
# key: 932
# already investigated...
# key: 933
# already investigated...
# key: 934
# already investigated...
# key: 935
# already investigated...
# key: 936
# already investigated...
# key: 937
# already investigated...
# key: 938
# already investigated...
# key: 939
# already investigated...
# key: 940
# already investigated...
# key: 941
# already investigated...
# key: 942
# already investigated...
# key: 943
# already investigated...
# key: 944
# already investigated...
# key: 945
# already investigated...
# key: 946
# already investigated...
# key: 947
# already investigated...
# key: 948
# already investigated...
# key: 949
# already investigated...
# key: 950
# already investigated...
# key: 951
# already investigated...
# key: 952
# already investigated...
# key: 953
# already investigated...
# key: 954
# already investigated...
# key: 955
# already investigated...
# key: 956
# already investigated...
# key: 957
# already investigated...
# key: 958
# already investigated...
# key: 959
# already investigated...
# key: 960
# already investigated...
# key: 961
# already investigated...
# key: 962
# already investigated...
# key: 963
# already investigated...
# key: 964
# already investigated...
# key: 965
# already investigated...
# key: 966
# already investigated...
# key: 967
# already investigated...
# key: 968
# already investigated...
# key: 969
# already investigated...
# key: 970
# already investigated...
# key: 971
# already investigated...
# key: 972
# already investigated...
# key: 973
# already investigated...
# key: 974
# already investigated...
# key: 975
# already investigated...
# key: 976
# already investigated...
# key: 977
# already investigated...
# key: 978
# already investigated...
# key: 979
# already investigated...
# key: 980
# already investigated...
# key: 981
# already investigated...
# key: 982
# already investigated...
# key: 983
# already investigated...
# key: 984
# already investigated...
# key: 985
# already investigated...
# key: 986
# already investigated...
# key: 987
# already investigated...
# key: 988
# already investigated...
# key: 989
# already investigated...
# key: 990
# already investigated...
# key: 991
# already investigated...
# key: 992
# already investigated...
# key: 993
# already investigated...
# key: 994
# already investigated...
# key: 995
# already investigated...
# key: 996
# already investigated...
# key: 997
# already investigated...
# key: 998
# already investigated...
# key: 999
# already investigated...
# key: 1000
# already investigated...
# key: 1001
# already investigated...
# key: 1002
# already investigated...
# key: 1003
# already investigated...
# key: 1004
# already investigated...
# key: 1005
# already investigated...
# key: 1006
# already investigated...
# key: 1007
# already investigated...
# key: 1008
# already investigated...
# key: 1009
# already investigated...
# key: 1010
# already investigated...
# key: 1011
# already investigated...
# key: 1012
# already investigated...
# key: 1013
# already investigated...
# key: 1014
# already investigated...
# key: 1015
# already investigated...
# key: 1016
# already investigated...
# key: 1017
# already investigated...
# key: 1018
# already investigated...
# key: 1019
# already investigated...
# key: 1020
# already investigated...
# key: 1021
# already investigated...
# key: 1022
# already investigated...
# key: 1023
# already investigated...
# key: 1024
# already investigated...
# key: 1025
# already investigated...
# key: 1026
# already investigated...
# key: 1027
# already investigated...
# key: 1028
# already investigated...
# key: 1029
# already investigated...
# key: 1030
# already investigated...
# key: 1031
# already investigated...
# key: 1032
# already investigated...
# key: 1033
# already investigated...
# key: 1034
# already investigated...
# key: 1035
# already investigated...
# key: 1036
# already investigated...
# key: 1037
# already investigated...
# key: 1038
# already investigated...
# key: 1039
# already investigated...
# key: 1040
# already investigated...
# key: 1041
# No data elements in server response. Check log and query location/tags.
# key: 1042
# No data elements in server response. Check log and query location/tags.
# key: 1043
# No data elements in server response. Check log and query location/tags.
# key: 1044
# No data elements in server response. Check log and query location/tags.
# key: 1045
# already investigated...
# key: 1046
# already investigated...
# key: 1047
# already investigated...
# key: 1048
# already investigated...
# key: 1049
# already investigated...
# key: 1050
# already investigated...
# key: 1051
# already investigated...
# key: 1052
# already investigated...
# key: 1053
# already investigated...
# key: 1054
# already investigated...
# key: 1055
# already investigated...
# key: 1056
# already investigated...
# key: 1057
# already investigated...
# key: 1058
# already investigated...
# key: 1059
# already investigated...
# key: 1060
# already investigated...
# key: 1061
# already investigated...
# key: 1062
# already investigated...
# key: 1063
# already investigated...
# key: 1064
# already investigated...
# key: 1065
# already investigated...
# key: 1066
# already investigated...
# key: 1067
# already investigated...
# key: 1068
# already investigated...
# key: 1069
# already investigated...
# key: 1070
# already investigated...
# key: 1071
# already investigated...
# key: 1072
# already investigated...
# key: 1073
# already investigated...
# key: 1074
# already investigated...
# key: 1075
# already investigated...
# key: 1076
# already investigated...
# key: 1077
# already investigated...
# key: 1078
# already investigated...
# key: 1079
# already investigated...
# key: 1080
# already investigated...
# key: 1081
# already investigated...
# key: 1082
# already investigated...
# key: 1083
# already investigated...
# key: 1084
# already investigated...
# key: 1085
# already investigated...
# key: 1086
# already investigated...
# key: 1087
# already investigated...
# key: 1088
# already investigated...
# key: 1089
# already investigated...
# key: 1090
# already investigated...
# key: 1091
# already investigated...
# key: 1092
# already investigated...
# key: 1093
# already investigated...
# key: 1094
# already investigated...
# key: 1095
# already investigated...
# key: 1096
# already investigated...
# key: 1097
# already investigated...
# key: 1098
# already investigated...
# key: 1099
# already investigated...
# key: 1100
# already investigated...
# key: 1101
# already investigated...
# key: 1102
# already investigated...
# key: 1103
# already investigated...
# key: 1104
# already investigated...
# key: 1105
# already investigated...
# key: 1106
# already investigated...
# key: 1107
# already investigated...
# key: 1108
# already investigated...
# key: 1109
# already investigated...
# key: 1110
# already investigated...
# key: 1111
# already investigated...
# key: 1112
# already investigated...
# key: 1113
# already investigated...
# key: 1114
# already investigated...
# key: 1115
# already investigated...
# key: 1116
# already investigated...
# key: 1117
# already investigated...
# key: 1118
# already investigated...
# key: 1119
# already investigated...
# key: 1120
# already investigated...
# key: 1121
# already investigated...
# key: 1122
# already investigated...
# key: 1123
# already investigated...
# key: 1124
# already investigated...
# key: 1125
# already investigated...
# key: 1126
# already investigated...
# key: 1127
# already investigated...
# key: 1128
# already investigated...
# key: 1129
# already investigated...
# key: 1130
# already investigated...
# key: 1131
# already investigated...
# key: 1132
# already investigated...
# key: 1133
# already investigated...
# key: 1134
# already investigated...
# key: 1135
# already investigated...
# key: 1136
# already investigated...
# key: 1137
# already investigated...
# key: 1138
# already investigated...
# key: 1139
# already investigated...
# key: 1140
# already investigated...
# key: 1141
# already investigated...
# key: 1142
# already investigated...
# key: 1143
# already investigated...
# key: 1144
# already investigated...
# key: 1145
# already investigated...
# key: 1146
# already investigated...
# key: 1147
# already investigated...
# key: 1148
# already investigated...
# key: 1149
# already investigated...
# key: 1150
# already investigated...
# key: 1151
# already investigated...
# key: 1152
# already investigated...
# key: 1153
# already investigated...
# key: 1154
# already investigated...
# key: 1155
# already investigated...
# key: 1156
# already investigated...
# key: 1157
# already investigated...
# key: 1158
# already investigated...
# key: 1159
# already investigated...
# key: 1160
# already investigated...
# key: 1161
# already investigated...
# key: 1162
# already investigated...
# key: 1163
# already investigated...
# key: 1164
# already investigated...
# key: 1165
# already investigated...
# key: 1166
# already investigated...
# key: 1167
# already investigated...
# key: 1168
# already investigated...
# key: 1169
# already investigated...
# key: 1170
# already investigated...
# key: 1171
# already investigated...
# key: 1172
# already investigated...
# key: 1173
# already investigated...
# key: 1174
# already investigated...
# key: 1175
# already investigated...
# key: 1176
# already investigated...
# key: 1177
# already investigated...
# key: 1178
# already investigated...
# key: 1179
# already investigated...
# key: 1180
# already investigated...
# key: 1181
# already investigated...
# key: 1182
# already investigated...
# key: 1183
# already investigated...
# key: 1184
# already investigated...
# key: 1185
# already investigated...
# key: 1186
# already investigated...
# key: 1187
# already investigated...
# key: 1188
# already investigated...
# key: 1189
# already investigated...
# key: 1190
# already investigated...
# key: 1191
# already investigated...
# key: 1192
# already investigated...
# key: 1193
# already investigated...
# key: 1194
# already investigated...
# key: 1195
# already investigated...
# key: 1196
# already investigated...
# key: 1197
# already investigated...
# key: 1198
# already investigated...
# key: 1199
# already investigated...
# key: 1200
# already investigated...
# key: 1201
# already investigated...
# key: 1202
# already investigated...
# key: 1203
# already investigated...
# key: 1204
# already investigated...
# key: 1205
# already investigated...
# key: 1206
# already investigated...
# key: 1207
# already investigated...
# key: 1208
# already investigated...
# key: 1209
# already investigated...
# key: 1210
# already investigated...
# key: 1211
# already investigated...
# key: 1212
# already investigated...
# key: 1213
# already investigated...
# key: 1214
# already investigated...
# key: 1215
# already investigated...
# key: 1216
# already investigated...
# key: 1217
# already investigated...
# key: 1218
# already investigated...
# key: 1219
# already investigated...
# key: 1220
# already investigated...
# key: 1221
# already investigated...
# key: 1222
# already investigated...
# key: 1223
# already investigated...
# key: 1224
# already investigated...
# key: 1225
# already investigated...
# key: 1226
# already investigated...
# key: 1227
# already investigated...
# key: 1228
# already investigated...
# key: 1229
# already investigated...
# key: 1230
# already investigated...
# key: 1231
# already investigated...
# key: 1232
# already investigated...
# key: 1233
# already investigated...
# key: 1234
# already investigated...
# key: 1235
# already investigated...
# key: 1236
# already investigated...
# key: 1237
# already investigated...
# key: 1238
# already investigated...
# key: 1239
# already investigated...
# key: 1240
# already investigated...
# key: 1241
# already investigated...
# key: 1242
# already investigated...
# key: 1243
# already investigated...
# key: 1244
# already investigated...
# key: 1245
# already investigated...
# key: 1246
# already investigated...
# key: 1247
# already investigated...
# key: 1248
# already investigated...
# key: 1249
# already investigated...
# key: 1250
# already investigated...
# key: 1251
# already investigated...
# key: 1252
# already investigated...
# key: 1253
# already investigated...
# key: 1254
# already investigated...
# key: 1255
# already investigated...
# key: 1256
# already investigated...
# key: 1257
# already investigated...
# key: 1258
# already investigated...
# key: 1259
# already investigated...
# key: 1260
# already investigated...
# key: 1261
# already investigated...
# key: 1262
# already investigated...
# key: 1263
# already investigated...
# key: 1264
# already investigated...
# key: 1265
# already investigated...
# key: 1266
# already investigated...
# key: 1267
# already investigated...
# key: 1268
# already investigated...
# key: 1269
# already investigated...
# key: 1270
# already investigated...
# key: 1271
# already investigated...
# key: 1272
# already investigated...
# key: 1273
# already investigated...
# key: 1274
# already investigated...
# key: 1275
# already investigated...
# key: 1276
# already investigated...
# key: 1277
# already investigated...
# key: 1278
# already investigated...
# key: 1279
# already investigated...
# key: 1280
# already investigated...
# key: 1281
# already investigated...
# key: 1282
# already investigated...
# key: 1283
# already investigated...
# key: 1284
# already investigated...
# key: 1285
# already investigated...
# key: 1286
# already investigated...
# key: 1287
# already investigated...
# key: 1288
# already investigated...
# key: 1289
# already investigated...
# key: 1290
# already investigated...
# key: 1291
# already investigated...
# key: 1292
# already investigated...
# key: 1293
# already investigated...
# key: 1294
# already investigated...
# key: 1295
# already investigated...
# key: 1296
# already investigated...
# key: 1297
# already investigated...
# key: 1298
# already investigated...
# key: 1299
# already investigated...
# key: 1300
# already investigated...
# key: 1301
# already investigated...
# key: 1302
# already investigated...
# key: 1303
# already investigated...
# key: 1304
# already investigated...
# key: 1305
# already investigated...
# key: 1306
# already investigated...
# key: 1307
# already investigated...
# key: 1308
# already investigated...
# key: 1309
# already investigated...
# key: 1310
# already investigated...
# key: 1311
# already investigated...
# key: 1312
# already investigated...
# key: 1313
# already investigated...
# key: 1314
# already investigated...
# key: 1315
# already investigated...
# key: 1316
# already investigated...
# key: 1317
# already investigated...
# key: 1318
# already investigated...
# key: 1319
# already investigated...
# key: 1320
# already investigated...
# key: 1321
# already investigated...
# key: 1322
# already investigated...
# key: 1323
# already investigated...
# key: 1324
# already investigated...
# key: 1325
# already investigated...
# key: 1326
# already investigated...
# key: 1327
# already investigated...
# key: 1328
# already investigated...
# key: 1329
# already investigated...
# key: 1330
# already investigated...
# key: 1331
# already investigated...
# key: 1332
# already investigated...
# key: 1333
# already investigated...
# key: 1334
# already investigated...
# key: 1335
# already investigated...
# key: 1336
# already investigated...
# key: 1337
# already investigated...
# key: 1338
# already investigated...
# key: 1339
# already investigated...
# key: 1340
# already investigated...
# key: 1341
# already investigated...
# key: 1342
# already investigated...
# key: 1343
# already investigated...
# key: 1344
# already investigated...
# key: 1345
# already investigated...
# key: 1346
# already investigated...
# key: 1347
# already investigated...
# key: 1348
# already investigated...
# key: 1349
# already investigated...
# key: 1350
# already investigated...
# key: 1351
# already investigated...
# key: 1352
# already investigated...
# key: 1353
# already investigated...
# key: 1354
# already investigated...
# key: 1355
# already investigated...
# key: 1356
# already investigated...
# key: 1357
# already investigated...
# key: 1358
# already investigated...
# key: 1359
# already investigated...
# key: 1360
# already investigated...
# key: 1361
# already investigated...
# key: 1362
# already investigated...
# key: 1363
# already investigated...
# key: 1364
# already investigated...
# key: 1365
# already investigated...
# key: 1366
# already investigated...
# key: 1367
# already investigated...
# key: 1368
# already investigated...
# key: 1369
# already investigated...
# key: 1370
# already investigated...
# key: 1371
# already investigated...
# key: 1372
# already investigated...
# key: 1373
# already investigated...
# key: 1374
# already investigated...
# key: 1375
# already investigated...
# key: 1376
# already investigated...
# key: 1377
# already investigated...
# key: 1378
# already investigated...
# key: 1379
# already investigated...
# key: 1380
# already investigated...
# key: 1381
# already investigated...
# key: 1382
# already investigated...
# key: 1383
# already investigated...
# key: 1384
# already investigated...
# key: 1385
# already investigated...
# key: 1386
# already investigated...
# key: 1387
# already investigated...
# key: 1388
# already investigated...
# key: 1389
# already investigated...
# key: 1390
# already investigated...
# key: 1391
# already investigated...
# key: 1392
# already investigated...
# key: 1393
# already investigated...
# key: 1394
# already investigated...
# key: 1395
# already investigated...
# key: 1396
# already investigated...
# key: 1397
# already investigated...
# key: 1398
# already investigated...
# key: 1399
# already investigated...
# key: 1400
# already investigated...
# key: 1401
# already investigated...
# key: 1402
# already investigated...
# key: 1403
# already investigated...
# key: 1404
# already investigated...
# key: 1405
# already investigated...
# key: 1406
# already investigated...
# key: 1407
# already investigated...
# key: 1408
# already investigated...
# key: 1409
# already investigated...
# key: 1410
# already investigated...
# key: 1411
# already investigated...
# key: 1412
# already investigated...
# key: 1413
# already investigated...
# key: 1414
# already investigated...
# key: 1415
# already investigated...
# key: 1416
# already investigated...
# key: 1417
# already investigated...
# key: 1418
# already investigated...
# key: 1419
# already investigated...
# key: 1420
# already investigated...
# key: 1421
# already investigated...
# key: 1422
# already investigated...
# key: 1423
# already investigated...
# key: 1424
# already investigated...
# key: 1425
# already investigated...
# key: 1426
# already investigated...
# key: 1427
# already investigated...
# key: 1428
# already investigated...
# key: 1429
# already investigated...
# key: 1430
# already investigated...
# key: 1431
# already investigated...
# key: 1432
# already investigated...
# key: 1433
# already investigated...
# key: 1434
# already investigated...
# key: 1435
# already investigated...
# key: 1436
# already investigated...
# key: 1437
# already investigated...
# key: 1438
# ...
# already investigated...
# key: 3925
# already investigated...
# key: 3926
# already investigated...
# key: 3927
# already investigated...
# key: 3928
# already investigated...
# key: 3929
# already investigated...
# key: 3930
# already investigated...
# key: 3931
# already investigated...
# key: 3932
# already investigated...
# key: 3933
# already investigated...
# key: 3934
# already investigated...
# key: 3935
# already investigated...
# key: 3936
# already investigated...
# key: 3937
# already investigated...
# key: 3938
# already investigated...
# key: 3939
# already investigated...
# key: 3940
# already investigated...
# key: 3941
# already investigated...
# key: 3942
# already investigated...
# key: 3943
# already investigated...
# key: 3944
# already investigated...
# key: 3945
# already investigated...
# key: 3946
# already investigated...
# key: 3947
# already investigated...
# key: 3948
# already investigated...
# key: 3949
# already investigated...
# key: 3950
# already investigated...
# key: 3951
# already investigated...
# key: 3952
# already investigated...
# key: 3953
# already investigated...
# key: 3954
# already investigated...
# key: 3955
# already investigated...
# key: 3956
# already investigated...
# key: 3957
# already investigated...
# key: 3958
# already investigated...
# key: 3959
# already investigated...
# key: 3960
# already investigated...
# key: 3961
# already investigated...
# key: 3962
# already investigated...
# key: 3963
# already investigated...
# key: 3964
# already investigated...
# key: 3965
# already investigated...
# key: 3966
# already investigated...
# key: 3967
# already investigated...
# key: 3968
# already investigated...
# key: 3969
# already investigated...
# key: 3970
# already investigated...
# key: 3971
# already investigated...
# key: 3972
# already investigated...
# key: 3973
# already investigated...
# key: 3974
# already investigated...
# key: 3975
# already investigated...
# key: 3976
# already investigated...
# key: 3977
# already investigated...
# key: 3978
# already investigated...
# key: 3979
# already investigated...
# key: 3980
# already investigated...
# key: 3981
# already investigated...
# key: 3982
# already investigated...
# key: 3983
# already investigated...
# key: 3984
# already investigated...
# key: 3985
# already investigated...
# key: 3986
# already investigated...
# key: 3987
# already investigated...
# key: 3988
# already investigated...
# key: 3989
# already investigated...
# key: 3990
# already investigated...
# key: 3991
# already investigated...
# key: 3992
# already investigated...
# key: 3993
# already investigated...
# key: 3994
# already investigated...
# key: 3995
# already investigated...
# key: 3996
# already investigated...
# key: 3997
# already investigated...
# key: 3998
# already investigated...
# key: 3999
# already investigated...
# key: 4000
# already investigated...
# key: 4001
# already investigated...
# key: 4002
# already investigated...
# key: 4003
# already investigated...
# key: 4004
# already investigated...
# key: 4005
# already investigated...
# key: 4006
# already investigated...
# key: 4007
# already investigated...
# key: 4008
# already investigated...
# key: 4009
# already investigated...
# key: 4010
# already investigated...
# key: 4011
# already investigated...
# key: 4012
# already investigated...
# key: 4013
# already investigated...
# key: 4014
# already investigated...
# key: 4015
# already investigated...
# key: 4016
# already investigated...
# key: 4017
# already investigated...
# key: 4018
# already investigated...
# key: 4019
# already investigated...
# key: 4020
# already investigated...
# key: 4021
# already investigated...
# key: 4022
# already investigated...
# key: 4023
# already investigated...
# key: 4024
# already investigated...
# key: 4025
# already investigated...
# key: 4026
# already investigated...
# key: 4027
# already investigated...
# key: 4028
# already investigated...
# key: 4029
# already investigated...
# key: 4030
# already investigated...
# key: 4031
# already investigated...
# key: 4032
# already investigated...
# key: 4033
# already investigated...
# key: 4034
# already investigated...
# key: 4035
# already investigated...
# key: 4036
# already investigated...
# key: 4037
# already investigated...
# key: 4038
# already investigated...
# key: 4039
# already investigated...
# key: 4040
# already investigated...
# key: 4041
# already investigated...
# key: 4042
# already investigated...
# key: 4043
# already investigated...
# key: 4044
# already investigated...
# key: 4045
# already investigated...
# key: 4046
# already investigated...
# key: 4047
# already investigated...
# key: 4048
# already investigated...
# key: 4049
# already investigated...
# key: 4050
# already investigated...
# key: 4051
# already investigated...
# key: 4052
# already investigated...
# key: 4053
# already investigated...
# key: 4054
# already investigated...
# key: 4055
# already investigated...
# key: 4056
# already investigated...
# key: 4057
# already investigated...
# key: 4058
# already investigated...
# key: 4059
# already investigated...
# key: 4060
# already investigated...
# key: 4061
# already investigated...
# key: 4062
# already investigated...
# key: 4063
# already investigated...
# key: 4064
# already investigated...
# key: 4065
# already investigated...
# key: 4066
# already investigated...
# key: 4067
# already investigated...
# key: 4068
# already investigated...
# key: 4069
# already investigated...
# key: 4070
# already investigated...
# key: 4071
# already investigated...
# key: 4072
# already investigated...
# key: 4073
# already investigated...
# key: 4074
# already investigated...
# key: 4075
# already investigated...
# key: 4076
# already investigated...
# key: 4077
# already investigated...
# key: 4078
# already investigated...
# key: 4079
# already investigated...
# key: 4080
# already investigated...
# key: 4081
# already investigated...
# key: 4082
# already investigated...
# key: 4083
# already investigated...
# key: 4084
# already investigated...
# key: 4085
# already investigated...
# key: 4086
# already investigated...
# key: 4087
# already investigated...
# key: 4088
# already investigated...
# key: 4089
# already investigated...
# key: 4090
# already investigated...
# key: 4091
# already investigated...
# key: 4092
# already investigated...
# key: 4093
# already investigated...
# key: 4094
# already investigated...
# key: 4095
# already investigated...
# key: 4096
# already investigated...
# key: 4097
# already investigated...
# key: 4098
# already investigated...
# key: 4099
# already investigated...
# key: 4100
# already investigated...
# key: 4101
# already investigated...
# key: 4102
# already investigated...
# key: 4103
# already investigated...
# key: 4104
# already investigated...
# key: 4105
# already investigated...
# key: 4106
# already investigated...
# key: 4107
# already investigated...
# key: 4108
# already investigated...
# key: 4109
# already investigated...
# key: 4110
# already investigated...
# key: 4111
# already investigated...
# key: 4112
# already investigated...
# key: 4113
# already investigated...
# key: 4114
# already investigated...
# key: 4115
# already investigated...
# key: 4116
# already investigated...
# key: 4117
# already investigated...
# key: 4118
# already investigated...
# key: 4119
# already investigated...
# key: 4120
# already investigated...
# key: 4121
# already investigated...
# key: 4122
# already investigated...
# key: 4123
# already investigated...
# key: 4124
# already investigated...
# key: 4125
# already investigated...
# key: 4126
# already investigated...
# key: 4127
# already investigated...
# key: 4128
# already investigated...
# key: 4129
# already investigated...
# key: 4130
# already investigated...
# key: 4131
# already investigated...
# key: 4132
# already investigated...
# key: 4133
# already investigated...
# key: 4134
# already investigated...
# key: 4135
# already investigated...
# key: 4136
# already investigated...
# key: 4137
# already investigated...
# key: 4138
# already investigated...
# key: 4139
# already investigated...
# key: 4140
# already investigated...
# key: 4141
# already investigated...
# key: 4142
# already investigated...
# key: 4143
# already investigated...
# key: 4144
# already investigated...
# key: 4145
# already investigated...
# key: 4146
# already investigated...
# key: 4147
# already investigated...
# key: 4148
# already investigated...
# key: 4149
# already investigated...
# key: 4150
# already investigated...
# key: 4151
# already investigated...
# key: 4152
# already investigated...
# key: 4153
# already investigated...
# key: 4154
# already investigated...
# key: 4155
# already investigated...
# key: 4156
# already investigated...
# key: 4157
# already investigated...
# key: 4158
# already investigated...
# key: 4159
# already investigated...
# key: 4160
# already investigated...
# key: 4161
# already investigated...
# key: 4162
# already investigated...
# key: 4163
# already investigated...
# key: 4164
# already investigated...
# key: 4165
# already investigated...
# key: 4166
# already investigated...
# key: 4167
# already investigated...
# key: 4168
# already investigated...
# key: 4169
# already investigated...
# key: 4170
# already investigated...
# key: 4171
# already investigated...
# key: 4172
# already investigated...
# key: 4173
# already investigated...
# key: 4174
# already investigated...
# key: 4175
# already investigated...
# key: 4176
# already investigated...
# key: 4177
# already investigated...
# key: 4178
# already investigated...
# key: 4179
# already investigated...
# key: 4180
# already investigated...
# key: 4181
# already investigated...
# key: 4182
# already investigated...
# key: 4183
# already investigated...
# key: 4184
# already investigated...
# key: 4185
# already investigated...
# key: 4186
# already investigated...
# key: 4187
# already investigated...
# key: 4188
# already investigated...
# key: 4189
# already investigated...
# key: 4190
# already investigated...
# key: 4191
# already investigated...
# key: 4192
# already investigated...
# key: 4193
# already investigated...
# key: 4194
# already investigated...
# key: 4195
# already investigated...
# key: 4196
# already investigated...
# key: 4197
# already investigated...
# key: 4198
# already investigated...
# key: 4199
# already investigated...
# key: 4200
# already investigated...
# key: 4201
# already investigated...
# key: 4202
# already investigated...
# key: 4203
# already investigated...
# key: 4204
# already investigated...
# key: 4205
# already investigated...
# key: 4206
# already investigated...
# key: 4207
# already investigated...
# key: 4208
# already investigated...
# key: 4209
# already investigated...
# key: 4210
# already investigated...
# key: 4211
# already investigated...
# key: 4212
# already investigated...
# key: 4213
# already investigated...
# key: 4214
# already investigated...
# key: 4215
# already investigated...
# key: 4216
# already investigated...
# key: 4217
# already investigated...
# key: 4218
# already investigated...
# key: 4219
# already investigated...
# key: 4220
# already investigated...
# key: 4221
# already investigated...
# key: 4222
# already investigated...
# key: 4223
# already investigated...
# key: 4224
# already investigated...
# key: 4225
# already investigated...
# key: 4226
# already investigated...
# key: 4227
# already investigated...
# key: 4228
# already investigated...
# key: 4229
# already investigated...
# key: 4230
# already investigated...
# key: 4231
# already investigated...
# key: 4232
# already investigated...
# key: 4233
# already investigated...
# key: 4234
# already investigated...
# key: 4235
# already investigated...
# key: 4236
# already investigated...
# key: 4237
# already investigated...
# key: 4238
# already investigated...
# key: 4239
# already investigated...
# key: 4240
# already investigated...
# key: 4241
# already investigated...
# key: 4242
# already investigated...
# key: 4243
# already investigated...
# key: 4244
# already investigated...
# key: 4245
# already investigated...
# key: 4246
# already investigated...
# key: 4247
# already investigated...
# key: 4248
# already investigated...
# key: 4249
# already investigated...
# key: 4250
# already investigated...
# key: 4251
# already investigated...
# key: 4252
# already investigated...
# key: 4253
# already investigated...
# key: 4254
# already investigated...
# key: 4255
# already investigated...
# key: 4256
# already investigated...
# key: 4257
# already investigated...
# key: 4258
# already investigated...
# key: 4259
# already investigated...
# key: 4260
# already investigated...
# key: 4261
# already investigated...
# key: 4262
# already investigated...
# key: 4263
# already investigated...
# key: 4264
# already investigated...
# key: 4265
# already investigated...
# key: 4266
# already investigated...
# key: 4267
# already investigated...
# key: 4268
# already investigated...
# key: 4269
# already investigated...
# key: 4270
# already investigated...
# key: 4271
# already investigated...
# key: 4272
# already investigated...
# key: 4273
# already investigated...
# key: 4274
# already investigated...
# key: 4275
# already investigated...
# key: 4276
# already investigated...
# key: 4277
# already investigated...
# key: 4278
# already investigated...
# key: 4279
# already investigated...
# key: 4280
# already investigated...
# key: 4281
# already investigated...
# key: 4282
# already investigated...
# key: 4283
# already investigated...
# key: 4284
# already investigated...
# key: 4285
# already investigated...
# key: 4286
# already investigated...
# key: 4287
# already investigated...
# key: 4288
# already investigated...
# key: 4289
# already investigated...
# key: 4290
# already investigated...
# key: 4291
# already investigated...
# key: 4292
# already investigated...
# key: 4293
# already investigated...
# key: 4294
# already investigated...
# key: 4295
# already investigated...
# key: 4296
# already investigated...
# key: 4297
# already investigated...
# key: 4298
# already investigated...
# key: 4299
# already investigated...
# key: 4300
# already investigated...
# key: 4301
# already investigated...
# key: 4302
# already investigated...
# key: 4303
# already investigated...
# key: 4304
# already investigated...
# key: 4305
# already investigated...
# key: 4306
# already investigated...
# key: 4307
# already investigated...
# key: 4308
# already investigated...
# key: 4309
# already investigated...
# key: 4310
# already investigated...
# key: 4311
# already investigated...
# key: 4312
# already investigated...
# key: 4313
# already investigated...
# key: 4314
# already investigated...
# key: 4315
# already investigated...
# key: 4316
# already investigated...
# key: 4317
# already investigated...
# key: 4318
# already investigated...
# key: 4319
# already investigated...
# key: 4320
# already investigated...
# key: 4321
# already investigated...
# key: 4322
# already investigated...
# key: 4323
# already investigated...
# key: 4324
# already investigated...
# key: 4325
# already investigated...
# key: 4326
# already investigated...
# key: 4327
# already investigated...
# key: 4328
# already investigated...
# key: 4329
# already investigated...
# key: 4330
# already investigated...
# key: 4331
# already investigated...
# key: 4332
# already investigated...
# key: 4333
# already investigated...
# key: 4334
# already investigated...
# key: 4335
# already investigated...
# key: 4336
# already investigated...
# key: 4337
# already investigated...
# key: 4338
# already investigated...
# key: 4339
# already investigated...
# key: 4340
# already investigated...
# key: 4341
# already investigated...
# key: 4342
# already investigated...
# key: 4343
# already investigated...
# key: 4344
# already investigated...
# key: 4345
# already investigated...
# key: 4346
# already investigated...
# key: 4347
# already investigated...
# key: 4348
# already investigated...
# key: 4349
# already investigated...
# key: 4350
# already investigated...
# key: 4351
# already investigated...
# key: 4352
# already investigated...
# key: 4353
# already investigated...
# key: 4354
# already investigated...
# key: 4355
# already investigated...
# key: 4356
# already investigated...
# key: 4357
# already investigated...
# key: 4358
# already investigated...
# key: 4359
# already investigated...
# key: 4360
# already investigated...
# key: 4361
# already investigated...
# key: 4362
# already investigated...
# key: 4363
# already investigated...
# key: 4364
# already investigated...
# key: 4365
# No data elements in server response. Check log and query location/tags.
# key: 4366
# No data elements in server response. Check log and query location/tags.
# key: 4367
# already investigated...
# key: 4368
# already investigated...
# key: 4369
# already investigated...
# key: 4370
# already investigated...
# key: 4371
# already investigated...
# key: 4372
# already investigated...
# key: 4373
# already investigated...
# key: 4374
# already investigated...
# key: 4375
# already investigated...
# key: 4376
# already investigated...
# key: 4377
# already investigated...
# key: 4378
# already investigated...
# key: 4379
# already investigated...
# key: 4380
# already investigated...
# key: 4381
# already investigated...
# key: 4382
# already investigated...
# key: 4383
# already investigated...
# key: 4384
# already investigated...
# key: 4385
# already investigated...
# key: 4386
# already investigated...
# key: 4387
# already investigated...
# key: 4388
# already investigated...
# key: 4389
# already investigated...
# key: 4390
# already investigated...
# key: 4391
# already investigated...

# %%
import pyproj
from shapely.geometry import Point
from shapely.ops import transform

wgs84_pt = Point(test_case['lng'], test_case['lat'])
wgs84 = pyproj.CRS('EPSG:4326')
utm = pyproj.CRS('EPSG:32755')

project = pyproj.Transformer.from_crs(wgs84, utm, always_xy=True).transform

utm_point = transform(project, wgs84_pt)

features = gpd.read_file('dataset/osm-poi-{0}-dist-{1}-features.geojson'.format(case_id, dist_threshold))
features = features.to_crs('EPSG:32755')

features['distance'] = [utm_point.distance(geom) for geom in features.geometry]

# %%
features
# Out:
#     element_type      osmid     highway traffic_signals:direction access  \
# 0           node  319157917         nan                       nan    yes
# 1           node  368393200         nan                       nan    nan
# 2           node  371974432         nan                       nan    nan
# 3           node  493873180    crossing                       nan    nan
# 4           node  501027469    crossing                       nan    nan
# ..           ...        ...         ...                       ...    ...
# 435     relation    6614802         nan                       nan    nan
# 436     relation    6623509         nan                       nan    nan
# 437     relation   13238592  pedestrian                       nan    nan
# 438     relation   16464561         nan                       nan    nan
# 439     relation   16505481  pedestrian                       nan    nan
#
#       amenity  fee                operator toilets:disposal unisex  ...  \
# 0     toilets   no  Melbourne City Council            flush    yes  ...
# 1      cinema  nan        Melbourne museum              nan    nan  ...
# 2    fountain  nan                     nan              nan    nan  ...
# 3         nan  nan                     nan              nan    nan  ...
# 4         nan  nan                     nan              nan    nan  ...
# ..        ...  ...                     ...              ...    ...  ...
# 435       nan  nan  Melbourne City Council              nan    nan  ...
# 436       nan  nan                     nan              nan    nan  ...
# 437       nan  nan                     nan              nan    nan  ...
# 438       nan  nan                     nan              nan    nan  ...
# 439       nan  nan                     nan              nan    nan  ...
#
#     source:population name:mk short_name political_division heritage  \
# 0                 nan     nan        nan                nan      nan
# 1                 nan     nan        nan                nan      nan
# 2                 nan     nan        nan                nan      nan
# 3                 nan     nan        nan                nan      nan
# 4                 nan     nan        nan                nan      nan
# ..                ...     ...        ...                ...      ...
# 435               nan     nan        nan                nan      nan
# 436               nan     nan        nan                nan        1
# 437               nan     nan        nan                nan      nan
# 438               nan     nan        nan                nan      nan
# 439               nan     nan        nan                nan      nan
#
#     heritage:operator                    heritage:website area  \
# 0                 nan                                 nan  nan
# 1                 nan                                 nan  nan
# 2                 nan                                 nan  nan
# 3                 nan                                 nan  nan
# 4                 nan                                 nan  nan
# ..                ...                                 ...  ...
# 435               nan                                 nan  nan
# 436               whc  http://whc.unesco.org/en/list/1131  nan
# 437               nan                                 nan  yes
# 438               nan                                 nan  nan
# 439               nan                                 nan  nan
#
#                                               geometry    distance
# 0                       POINT (321223.384 5813738.129)  218.599034
# 1                       POINT (321343.567 5814046.274)  188.373535
# 2                       POINT (321413.415 5813831.827)   37.211904
# 3                       POINT (321256.686 5813883.765)  144.563983
# 4                       POINT (321600.961 5813827.093)  204.586235
# ..                                                 ...         ...
# 435  MULTIPOLYGON (((321219.805 5813634.926, 321210...    3.048837
# 436  MULTIPOLYGON (((321415.382 5813963.959, 321416...    3.048837
# 437  POLYGON ((321571.451 5813919.342, 321569.416 5...   96.331620
# 438  POLYGON ((321163.337 5813990.989, 321180.796 5...  209.794588
# 439  POLYGON ((321495.098 5813936.836, 321494.024 5...   71.028757
#
# [440 rows x 141 columns]

# %%
# filter geometry, distance
# filter nan, no values
# filter values for yes
# involve name, short_name if not nan first
# location inside if exists!
not_consider = ['geometry', 'distance', 'element_type', 'osmid']
consider_first = ['name', 'short_name']
cols = list(features.columns)

# %%
def generate_textual_descriptions(row, cols=cols):
    full_name = ''
    for c in consider_first:
        if c in cols and row[c] != 'nan':
            full_name += ' ' + row[c]
    for c in cols:
        if c not in consider_first and c not in not_consider and ':' not in c and row[c] != 'nan' and row[c] != 'no' and 'http' not in row[c] and '[' not in row[c] and 'wiki' not in c:
            if row[c] == 'yes':
                full_name += ' ' + c
            else:
                full_name += ' {0} {1}'.format(c, row[c])
    return full_name.strip()

# %%
features['full_name'] = features.apply(generate_textual_descriptions, axis=1)
features
# Out:
#     element_type      osmid     highway traffic_signals:direction access  \
# 0           node  319157917         nan                       nan    yes
# 1           node  368393200         nan                       nan    nan
# 2           node  371974432         nan                       nan    nan
# 3           node  493873180    crossing                       nan    nan
# 4           node  501027469    crossing                       nan    nan
# ..           ...        ...         ...                       ...    ...
# 435     relation    6614802         nan                       nan    nan
# 436     relation    6623509         nan                       nan    nan
# 437     relation   13238592  pedestrian                       nan    nan
# 438     relation   16464561         nan                       nan    nan
# 439     relation   16505481  pedestrian                       nan    nan
#
#       amenity  fee                operator toilets:disposal unisex  ...  \
# 0     toilets   no  Melbourne City Council            flush    yes  ...
# 1      cinema  nan        Melbourne museum              nan    nan  ...
# 2    fountain  nan                     nan              nan    nan  ...
# 3         nan  nan                     nan              nan    nan  ...
# 4         nan  nan                     nan              nan    nan  ...
# ..        ...  ...                     ...              ...    ...  ...
# 435       nan  nan  Melbourne City Council              nan    nan  ...
# 436       nan  nan                     nan              nan    nan  ...
# 437       nan  nan                     nan              nan    nan  ...
# 438       nan  nan                     nan              nan    nan  ...
# 439       nan  nan                     nan              nan    nan  ...
#
#     name:mk short_name political_division heritage heritage:operator  \
# 0       nan        nan                nan      nan               nan
# 1       nan        nan                nan      nan               nan
# 2       nan        nan                nan      nan               nan
# 3       nan        nan                nan      nan               nan
# 4       nan        nan                nan      nan               nan
# ..      ...        ...                ...      ...               ...
# 435     nan        nan                nan      nan               nan
# 436     nan        nan                nan        1               whc
# 437     nan        nan                nan      nan               nan
# 438     nan        nan                nan      nan               nan
# 439     nan        nan                nan      nan               nan
#
#                        heritage:website area  \
# 0                                   nan  nan
# 1                                   nan  nan
# 2                                   nan  nan
# 3                                   nan  nan
# 4                                   nan  nan
# ..                                  ...  ...
# 435                                 nan  nan
# 436  http://whc.unesco.org/en/list/1131  nan
# 437                                 nan  yes
# 438                                 nan  nan
# 439                                 nan  nan
#
#                                               geometry    distance  \
# 0                       POINT (321223.384 5813738.129)  218.599034
# 1                       POINT (321343.567 5814046.274)  188.373535
# 2                       POINT (321413.415 5813831.827)   37.211904
# 3                       POINT (321256.686 5813883.765)  144.563983
# 4                       POINT (321600.961 5813827.093)  204.586235
# ..                                                 ...         ...
# 435  MULTIPOLYGON (((321219.805 5813634.926, 321210...    3.048837
# 436  MULTIPOLYGON (((321415.382 5813963.959, 321416...    3.048837
# 437  POLYGON ((321571.451 5813919.342, 321569.416 5...   96.331620
# 438  POLYGON ((321163.337 5813990.989, 321180.796 5...  209.794588
# 439  POLYGON ((321495.098 5813936.836, 321494.024 5...   71.028757
#
#                                              full_name
# 0    access amenity toilets operator Melbourne City...
# 1    IMAX Melbourne amenity cinema operator Melbour...
# 2                                     amenity fountain
# 3                      highway crossing crossing zebra
# 4    highway crossing crossing traffic_signals tact...
# ..                                                 ...
# 435  Carlton Gardens operator Melbourne City Counci...
# 436  Royal Exhibition Building and Carlton Gardens ...
# 437          highway pedestrian type multipolygon area
# 438                         building type multipolygon
# 439               highway pedestrian type multipolygon
#
# [440 rows x 142 columns]

# %%
def compute_similarities_topk(query, sentences, sentence_embeddings, model=sbert_model, k=10, verbose=False):
    query_vec = embed_texts(query)
    scores = util.dot_score(query_vec, sentence_embeddings)[0].cpu().tolist()
    doc_score_pairs = list(zip(sentences, scores))
    doc_score_pairs = sorted(doc_score_pairs, key=lambda x: x[1], reverse=True)
    if verbose:
        print("Query:", query)
        for doc, score in doc_score_pairs:
            print('\t', score, '\t', doc)
    return np.argsort(scores)[-k:]

# %%
# example_sentence_embeddings = embed_texts(example_sentences, model=msmarco_model)
# compute_similarities(example_poi_osm, example_sentences, example_sentence_embeddings, model=msmarco_model)
feature_descriptions = list(features['full_name'])
feature_embeddings = embed_texts(feature_descriptions, model=msmarco_model)
case_description = nominatim_output[str(case_id)]['title'] + ' ' + nominatim_output[str(case_id)]['summary']
k_similar = compute_similarities_topk(case_description, feature_descriptions, feature_embeddings, model=msmarco_model, verbose=True)
k_similar
# Out:
# Query: 13. Royal Exhibition Building The Royal Exhibition Building is the only surviving Great Hall that once housed a 19th-century international exhibition and is still used for exhibitions.
# 	 44.04184341430664 	 Royal Exhibition Building and Carlton Gardens tourism attraction type multipolygon heritage 1
# 	 40.16721725463867 	 Royal Exhibition Building source Vicmap Address historic building tourism attraction building height 20 layer 1
# 	 39.15629196166992 	 Royal Exhibition Building Opening historic memorial memorial plaque
# 	 36.941375732421875 	 Melbourne Museum fee operator Museum Victoria wheelchair phone +61 3 8341 7777 source Vicmap Address tourism museum building layer 1 atm internet_access wlan opening_hours Mo-Su 10:00-17:00,09:00-17:00
# 	 36.46418380737305 	 access historic monument inscription To Victoria from one of her earliest colonists in pleasant remeberance 1840 - 88
# 	 35.37289047241211 	 Exhibition Building/Rathdowne Street highway bus_stop tactile_paving network PTV - Metropolitan Buses public_transport platform ref ID.345 bus route_ref 250;251;402
# 	 35.28831481933594 	 amenity charging_station operator Museums Victoria capacity 2 location underground
# 	 34.92707824707031 	 Exhibition Building/Rathdowne Street highway bus_stop tactile_paving network PTV - Metropolitan Buses public_transport platform ref ID.655 bus route_ref 250;251;402
# 	 34.91514205932617 	 IMAX Melbourne amenity cinema operator Melbourne museum check_date 2022-10-02 phone +61 3 9663 5454 screen 1
# 	 33.64551544189453 	 artwork_type sculpture tourism artwork
# 	 32.769840240478516 	 natural tree_row
# 	 32.769840240478516 	 natural tree_row
# 	 32.769840240478516 	 natural tree_row
# 	 32.769840240478516 	 natural tree_row
# 	 32.769840240478516 	 natural tree_row
# 	 32.05301284790039 	 natural wood leaf_type broadleaved
# 	 32.05301284790039 	 natural wood leaf_type broadleaved
# 	 31.955154418945312 	 historic monument
# 	 31.633033752441406 	 access customers amenity charging_station fee operator Melbourne Museum capacity 2
# 	 31.522321701049805 	 building office
# 	 31.441055297851562 	 Museum Cafe amenity cafe wheelchair
# 	 31.186939239501953 	 Carlton Gardens operator Melbourne City Council leisure park type multipolygon
# 	 31.179277420043945 	 South Carlton Gardens natural park
# 	 30.93800163269043 	 Rathdowne Street highway tertiary source nearmap network AU:VIC:S ref 46 lit surface asphalt oneway lanes 2 maxspeed 40
# 	 30.93800163269043 	 Rathdowne Street highway tertiary source nearmap network AU:VIC:S ref 46 lit surface asphalt oneway lanes 2 maxspeed 40
# 	 30.93800163269043 	 Rathdowne Street highway tertiary source nearmap network AU:VIC:S ref 46 lit surface asphalt oneway lanes 2 maxspeed 40
# 	 30.92024803161621 	 natural tree
# 	 30.92024803161621 	 natural tree
# 	 30.92024803161621 	 natural tree
# 	 30.92024803161621 	 natural tree
# 	 30.92024803161621 	 natural tree
# 	 30.92024803161621 	 natural tree
# 	 30.92024803161621 	 natural tree
# 	 30.92024803161621 	 natural tree
# 	 30.92024803161621 	 natural tree
# 	 30.92024803161621 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.920244216918945 	 natural tree
# 	 30.833452224731445 	 amenity bench material stone
# 	 30.833452224731445 	 amenity bench material stone
# 	 30.833452224731445 	 amenity bench material stone
# 	 30.833452224731445 	 amenity bench material stone
# 	 30.833452224731445 	 amenity bench material stone
# 	 30.747556686401367 	 natural tree_row leaf_type broadleaved
# 	 30.01384735107422 	 source Vicmap Address building
# 	 30.01384735107422 	 source Vicmap Address building
# 	 29.33439826965332 	 Melbourne District Melbourne boundary political type boundary political_division au_vic_la
# 	 29.300457000732422 	 amenity fountain
# 	 29.300457000732422 	 amenity fountain
# 	 28.90957260131836 	 Stop 11: Melbourne Museum operator Yarra Trams wheelchair tactile_paving railway platform network PTV - Metropolitan Trams public_transport platform ref 11 tram bench bin lit route_ref 86;96 shelter passenger_information_display
# 	 28.820064544677734 	 amenity bicycle_parking
# 	 28.531570434570312 	 amenity waste_basket check_date 2022-10-04
# 	 28.531570434570312 	 amenity waste_basket check_date 2022-10-04
# 	 28.1014347076416 	 amenity drinking_water
# 	 28.06793785095215 	 amenity parking_entrance fee parking underground
# 	 28.06793785095215 	 amenity parking_entrance fee parking underground
# 	 28.06793785095215 	 amenity parking_entrance fee parking underground
# 	 28.065263748168945 	 amenity bench backrest
# 	 28.065263748168945 	 amenity bench backrest
# 	 28.065263748168945 	 amenity bench backrest
# 	 28.065263748168945 	 amenity bench backrest
# 	 28.065263748168945 	 amenity bench backrest
# 	 28.065263748168945 	 amenity bench backrest
# 	 28.065263748168945 	 amenity bench backrest
# 	 28.065263748168945 	 amenity bench backrest
# 	 28.065263748168945 	 amenity bench backrest
# 	 27.694950103759766 	 City of Melbourne Melbourne phone +61 3 9658 9658 place municipality admin_level 6 boundary administrative population 149615 type boundary
# 	 27.689970016479492 	 access amenity toilets operator Melbourne City Council unisex wheelchair
# 	 27.61655616760254 	 natural water
# 	 27.61655616760254 	 natural water
# 	 27.522184371948242 	 building roof layer 1
# 	 27.522184371948242 	 building roof layer 1
# 	 27.522184371948242 	 building roof layer 1
# 	 27.431102752685547 	 leisure park
# 	 27.381145477294922 	 building
# 	 27.381145477294922 	 building
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.968103408813477 	 leisure garden
# 	 26.760311126708984 	 highway unclassified noname surface asphalt service parking_aisle
# 	 26.215307235717773 	 amenity bicycle_parking check_date 2023-06-29
# 	 26.037960052490234 	 Museum Playground access customers leisure playground
# 	 26.015087127685547 	 highway unclassified bicycle designated noname surface asphalt oneway service parking_aisle
# 	 26.007747650146484 	 City of Yarra place municipality admin_level 6 boundary administrative population 98521 type boundary
# 	 25.917369842529297 	 amenity drinking_water check_date 2023-06-29 fountain bubbler
# 	 25.803342819213867 	 amenity drinking_water check_date 2022-10-04
# 	 25.745943069458008 	 Princes Street highway residential source Yahoo surface asphalt
# 	 25.710407257080078 	 building type multipolygon
# 	 25.59331703186035 	 amenity bicycle_parking check_date 2023-04-24
# 	 25.582109451293945 	 Princes Street highway residential source Yahoo lit surface asphalt
# 	 25.24974250793457 	 source Vicmap Address landuse residential
# 	 25.243581771850586 	 Forest Gallery covered source nearmap leisure garden
# 	 25.004905700683594 	 source Vicmap Address building apartments
# 	 24.986474990844727 	 highway unclassified bicycle designated lit noname surface asphalt service parking_aisle
# 	 24.982067108154297 	 Richmond District Richmond boundary political type boundary political_division au_vic_la
# 	 24.869022369384766 	 Fitzroy place suburb admin_level 9 boundary administrative population 10445 postal_code 3065 type boundary
# 	 24.468175888061523 	 Carlton place suburb admin_level 9 boundary administrative population 19001 postal_code 3053 type boundary
# 	 24.384056091308594 	 Nicholson Street highway primary lit surface asphalt oneway lanes 2 maxspeed 60
# 	 24.384056091308594 	 Nicholson Street highway primary lit surface asphalt oneway lanes 2 maxspeed 60
# 	 24.239709854125977 	 amenity bicycle_parking check_date 2023-04-24 covered bicycle_parking stands
# 	 23.834609985351562 	 leisure garden layer 1
# 	 23.714807510375977 	 Commonwealth Bank amenity atm operator Commonwealth Bank brand Commonwealth Bank
# 	 23.677278518676758 	 Nicholson Street highway primary lit surface asphalt oneway lanes 2 maxspeed 40
# 	 23.677278518676758 	 Nicholson Street highway primary lit surface asphalt oneway lanes 2 maxspeed 40
# 	 23.658432006835938 	 amenity bench backrest source nearmap
# 	 23.658432006835938 	 amenity bench backrest source nearmap
# 	 23.658418655395508 	 amenity bench backrest source nearmap
# 	 23.658418655395508 	 amenity bench backrest source nearmap
# 	 23.195417404174805 	 highway tertiary_link surface asphalt
# 	 23.195417404174805 	 highway tertiary_link surface asphalt
# 	 23.141393661499023 	 Telstra amenity telephone operator Telstra
# 	 22.12693214416504 	 highway service service driveway
# 	 22.010757446289062 	 highway pedestrian noname surface asphalt
# 	 22.010757446289062 	 highway pedestrian noname surface asphalt
# 	 22.010757446289062 	 highway pedestrian noname surface asphalt
# 	 21.906103134155273 	 highway cycleway bicycle designated foot designated source nearmap surface asphalt
# 	 21.757463455200195 	 highway pedestrian noname
# 	 21.757463455200195 	 highway pedestrian noname
# 	 21.512298583984375 	 natural water layer 2
# 	 21.101722717285156 	 Queensberry Street highway tertiary source nearmap lit surface asphalt oneway lanes 2 maxspeed 50
# 	 20.849037170410156 	 highway service surface asphalt
# 	 20.634817123413086 	 building apartments
# 	 20.61789321899414 	 highway footway crossing marked bicycle designated surface asphalt footway crossing
# 	 20.452041625976562 	 source nearmap natural water layer 1
# 	 20.400785446166992 	 highway footway surface asphalt
# 	 20.364839553833008 	 Queensberry Street highway tertiary source nearmap;Bing;nearmap lit surface asphalt oneway lanes 2 maxspeed 50
# 	 20.333114624023438 	 highway pedestrian surface asphalt service laneway
# 	 20.31014633178711 	 highway crossing crossing unmarked kerb flush
# 	 20.268638610839844 	 highway service
# 	 20.246965408325195 	 highway footway crossing marked surface concrete footway crossing
# 	 20.071624755859375 	 landuse grass
# 	 20.071624755859375 	 landuse grass
# 	 20.071624755859375 	 landuse grass
# 	 20.071624755859375 	 landuse grass
# 	 20.071624755859375 	 landuse grass
# 	 20.071624755859375 	 landuse grass
# 	 20.071624755859375 	 landuse grass
# 	 19.87926483154297 	 highway crossing crossing traffic_signals tactile_paving button_operated
# 	 19.874996185302734 	 highway service source nearmap surface asphalt oneway
# 	 19.854101181030273 	 highway footway bicycle designated source nearmap surface asphalt footway sidewalk
# 	 19.672908782958984 	 highway crossing crossing traffic_signals tactile_paving button_operated foot designated
# 	 19.668075561523438 	 highway footway surface asphalt footway crossing
# 	 19.668075561523438 	 highway footway surface asphalt footway crossing
# 	 19.588985443115234 	 layer 1 landuse grass
# 	 19.588985443115234 	 layer 1 landuse grass
# 	 19.5889835357666 	 layer 1 landuse grass
# 	 19.5889835357666 	 layer 1 landuse grass
# 	 19.564165115356445 	 highway footway source nearmap surface asphalt footway sidewalk
# 	 19.55665397644043 	 highway traffic_signals
# 	 19.55665397644043 	 highway traffic_signals
# 	 19.55665397644043 	 highway traffic_signals
# 	 19.183929443359375 	 railway tram service crossover electrified contact_line frequency 0 gauge 1435 voltage 600
# 	 19.03139877319336 	 Nicholson Street source nearmap railway tram oneway electrified contact_line frequency 0 gauge 1435 voltage 600
# 	 19.03139877319336 	 Nicholson Street source nearmap railway tram oneway electrified contact_line frequency 0 gauge 1435 voltage 600
# 	 19.028852462768555 	 highway pedestrian lit
# 	 18.564157485961914 	 highway pedestrian source nearmap noname surface asphalt
# 	 18.564157485961914 	 highway pedestrian source nearmap noname surface asphalt
# 	 18.564157485961914 	 highway pedestrian source nearmap noname surface asphalt
# 	 18.564157485961914 	 highway pedestrian source nearmap noname surface asphalt
# 	 18.564157485961914 	 highway pedestrian source nearmap noname surface asphalt
# 	 18.564157485961914 	 highway pedestrian source nearmap noname surface asphalt
# 	 18.564157485961914 	 highway pedestrian source nearmap noname surface asphalt
# 	 18.564157485961914 	 highway pedestrian source nearmap noname surface asphalt
# 	 18.564157485961914 	 highway pedestrian source nearmap noname surface asphalt
# 	 18.452146530151367 	 highway pedestrian source nearmap lit noname surface asphalt
# 	 18.452146530151367 	 highway pedestrian source nearmap lit noname surface asphalt
# 	 18.452146530151367 	 highway pedestrian source nearmap lit noname surface asphalt
# 	 18.452146530151367 	 highway pedestrian source nearmap lit noname surface asphalt
# 	 18.452146530151367 	 highway pedestrian source nearmap lit noname surface asphalt
# 	 18.273319244384766 	 highway traffic_signals traffic_signals pedestrian_crossing
# 	 17.964460372924805 	 highway service source nearmap oneway
# 	 17.964458465576172 	 highway service source nearmap oneway
# 	 17.96002960205078 	 highway pedestrian type multipolygon area
# 	 17.83043670654297 	 highway pedestrian
# 	 17.83043670654297 	 highway pedestrian
# 	 17.83043670654297 	 highway pedestrian
# 	 17.83043670654297 	 highway pedestrian
# 	 17.828569412231445 	 highway pedestrian source nearmap noname
# 	 17.828567504882812 	 highway pedestrian source nearmap noname
# 	 17.813873291015625 	 highway footway source nearmap surface asphalt
# 	 17.35991859436035 	 highway pedestrian type multipolygon
# 	 17.193981170654297 	 highway crossing crossing zebra
# 	 16.92513084411621 	 highway pedestrian source nearmap,bing
# 	 14.39432430267334 	 highway service bicycle source nearmap
# 	 14.092531204223633 	 highway pedestrian source nearmap
# 	 14.092528343200684 	 highway pedestrian source nearmap
# 	 14.092528343200684 	 highway pedestrian source nearmap
# array([ 46,   1,  26,  27,  44,  49, 298,  43, 297, 436], dtype=int64)

# %%
features.iloc[k_similar]
# Out:
#     element_type       osmid   highway traffic_signals:direction access  \
# 46          node  9106562132       nan                       nan    nan
# 1           node   368393200       nan                       nan    nan
# 26          node  4061250667  bus_stop                       nan    nan
# 27          node  4332324003       nan                       nan    nan
# 44          node  7248901076  bus_stop                       nan    nan
# 49          node  9307551791       nan                       nan    yes
# 298          way     4817074       nan                       nan    nan
# 43          node  6810298878       nan                       nan    nan
# 297          way     4817059       nan                       nan    nan
# 436     relation     6623509       nan                       nan    nan
#
#               amenity  fee          operator toilets:disposal unisex  ...  \
# 46                nan  nan               nan              nan    nan  ...
# 1              cinema  nan  Melbourne museum              nan    nan  ...
# 26                nan  nan               nan              nan    nan  ...
# 27   charging_station  nan  Museums Victoria              nan    nan  ...
# 44                nan  nan               nan              nan    nan  ...
# 49                nan  nan               nan              nan    nan  ...
# 298               nan  yes   Museum Victoria              nan    nan  ...
# 43                nan  nan               nan              nan    nan  ...
# 297               nan  nan               nan              nan    nan  ...
# 436               nan  nan               nan              nan    nan  ...
#
#     name:mk short_name political_division heritage heritage:operator  \
# 46      nan        nan                nan      nan               nan
# 1       nan        nan                nan      nan               nan
# 26      nan        nan                nan      nan               nan
# 27      nan        nan                nan      nan               nan
# 44      nan        nan                nan      nan               nan
# 49      nan        nan                nan      nan               nan
# 298     nan        nan                nan      nan               nan
# 43      nan        nan                nan      nan               nan
# 297     nan        nan                nan      nan               nan
# 436     nan        nan                nan        1               whc
#
#                        heritage:website area  \
# 46                                  nan  nan
# 1                                   nan  nan
# 26                                  nan  nan
# 27                                  nan  nan
# 44                                  nan  nan
# 49                                  nan  nan
# 298                                 nan  nan
# 43                                  nan  nan
# 297                                 nan  nan
# 436  http://whc.unesco.org/en/list/1131  nan
#
#                                               geometry    distance  \
# 46                      POINT (321559.646 5813927.545)  170.659614
# 1                       POINT (321343.567 5814046.274)  188.373535
# 26                      POINT (321243.477 5813954.530)  179.719018
# 27                      POINT (321463.713 5813962.011)  114.580080
# 44                      POINT (321211.629 5813902.092)  191.907516
# 49                      POINT (321592.650 5813874.406)  192.577146
# 298  POLYGON ((321505.691 5814023.082, 321459.066 5...  159.043248
# 43                      POINT (321503.096 5813888.150)  105.093724
# 297  POLYGON ((321415.382 5813963.959, 321416.338 5...   11.700249
# 436  MULTIPOLYGON (((321415.382 5813963.959, 321416...    3.048837
#
#                                              full_name
# 46              artwork_type sculpture tourism artwork
# 1    IMAX Melbourne amenity cinema operator Melbour...
# 26   Exhibition Building/Rathdowne Street highway b...
# 27   amenity charging_station operator Museums Vict...
# 44   Exhibition Building/Rathdowne Street highway b...
# 49   access historic monument inscription To Victor...
# 298  Melbourne Museum fee operator Museum Victoria ...
# 43   Royal Exhibition Building Opening historic mem...
# 297  Royal Exhibition Building source Vicmap Addres...
# 436  Royal Exhibition Building and Carlton Gardens ...
#
# [10 rows x 142 columns]

# %%
def get_top_k(case_id, k=10, model = msmarco_model, verbose=False):
    test_case = nominatim_output[str(case_id)]
    
    features = gpd.read_file('dataset/osm-poi-{0}-dist-{1}-features.geojson'.format(case_id, dist_threshold))
    cols = list(features.columns)
    if verbose:
        print(features.head())
        print(cols)
    features['full_name'] = features.apply(lambda row: generate_textual_descriptions(row, cols), axis=1)
    
    feature_descriptions = list(features['full_name'])
    feature_embeddings = embed_texts(feature_descriptions, model=model)
    
    case_description = test_case['title'] + ' ' + test_case['summary']
    k_similar = compute_similarities_topk(case_description, feature_descriptions, feature_embeddings, model=model, verbose=verbose)
    return features.iloc[np.flip(k_similar)]

# %% [markdown]
# ## Annotation Experiment

# %%
if os.path.isfile('dataset/annotated-osm-entities.json'):
    with open('dataset/annotated-osm-entities.json', 'r') as fp:
        annotations = json.load(fp)
else:
    annotations = {}
annotations
# Out:
# {'0': [['way', 1089591567]],
#  '1': [['way', 1007494584]],
#  '2': [],
#  '3': [],
#  '4': [['way', 30501938]],
#  '5': [],
#  '6': [['way', 69366108], ['node', 5315720235]],
#  '7': [['node', 11158854687],
#   ['node', 4583492091],
#   ['node', 831201411],
#   ['node', 11158854665],
#   ['node', 11158854688]],
#  '8': [['node', 3621405496]],
#  '9': [],
#  '10': [['node', 831201041]],
#  '11': [['node', 3933086392]],
#  '12': [['way', 26564416]],
#  '13': [['way', 49961266]],
#  '14': [['way', 26564392]],
#  '15': [['node', 5371634608]],
#  '16': [['node', 7228362154], ['way', 32710391]],
#  '17': [['way', 435967756]],
#  '18': [],
#  '19': [],
#  '20': [['way', 1016758027]],
#  '21': [['node', 368393200]],
#  '22': [['way', 4817074]],
#  '23': [['way', 4817059]],
#  '24': [['relation', 6614802]],
#  '25': [['way', 29369985]],
#  '26': [['way', 30066634]],
#  '27': [['way', 830995835], ['way', 830995836], ['way', 830995837]],
#  '28': [['node', 6515021014]],
#  '29': [['node', 331165028]],
#  '30': [['node', 243419251]],
#  '31': [['node', 649798969]],
#  '32': [['way', 668210311]],
#  '33': [['way', 288182899]],
#  '34': [['way', 337874851]],
#  '36': [['node', 6457301034]],
#  '37': [],
#  '38': [['way', 687712378]],
#  '39': [['way', 632497723]],
#  '40': [['way', 686511907]],
#  '41': [],
#  '42': [['way', 686511908]],
#  '43': [],
#  '44': [],
#  '45': [],
#  '46': [['way', 686515751]],
#  '47': [],
#  '48': [['node', 1998491084]],
#  '49': [['way', 686249537]],
#  '50': [],
#  '51': [['way', 686249528]],
#  '52': [['way', 686249531]],
#  '53': [['node', 6485063081]],
#  '54': [],
#  '55': [],
#  '56': [],
#  '57': [],
#  '58': [['way', 687252477]],
#  '59': [['node', 9810267033]],
#  '60': [],
#  '61': [['way', 687253356]],
#  '62': [['way', 688057979]],
#  '63': [['node', 6469255452]],
#  '64': [['way', 688057382]],
#  '65': [['way', 687904953]],
#  '66': [['way', 1160145426]],
#  '67': [['node', 9810267032]],
#  '68': [['way', 675079682]],
#  '69': [['way', 686511921]],
#  '70': [['way', 686511916]],
#  '71': [['node', 10635926320]],
#  '72': [],
#  '73': [],
#  '74': [['way', 1098427843]],
#  '75': [],
#  '76': [['node', 2774230035]],
#  '77': [['way', 233836125]],
#  '78': [['node', 9161912879]],
#  '79': [],
#  '80': [['node', 11311118815], ['node', 11311107053]],
#  '81': [['way', 342431866]],
#  '82': [],
#  '83': [['node', 6741658224]],
#  '84': [['way', 721761329]],
#  '85': [['way', 539618149]],
#  '86': [['way', 8038239]],
#  '87': [],
#  '88': [['way', 8038239]],
#  '89': [['way', 8038230]],
#  '90': [['way', 210337258]],
#  '91': [['node', 8998978450]],
#  '92': [['node', 8998978445]],
#  '93': [['node', 4148845957], ['node', 4148845958]],
#  '95': [],
#  '96': [],
#  '97': [['way', 231442494], ['way', 231442496]],
#  '98': [['way', 231532290]],
#  '99': [['way', 92640804]],
#  '100': [['way', 958620192]],
#  '101': [['way', 471789660]],
#  '102': [['way', 147610651]],
#  '103': [['node', 3632860913], ['node', 357080124]],
#  '104': [['way', 181376801]],
#  '105': [],
#  '106': [],
#  '107': [['way', 36897615]],
#  '108': [],
#  '109': [],
#  '110': [],
#  '111': [],
#  '112': [['node', 1608117633]],
#  '113': [],
#  '114': [],
#  '115': [],
#  '116': [['way', 1088334181],
#   ['way', 1088334180],
#   ['way', 1088334179],
#   ['way', 1088334182],
#   ['way', 1088334183],
#   ['way', 1088334184],
#   ['way', 1088334185]],
#  '117': [],
#  '118': [],
#  '119': [],
#  '120': [['way', 1088334167], ['way', 1088334166], ['way', 1088334168]],
#  '121': [['way', 218195747], ['way', 218195734], ['way', 218195738]],
#  '122': [],
#  '123': [['way', 167060008]],
#  '124': [],
#  '125': [],
#  '126': [['way', 392555683]],
#  '127': [],
#  '128': [],
#  '129': [['way', 1008233190]],
#  '130': [['way', 1008233190]],
#  '131': [['way', 1008233190]],
#  '132': [['node', 7005511179]],
#  '133': [],
#  '134': [['way', 8065262]],
#  '135': [],
#  '136': [],
#  '137': [['way', 8065262]],
#  '138': [],
#  '139': [['way', 27246521]],
#  '140': [['node', 6813556950]],
#  '141': [['way', 969980200]],
#  '142': [['way', 551566138]],
#  '143': [['way', 988671295]],
#  '144': [],
#  '145': [['node', 9768437122]],
#  '146': [['way', 984506297]],
#  '147': [],
#  '148': [['way', 117907012]],
#  '149': [['way', 1061599415],
#   ['way', 1061599404],
#   ['way', 8155881731],
#   ['node', 1327155803]],
#  '150': [['way', 461975104], ['way', 117907012]],
#  '151': [['way', 233100431], ['way', 1028843720]],
#  '152': [['way', 1054321732]],
#  '153': [['way', 1098121848]],
#  '154': [],
#  '155': [],
#  '156': [['node', 3294344712]],
#  '157': [['way', 246723285]],
#  '158': [['way', 951694224]],
#  '159': [],
#  '160': [['way', 330869393]],
#  '161': [],
#  '162': [],
#  '163': [['way', 45422580]],
#  '164': [],
#  '165': [],
#  '166': [],
#  '167': [['way', 1011672045]],
#  '168': [['way', 24488865]],
#  '169': [],
#  '170': [],
#  '171': [],
#  '172': [],
#  '173': [],
#  '174': [['way', 196098436]],
#  '175': [['node', 4469522889]],
#  '176': [['node', 2318297625]],
#  '177': [['way', 32656612]],
#  '178': [['node', 589396597]],
#  '179': [['way', 24530652]],
#  '180': [['way', 32943319]],
#  '181': [],
#  '182': [['way', 219393602]],
#  '183': [],
#  '184': [['way', 726571334]],
#  '185': [],
#  '186': [],
#  '187': [],
#  '188': [['way', 46652486]],
#  '189': [['way', 22931009]],
#  '190': [['way', 4308557]],
#  '191': [],
#  '192': [['way', 17037928]],
#  '193': [['way', 46817076]],
#  '194': [['node', 11466742435]],
#  '195': [['way', 17037612]],
#  '196': [],
#  '197': [['way', 525738401]],
#  '198': [['way', 46699058]],
#  '199': [['way', 22820458]],
#  '200': [],
#  '201': [],
#  '202': [['way', 28775707]],
#  '203': [['way', 260997166]],
#  '204': [],
#  '205': [['way', 26564392]],
#  '206': [],
#  '207': [],
#  '208': [],
#  '209': [['way', 46194494]],
#  '210': [['way', 47063198], ['node', 270652136]],
#  '211': [],
#  '212': [],
#  '213': [],
#  '214': [],
#  '215': [['relation', 4024684]],
#  '216': [],
#  '217': [],
#  '218': [],
#  '219': [],
#  '220': [],
#  '221': [['way', 926075393]],
#  '222': [],
#  '223': [],
#  '224': [['way', 266053739]],
#  '225': [],
#  '226': [],
#  '227': [],
#  '228': [['way', 629160097], ['way', 629160090]],
#  '229': [['node', 3008339621], ['node', 702322193]],
#  '230': [],
#  '231': [['node', 9295131630]],
#  '232': [],
#  '233': [],
#  '234': [['way', 219971240]],
#  '235': [['way', 158514482],
#   ['way', 1030246052],
#   ['node', 1707006508],
#   ['node', 5574887776],
#   ['node', 5574888853]],
#  '236': [],
#  '237': [['way', 487543644]],
#  '238': [],
#  '239': [['way', 35200710]],
#  '240': [['way', 35200710]],
#  '241': [['way', 1080887782], ['way', 179896505]],
#  '242': [],
#  '243': [['way', 179896505]],
#  '244': [['way', 5914565], ['way', 255495106]],
#  '245': [['way', 34614467]],
#  '246': [],
#  '247': [['way', 89640136]],
#  '248': [],
#  '249': [['way', 89752395], ['way', 5914565]],
#  '250': [],
#  '251': [['way', 37722945]],
#  '252': [],
#  '253': [],
#  '254': [],
#  '255': [],
#  '256': [],
#  '257': [],
#  '258': [['way', 604106938]],
#  '259': [],
#  '260': [['way', 617332907]],
#  '261': [['way', 617332910]],
#  '262': [['way', 617332920]],
#  '263': [['way', 1036449860]],
#  '264': [['way', 45810508]],
#  '265': [['way', 45810540]],
#  '266': [['way', 1093776316]],
#  '267': [['way', 45810543],
#   ['way', 729799716],
#   ['way', 311890145],
#   ['way', 1035917503]],
#  '268': [['way', 729799716]],
#  '269': [['way', 41411230]],
#  '270': [['way', 267164575]],
#  '271': [],
#  '272': [['way', 1010522855]],
#  '273': [['way', 95649761], ['way', 95649764], ['way', 95649767]],
#  '274': [['node', 2718787387]],
#  '275': [['way', 1211389019]],
#  '276': [['way', 23043775]],
#  '277': [['way', 23043770]],
#  '278': [['node', 265022296]],
#  '279': [['way', 44948474]],
#  '280': [],
#  '281': [['way', 3302170025]],
#  '282': [],
#  '283': [],
#  '284': [['way', 28755691]],
#  '285': [],
#  '286': [],
#  '287': [['way', 446436436]],
#  '288': [['way', 28755691]],
#  '289': [['way', 45041177]],
#  '290': [['node', 2707956414]],
#  '291': [['way', 172237649], ['way', 172237582], ['way', 172237647]],
#  '292': [],
#  '293': [['way', 172237557]],
#  '294': [['way', 176328441]],
#  '295': [['way', 1230053996]],
#  '296': [],
#  '297': [['way', 1230053997], ['way', 173009911]],
#  '298': [],
#  '299': [],
#  '300': [],
#  '301': [],
#  '302': [],
#  '303': [],
#  '304': [],
#  '305': [],
#  '306': [],
#  '307': [],
#  '308': [],
#  '309': [],
#  '310': [['way', 13858293]],
#  '311': [['node', 3105263070]],
#  '312': [['node', 3105263071]],
#  '313': [],
#  '314': [],
#  '315': [],
#  '316': [],
#  '317': [],
#  '318': [],
#  '319': [],
#  '320': [['node', 765658682]],
#  '321': [['way', 61282475]],
#  '322': [],
#  '323': [['node', 2873300635]],
#  '324': [['way', 61289198]],
#  '325': [['node', 765662619]],
#  '326': [['way', 61289198]],
#  '327': [['node', 765716038]],
#  '328': [['way', 193844693]],
#  '329': [],
#  '330': [['way', 193844693]],
#  '331': [['node', 765716038]]}

# %% [markdown]
# ### Iterate from here!

# %%
already_investigated = [int(key) for key in annotations.keys()]
case_id = max(already_investigated) + 1
print(case_id)
print(nominatim_output[str(case_id)])
top_k_df = get_top_k(case_id)
top_k_df[['element_type','osmid', 'name', 'full_name']]
# Out:
# 341
# {'walk_id': 23, 'title': 'Playground', 'summary': "A colourful playground to let your little ones run wild (if you've got kids to entertain).", 'lat': -37.77917777, 'lng': 144.96626599, 'osm': None}
#     element_type        osmid                     name  \
# 139          way    715659053                      nan
# 85           way    198843622  Hardy Gallagher Reserve
# 146          way   1100733362                      nan
# 52           way     22787631         Communal Gardens
# 54           way     26131217      Linear Park Reserve
# 21          node  10074058696                      nan
# 27          node  10074058702                      nan
# 25          node  10074058700                      nan
# 24          node  10074058699                      nan
# 23          node  10074058698                      nan
#
#                                 full_name
# 139                    leisure playground
# 85   Hardy Gallagher Reserve leisure park
# 146                          leisure park
# 52        Communal Gardens leisure garden
# 54       Linear Park Reserve leisure park
# 21                           natural tree
# 27                           natural tree
# 25                           natural tree
# 24                           natural tree
# 23                           natural tree

# %%
gdf.iloc[case_id:case_id+1].explore(marker_type='marker')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de3a6f7f85f5cc9d6fad99bb6bece5a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de3a6f7f85f5cc9d6fad99bb6bece5a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de3a6f7f85f5cc9d6fad99bb6bece5a9 = L.map(
#                 &quot;map_de3a6f7f85f5cc9d6fad99bb6bece5a9&quot;,
#                 {
#                     center: [-37.77917777, 144.96626599],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_de3a6f7f85f5cc9d6fad99bb6bece5a9);
#
#
#
#
#
#             var tile_layer_8b305f88bb752edcf871a8612f19a637 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_de3a6f7f85f5cc9d6fad99bb6bece5a9);
#
#
#             map_de3a6f7f85f5cc9d6fad99bb6bece5a9.fitBounds(
#                 [[-37.77917777, 144.96626599], [-37.77917777, 144.96626599]],
#                 {}
#             );
#
#
#         function geo_json_1daf88c6b925e0b7d4af270687fcdba7_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_1daf88c6b925e0b7d4af270687fcdba7_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_1daf88c6b925e0b7d4af270687fcdba7_pointToLayer(feature, latlng) {
#             var opts = {&quot;fill&quot;: true, &quot;radius&quot;: 2};
#
#             let style = geo_json_1daf88c6b925e0b7d4af270687fcdba7_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_1daf88c6b925e0b7d4af270687fcdba7_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_1daf88c6b925e0b7d4af270687fcdba7.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_1daf88c6b925e0b7d4af270687fcdba7_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_1daf88c6b925e0b7d4af270687fcdba7 = L.geoJson(null, {
#                 onEachFeature: geo_json_1daf88c6b925e0b7d4af270687fcdba7_onEachFeature,
#
#                 style: geo_json_1daf88c6b925e0b7d4af270687fcdba7_styler,
#                 pointToLayer: geo_json_1daf88c6b925e0b7d4af270687fcdba7_pointToLayer
#         });
#
#         function geo_json_1daf88c6b925e0b7d4af270687fcdba7_add (data) {
#             geo_json_1daf88c6b925e0b7d4af270687fcdba7
#                 .addData(data)
#                 .addTo(map_de3a6f7f85f5cc9d6fad99bb6bece5a9);
#         }
#             geo_json_1daf88c6b925e0b7d4af270687fcdba7_add({&quot;bbox&quot;: [144.96626599, -37.77917777, 144.96626599, -37.77917777], &quot;features&quot;: [{&quot;bbox&quot;: [144.96626599, -37.77917777, 144.96626599, -37.77917777], &quot;geometry&quot;: {&quot;coordinates&quot;: [144.96626599, -37.77917777], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;341&quot;, &quot;properties&quot;: {&quot;description&quot;: &quot;Playground: A colourful playground to let your little ones run wild (if you\u0027ve got kids to entertain).&quot;, &quot;latitude&quot;: -37.77917777, &quot;longitude&quot;: 144.96626599, &quot;poi_summary&quot;: &quot;A colourful playground to let your little ones run wild (if you\u0027ve got kids to entertain).&quot;, &quot;poi_title&quot;: &quot;Playground&quot;, &quot;refined_description&quot;: &quot;Playground: A colourful playground to let your little ones run wild (if you\u0027ve got kids to entertain).&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#     geo_json_1daf88c6b925e0b7d4af270687fcdba7.bindTooltip(
#     function(layer

# %%
print('https://www.openstreetmap.org/#map=18/{0}/{1}'.format(nominatim_output[str(case_id)]['lat'], nominatim_output[str(case_id)]['lng']))
# Out:
# https://www.openstreetmap.org/#map=18/-37.77917777/144.96626599

# %%
annotations[case_id] = [('way', 715659053)]
if len(annotations.keys()) % 10 == 0:
    with open('dataset/annotated-osm-entities.json', 'w', encoding='utf-8') as fp:
        json.dump(annotations, fp)
    print('annotation file saved')
annotations
# Out:
# annotation file saved
# {'0': [['way', 1089591567]],
#  '1': [['way', 1007494584]],
#  '2': [],
#  '3': [],
#  '4': [['way', 30501938]],
#  '5': [],
#  '6': [['way', 69366108], ['node', 5315720235]],
#  '7': [['node', 11158854687],
#   ['node', 4583492091],
#   ['node', 831201411],
#   ['node', 11158854665],
#   ['node', 11158854688]],
#  '8': [['node', 3621405496]],
#  '9': [],
#  '10': [['node', 831201041]],
#  '11': [['node', 3933086392]],
#  '12': [['way', 26564416]],
#  '13': [['way', 49961266]],
#  '14': [['way', 26564392]],
#  '15': [['node', 5371634608]],
#  '16': [['node', 7228362154], ['way', 32710391]],
#  '17': [['way', 435967756]],
#  '18': [],
#  '19': [],
#  '20': [['way', 1016758027]],
#  '21': [['node', 368393200]],
#  '22': [['way', 4817074]],
#  '23': [['way', 4817059]],
#  '24': [['relation', 6614802]],
#  '25': [['way', 29369985]],
#  '26': [['way', 30066634]],
#  '27': [['way', 830995835], ['way', 830995836], ['way', 830995837]],
#  '28': [['node', 6515021014]],
#  '29': [['node', 331165028]],
#  '30': [['node', 243419251]],
#  '31': [['node', 649798969]],
#  '32': [['way', 668210311]],
#  '33': [['way', 288182899]],
#  '34': [['way', 337874851]],
#  '36': [['node', 6457301034]],
#  '37': [],
#  '38': [['way', 687712378]],
#  '39': [['way', 632497723]],
#  '40': [['way', 686511907]],
#  '41': [],
#  '42': [['way', 686511908]],
#  '43': [],
#  '44': [],
#  '45': [],
#  '46': [['way', 686515751]],
#  '47': [],
#  '48': [['node', 1998491084]],
#  '49': [['way', 686249537]],
#  '50': [],
#  '51': [['way', 686249528]],
#  '52': [['way', 686249531]],
#  '53': [['node', 6485063081]],
#  '54': [],
#  '55': [],
#  '56': [],
#  '57': [],
#  '58': [['way', 687252477]],
#  '59': [['node', 9810267033]],
#  '60': [],
#  '61': [['way', 687253356]],
#  '62': [['way', 688057979]],
#  '63': [['node', 6469255452]],
#  '64': [['way', 688057382]],
#  '65': [['way', 687904953]],
#  '66': [['way', 1160145426]],
#  '67': [['node', 9810267032]],
#  '68': [['way', 675079682]],
#  '69': [['way', 686511921]],
#  '70': [['way', 686511916]],
#  '71': [['node', 10635926320]],
#  '72': [],
#  '73': [],
#  '74': [['way', 1098427843]],
#  '75': [],
#  '76': [['node', 2774230035]],
#  '77': [['way', 233836125]],
#  '78': [['node', 9161912879]],
#  '79': [],
#  '80': [['node', 11311118815], ['node', 11311107053]],
#  '81': [['way', 342431866]],
#  '82': [],
#  '83': [['node', 6741658224]],
#  '84': [['way', 721761329]],
#  '85': [['way', 539618149]],
#  '86': [['way', 8038239]],
#  '87': [],
#  '88': [['way', 8038239]],
#  '89': [['way', 8038230]],
#  '90': [['way', 210337258]],
#  '91': [['node', 8998978450]],
#  '92': [['node', 8998978445]],
#  '93': [['node', 4148845957], ['node', 4148845958]],
#  '95': [],
#  '96': [],
#  '97': [['way', 231442494], ['way', 231442496]],
#  '98': [['way', 231532290]],
#  '99': [['way', 92640804]],
#  '100': [['way', 958620192]],
#  '101': [['way', 471789660]],
#  '102': [['way', 147610651]],
#  '103': [['node', 3632860913], ['node', 357080124]],
#  '104': [['way', 181376801]],
#  '105': [],
#  '106': [],
#  '107': [['way', 36897615]],
#  '108': [],
#  '109': [],
#  '110': [],
#  '111': [],
#  '112': [['node', 1608117633]],
#  '113': [],
#  '114': [],
#  '115': [],
#  '116': [['way', 1088334181],
#   ['way', 1088334180],
#   ['way', 1088334179],
#   ['way', 1088334182],
#   ['way', 1088334183],
#   ['way', 1088334184],
#   ['way', 1088334185]],
#  '117': [],
#  '118': [],
#  '119': [],
#  '120': [['way', 1088334167], ['way', 1088334166], ['way', 1088334168]],
#  '121': [['way', 218195747], ['way', 218195734], ['way', 218195738]],
#  '122': [],
#  '123': [['way', 167060008]],
#  '124': [],
#  '125': [],
#  '126': [['way', 392555683]],
#  '127': [],
#  '128': [],
#  '129': [['way', 1008233190]],
#  '130': [['way', 1008233190]],
#  '131': [['way', 1008233190]],
#  '132': [['node', 7005511179]],
#  '133': [],
#  '134': [['way', 8065262]],
#  '135': [],
#  '136': [],
#  '137': [['way', 8065262]],
#  '138': [],
#  '139': [['way', 27246521]],
#  '140': [['node', 6813556950]],
#  '141': [['way', 969980200]],
#  '142': [['way', 551566138]],
#  '143': [['way', 988671295]],
#  '144': [],
#  '145': [['node', 9768437122]],
#  '146': [['way', 984506297]],
#  '147': [],
#  '148': [['way', 117907012]],
#  '149': [['way', 1061599415],
#   ['way', 1061599404],
#   ['way', 8155881731],
#   ['node', 1327155803]],
#  '150': [['way', 461975104], ['way', 117907012]],
#  '151': [['way', 233100431], ['way', 1028843720]],
#  '152': [['way', 1054321732]],
#  '153': [['way', 1098121848]],
#  '154': [],
#  '155': [],
#  '156': [['node', 3294344712]],
#  '157': [['way', 246723285]],
#  '158': [['way', 951694224]],
#  '159': [],
#  '160': [['way', 330869393]],
#  '161': [],
#  '162': [],
#  '163': [['way', 45422580]],
#  '164': [],
#  '165': [],
#  '166': [],
#  '167': [['way', 1011672045]],
#  '168': [['way', 24488865]],
#  '169': [],
#  '170': [],
#  '171': [],
#  '172': [],
#  '173': [],
#  '174': [['way', 196098436]],
#  '175': [['node', 4469522889]],
#  '176': [['node', 2318297625]],
#  '177': [['way', 32656612]],
#  '178': [['node', 589396597]],
#  '179': [['way', 24530652]],
#  '180': [['way', 32943319]],
#  '181': [],
#  '182': [['way', 219393602]],
#  '183': [],
#  '184': [['way', 726571334]],
#  '185': [],
#  '186': [],
#  '187': [],
#  '188': [['way', 46652486]],
#  '189': [['way', 22931009]],
#  '190': [['way', 4308557]],
#  '191': [],
#  '192': [['way', 17037928]],
#  '193': [['way', 46817076]],
#  '194': [['node', 11466742435]],
#  '195': [['way', 17037612]],
#  '196': [],
#  '197': [['way', 525738401]],
#  '198': [['way', 46699058]],
#  '199': [['way', 22820458]],
#  '200': [],
#  '201': [],
#  '202': [['way', 28775707]],
#  '203': [['way', 260997166]],
#  '204': [],
#  '205': [['way', 26564392]],
#  '206': [],
#  '207': [],
#  '208': [],
#  '209': [['way', 46194494]],
#  '210': [['way', 47063198], ['node', 270652136]],
#  '211': [],
#  '212': [],
#  '213': [],
#  '214': [],
#  '215': [['relation', 4024684]],
#  '216': [],
#  '217': [],
#  '218': [],
#  '219': [],
#  '220': [],
#  '221': [['way', 926075393]],
#  '222': [],
#  '223': [],
#  '224': [['way', 266053739]],
#  '225': [],
#  '226': [],
#  '227': [],
#  '228': [['way', 629160097], ['way', 629160090]],
#  '229': [['node', 3008339621], ['node', 702322193]],
#  '230': [],
#  '231': [['node', 9295131630]],
#  '232': [],
#  '233': [],
#  '234': [['way', 219971240]],
#  '235': [['way', 158514482],
#   ['way', 1030246052],
#   ['node', 1707006508],
#   ['node', 5574887776],
#   ['node', 5574888853]],
#  '236': [],
#  '237': [['way', 487543644]],
#  '238': [],
#  '239': [['way', 35200710]],
#  '240': [['way', 35200710]],
#  '241': [['way', 1080887782], ['way', 179896505]],
#  '242': [],
#  '243': [['way', 179896505]],
#  '244': [['way', 5914565], ['way', 255495106]],
#  '245': [['way', 34614467]],
#  '246': [],
#  '247': [['way', 89640136]],
#  '248': [],
#  '249': [['way', 89752395], ['way', 5914565]],
#  '250': [],
#  '251': [['way', 37722945]],
#  '252': [],
#  '253': [],
#  '254': [],
#  '255': [],
#  '256': [],
#  '257': [],
#  '258': [['way', 604106938]],
#  '259': [],
#  '260': [['way', 617332907]],
#  '261': [['way', 617332910]],
#  '262': [['way', 617332920]],
#  '263': [['way', 1036449860]],
#  '264': [['way', 45810508]],
#  '265': [['way', 45810540]],
#  '266': [['way', 1093776316]],
#  '267': [['way', 45810543],
#   ['way', 729799716],
#   ['way', 311890145],
#   ['way', 1035917503]],
#  '268': [['way', 729799716]],
#  '269': [['way', 41411230]],
#  '270': [['way', 267164575]],
#  '271': [],
#  '272': [['way', 1010522855]],
#  '273': [['way', 95649761], ['way', 95649764], ['way', 95649767]],
#  '274': [['node', 2718787387]],
#  '275': [['way', 1211389019]],
#  '276': [['way', 23043775]],
#  '277': [['way', 23043770]],
#  '278': [['node', 265022296]],
#  '279': [['way', 44948474]],
#  '280': [],
#  '281': [['way', 3302170025]],
#  '282': [],
#  '283': [],
#  '284': [['way', 28755691]],
#  '285': [],
#  '286': [],
#  '287': [['way', 446436436]],
#  '288': [['way', 28755691]],
#  '289': [['way', 45041177]],
#  '290': [['node', 2707956414]],
#  '291': [['way', 172237649], ['way', 172237582], ['way', 172237647]],
#  '292': [],
#  '293': [['way', 172237557]],
#  '294': [['way', 176328441]],
#  '295': [['way', 1230053996]],
#  '296': [],
#  '297': [['way', 1230053997], ['way', 173009911]],
#  '298': [],
#  '299': [],
#  '300': [],
#  '301': [],
#  '302': [],
#  '303': [],
#  '304': [],
#  '305': [],
#  '306': [],
#  '307': [],
#  '308': [],
#  '309': [],
#  '310': [['way', 13858293]],
#  '311': [['node', 3105263070]],
#  '312': [['node', 3105263071]],
#  '313': [],
#  '314': [],
#  '315': [],
#  '316': [],
#  '317': [],
#  '318': [],
#  '319': [],
#  '320': [['node', 765658682]],
#  '321': [['way', 61282475]],
#  '322': [],
#  '323': [['node', 2873300635]],
#  '324': [['way', 61289198]],
#  '325': [['node', 765662619]],
#  '326': [['way', 61289198]],
#  '327': [['node', 765716038]],
#  '328': [['way', 193844693]],
#  '329': [],
#  '330': [['way', 193844693]],
#  '331': [['node', 765716038]],
#  332: [('way', 706103063)],
#  333: [('way', 283470449)],
#  334: [('way', 706103062)],
#  335: [('way', 283470449)],
#  336: [('node', 4159110243)],
#  337: [],
#  338: [],
#  339: [],
#  340: [('node', 2363102335)],
#  341: [('way', 715659053)]}

# %% [markdown]
# ## Annotation Analysis
#
# - a place
# - a path
# - a vista

# %%
api_endpoint = 'https://www.openstreetmap.org/api/0.6/{0}/{1}.json'

def get_info(otype, oid):
    if otype not in ['node', 'way', 'relation']:
        print('wrong type - {}'.format(otype))
    resp = requests.get(api_endpoint.format(otype, oid), headers=headers)
    return resp.json()

# %%
get_info('node', 4506300751)
# Out:
# {'version': '0.6',
#  'generator': 'CGImap 0.8.10 (1564108 spike-06.openstreetmap.org)',
#  'copyright': 'OpenStreetMap and contributors',
#  'attribution': 'http://www.openstreetmap.org/copyright',
#  'license': 'http://opendatacommons.org/licenses/odbl/1-0/',
#  'elements': [{'type': 'node',
#    'id': 4506300751,
#    'lat': 50.405,
#    'lon': 9.2805862,
#    'timestamp': '2023-01-21T17:13:36Z',
#    'version': 5,
#    'changeset': 131548253,
#    'user': 'cEvLGWiQ',
#    'uid': 5432507,
#    'tags': {'addr:city': 'Birstein',
#     'addr:housenumber': '1',
#     'addr:postcode': '63633',
#     'addr:street': 'Volkartshainer Weg',
#     'name': 'Scheffehof',
#     'phone': '+496054 6920',
#     'tourism': 'trail_riding_station'}}]}
