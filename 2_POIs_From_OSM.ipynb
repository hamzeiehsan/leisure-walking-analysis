# %% [markdown]
# # POIs from OSM
#
# Aim is to download all candidate POIs from OSM. This set is used to provide suggestions for manaul annotations and later to build a candidate set of not-recommended POIs.

# %% [markdown]
# ## Setup
#
# Loading libraries and models

# %%
# working with files
import os.path
# sys
import sys

# warning off
import warnings
# IO
import json
# calling Webservices
import requests
# systematic thread stops for polite crawling
import time

# set random seed for reproducibility of results
from umap import UMAP

# dataframe 
import numpy as np
import pandas as pd
import geopandas as gpd

# geocoding
from geopy.geocoders import Nominatim

# getting data from OSM
import osmnx as ox

# topic modelling
from bertopic import BERTopic
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.representation import KeyBERTInspired

# nlp
from sentence_transformers import SentenceTransformer, util
import spacy
from nltk.corpus import stopwords

# visualization
import matplotlib.pyplot as plt

# logging
from loguru import logger

# set logger level
logger.remove(0)
logger.add(sys.stderr, level="INFO")

warnings.filterwarnings("ignore")

# en_core_web_lg must be downloaded, if not run: 'python -m spacy download en_core_web_lg' first!
nlp = spacy.load('en_core_web_lg')

umap_model = UMAP(random_state=42)

stopword_removal = False

# %% [markdown]
# ## Dataset
#
# Reading the dataset crawled from WalkingMap website.

# %%
with open('dataset/walkingmaps.json', 'r', encoding='utf-8') as fp:
    dataset = json.load(fp)

# %%
logger.debug(f'an example record in dataset: {dataset[1]}')
logger.info(f'structure of records in dataset: {dataset[1].keys()}')
# Out:
# 2025-01-25 20:25:12.429 | INFO     | __main__:<module>:2 - structure of records in dataset: dict_keys(['markers', 'pathDetails', 'pois', 'title', 'description'])

# %% [markdown]
# ### Dataset Transformation
#
# Aim: Transforming the dataset into pandas and geopandas dataframes, with a focus on POIs
#
# A basic preprocessing step to create a dataset of POI descriptions, also including A preliminary analysis their location.

# %%
counter = 0
total = 0
for record in dataset:
    if 'pois' in record.keys() and len(record['pois']) > 0:
        counter+=1
        total += len(record['pois'])
logger.info('records: {0} total POIs: {1} - average per record: {2}'.format(counter, total, round(total/counter)))
# Out:
# 2025-01-25 20:25:14.304 | INFO     | __main__:<module>:7 - records: 386 total POIs: 4392 - average per record: 11

# %%
import statistics 

verbal_descriptions = []
poi_descriptions = []
for record in dataset:
    if 'pois' in record.keys() and len(record['pois']) > 0:
        vb = record['title']+' '+record['description']
        verbal_descriptions.append(vb)
        for poi in record['pois']:
            pvb = poi['title']+' '+poi['summary']
            poi_descriptions.append(pvb)

wc_vb = [len(vb.split(' ')) for vb in verbal_descriptions]
logger.info(f'word count verbal description \n\t- average: {int(statistics.mean(wc_vb))} - median: {statistics.median(wc_vb)} - min: {min(wc_vb)} - max: {max(wc_vb)}')
wc_pvb = [len(pvb.split(' ')) for pvb in poi_descriptions]
logger.info(f'word count POI verbal description \n\t- average: {int(statistics.mean(wc_pvb))} - median: {statistics.median(wc_pvb)} - min: {min(wc_pvb)} - max: {max(wc_pvb)}')
cc_vb = [len(vb) for vb in verbal_descriptions]
logger.info(f'character count verbal description \n\t- average: {int(statistics.mean(cc_vb))} - median: {statistics.median(cc_vb)} - min: {min(cc_vb)} - max: {max(cc_vb)}')
cc_pvb = [len(pvb) for pvb in poi_descriptions]
logger.info(f'character count POI verbal description \n\t- average: {int(statistics.mean(cc_pvb))} - median: {statistics.median(cc_pvb)} - min: {min(cc_pvb)} - max: {max(cc_pvb)}')
# Out:
# 2025-01-25 20:25:18.824 | INFO     | __main__:<module>:14 - word count verbal description
# 	- average: 181 - median: 130.0 - min: 7 - max: 540
# 2025-01-25 20:25:18.836 | INFO     | __main__:<module>:16 - word count POI verbal description
# 	- average: 22 - median: 23.0 - min: 2 - max: 116
# 2025-01-25 20:25:18.837 | INFO     | __main__:<module>:18 - character count verbal description
# 	- average: 1062 - median: 764.0 - min: 43 - max: 3052
# 2025-01-25 20:25:18.840 | INFO     | __main__:<module>:20 - character count POI verbal description
# 	- average: 130 - median: 127.0 - min: 11 - max: 296

# %%
data_structure = {'record_title':[], 'record_description':[], 'poi_title':[], 'poi_summary':[], 'latitude': [], 'longitude': []}
for record in dataset:
    if 'pois' in record.keys() and len(record['pois']) > 0:
        for poi in record['pois']:
            data_structure['record_title'].append(record['title'])
            data_structure['record_description'].append(record['description'])
            data_structure['poi_title'].append(poi['title'])
            data_structure['poi_summary'].append(poi['summary'])
            data_structure['latitude'].append(poi['lat'])
            data_structure['longitude'].append(poi['lng'])

# %%
df = pd.DataFrame(data_structure)

gdf = gpd.GeoDataFrame(df[['poi_title', 'poi_summary', 'latitude', 'longitude']], geometry=gpd.points_from_xy(df.longitude, df.latitude), crs="EPSG:4326")

# %%
gdf.head()
# Out:
#                          poi_title  \
# 0  Fairhaven Surf Life Saving Club
# 1                       Beach walk
# 2                       Rock pools
# 3                       Sand dunes
# 4                  Painkalac Creek
#
#                                          poi_summary   latitude   longitude  \
# 0  Fairhaven is a well known surf beach. The beac... -38.468759  144.084459
# 1  From Sprout Creek, Eastern View, Moggs Creek, ... -38.468542  144.089693
# 2  See what sort of shells and stones you can col... -38.468459  144.092420
# 3  The beautiful rolling sand dunes shape the bea... -38.468418  144.095318
# 4  The creek separates Aireys Inlet from Fairhave... -38.468390  144.097312
#
#                       geometry
# 0  POINT (144.08446 -38.46876)
# 1  POINT (144.08969 -38.46854)
# 2  POINT (144.09242 -38.46846)
# 3  POINT (144.09532 -38.46842)
# 4  POINT (144.09731 -38.46839)

# %%
df.head()
# Out:
#                                         record_title  \
# 0  Fairhaven to Aireys Inlet Walk created by tedm...
# 1  Fairhaven to Aireys Inlet Walk created by tedm...
# 2  Fairhaven to Aireys Inlet Walk created by tedm...
# 3  Fairhaven to Aireys Inlet Walk created by tedm...
# 4  Fairhaven to Aireys Inlet Walk created by tedm...
#
#                                   record_description  \
# 0  Apart from the points of interested listed, he...
# 1  Apart from the points of interested listed, he...
# 2  Apart from the points of interested listed, he...
# 3  Apart from the points of interested listed, he...
# 4  Apart from the points of interested listed, he...
#
#                          poi_title  \
# 0  Fairhaven Surf Life Saving Club
# 1                       Beach walk
# 2                       Rock pools
# 3                       Sand dunes
# 4                  Painkalac Creek
#
#                                          poi_summary   latitude   longitude
# 0  Fairhaven is a well known surf beach. The beac... -38.468759  144.084459
# 1  From Sprout Creek, Eastern View, Moggs Creek, ... -38.468542  144.089693
# 2  See what sort of shells and stones you can col... -38.468459  144.092420
# 3  The beautiful rolling sand dunes shape the bea... -38.468418  144.095318
# 4  The creek separates Aireys Inlet from Fairhave... -38.468390  144.097312

# %% [markdown]
# ## OSM Points of Interests
#
# **Aim**: Collect rich OSM POI information in the bounding box area of the lesiure walk.
#
# **Approach**: Using OSM tags for `{'amenity': True, 'natural': True, 'animal': True, 'leisure': True}` to collect information inside the bounding boxes of leisure walks.

# %%
# bounding box of each path
paths = []
for record in dataset:
    min_lat = 90
    max_lat = -90
    min_lng = 180
    max_lng = -180
    for latlng in record['pathDetails']:
        if min_lat > latlng['lat']:
            min_lat = latlng['lat']
        if max_lat < latlng['lat']:
            max_lat = latlng['lat']
        if min_lng > latlng['lng']:
            min_lng = latlng['lng']
        if max_lng < latlng['lng']:
            max_lng = latlng['lng']
    paths.append({'min_lat': min_lat, 'max_lat': max_lat, 'min_lng': min_lng, 'max_lng': max_lng})

# %%
logger.debug(f'all path bounding boxes: {paths}')  # bounding box information leisure walks
logger.info(f'example path bounding boxes: {paths[0]}')  # bounding box information leisure walks
# Out:
# 2025-01-25 20:25:55.110 | INFO     | __main__:<module>:2 - example path bounding boxes: {'min_lat': -37.82326007, 'max_lat': -37.81401352, 'min_lng': 144.96751249, 'max_lng': 144.97828424}

# %%
tags = {'amenity': True, 'natural': True, 'animal': True, 'leisure': True}

# %%
path = paths[0]
feature_gdf = ox.features_from_bbox(north=path['max_lat'], south=path['min_lat'], east=path['max_lng'], west=path['min_lng'], tags=tags)

# %%
feature_gdf.head()
# Out:
#                         addr:city addr:housenumber addr:postcode  \
# element_type osmid
# node         176729780  Melbourne              191          3000
#              247024808        NaN              NaN           NaN
#              247689970        NaN              NaN           NaN
#              266733834        NaN              NaN           NaN
#              304169365        NaN              NaN           NaN
#
#                            addr:street           amenity  \
# element_type osmid
# node         176729780  Collins Street           theatre
#              247024808             NaN  parking_entrance
#              247689970             NaN  parking_entrance
#              266733834             NaN           parking
#              304169365             NaN           theatre
#
#                                          name        operator  \
# element_type osmid
# node         176729780         Regent Theatre  Marriner Group
#              247024808                    NaN             NaN
#              247689970                    NaN             NaN
#              266733834  Sofitel Hotel Carpark  Wilson Parking
#              304169365      Playhouse Theatre             NaN
#
#                                                                   website  \
# element_type osmid
# node         176729780  https://www.marrinergroup.com.au/theatre-regen...
#              247024808                                                NaN
#              247689970                                                NaN
#              266733834                                                NaN
#              304169365                                                NaN
#
#                         wikidata                     geometry  ...  \
# element_type osmid                                             ...
# node         176729780  Q7308110  POINT (144.96760 -37.81550)  ...
#              247024808       NaN  POINT (144.97019 -37.81548)  ...
#              247689970       NaN  POINT (144.97070 -37.81789)  ...
#              266733834       NaN  POINT (144.97302 -37.81451)  ...
#              304169365       NaN  POINT (144.96840 -37.82172)  ...
#
#                        motor_vehicle contact:instagram building:part  \
# element_type osmid
# node         176729780           NaN               NaN           NaN
#              247024808           NaN               NaN           NaN
#              247689970           NaN               NaN           NaN
#              266733834           NaN               NaN           NaN
#              304169365           NaN               NaN           NaN
#
#                        not:operator:wikidata water unisex ways type  \
# element_type osmid
# node         176729780                   NaN   NaN    NaN  NaN  NaN
#              247024808                   NaN   NaN    NaN  NaN  NaN
#              247689970                   NaN   NaN    NaN  NaN  NaN
#              266733834                   NaN   NaN    NaN  NaN  NaN
#              304169365                   NaN   NaN    NaN  NaN  NaN
#
#                        intermittent salt
# element_type osmid
# node         176729780          NaN  NaN
#              247024808          NaN  NaN
#              247689970          NaN  NaN
#              266733834          NaN  NaN
#              304169365          NaN  NaN
#
# [5 rows x 139 columns]

# %%
logger.debug(f'feature columns: {feature_gdf.columns}')
logger.info(f'number of feature columns in feature gdf: {len(feature_gdf.columns)}')
# Out:
# 2025-01-25 20:26:01.589 | INFO     | __main__:<module>:2 - number of feature columns in feature gdf: 139

# %%
feature_gdf.amenity = feature_gdf.amenity.astype(str)
feature_gdf.natural = feature_gdf.natural.astype(str)
feature_gdf.leisure = feature_gdf.leisure.astype(str)
feature_gdf.name = feature_gdf.name.astype(str)

# %%
feature_gdf = feature_gdf[['name', 'amenity', 'natural', 'leisure', 'geometry']].dropna(how='all')
feature_gdf.head()
# Out:
#                                          name           amenity natural  \
# element_type osmid
# node         176729780         Regent Theatre           theatre     nan
#              247024808                    nan  parking_entrance     nan
#              247689970                    nan  parking_entrance     nan
#              266733834  Sofitel Hotel Carpark           parking     nan
#              304169365      Playhouse Theatre           theatre     nan
#
#                        leisure                     geometry
# element_type osmid
# node         176729780     nan  POINT (144.96760 -37.81550)
#              247024808     nan  POINT (144.97019 -37.81548)
#              247689970     nan  POINT (144.97070 -37.81789)
#              266733834     nan  POINT (144.97302 -37.81451)
#              304169365     nan  POINT (144.96840 -37.82172)

# %%
for idx, path in enumerate(paths):
    
    if os.path.isfile('dataset/features-osm-{}.geojson'.format(idx)):
        logger.debug('features for path {0} out of {1} is already loaded and saved.'.format(idx, len(paths)))
        continue;
    try:
        feature_gdf = ox.features_from_bbox(north=path['max_lat'], south=path['min_lat'], east=path['max_lng'], west=path['min_lng'], tags=tags)
        cols = feature_gdf.columns
        #preprocess
        if 'amenity' not in cols:
            feature_gdf['amenity'] = np.nan
        feature_gdf.amenity = feature_gdf.amenity.astype(str)    
        if 'natural' not in cols:
            feature_gdf['natural'] = np.nan
        feature_gdf.natural = feature_gdf.natural.astype(str)    
        if 'leisure' not in cols:
            feature_gdf['leisure'] = np.nan
        feature_gdf.leisure = feature_gdf.leisure.astype(str)
        if 'name' not in cols:
            feature_gdf['name'] = np.nan
        feature_gdf.name = feature_gdf.name.astype(str)
        feature_gdf = feature_gdf[['name', 'amenity', 'natural', 'leisure', 'geometry']].dropna(how='all')
    
        feature_gdf.to_file("dataset/features-osm-{}.geojson".format(idx), driver='GeoJSON')
        logger.info('features for path {0} out of {1} is loaded from OSM and saved ...'.format(idx, len(paths)))
    except Exception as e:
        logger.warning('error in writing path {0} out of {1}...'.format(idx, len(paths)))
        logger.warning(e)
# Out:
# 2025-01-25 20:26:05.802 | WARNING  | __main__:<module>:27 - error in writing path 59 out of 387...
# 2025-01-25 20:26:05.802 | WARNING  | __main__:<module>:28 - No data elements in server response. Check log and query location/tags.
# 2025-01-25 20:26:05.918 | WARNING  | __main__:<module>:27 - error in writing path 128 out of 387...
# 2025-01-25 20:26:05.919 | WARNING  | __main__:<module>:28 - No data elements in server response. Check log and query location/tags.
# 2025-01-25 20:26:06.032 | WARNING  | __main__:<module>:27 - error in writing path 151 out of 387...
# 2025-01-25 20:26:06.033 | WARNING  | __main__:<module>:28 - No data elements in server response. Check log and query location/tags.
# 2025-01-25 20:26:06.150 | WARNING  | __main__:<module>:27 - error in writing path 309 out of 387...
# 2025-01-25 20:26:06.151 | WARNING  | __main__:<module>:28 - No data elements in server response. Check log and query location/tags.
# 2025-01-25 20:26:06.266 | WARNING  | __main__:<module>:27 - error in writing path 338 out of 387...
# 2025-01-25 20:26:06.266 | WARNING  | __main__:<module>:28 - No data elements in server response. Check log and query location/tags.

# %%
feature_gdf.head()
# Out:
#                                          name           amenity natural  \
# element_type osmid
# node         176729780         Regent Theatre           theatre     nan
#              247024808                    nan  parking_entrance     nan
#              247689970                    nan  parking_entrance     nan
#              266733834  Sofitel Hotel Carpark           parking     nan
#              304169365      Playhouse Theatre           theatre     nan
#
#                        leisure                     geometry
# element_type osmid
# node         176729780     nan  POINT (144.96760 -37.81550)
#              247024808     nan  POINT (144.97019 -37.81548)
#              247689970     nan  POINT (144.97070 -37.81789)
#              266733834     nan  POINT (144.97302 -37.81451)
#              304169365     nan  POINT (144.96840 -37.82172)

# %% [markdown]
# ## Matching POIs to OSM POIs
#
# **Aim** To match collected OSM POIs with described POIs
#
# **Approach** using textual matching of POIs description to OSM tags (*semantic criterion*) and spatial matching based on proximity (*spatial criterion*):
#
# - spatial criterion: defining containment
# - semantic criterion: defining semantic similarity using word embeddings

# %% [markdown]
# ### Semantic Matching
#
# Ranking the relevance of textual descriptions in OSM POIs and LW POIS
#
# Example to test how it works

# %%
sbert_model = SentenceTransformer('bert-base-nli-mean-tokens') # symmetric semantic search
msmarco_model = SentenceTransformer('sentence-transformers/msmarco-distilbert-dot-v5')  # asymmetric semantic search

# embedding derived from BERT for the pois
def embed_texts(sentences, model=sbert_model):
    sentence_embeddings = model.encode(sentences)
    return sentence_embeddings


def compute_similarities(query, sentences, sentence_embeddings, model=sbert_model):
    query_vec = embed_texts(query)
    scores = util.dot_score(query_vec, sentence_embeddings)[0].cpu().tolist()
    doc_score_pairs = list(zip(sentences, scores))
    doc_score_pairs = sorted(doc_score_pairs, key=lambda x: x[1], reverse=True)
    logger.debug("Query:", query)
    for doc, score in doc_score_pairs:
        logger.info(f'\t{score}\t{doc}')
    return doc_score_pairs

# %%
def only_noun_phrases(sentence):
    doc = nlp(sentence)
    phrases = set() 
    for nc in doc.noun_chunks:
        phrases.add(nc.text)
        phrases.add(doc[nc.root.left_edge.i:nc.root.right_edge.i+1].text)
    return ' '.join(phrases)

# %%
example_poi_osm = "Gaswork park theatre"
example_sentences = ["Gasworks Park: There are artists studios, a theatre and a cafe. Every 3rd Saturday there is a Farmers' Market.  In the park you'll also come across various wonderful sculptures and installations.",
                                                 "Australia's Number One university and world leader in education, teaching and research excellence.",
                                                 "Completed in 1870, the Melbourne Town Hall is at the heart of the city's cultural and civic activity",
                                                 "The magnificent octagonal domed reading room is both a quiet space for study and an iconic Melbourne location to take an unforgettable selfie.?"]
example_sentence_embeddings = embed_texts(example_sentences)
compute_similarities(example_poi_osm, example_sentences, example_sentence_embeddings)
# Out:
# 2025-01-25 20:26:15.807 | INFO     | __main__:compute_similarities:17 - 	112.580322265625	Completed in 1870, the Melbourne Town Hall is at the heart of the city's cultural and civic activity
# 2025-01-25 20:26:15.808 | INFO     | __main__:compute_similarities:17 - 	92.63180541992188	Gasworks Park: There are artists studios, a theatre and a cafe. Every 3rd Saturday there is a Farmers' Market.  In the park you'll also come across various wonderful sculptures and installations.
# 2025-01-25 20:26:15.809 | INFO     | __main__:compute_similarities:17 - 	84.313232421875	The magnificent octagonal domed reading room is both a quiet space for study and an iconic Melbourne location to take an unforgettable selfie.?
# 2025-01-25 20:26:15.809 | INFO     | __main__:compute_similarities:17 - 	62.57238006591797	Australia's Number One university and world leader in education, teaching and research excellence.
# [("Completed in 1870, the Melbourne Town Hall is at the heart of the city's cultural and civic activity",
#   112.580322265625),
#  ("Gasworks Park: There are artists studios, a theatre and a cafe. Every 3rd Saturday there is a Farmers' Market.  In the park you'll also come across various wonderful sculptures and installations.",
#   92.63180541992188),
#  ('The magnificent octagonal domed reading room is both a quiet space for study and an iconic Melbourne location to take an unforgettable selfie.?',
#   84.313232421875),
#  ("Australia's Number One university and world leader in education, teaching and research excellence.",
#   62.57238006591797)]

# %%
# with preprocessing
only_noun_example_sentences = [only_noun_phrases(sentence) for sentence in example_sentences]
example_sentence_embeddings = embed_texts(only_noun_example_sentences)
compute_similarities(example_poi_osm, only_noun_example_sentences, example_sentence_embeddings)
# Out:
# 2025-01-25 20:26:16.815 | INFO     | __main__:compute_similarities:17 - 	125.21781921386719	a theatre and a cafe a cafe various wonderful sculptures and installations a Farmers' Market the park artists studios artists studios, a theatre and a cafe various wonderful sculptures you a theatre Gasworks Park: Gasworks Park installations
# 2025-01-25 20:26:16.816 | INFO     | __main__:compute_similarities:17 - 	121.1483154296875	the heart of the city's cultural and civic activity the city's cultural and civic activity the heart the Melbourne Town Hall
# 2025-01-25 20:26:16.816 | INFO     | __main__:compute_similarities:17 - 	72.54638671875	an iconic Melbourne location The magnificent octagonal domed reading room a quiet space for study and an iconic Melbourne location to take an unforgettable selfie a quiet space study an unforgettable selfie an iconic Melbourne location to take an unforgettable selfie
# 2025-01-25 20:26:16.816 | INFO     | __main__:compute_similarities:17 - 	60.15925598144531	education Australia's Number One university and world leader research Australia's Number One university and world leader in education, teaching and research excellence. teaching teaching and research excellence excellence education, teaching and research excellence
# [("a theatre and a cafe a cafe various wonderful sculptures and installations a Farmers' Market the park artists studios artists studios, a theatre and a cafe various wonderful sculptures you a theatre Gasworks Park: Gasworks Park installations",
#   125.21781921386719),
#  ("the heart of the city's cultural and civic activity the city's cultural and civic activity the heart the Melbourne Town Hall",
#   121.1483154296875),
#  ('an iconic Melbourne location The magnificent octagonal domed reading room a quiet space for study and an iconic Melbourne location to take an unforgettable selfie a quiet space study an unforgettable selfie an iconic Melbourne location to take an unforgettable selfie',
#   72.54638671875),
#  ("education Australia's Number One university and world leader research Australia's Number One university and world leader in education, teaching and research excellence. teaching teaching and research excellence excellence education, teaching and research excellence",
#   60.15925598144531)]

# %%
example_sentence_embeddings = embed_texts(example_sentences, model=msmarco_model)
compute_similarities(example_poi_osm, example_sentences, example_sentence_embeddings, model=msmarco_model)
# Out:
# 2025-01-25 20:26:17.606 | INFO     | __main__:compute_similarities:17 - 	42.83140563964844	Gasworks Park: There are artists studios, a theatre and a cafe. Every 3rd Saturday there is a Farmers' Market.  In the park you'll also come across various wonderful sculptures and installations.
# 2025-01-25 20:26:17.606 | INFO     | __main__:compute_similarities:17 - 	30.717838287353516	Completed in 1870, the Melbourne Town Hall is at the heart of the city's cultural and civic activity
# 2025-01-25 20:26:17.607 | INFO     | __main__:compute_similarities:17 - 	25.081661224365234	The magnificent octagonal domed reading room is both a quiet space for study and an iconic Melbourne location to take an unforgettable selfie.?
# 2025-01-25 20:26:17.607 | INFO     | __main__:compute_similarities:17 - 	18.959270477294922	Australia's Number One university and world leader in education, teaching and research excellence.
# [("Gasworks Park: There are artists studios, a theatre and a cafe. Every 3rd Saturday there is a Farmers' Market.  In the park you'll also come across various wonderful sculptures and installations.",
#   42.83140563964844),
#  ("Completed in 1870, the Melbourne Town Hall is at the heart of the city's cultural and civic activity",
#   30.717838287353516),
#  ('The magnificent octagonal domed reading room is both a quiet space for study and an iconic Melbourne location to take an unforgettable selfie.?',
#   25.081661224365234),
#  ("Australia's Number One university and world leader in education, teaching and research excellence.",
#   18.959270477294922)]

# %%
example_sentence_embeddings = embed_texts(only_noun_example_sentences, model=msmarco_model)
compute_similarities(example_poi_osm, only_noun_example_sentences, example_sentence_embeddings, model=msmarco_model)
# Out:
# 2025-01-25 20:26:19.009 | INFO     | __main__:compute_similarities:17 - 	43.246639251708984	a theatre and a cafe a cafe various wonderful sculptures and installations a Farmers' Market the park artists studios artists studios, a theatre and a cafe various wonderful sculptures you a theatre Gasworks Park: Gasworks Park installations
# 2025-01-25 20:26:19.010 | INFO     | __main__:compute_similarities:17 - 	30.413190841674805	the heart of the city's cultural and civic activity the city's cultural and civic activity the heart the Melbourne Town Hall
# 2025-01-25 20:26:19.010 | INFO     | __main__:compute_similarities:17 - 	24.648412704467773	an iconic Melbourne location The magnificent octagonal domed reading room a quiet space for study and an iconic Melbourne location to take an unforgettable selfie a quiet space study an unforgettable selfie an iconic Melbourne location to take an unforgettable selfie
# 2025-01-25 20:26:19.011 | INFO     | __main__:compute_similarities:17 - 	18.057191848754883	education Australia's Number One university and world leader research Australia's Number One university and world leader in education, teaching and research excellence. teaching teaching and research excellence excellence education, teaching and research excellence
# [("a theatre and a cafe a cafe various wonderful sculptures and installations a Farmers' Market the park artists studios artists studios, a theatre and a cafe various wonderful sculptures you a theatre Gasworks Park: Gasworks Park installations",
#   43.246639251708984),
#  ("the heart of the city's cultural and civic activity the city's cultural and civic activity the heart the Melbourne Town Hall",
#   30.413190841674805),
#  ('an iconic Melbourne location The magnificent octagonal domed reading room a quiet space for study and an iconic Melbourne location to take an unforgettable selfie a quiet space study an unforgettable selfie an iconic Melbourne location to take an unforgettable selfie',
#   24.648412704467773),
#  ("education Australia's Number One university and world leader research Australia's Number One university and world leader in education, teaching and research excellence. teaching teaching and research excellence excellence education, teaching and research excellence",
#   18.057191848754883)]

# %% [markdown]
# #### Conclusions
#
# The process of matching cannot be fully autoamted - the tasks is more complex than using BERT embeddings for matching. Even trained embedding on MSMARCO do not lead to good performance and seems to be confused between correct and incorrect matches.

# %% [markdown]
# ### Matching: Case Investigation
#
# Checking the POIs in description with respect to OSM POIs
#
# **Aim**: Manually checking few examples in the dataset to see how the descriptions provided by people is different from tags stored in OSM to design a better approach for labelling the dataset.
#
# **Approach**: Given a case_id (walk), we pull all the POI information in WalkingMap dataset and extracted POIs from OSM in previous step, and we analysis spatial and semantic criteria and their success/failure in performing matching process.

# %%
def get_case(idx):
    record = dataset[idx]  
    pois = {'title': [], 'summary': [], 'lat': [], 'lng': []}
    for poi in record['pois']:
        pois['title'].append(poi['title'])
        pois['summary'].append(poi['summary'])
        pois['lat'].append(poi['lat'])
        pois['lng'].append(poi['lng'])
        
    df = pd.DataFrame(pois)
    gdf = gpd.GeoDataFrame(df[['title', 'summary', 'lat', 'lng']],
                           geometry=gpd.points_from_xy(df.lng, df.lat), crs="EPSG:4326")
    
    if os.path.isfile('dataset/features-osm-{}.geojson'.format(idx)):
        osm_pois = gpd.read_file('dataset/features-osm-{}.geojson'.format(idx))
    else:
        logger.warning('OSM features are not loaded - potentially empty dataframe')
        osm_pois = None
    return gdf, osm_pois

# %%
lw_poi, osm_poi = get_case(1)

# %%
lw_poi
# Out:
#                                         title  \
# 0             Fairhaven Surf Life Saving Club
# 1                                  Beach walk
# 2                                  Rock pools
# 3                                  Sand dunes
# 4                             Painkalac Creek
# 5       Rocks and caves under the light house
# 6   Aireys Inlet playground and picnic ground
# 7                    Aireys Inlet lower shops
# 8                          Loutit Bay lookout
# 9           Historical homestead and building
# 10                     Split Point Lighthouse
#
#                                               summary        lat         lng  \
# 0   Fairhaven is a well known surf beach. The beac... -38.468759  144.084459
# 1   From Sprout Creek, Eastern View, Moggs Creek, ... -38.468542  144.089693
# 2   See what sort of shells and stones you can col... -38.468459  144.092420
# 3   The beautiful rolling sand dunes shape the bea... -38.468418  144.095318
# 4   The creek separates Aireys Inlet from Fairhave... -38.468390  144.097312
# 5   There are more rockpools and rocky outcrops to... -38.468822  144.100861
# 6   There is small skateboard ramp for children to... -38.466199  144.098772
# 7   Pick up a coffee, newspaper or Fish and Chips!... -38.465536  144.098801
# 8   Return to Painkalac Creek inlet and walk to th... -38.467916  144.103435
# 9   At the lighthouse is the original homestead fo... -38.468048  144.103832
# 10  Follow the signs and continue up the walking t... -38.468114  144.104029
#
#                        geometry
# 0   POINT (144.08446 -38.46876)
# 1   POINT (144.08969 -38.46854)
# 2   POINT (144.09242 -38.46846)
# 3   POINT (144.09532 -38.46842)
# 4   POINT (144.09731 -38.46839)
# 5   POINT (144.10086 -38.46882)
# 6   POINT (144.09877 -38.46620)
# 7   POINT (144.09880 -38.46554)
# 8   POINT (144.10344 -38.46792)
# 9   POINT (144.10383 -38.46805)
# 10  POINT (144.10403 -38.46811)

# %%
osm_poi
# Out:
#    element_type       osmid                                 name  \
# 0          node   831201200                                  nan
# 1          node   831201305                                  nan
# 2          node   831201411                                  nan
# 3          node   831201826                                  nan
# 4          node  5315720235                                  nan
# 5          node  8568393481                                  nan
# 6           way    30501938              Painkalac Creek Estuary
# 7           way    69366065                                  nan
# 8           way    69366070                                  nan
# 9           way    69366078                                  nan
# 10          way    69366081              Aireys Inlet Skate Park
# 11          way    69366092                     Bark Hut Reserve
# 12          way    69366108                                  nan
# 13          way    69366116                                  nan
# 14          way    69560073                 Aireys Inlet Reserve
# 15          way    95186468                                  nan
# 16          way   161748270                Allen Noble Sanctuary
# 17          way   283542690                                  nan
# 18          way   865565686                                  nan
# 19          way   865569273                                  nan
# 20          way  1007494584                            Fairhaven
# 21          way  1009404376                           Table Rock
# 22     relation     9212148  Lorne - Queenscliff Coastal Reserve
# 23     relation     9212157          Eagle Rock Marine Sanctuary
# 24     relation     9457256                          Bass Strait
#
#          amenity    natural         leisure  \
# 0        toilets        nan             nan
# 1        toilets        nan             nan
# 2            bbq        nan             nan
# 3        shelter        nan             nan
# 4            nan        nan    picnic_table
# 5   waste_basket        nan             nan
# 6            nan      water             nan
# 7        parking        nan             nan
# 8        parking        nan             nan
# 9            nan        nan      playground
# 10           nan        nan           pitch
# 11           nan        nan            park
# 12           nan        nan      playground
# 13       parking        nan             nan
# 14           nan        nan            park
# 15           nan  coastline             nan
# 16           nan    wetland             nan
# 17       parking        nan             nan
# 18           nan        nan   swimming_pool
# 19           nan        nan   swimming_pool
# 20           nan      beach             nan
# 21           nan      beach             nan
# 22           nan        nan  nature_reserve
# 23           nan        nan  nature_reserve
# 24           nan     strait             nan
#
#                                              geometry
# 0                         POINT (144.09837 -38.46594)
# 1                         POINT (144.10104 -38.46734)
# 2                         POINT (144.09857 -38.46592)
# 3                         POINT (144.09864 -38.46595)
# 4                         POINT (144.10073 -38.46681)
# 5                         POINT (144.10029 -38.46666)
# 6   POLYGON ((144.09591 -38.46359, 144.09625 -38.4...
# 7   POLYGON ((144.10000 -38.46659, 144.09998 -38.4...
# 8   POLYGON ((144.09836 -38.46586, 144.09836 -38.4...
# 9   POLYGON ((144.10198 -38.46581, 144.10217 -38.4...
# 10  POLYGON ((144.09837 -38.46610, 144.09862 -38.4...
# 11  POLYGON ((144.10218 -38.46611, 144.10185 -38.4...
# 12  POLYGON ((144.09846 -38.46595, 144.09868 -38.4...
# 13  POLYGON ((144.09880 -38.46545, 144.09894 -38.4...
# 14  POLYGON ((144.09882 -38.46563, 144.09879 -38.4...
# 15  LINESTRING (143.86352 -38.66725, 143.86349 -38...
# 16  POLYGON ((144.10274 -38.46564, 144.10266 -38.4...
# 17  POLYGON ((144.09879 -38.46604, 144.09885 -38.4...
# 18  POLYGON ((144.08774 -38.46745, 144.08774 -38.4...
# 19  POLYGON ((144.10330 -38.46597, 144.10337 -38.4...
# 20  POLYGON ((144.06686 -38.46862, 144.06692 -38.4...
# 21  POLYGON ((144.10310 -38.46865, 144.10247 -38.4...
# 22  MULTIPOLYGON (((143.94680 -38.57970, 143.94656...
# 23  POLYGON ((144.10158 -38.46903, 144.10159 -38.4...
# 24  POLYGON ((143.51178 -38.85797, 143.51209 -38.8...

# %%
# projection 

lw_projected = lw_poi.to_crs("EPSG:32755")
osm_projected = osm_poi.to_crs("EPSG:32755")

# %%
poi_case = 6  # analysing a specific POI in the fetched case 

lw_poi.iloc[poi_case]
# Out:
# title               Aireys Inlet playground and picnic ground
# summary     There is small skateboard ramp for children to...
# lat                                                -38.466199
# lng                                                144.098772
# geometry                    POINT (144.09877169 -38.46619881)
# Name: 6, dtype: object

# %%
osm_projected['distance_to_{}'.format(poi_case)] = osm_projected.distance(lw_projected.iloc[poi_case]['geometry'])
osm_projected.sort_values(by='distance_to_{}'.format(poi_case))
# Out:
#    element_type       osmid                                 name  \
# 17          way   283542690                                  nan
# 14          way    69560073                 Aireys Inlet Reserve
# 10          way    69366081              Aireys Inlet Skate Park
# 12          way    69366108                                  nan
# 3          node   831201826                                  nan
# 2          node   831201411                                  nan
# 8           way    69366070                                  nan
# 0          node   831201200                                  nan
# 6           way    30501938              Painkalac Creek Estuary
# 13          way    69366116                                  nan
# 22     relation     9212148  Lorne - Queenscliff Coastal Reserve
# 7           way    69366065                                  nan
# 5          node  8568393481                                  nan
# 21          way  1009404376                           Table Rock
# 4          node  5315720235                                  nan
# 1          node   831201305                                  nan
# 20          way  1007494584                            Fairhaven
# 11          way    69366092                     Bark Hut Reserve
# 24     relation     9457256                          Bass Strait
# 15          way    95186468                                  nan
# 16          way   161748270                Allen Noble Sanctuary
# 9           way    69366078                                  nan
# 23     relation     9212157          Eagle Rock Marine Sanctuary
# 19          way   865569273                                  nan
# 18          way   865565686                                  nan
#
#          amenity    natural         leisure  \
# 17       parking        nan             nan
# 14           nan        nan            park
# 10           nan        nan           pitch
# 12           nan        nan      playground
# 3        shelter        nan             nan
# 2            bbq        nan             nan
# 8        parking        nan             nan
# 0        toilets        nan             nan
# 6            nan      water             nan
# 13       parking        nan             nan
# 22           nan        nan  nature_reserve
# 7        parking        nan             nan
# 5   waste_basket        nan             nan
# 21           nan      beach             nan
# 4            nan        nan    picnic_table
# 1        toilets        nan             nan
# 20           nan      beach             nan
# 11           nan        nan            park
# 24           nan     strait             nan
# 15           nan  coastline             nan
# 16           nan    wetland             nan
# 9            nan        nan      playground
# 23           nan        nan  nature_reserve
# 19           nan        nan   swimming_pool
# 18           nan        nan   swimming_pool
#
#                                              geometry  distance_to_6
# 17  POLYGON ((246877.221 5738486.891, 246882.476 5...       0.902516
# 14  POLYGON ((246878.250 5738531.576, 246875.373 5...       8.479294
# 10  POLYGON ((246840.654 5738478.916, 246862.497 5...      13.688306
# 12  POLYGON ((246848.251 5738495.055, 246867.426 5...      15.267822
# 3                      POINT (246863.920 5738496.515)      30.304774
# 2                      POINT (246857.373 5738499.131)      35.687710
# 8   POLYGON ((246838.886 5738505.614, 246838.829 5...      37.170695
# 0                      POINT (246840.125 5738496.254)      45.318589
# 6   POLYGON ((246617.006 5738750.566, 246645.487 5...      51.867211
# 13  POLYGON ((246876.055 5738551.594, 246888.002 5...      78.705460
# 22  MULTIPOLYGON (((234032.450 5725441.094, 234011...      79.652279
# 7   POLYGON ((246984.925 5738428.679, 246983.636 5...     115.908134
# 5                      POINT (247010.317 5738421.768)     142.141188
# 21  POLYGON ((247262.849 5738208.293, 247207.715 5...     148.460931
# 4                      POINT (247049.329 5738406.199)     184.116072
# 1                      POINT (247078.137 5738347.966)     235.344292
# 20  POLYGON ((244099.773 5738111.317, 244107.674 5...     242.844765
# 11  POLYGON ((247173.589 5738487.885, 247143.808 5...     271.562240
# 24  POLYGON ((197305.719 5693199.862, 197332.262 5...     277.569933
# 15  LINESTRING (227108.604 5715478.392, 227106.040...     277.569933
# 16  POLYGON ((247220.495 5738541.191, 247213.006 5...     279.422113
# 9   POLYGON ((247155.210 5738521.192, 247170.344 5...     283.902017
# 23  POLYGON ((247131.297 5738162.720, 247131.845 5...     388.207314
# 19  POLYGON ((247270.470 5738506.467, 247276.519 5...     394.194319
# 18  POLYGON ((245917.657 5738299.103, 245917.799 5...     968.728085

# %% [markdown]
# #### Conclusions:
#
# With manual investigation, we find out that spatial criterion can be a case to filter unwanted records but matching process needs more information than just matching by location because:
#
# 1. POIs visible vs. POIs in nearby: Sometime people describe a place or object in nearby, sometimes the actual POI is far and the location in leisure walk is just a place to see that POI
# 2. OSM and LW location errors
# 3. No match: Not always we can match POIs in LW to OSM, as there are cases missing...
# 4. Multiple matches: Not always a POI described in LW can be matched with only 1 OSM record - different conceptualization, possible ambiguity in description or OSM data -- e.g., a playground described in a park, but in OSM we have three different objects labelled as playground and all near to the location provided in LW.

# %%
# todo - maybe creating a dataset as well! the task is actually difficult!
def generate_req_id(row):
    return row['element_type'][0].upper()+str(row['osmid'])

osm_poi['req_id'] = osm_poi.apply(generate_req_id, axis=1)
logger.debug(f'{osm_poi.req_id.tolist()}')

# %%
req_ids = set()

# read all osm ids and save in a file
for idx, path in enumerate(paths):
    if os.path.isfile('dataset/features-osm-{}.geojson'.format(idx)):
        osm_poi = gpd.read_file('dataset/features-osm-{}.geojson'.format(idx))
        osm_poi['req_id'] = osm_poi.apply(generate_req_id, axis=1)
        req_ids.update(osm_poi.req_id.tolist())

# %%
headers = {"Content-Type": "application/json; charset=utf-8"}
address_endpoint_template = "https://nominatim.openstreetmap.org/lookup?osm_ids={}&format=json&extratags=1"

def download_osm_details(rids):
    resp = requests.get(address_endpoint_template.format(','.join(rids), headers=headers))
    return resp.json()

# %%
req_ids = list(req_ids)

all_osm_info = []

if os.path.isfile('dataset/osm-detailed-pois.json'):
    with open('dataset/osm-detailed-pois.json', 'r') as fp:
        all_osm_info = json.load(fp)
else:
    bucket_size = 50  # maximum value for OSM lookup!
    for i in range(0, len(req_ids), bucket_size):
        try:
            all_osm_info.append(download_osm_details(req_ids[i:i+bucket_size]))
            logger.info('bucket done: {}'.format(i))
            time.sleep(0.5)
        except Exception as e:
            logger.warning(e)
            logger.warning('error in bucket: {}'.format(i))

# %%
all_osm_list = []
for bucket in all_osm_info:
    all_osm_list.extend(bucket)

# %%
with open('dataset/osm-detailed-pois.json', 'w', encoding='utf-8') as fp:
    json.dump(all_osm_info, fp)

with open('dataset/processed-osm-detailed-pois.json', 'w', encoding='utf-8') as fp:
    json.dump(all_osm_list, fp)
    
logger.info('Detailed information about OSM pois are stored in `dataset/osm-detailed-pois.json`')
# Out:
# 2025-01-25 20:27:16.738 | INFO     | __main__:<module>:7 - Detailed information about OSM pois are stored in `dataset/osm-detailed-pois.json`

# %%
print(len(req_ids))
print(len(all_osm_info))
print(len(all_osm_list))
osm_poi_details_df = pd.DataFrame(all_osm_list)
osm_poi_details_df.head()
# Out:
# 84203
# 1685
# 27900
#    place_id                                            licence osm_type  \
# 0  50105769  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
# 1  50264145  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
# 2  49748802  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
# 3  50013438  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
# 4  50156137  Data © OpenStreetMap contributors, ODbL 1.0. h...     node
#
#        osm_id                  lat                 lon    class  \
# 0   210529635         -37.77131895  144.88922947664923  amenity
# 1  1005592702           -37.755842  144.79434671579116  amenity
# 2   948227337  -38.338870549999996  144.72523383795718  leisure
# 3   542417354  -37.985324399999996   145.2116291306154  amenity
# 4   678349689           -37.800412          144.966749  amenity
#
#             type  place_rank  importance addresstype                 name  \
# 0        parking          30     0.00001     amenity  David Jones Carpark
# 1        parking          30     0.00001     amenity
# 2  swimming_pool          30     0.00001     leisure
# 3        parking          30     0.00001     amenity
# 4     restaurant          30     0.00001     amenity         Il Cantuccio
#
#                                         display_name  \
# 0  David Jones Carpark, Primary Place, Maribyrnon...
# 1  Ken Jordan Road, Cairnlea, Melbourne, City of ...
# 2  Stonecutters Road, Portsea, Melbourne, Shire o...
# 3  Robinson Street, Dandenong, Melbourne, City of...
# 4  Il Cantuccio, 209, Lygon Street, Little Italy,...
#
#                                              address  \
# 0  {'amenity': 'David Jones Carpark', 'road': 'Pr...
# 1  {'road': 'Ken Jordan Road', 'suburb': 'Cairnle...
# 2  {'road': 'Stonecutters Road', 'suburb': 'Ports...
# 3  {'road': 'Robinson Street', 'suburb': 'Dandeno...
# 4  {'amenity': 'Il Cantuccio', 'house_number': '2...
#
#                                            extratags  \
# 0  {'parking': 'multi-storey', 'building': 'parki...
# 1                         {'parking': 'street_side'}
# 2                                               None
# 3                                               None
# 4  {'phone': '+61 3 9347 9959', 'cuisine': 'itali...
#
#                                          boundingbox
# 0  [-37.7716973, -37.7708987, 144.8879962, 144.89...
# 1  [-37.7559597, -37.7557312, 144.7942967, 144.79...
# 2  [-38.3389150, -38.3388240, 144.7251718, 144.72...
# 3  [-37.9856572, -37.9849960, 145.2114001, 145.21...
# 4  [-37.8004620, -37.8003620, 144.9666990, 144.96...

# %%
osm_poi_details_df[(osm_poi_details_df['osm_type'] == 'way') & (osm_poi_details_df['osm_id'] == 542417354)]['display_name'].values[0]  # example
# Out:
# 'Robinson Street, Dandenong, Melbourne, City of Greater Dandenong, Victoria, 3177, Australia'

# %%
def enrich(row):
    info = osm_poi_details_df[(osm_poi_details_df['osm_type'] == row['element_type']) & 
    (osm_poi_details_df['osm_id'] == row['osmid'])]
    if len(info) > 0:
        t_name = ' '.join(info['display_name'].values[0].split(',')[:2])
        if info['extratags'].values[0] is not None:
            t_name += ' '.join([k+' '+v for (k,v) in info['extratags'].values[0].items()])
    else:
        t_name = ''
    h_name = ''
    parents = osm_poi.loc[(osm_poi.geometry.contains(row.geometry)) & (osm_poi.id != row.id)]['name'].values.tolist()
    if len(parents) > 0:
        h_name += ' in '+ ', '.join([p for p in parents if p != 'nan'])
    p_name = ''
    if row['amenity'] != 'nan':
        p_name += 'amenity {} '.format(row['amenity']).replace('_', ' ')
    if row['natural'] != 'nan':
        p_name += 'natural {} '.format(row['natural']).replace('_', ' ')
    if row['leisure'] != 'nan':
        p_name += 'leisure {} '.format(row['leisure']).replace('_', ' ')
    if row['name'] == 'nan':
        return p_name+ t_name + h_name
    return row['name'] + ' ' + p_name + t_name + h_name

# %%
osm_poi.reset_index(inplace=True)
osm_poi = osm_poi.rename(columns= {'index': 'id'})
osm_poi.head()
# Out:
#    id element_type        osmid name amenity natural leisure  \
# 0   0         node  10889194475  nan     nan    tree     nan
# 1   1         node  10889194476  nan     nan    tree     nan
# 2   2         node  10889194477  nan     nan    tree     nan
# 3   3         node  10889194478  nan     nan    tree     nan
# 4   4         node  10889194481  nan     nan    tree     nan
#
#                       geometry        req_id
# 0  POINT (145.05762 -37.65706)  N10889194475
# 1  POINT (145.05774 -37.65697)  N10889194476
# 2  POINT (145.05782 -37.65706)  N10889194477
# 3  POINT (145.05787 -37.65710)  N10889194478
# 4  POINT (145.05794 -37.65696)  N10889194481

# %%
osm_poi['full_name'] = osm_poi.apply(enrich, axis=1)
osm_poi.head()
# Out:
#    id element_type        osmid name amenity natural leisure  \
# 0   0         node  10889194475  nan     nan    tree     nan
# 1   1         node  10889194476  nan     nan    tree     nan
# 2   2         node  10889194477  nan     nan    tree     nan
# 3   3         node  10889194478  nan     nan    tree     nan
# 4   4         node  10889194481  nan     nan    tree     nan
#
#                       geometry        req_id      full_name
# 0  POINT (145.05762 -37.65706)  N10889194475  natural tree
# 1  POINT (145.05774 -37.65697)  N10889194476  natural tree
# 2  POINT (145.05782 -37.65706)  N10889194477  natural tree
# 3  POINT (145.05787 -37.65710)  N10889194478  natural tree
# 4  POINT (145.05794 -37.65696)  N10889194481  natural tree

# %%
osm_poi.loc[(osm_poi.geometry.contains(osm_poi.loc[70].geometry)) & (osm_poi.index != 70)]['name'].values.tolist()
# Out:
# ['Mill Park Recreation Reserve']

# %%
osm_poi.iloc[70]['full_name']
# Out:
# 'leisure pitch Lady Penrhyn Avenue  Mill Parksport softball in Mill Park Recreation Reserve'

# %%
for idx, path in enumerate(paths):
    if os.path.isfile('dataset/features-osm-{}.geojson'.format(idx)):
        if os.path.isfile("dataset/features-osm-poi-{}.geojson".format(idx)):
            continue
        osm_poi = gpd.read_file('dataset/features-osm-{}.geojson'.format(idx))
        logger.info('analysing: {0} - number of features: {1}'.format(idx, len(osm_poi)))
        osm_poi.reset_index(inplace=True)
        osm_poi = osm_poi.rename(columns= {'index': 'id'})
        osm_poi['full_name'] = osm_poi.apply(enrich, axis=1)
        osm_poi.to_file("dataset/features-osm-poi-{}.geojson".format(idx), driver='GeoJSON')
        logger.info('enriched features for path {0} out of {1} is loaded from OSM and saved ...'.format(idx, len(paths)))

# %%
osm_poi.head()
# Out:
#    id element_type        osmid name amenity natural leisure  \
# 0   0         node  10889194475  nan     nan    tree     nan
# 1   1         node  10889194476  nan     nan    tree     nan
# 2   2         node  10889194477  nan     nan    tree     nan
# 3   3         node  10889194478  nan     nan    tree     nan
# 4   4         node  10889194481  nan     nan    tree     nan
#
#                       geometry        req_id      full_name
# 0  POINT (145.05762 -37.65706)  N10889194475  natural tree
# 1  POINT (145.05774 -37.65697)  N10889194476  natural tree
# 2  POINT (145.05782 -37.65706)  N10889194477  natural tree
# 3  POINT (145.05787 -37.65710)  N10889194478  natural tree
# 4  POINT (145.05794 -37.65696)  N10889194481  natural tree

# %% [markdown]
# ### Matching LW POIs to OSM POIs: Experiment
#
# **Aim**: To investigate how to perform automatic matching of POIs in LW to OSM, or provide a set of candidate for a semi-automatic matching process (filtering: automatic, matching: manual)
#
# Using:
#
# - *Spatial criterion*: nearby or contained
# - *Thematic criterion*: topic representation of POI with types in OSM POIs
# - *Linguistic criterion*: description of the POI with detailed contextual information from OSM (name, type, hierarchy)
#
# **Note**: The POIs might be missing in OSM data

# %%
def get_case_with_details(idx):
    record = dataset[idx]  
    pois = {'title': [], 'summary': [], 'lat': [], 'lng': []}
    for poi in record['pois']:
        pois['title'].append(poi['title'])
        pois['summary'].append(poi['summary'])
        pois['lat'].append(poi['lat'])
        pois['lng'].append(poi['lng'])
        
    df = pd.DataFrame(pois)
    gdf = gpd.GeoDataFrame(df[['title', 'summary', 'lat', 'lng']],
                           geometry=gpd.points_from_xy(df.lng, df.lat), crs="EPSG:4326")
    
    if os.path.isfile('dataset/features-osm-poi-{}.geojson'.format(idx)):
        osm_pois = gpd.read_file('dataset/features-osm-poi-{}.geojson'.format(idx))
    else:
        logger.warning('OSM features are not loaded - potentially empty dataframe')
        osm_pois = None
    return gdf, osm_pois

# %%
test_case_idx = 2
test_case_gdf, test_case_pois = get_case_with_details(test_case_idx)

# %%
test_case_gdf = test_case_gdf.to_crs("EPSG:32755")
test_case_gdf
# Out:
#                                              title  \
# 0                            1. Tramway signal box
# 1                                    2. City Baths
# 2                             3. Magistrates Court
# 3                            4. Old Melbourne Gaol
# 4                       5. Eight Hour Day Monument
# 5                                   6. Trades Hall
# 6                                   7. Medley Hall
# 7                             8. Lygon shop corner
# 8                                9. Matthais House
# 9                 10. Sacred Heart Catholic Church
# 10                                11. IMAX Theatre
# 11                            12. Melbourne Museum
# 12                   13. Royal Exhibition Building
# 13                             14. Carlton Gardens
# 14                                  15. Playground
# 15              16. Carlton Gardens Primary School
# 16  17. Terrace Houses (201 - 205 Drummond Street)
# 17                              18. Museo Italiano
# 18                             19. La Mama Theatre
# 19                  19. Underground public toilets
# 20                     21. 313-315 Drummond Street
# 21                         22. Carlton Court House
#
#                                               summary        lat         lng  \
# 0   Built in 1928 soon after the electrification o... -37.806953  144.962813
# 1   Built in 1903, the design reflected the social... -37.807382  144.962990
# 2   Built on the site of the earlier Supreme Court... -37.808828  144.966112
# 3   Built between 1851 - 1864. As the oldest survi... -37.807569  144.965710
# 4   Built in 1923, the monument commemorates the E... -37.807126  144.965808
# 5   Built in stages from 1873 - 1926, Trades Hall ... -37.806905  144.965989
# 6   Built in 1893 as a private residence, the buil... -37.805803  144.967618
# 7   Lygon Buildings is architecturally significant... -37.804863  144.966279
# 8   A two storeyed stucco faced bluestone house of... -37.803827  144.967759
# 9   Built in 1855-56. In the 1930s and 1940s the C... -37.803051  144.969378
# 10  IMAX is the world's largest cinema format, wit... -37.803371  144.969616
# 11  The museum has eight galleries, including one ... -37.803674  144.969564
# 12  The Royal Exhibition Building is the only surv... -37.805135  144.971235
# 13  Developed in 19th-century Gardenesque style, t... -37.805630  144.971385
# 14  Wonderful playground with swings, slides and m... -37.802505  144.970700
# 15  The school is an Italian Gothic style building... -37.801938  144.969625
# 16  Built in 1884, Holcombe Terrace is a fine exam... -37.800896  144.968340
# 17  Museo Italiano displays and interprets the exp... -37.798813  144.968136
# 18  Built in 1883, the building was used for vario... -37.798753  144.967652
# 19  The underground public toilets, built in 1939,... -37.798724  144.967416
# 20  Built in 1889, the buliding is architecturally... -37.798425  144.968750
# 21  The Carlton Court House is historically signif... -37.797703  144.968867
#
#                           geometry
# 0   POINT (320663.065 5813648.747)
# 1   POINT (320679.723 5813601.482)
# 2   POINT (320958.059 5813447.052)
# 3   POINT (320919.660 5813585.973)
# 4   POINT (320927.197 5813635.299)
# 5   POINT (320942.628 5813660.156)
# 6   POINT (321083.333 5813785.590)
# 7   POINT (320963.170 5813887.275)
# 8   POINT (321091.019 5814005.140)
# 9   POINT (321231.646 5814094.295)
# 10  POINT (321253.423 5814059.312)
# 11  POINT (321249.542 5814025.589)
# 12  POINT (321400.230 5813866.625)
# 13  POINT (321414.635 5813812.021)
# 14  POINT (321346.754 5814157.403)
# 15  POINT (321250.714 5814218.329)
# 16  POINT (321135.071 5814331.466)
# 17  POINT (321112.101 5814562.205)
# 18  POINT (321069.304 5814567.889)
# 19  POINT (321048.512 5814570.650)
# 20  POINT (321165.248 5814606.489)
# 21  POINT (321173.746 5814686.735)

# %%
test_case_pois = test_case_pois.to_crs("EPSG:32755")
logger.info(f'size of the OSM POI dataframe: {len(test_case_pois.id)}')
test_case_pois.head()
# Out:
# 2025-01-25 20:27:34.150 | INFO     | __main__:<module>:2 - size of the OSM POI dataframe: 2380
#    id element_type      osmid name    amenity natural leisure  \
# 0   0         node  242538793  nan   post_box     nan     nan
# 1   1         node  242540159  nan  telephone     nan     nan
# 2   2         node  242823091  nan  telephone     nan     nan
# 3   3         node  242823102  nan   post_box     nan     nan
# 4   4         node  242823114  nan    toilets     nan     nan
#
#                                            full_name  \
# 0       amenity post box Queensberry Street  Carlton
# 1  amenity telephone Swanston Street  East End Th...
# 2  amenity telephone Swanston Street  East End Th...
# 3            amenity post box Pelham Street  Carlton
# 4  amenity toilets Rathdowne Street  Carltonfee n...
#
#                          geometry
# 0  POINT (320727.351 5813899.378)
# 1  POINT (320749.536 5813412.933)
# 2  POINT (320730.759 5813422.172)
# 3  POINT (321220.734 5814072.447)
# 4  POINT (321272.049 5814137.476)

# %%
test_row_id = 6
test_row = test_case_gdf.loc[test_row_id]
test_row
# Out:
# title                                          7. Medley Hall
# summary     Built in 1893 as a private residence, the buil...
# lat                                                -37.805803
# lng                                                144.967618
# geometry         POINT (321083.33274179127 5813785.590421503)
# Name: 6, dtype: object

# %%
test_case_pois.loc[test_row.geometry.distance(test_case_pois.geometry) < 100]
# Out:
#         id element_type      osmid                           name  \
# 2153  2153          way  265141186  Lygon Street Christian Chapel
# 2231  2231          way  710777495                            nan
# 2232  2232          way  710777496                            nan
# 2254  2254          way  743141724                            nan
# 2283  2283          way  831017470                            nan
# 2284  2284          way  831017484                            nan
# 2285  2285          way  831017485                            nan
#
#                amenity natural leisure  \
# 2153  place_of_worship     nan     nan
# 2231           parking     nan     nan
# 2232           parking     nan     nan
# 2254           parking     nan     nan
# 2283           parking     nan     nan
# 2284           parking     nan     nan
# 2285           parking     nan     nan
#
#                                               full_name  \
# 2153  Lygon Street Christian Chapel amenity place of...
# 2231  amenity parking McDonald Lane  Carltonaccess p...
# 2232  amenity parking Elm Tree Place  Carltonaccess ...
# 2254  amenity parking McDonald Lane  Carltonaccess c...
# 2283  amenity parking Hudson Place  Carltonaccess pr...
# 2284  amenity parking Trades Hall Place  Carltonacce...
# 2285  amenity parking Trades Hall Place  Carltonacce...
#
#                                                geometry
# 2153  POLYGON ((321008.928 5813761.985, 320994.084 5...
# 2231  POLYGON ((321000.885 5813812.657, 320997.612 5...
# 2232  POLYGON ((321135.119 5813776.077, 321133.814 5...
# 2254  POLYGON ((320978.251 5813859.025, 321001.671 5...
# 2283  POLYGON ((321146.543 5813801.593, 321159.873 5...
# 2284  POLYGON ((321003.601 5813711.301, 321007.125 5...
# 2285  POLYGON ((321009.308 5813760.340, 321010.362 5...

# %%
# geocoding results for all POIs
titles = [pt for pt in data_structure['poi_title']]

# %%
geocoder = Nominatim(user_agent='research_app')  # can geocoding be of help?

# %%
paths[test_case_idx]
# Out:
# {'min_lat': -37.80922028,
#  'max_lat': -37.79740113,
#  'min_lng': 144.96275961,
#  'max_lng': 144.97345358}

# %%
result = geocoder.geocode("Medley Hall", viewbox=[(paths[test_case_idx]['max_lat'], paths[test_case_idx]['max_lng']), 
                                                         (paths[test_case_idx]['min_lat'], paths[test_case_idx]['min_lng'])],
                          bounded=True)

# %%
result

# %%
def geocode_by_name(name, path):
    name = name.lstrip('0123456789.- ')
    return geocoder.geocode(name, viewbox=[(path['max_lat'], path['max_lng']), 
                                                         (path['min_lat'], path['min_lng'])],
                          bounded=True)

# %%
if os.path.isfile('dataset/nominatim-geocoding.json'):
    with open('dataset/nominatim-geocoding.json') as fp:
        nominatim_output = json.load(fp)
    logger.info('nominatim dump file is already loaded')
else:
    geocoding_results = []
    for idx, path in enumerate(paths):
        record = dataset[idx]
        for poi in record['pois']:
            name = poi['title']
            result = geocode_by_name(name, path)
            geocoding_results.append(result)
            if result is not None:
                logger.info(name, path)
        if idx%10 == 0:
            time.sleep(1)
            logger.info('idx: {}'.format(idx))

    nominatim_output = {}
    counter = 0
    for idx, path in enumerate(paths):
        record = dataset[idx]
        for poi in record['pois']:
            geocoding_result = geocoding_results[counter]
        
            name = poi['title']
            description = poi['summary']
            lat = poi['lat']
            lng = poi['lng']

            nominatim_output[counter] = {'walk_id': idx, 'title': name, 'summary': description, 'lat': lat, 'lng': lng}
            if geocoding_result is not None:
                nominatim_output[counter]['osm'] = geocoding_result.raw
            else:
                nominatim_output[counter]['osm'] = None
            counter += 1
# Out:
# 2025-01-25 20:27:42.353 | INFO     | __main__:<module>:4 - nominatim dump file is already loaded

# %%
nominatim_output['23']
# Out:
# {'walk_id': 2,
#  'title': '13. Royal Exhibition Building',
#  'summary': 'The Royal Exhibition Building is the only surviving Great Hall that once housed a 19th-century international exhibition and is still used for exhibitions. ',
#  'lat': -37.80513488,
#  'lng': 144.97123539,
#  'osm': {'place_id': 17546919,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 4817059,
#   'lat': '-37.804666850000004',
#   'lon': '144.9714669305319',
#   'class': 'historic',
#   'type': 'building',
#   'place_rank': 30,
#   'importance': 0.39044459367468287,
#   'addresstype': 'historic',
#   'name': 'Royal Exhibition Building',
#   'display_name': 'Royal Exhibition Building, 9, Nicholson Street, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia',
#   'boundingbox': ['-37.8051500', '-37.8041865', '144.9705305', '144.9724671']}}

# %%
logger.debug(f'all nominatim outputs: {nominatim_output}')
logger.info(f'size of nominatim outputs: {len(nominatim_output.keys())}')
# Out:
# 2025-01-25 20:27:52.327 | INFO     | __main__:<module>:2 - size of nominatim outputs: 4392

# %% [markdown]
# ## Labelling Process:
#
# - label if the geocoding was correct - if geocoding was successful
# - find 10 most likely using textual and spatial criteria and record the element as a match

# %%
def get_feature_from_osm(lat, lng, dist=200, tags=tags):
    return ox.features_from_point((lat, lng), tags, dist)

# %%
case_id = 23
test_case = nominatim_output[str(case_id)]

# %%
test_case
# Out:
# {'walk_id': 2,
#  'title': '13. Royal Exhibition Building',
#  'summary': 'The Royal Exhibition Building is the only surviving Great Hall that once housed a 19th-century international exhibition and is still used for exhibitions. ',
#  'lat': -37.80513488,
#  'lng': 144.97123539,
#  'osm': {'place_id': 17546919,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 4817059,
#   'lat': '-37.804666850000004',
#   'lon': '144.9714669305319',
#   'class': 'historic',
#   'type': 'building',
#   'place_rank': 30,
#   'importance': 0.39044459367468287,
#   'addresstype': 'historic',
#   'name': 'Royal Exhibition Building',
#   'display_name': 'Royal Exhibition Building, 9, Nicholson Street, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia',
#   'boundingbox': ['-37.8051500', '-37.8041865', '144.9705305', '144.9724671']}}

# %%
dist_threshold = 200
features = get_feature_from_osm(test_case['lat'], test_case['lng'], dist=dist_threshold)
features
# Out:
#                         access           amenity changing_table  fee  \
# element_type osmid
# node         319157917     yes           toilets             no   no
#              368393200     NaN            cinema            NaN  NaN
#              371974432     NaN          fountain            NaN  NaN
#              767585574     NaN             bench            NaN  NaN
#              767689503     NaN  parking_entrance            NaN  yes
# ...                        ...               ...            ...  ...
# way          1249828891    NaN               NaN            NaN  NaN
#              1249828892    NaN               NaN            NaN  NaN
# relation     6614802       NaN               NaN            NaN  NaN
#              17205856      NaN               NaN            NaN  NaN
#              17205857      NaN               NaN            NaN  NaN
#
#                                        operator operator:wikidata  \
# element_type osmid
# node         319157917   Melbourne City Council         Q56477763
#              368393200         Melbourne museum               NaN
#              371974432                      NaN               NaN
#              767585574                      NaN               NaN
#              767689503                      NaN               NaN
# ...                                         ...               ...
# way          1249828891                     NaN               NaN
#              1249828892                     NaN               NaN
# relation     6614802     Melbourne City Council               NaN
#              17205856                       NaN               NaN
#              17205857                       NaN               NaN
#
#                         toilets:disposal unisex wheelchair  \
# element_type osmid
# node         319157917             flush    yes        yes
#              368393200               NaN    NaN        NaN
#              371974432               NaN    NaN        NaN
#              767585574               NaN    NaN        NaN
#              767689503               NaN    NaN        NaN
# ...                                  ...    ...        ...
# way          1249828891              NaN    NaN        NaN
#              1249828892              NaN    NaN        NaN
# relation     6614802                 NaN    NaN        NaN
#              17205856                NaN    NaN        NaN
#              17205857                NaN    NaN        NaN
#
#                                                                   geometry  \
# element_type osmid
# node         319157917                         POINT (144.96920 -37.80626)
#              368393200                         POINT (144.97064 -37.80351)
#              371974432                         POINT (144.97138 -37.80545)
#              767585574                         POINT (144.97296 -37.80630)
#              767689503                         POINT (144.96975 -37.80406)
# ...                                                                    ...
# way          1249828891  POLYGON ((144.97256 -37.80592, 144.97252 -37.8...
#              1249828892  POLYGON ((144.96983 -37.80600, 144.96980 -37.8...
# relation     6614802     MULTIPOLYGON (((144.96913 -37.80719, 144.96903...
#              17205856    POLYGON ((144.97226 -37.80608, 144.97222 -37.8...
#              17205857    POLYGON ((144.97004 -37.80614, 144.97007 -37.8...
#
#                          ...  \
# element_type osmid       ...
# node         319157917   ...
#              368393200   ...
#              371974432   ...
#              767585574   ...
#              767689503   ...
# ...                      ...
# way          1249828891  ...
#              1249828892  ...
# relation     6614802     ...
#              17205856    ...
#              17205857    ...
#
#                                                                      nodes  \
# element_type osmid
# node         319157917                                                 NaN
#              368393200                                                 NaN
#              371974432                                                 NaN
#              767585574                                                 NaN
#              767689503                                                 NaN
# ...                                                                    ...
# way          1249828891  [11618112476, 11618112477, 11618112478, 116181...
#              1249828892  [11618112487, 11618112488, 11618112489, 116181...
# relation     6614802     [[[4421481857, 4421481858, 4421481859, 4421481...
#              17205856    [[[371970971, 371970972, 11618112514, 37197097...
#              17205857    [[[371971531, 371971532, 5864830649, 116181125...
#
#                         layer leaf_type                                ways  \
# element_type osmid
# node         319157917    NaN       NaN                                 NaN
#              368393200    NaN       NaN                                 NaN
#              371974432    NaN       NaN                                 NaN
#              767585574    NaN       NaN                                 NaN
#              767689503    NaN       NaN                                 NaN
# ...                       ...       ...                                 ...
# way          1249828891   NaN       NaN                                 NaN
#              1249828892   NaN       NaN                                 NaN
# relation     6614802      NaN       NaN              [444681638, 444681637]
#              17205856     NaN       NaN  [33005170, 1249828890, 1249828891]
#              17205857     NaN       NaN              [33005173, 1249828892]
#
#                         addr:suburb          type           wikipedia  \
# element_type osmid
# node         319157917          NaN           NaN                 NaN
#              368393200          NaN           NaN                 NaN
#              371974432          NaN           NaN                 NaN
#              767585574          NaN           NaN                 NaN
#              767689503          NaN           NaN                 NaN
# ...                             ...           ...                 ...
# way          1249828891         NaN           NaN                 NaN
#              1249828892         NaN           NaN                 NaN
# relation     6614802        Carlton  multipolygon  en:Carlton Gardens
#              17205856           NaN  multipolygon                 NaN
#              17205857           NaN  multipolygon                 NaN
#
#                         intermittent salt water
# element_type osmid
# node         319157917           NaN  NaN   NaN
#              368393200           NaN  NaN   NaN
#              371974432           NaN  NaN   NaN
#              767585574           NaN  NaN   NaN
#              767689503           NaN  NaN   NaN
# ...                              ...  ...   ...
# way          1249828891          NaN  NaN   NaN
#              1249828892          NaN  NaN   NaN
# relation     6614802             NaN  NaN   NaN
#              17205856             no   no  pond
#              17205857            NaN  NaN  pond
#
# [334 rows x 53 columns]

# %%
logger.info(f'list of features from OSM results: {list(features.columns)}')
# Out:
# 2025-01-25 20:29:38.982 | INFO     | __main__:<module>:1 - list of features from OSM results: ['access', 'amenity', 'changing_table', 'fee', 'operator', 'operator:wikidata', 'toilets:disposal', 'unisex', 'wheelchair', 'geometry', 'check_date', 'name', 'payment:mastercard', 'payment:visa', 'phone', 'screen', 'website', 'wikidata', 'artist', 'covered', 'drinking_water', 'indoor', 'backrest', 'source', 'parking', 'bicycle_parking', 'fountain', 'leisure', 'brand', 'brand:wikidata', 'brand:wikipedia', 'operator:wikipedia', 'payment:cash', 'payment:credit_cards', 'toilets:wheelchair', 'natural', 'capacity', 'location', 'material', 'recycling:cans', 'recycling:glass_bottles', 'recycling:paper', 'recycling_type', 'nodes', 'layer', 'leaf_type', 'ways', 'addr:suburb', 'type', 'wikipedia', 'intermittent', 'salt', 'water']

# %%
for key, value in nominatim_output.items():
    logger.debug('key: {}'.format(key))
    if os.path.isfile('dataset/osm-poi-{0}-dist-{1}-features.geojson'.format(key, dist_threshold)):
        logger.debug('already investigated...')
        continue;
    try:
        # only set for next round - first run dist=200 to collect initial results and the empty frames are completed by considering 1000 meters thresholds.
        features = get_feature_from_osm(value['lat'], value['lng'], dist=1000)
        cols = list(features.columns)
        cols.remove('geometry')
        features[cols] = features[cols].astype(str)
        features.to_file('dataset/osm-poi-{0}-dist-{1}-features.geojson'.format(key, dist_threshold), driver="GeoJSON") 
        logger.info('done')
    except Exception as e:
        logger.warning(e)

# %%
import pyproj
from shapely.geometry import Point
from shapely.ops import transform

wgs84_pt = Point(test_case['lng'], test_case['lat'])
wgs84 = pyproj.CRS('EPSG:4326')
utm = pyproj.CRS('EPSG:32755')

project = pyproj.Transformer.from_crs(wgs84, utm, always_xy=True).transform

utm_point = transform(project, wgs84_pt)

features = gpd.read_file('dataset/osm-poi-{0}-dist-{1}-features.geojson'.format(case_id, dist_threshold))
features = features.to_crs('EPSG:32755')

features['distance'] = [utm_point.distance(geom) for geom in features.geometry]

# %%
features
# Out:
#     element_type      osmid     highway traffic_signals:direction access  \
# 0           node  319157917         nan                       nan    yes
# 1           node  368393200         nan                       nan    nan
# 2           node  371974432         nan                       nan    nan
# 3           node  493873180    crossing                       nan    nan
# 4           node  501027469    crossing                       nan    nan
# ..           ...        ...         ...                       ...    ...
# 435     relation    6614802         nan                       nan    nan
# 436     relation    6623509         nan                       nan    nan
# 437     relation   13238592  pedestrian                       nan    nan
# 438     relation   16464561         nan                       nan    nan
# 439     relation   16505481  pedestrian                       nan    nan
#
#       amenity  fee                operator toilets:disposal unisex  ...  \
# 0     toilets   no  Melbourne City Council            flush    yes  ...
# 1      cinema  nan        Melbourne museum              nan    nan  ...
# 2    fountain  nan                     nan              nan    nan  ...
# 3         nan  nan                     nan              nan    nan  ...
# 4         nan  nan                     nan              nan    nan  ...
# ..        ...  ...                     ...              ...    ...  ...
# 435       nan  nan  Melbourne City Council              nan    nan  ...
# 436       nan  nan                     nan              nan    nan  ...
# 437       nan  nan                     nan              nan    nan  ...
# 438       nan  nan                     nan              nan    nan  ...
# 439       nan  nan                     nan              nan    nan  ...
#
#     source:population name:mk short_name political_division heritage  \
# 0                 nan     nan        nan                nan      nan
# 1                 nan     nan        nan                nan      nan
# 2                 nan     nan        nan                nan      nan
# 3                 nan     nan        nan                nan      nan
# 4                 nan     nan        nan                nan      nan
# ..                ...     ...        ...                ...      ...
# 435               nan     nan        nan                nan      nan
# 436               nan     nan        nan                nan        1
# 437               nan     nan        nan                nan      nan
# 438               nan     nan        nan                nan      nan
# 439               nan     nan        nan                nan      nan
#
#     heritage:operator                    heritage:website area  \
# 0                 nan                                 nan  nan
# 1                 nan                                 nan  nan
# 2                 nan                                 nan  nan
# 3                 nan                                 nan  nan
# 4                 nan                                 nan  nan
# ..                ...                                 ...  ...
# 435               nan                                 nan  nan
# 436               whc  http://whc.unesco.org/en/list/1131  nan
# 437               nan                                 nan  yes
# 438               nan                                 nan  nan
# 439               nan                                 nan  nan
#
#                                               geometry    distance
# 0                       POINT (321223.384 5813738.129)  218.599034
# 1                       POINT (321343.567 5814046.274)  188.373535
# 2                       POINT (321413.415 5813831.827)   37.211904
# 3                       POINT (321256.686 5813883.765)  144.563983
# 4                       POINT (321600.961 5813827.093)  204.586235
# ..                                                 ...         ...
# 435  MULTIPOLYGON (((321219.805 5813634.926, 321210...    3.048837
# 436  MULTIPOLYGON (((321415.382 5813963.959, 321416...    3.048837
# 437  POLYGON ((321571.451 5813919.342, 321569.416 5...   96.331620
# 438  POLYGON ((321163.337 5813990.989, 321180.796 5...  209.794588
# 439  POLYGON ((321495.098 5813936.836, 321494.024 5...   71.028757
#
# [440 rows x 141 columns]

# %%
not_consider = ['geometry', 'distance', 'element_type', 'osmid']
consider_first = ['name', 'short_name']
cols = list(features.columns)

# %%
def generate_textual_descriptions(row, cols=cols):
    full_name = ''
    for c in consider_first:
        if c in cols and row[c] != 'nan':
            full_name += ' ' + row[c]
    for c in cols:
        if c not in consider_first and c not in not_consider and ':' not in c and row[c] != 'nan' and row[c] != 'no' and 'http' not in row[c] and '[' not in row[c] and 'wiki' not in c:
            if row[c] == 'yes':
                full_name += ' ' + c
            else:
                full_name += ' {0} {1}'.format(c, row[c])
    return full_name.strip()

# %%
features['full_name'] = features.apply(generate_textual_descriptions, axis=1)
features
# Out:
#     element_type      osmid     highway traffic_signals:direction access  \
# 0           node  319157917         nan                       nan    yes
# 1           node  368393200         nan                       nan    nan
# 2           node  371974432         nan                       nan    nan
# 3           node  493873180    crossing                       nan    nan
# 4           node  501027469    crossing                       nan    nan
# ..           ...        ...         ...                       ...    ...
# 435     relation    6614802         nan                       nan    nan
# 436     relation    6623509         nan                       nan    nan
# 437     relation   13238592  pedestrian                       nan    nan
# 438     relation   16464561         nan                       nan    nan
# 439     relation   16505481  pedestrian                       nan    nan
#
#       amenity  fee                operator toilets:disposal unisex  ...  \
# 0     toilets   no  Melbourne City Council            flush    yes  ...
# 1      cinema  nan        Melbourne museum              nan    nan  ...
# 2    fountain  nan                     nan              nan    nan  ...
# 3         nan  nan                     nan              nan    nan  ...
# 4         nan  nan                     nan              nan    nan  ...
# ..        ...  ...                     ...              ...    ...  ...
# 435       nan  nan  Melbourne City Council              nan    nan  ...
# 436       nan  nan                     nan              nan    nan  ...
# 437       nan  nan                     nan              nan    nan  ...
# 438       nan  nan                     nan              nan    nan  ...
# 439       nan  nan                     nan              nan    nan  ...
#
#     name:mk short_name political_division heritage heritage:operator  \
# 0       nan        nan                nan      nan               nan
# 1       nan        nan                nan      nan               nan
# 2       nan        nan                nan      nan               nan
# 3       nan        nan                nan      nan               nan
# 4       nan        nan                nan      nan               nan
# ..      ...        ...                ...      ...               ...
# 435     nan        nan                nan      nan               nan
# 436     nan        nan                nan        1               whc
# 437     nan        nan                nan      nan               nan
# 438     nan        nan                nan      nan               nan
# 439     nan        nan                nan      nan               nan
#
#                        heritage:website area  \
# 0                                   nan  nan
# 1                                   nan  nan
# 2                                   nan  nan
# 3                                   nan  nan
# 4                                   nan  nan
# ..                                  ...  ...
# 435                                 nan  nan
# 436  http://whc.unesco.org/en/list/1131  nan
# 437                                 nan  yes
# 438                                 nan  nan
# 439                                 nan  nan
#
#                                               geometry    distance  \
# 0                       POINT (321223.384 5813738.129)  218.599034
# 1                       POINT (321343.567 5814046.274)  188.373535
# 2                       POINT (321413.415 5813831.827)   37.211904
# 3                       POINT (321256.686 5813883.765)  144.563983
# 4                       POINT (321600.961 5813827.093)  204.586235
# ..                                                 ...         ...
# 435  MULTIPOLYGON (((321219.805 5813634.926, 321210...    3.048837
# 436  MULTIPOLYGON (((321415.382 5813963.959, 321416...    3.048837
# 437  POLYGON ((321571.451 5813919.342, 321569.416 5...   96.331620
# 438  POLYGON ((321163.337 5813990.989, 321180.796 5...  209.794588
# 439  POLYGON ((321495.098 5813936.836, 321494.024 5...   71.028757
#
#                                              full_name
# 0    access amenity toilets operator Melbourne City...
# 1    IMAX Melbourne amenity cinema operator Melbour...
# 2                                     amenity fountain
# 3                      highway crossing crossing zebra
# 4    highway crossing crossing traffic_signals tact...
# ..                                                 ...
# 435  Carlton Gardens operator Melbourne City Counci...
# 436  Royal Exhibition Building and Carlton Gardens ...
# 437          highway pedestrian type multipolygon area
# 438                         building type multipolygon
# 439               highway pedestrian type multipolygon
#
# [440 rows x 142 columns]

# %%
def compute_similarities_topk(query, sentences, sentence_embeddings, model=sbert_model, k=10, verbose=False):
    query_vec = embed_texts(query)
    scores = util.dot_score(query_vec, sentence_embeddings)[0].cpu().tolist()
    doc_score_pairs = list(zip(sentences, scores))
    doc_score_pairs = sorted(doc_score_pairs, key=lambda x: x[1], reverse=True)
    if verbose:
        logger.info(f"Query: {query}")
        for doc, score in doc_score_pairs:
            logger.info(f'\t{score}\t{doc}')
    return np.argsort(scores)[-k:]

# %%
feature_descriptions = list(features['full_name'])
feature_embeddings = embed_texts(feature_descriptions, model=msmarco_model)
case_description = nominatim_output[str(case_id)]['title'] + ' ' + nominatim_output[str(case_id)]['summary']
k_similar = compute_similarities_topk(case_description, feature_descriptions, feature_embeddings, model=msmarco_model, verbose=True)
k_similar
# Out:
# 2025-01-25 20:30:03.818 | INFO     | __main__:compute_similarities_topk:7 - Query: 13. Royal Exhibition Building The Royal Exhibition Building is the only surviving Great Hall that once housed a 19th-century international exhibition and is still used for exhibitions.
# 2025-01-25 20:30:03.819 | INFO     | __main__:compute_similarities_topk:9 - 	44.04185104370117	Royal Exhibition Building and Carlton Gardens tourism attraction type multipolygon heritage 1
# 2025-01-25 20:30:03.819 | INFO     | __main__:compute_similarities_topk:9 - 	40.16722869873047	Royal Exhibition Building source Vicmap Address historic building tourism attraction building height 20 layer 1
# 2025-01-25 20:30:03.820 | INFO     | __main__:compute_similarities_topk:9 - 	39.156288146972656	Royal Exhibition Building Opening historic memorial memorial plaque
# 2025-01-25 20:30:03.820 | INFO     | __main__:compute_similarities_topk:9 - 	36.94139099121094	Melbourne Museum fee operator Museum Victoria wheelchair phone +61 3 8341 7777 source Vicmap Address tourism museum building layer 1 atm internet_access wlan opening_hours Mo-Su 10:00-17:00,09:00-17:00
# 2025-01-25 20:30:03.820 | INFO     | __main__:compute_similarities_topk:9 - 	36.464195251464844	access historic monument inscription To Victoria from one of her earliest colonists in pleasant remeberance 1840 - 88
# 2025-01-25 20:30:03.821 | INFO     | __main__:compute_similarities_topk:9 - 	35.37290954589844	Exhibition Building/Rathdowne Street highway bus_stop tactile_paving network PTV - Metropolitan Buses public_transport platform ref ID.345 bus route_ref 250;251;402
# 2025-01-25 20:30:03.821 | INFO     | __main__:compute_similarities_topk:9 - 	35.2883415222168	amenity charging_station operator Museums Victoria capacity 2 location underground
# 2025-01-25 20:30:03.821 | INFO     | __main__:compute_similarities_topk:9 - 	34.927093505859375	Exhibition Building/Rathdowne Street highway bus_stop tactile_paving network PTV - Metropolitan Buses public_transport platform ref ID.655 bus route_ref 250;251;402
# 2025-01-25 20:30:03.822 | INFO     | __main__:compute_similarities_topk:9 - 	34.915157318115234	IMAX Melbourne amenity cinema operator Melbourne museum check_date 2022-10-02 phone +61 3 9663 5454 screen 1
# 2025-01-25 20:30:03.822 | INFO     | __main__:compute_similarities_topk:9 - 	33.64553451538086	artwork_type sculpture tourism artwork
# 2025-01-25 20:30:03.822 | INFO     | __main__:compute_similarities_topk:9 - 	32.76984786987305	natural tree_row
# 2025-01-25 20:30:03.822 | INFO     | __main__:compute_similarities_topk:9 - 	32.76984786987305	natural tree_row
# 2025-01-25 20:30:03.823 | INFO     | __main__:compute_similarities_topk:9 - 	32.76984786987305	natural tree_row
# 2025-01-25 20:30:03.823 | INFO     | __main__:compute_similarities_topk:9 - 	32.76984786987305	natural tree_row
# 2025-01-25 20:30:03.823 | INFO     | __main__:compute_similarities_topk:9 - 	32.76984786987305	natural tree_row
# 2025-01-25 20:30:03.824 | INFO     | __main__:compute_similarities_topk:9 - 	32.053016662597656	natural wood leaf_type broadleaved
# 2025-01-25 20:30:03.824 | INFO     | __main__:compute_similarities_topk:9 - 	32.053016662597656	natural wood leaf_type broadleaved
# 2025-01-25 20:30:03.824 | INFO     | __main__:compute_similarities_topk:9 - 	31.955171585083008	historic monument
# 2025-01-25 20:30:03.824 | INFO     | __main__:compute_similarities_topk:9 - 	31.633041381835938	access customers amenity charging_station fee operator Melbourne Museum capacity 2
# 2025-01-25 20:30:03.825 | INFO     | __main__:compute_similarities_topk:9 - 	31.5223388671875	building office
# 2025-01-25 20:30:03.825 | INFO     | __main__:compute_similarities_topk:9 - 	31.441062927246094	Museum Cafe amenity cafe wheelchair
# 2025-01-25 20:30:03.825 | INFO     | __main__:compute_similarities_topk:9 - 	31.18695640563965	Carlton Gardens operator Melbourne City Council leisure park type multipolygon
# 2025-01-25 20:30:03.826 | INFO     | __main__:compute_similarities_topk:9 - 	31.17928695678711	South Carlton Gardens natural park
# 2025-01-25 20:30:03.826 | INFO     | __main__:compute_similarities_topk:9 - 	30.938030242919922	Rathdowne Street highway tertiary source nearmap network AU:VIC:S ref 46 lit surface asphalt oneway lanes 2 maxspeed 40
# 2025-01-25 20:30:03.826 | INFO     | __main__:compute_similarities_topk:9 - 	30.938030242919922	Rathdowne Street highway tertiary source nearmap network AU:VIC:S ref 46 lit surface asphalt oneway lanes 2 maxspeed 40
# 2025-01-25 20:30:03.827 | INFO     | __main__:compute_similarities_topk:9 - 	30.938030242919922	Rathdowne Street highway tertiary source nearmap network AU:VIC:S ref 46 lit surface asphalt oneway lanes 2 maxspeed 40
# 2025-01-25 20:30:03.827 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.827 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.828 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.828 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.829 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.829 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.829 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.830 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.830 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.830 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.830 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.831 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.831 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.832 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.832 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.832 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.833 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.833 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.833 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.834 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.834 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.835 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.835 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.836 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.836 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.836 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.837 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.837 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.838 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.838 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.838 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.839 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.839 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.840 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.840 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.841 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.841 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.841 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.842 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.842 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.842 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.843 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.843 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.843 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.844 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.844 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.844 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.845 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.845 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.845 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.846 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.846 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.847 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.847 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.848 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.848 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.848 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.849 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.849 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.849 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.850 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.850 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.851 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.851 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.851 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.851 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.852 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.852 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.853 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.853 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.854 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.854 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.854 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.855 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.855 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.855 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.856 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.856 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.856 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.857 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.858 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.858 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.859 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.859 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.860 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.860 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.861 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.862 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.864 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.865 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.865 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.866 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.866 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.867 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.867 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.868 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.868 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.869 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.870 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.870 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.870 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.871 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.871 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.872 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.872 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.872 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.873 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.873 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.873 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.874 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.874 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.874 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.875 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.875 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.876 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.876 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.877 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.877 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.877 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.878 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.878 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.878 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.879 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.879 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.880 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.880 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.880 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.881 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.881 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.881 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.882 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.882 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.883 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.884 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.885 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.885 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.885 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.886 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.886 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.886 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.887 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.887 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.888 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.888 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.888 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.889 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.889 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.889 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.890 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.890 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.891 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.891 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.891 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.892 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.892 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.893 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.894 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.894 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.895 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.895 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.896 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.897 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.897 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.898 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.898 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.899 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.899 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.900 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.900 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.901 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.901 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.902 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.902 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.902 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.903 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.903 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.904 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.904 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.904 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.904 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.905 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.905 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.906 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.906 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.907 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.907 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.907 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.908 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.908 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.908 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.909 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.909 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.909 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.910 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.910 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.910 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.911 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.911 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.911 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.912 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.912 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.913 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.913 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.913 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.914 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.914 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.914 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.914 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.915 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.915 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.915 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.916 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.916 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.917 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.917 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.917 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.918 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.918 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.918 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.918 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.919 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.919 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.919 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.920 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.920 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.921 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.921 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.921 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.921 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.922 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.922 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.922 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.923 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.923 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.924 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.924 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.924 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.925 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.926 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.926 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.927 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.927 | INFO     | __main__:compute_similarities_topk:9 - 	30.92023468017578	natural tree
# 2025-01-25 20:30:03.928 | INFO     | __main__:compute_similarities_topk:9 - 	30.833450317382812	amenity bench material stone
# 2025-01-25 20:30:03.928 | INFO     | __main__:compute_similarities_topk:9 - 	30.833450317382812	amenity bench material stone
# 2025-01-25 20:30:03.929 | INFO     | __main__:compute_similarities_topk:9 - 	30.833450317382812	amenity bench material stone
# 2025-01-25 20:30:03.930 | INFO     | __main__:compute_similarities_topk:9 - 	30.833450317382812	amenity bench material stone
# 2025-01-25 20:30:03.931 | INFO     | __main__:compute_similarities_topk:9 - 	30.833450317382812	amenity bench material stone
# 2025-01-25 20:30:03.931 | INFO     | __main__:compute_similarities_topk:9 - 	30.74757957458496	natural tree_row leaf_type broadleaved
# 2025-01-25 20:30:03.932 | INFO     | __main__:compute_similarities_topk:9 - 	30.013858795166016	source Vicmap Address building
# 2025-01-25 20:30:03.932 | INFO     | __main__:compute_similarities_topk:9 - 	30.013858795166016	source Vicmap Address building
# 2025-01-25 20:30:03.933 | INFO     | __main__:compute_similarities_topk:9 - 	29.334415435791016	Melbourne District Melbourne boundary political type boundary political_division au_vic_la
# 2025-01-25 20:30:03.934 | INFO     | __main__:compute_similarities_topk:9 - 	29.300464630126953	amenity fountain
# 2025-01-25 20:30:03.934 | INFO     | __main__:compute_similarities_topk:9 - 	29.300464630126953	amenity fountain
# 2025-01-25 20:30:03.934 | INFO     | __main__:compute_similarities_topk:9 - 	28.909582138061523	Stop 11: Melbourne Museum operator Yarra Trams wheelchair tactile_paving railway platform network PTV - Metropolitan Trams public_transport platform ref 11 tram bench bin lit route_ref 86;96 shelter passenger_information_display
# 2025-01-25 20:30:03.935 | INFO     | __main__:compute_similarities_topk:9 - 	28.820085525512695	amenity bicycle_parking
# 2025-01-25 20:30:03.935 | INFO     | __main__:compute_similarities_topk:9 - 	28.53158950805664	amenity waste_basket check_date 2022-10-04
# 2025-01-25 20:30:03.936 | INFO     | __main__:compute_similarities_topk:9 - 	28.53158950805664	amenity waste_basket check_date 2022-10-04
# 2025-01-25 20:30:03.936 | INFO     | __main__:compute_similarities_topk:9 - 	28.1014347076416	amenity drinking_water
# 2025-01-25 20:30:03.937 | INFO     | __main__:compute_similarities_topk:9 - 	28.067947387695312	amenity parking_entrance fee parking underground
# 2025-01-25 20:30:03.937 | INFO     | __main__:compute_similarities_topk:9 - 	28.067947387695312	amenity parking_entrance fee parking underground
# 2025-01-25 20:30:03.937 | INFO     | __main__:compute_similarities_topk:9 - 	28.067947387695312	amenity parking_entrance fee parking underground
# 2025-01-25 20:30:03.938 | INFO     | __main__:compute_similarities_topk:9 - 	28.06528091430664	amenity bench backrest
# 2025-01-25 20:30:03.938 | INFO     | __main__:compute_similarities_topk:9 - 	28.06528091430664	amenity bench backrest
# 2025-01-25 20:30:03.938 | INFO     | __main__:compute_similarities_topk:9 - 	28.06528091430664	amenity bench backrest
# 2025-01-25 20:30:03.939 | INFO     | __main__:compute_similarities_topk:9 - 	28.06528091430664	amenity bench backrest
# 2025-01-25 20:30:03.939 | INFO     | __main__:compute_similarities_topk:9 - 	28.06528091430664	amenity bench backrest
# 2025-01-25 20:30:03.940 | INFO     | __main__:compute_similarities_topk:9 - 	28.06528091430664	amenity bench backrest
# 2025-01-25 20:30:03.940 | INFO     | __main__:compute_similarities_topk:9 - 	28.065279006958008	amenity bench backrest
# 2025-01-25 20:30:03.940 | INFO     | __main__:compute_similarities_topk:9 - 	28.065279006958008	amenity bench backrest
# 2025-01-25 20:30:03.941 | INFO     | __main__:compute_similarities_topk:9 - 	28.065279006958008	amenity bench backrest
# 2025-01-25 20:30:03.941 | INFO     | __main__:compute_similarities_topk:9 - 	27.69495391845703	City of Melbourne Melbourne phone +61 3 9658 9658 place municipality admin_level 6 boundary administrative population 149615 type boundary
# 2025-01-25 20:30:03.941 | INFO     | __main__:compute_similarities_topk:9 - 	27.68996810913086	access amenity toilets operator Melbourne City Council unisex wheelchair
# 2025-01-25 20:30:03.942 | INFO     | __main__:compute_similarities_topk:9 - 	27.616586685180664	natural water
# 2025-01-25 20:30:03.942 | INFO     | __main__:compute_similarities_topk:9 - 	27.616586685180664	natural water
# 2025-01-25 20:30:03.942 | INFO     | __main__:compute_similarities_topk:9 - 	27.52220344543457	building roof layer 1
# 2025-01-25 20:30:03.943 | INFO     | __main__:compute_similarities_topk:9 - 	27.52220344543457	building roof layer 1
# 2025-01-25 20:30:03.943 | INFO     | __main__:compute_similarities_topk:9 - 	27.52220344543457	building roof layer 1
# 2025-01-25 20:30:03.943 | INFO     | __main__:compute_similarities_topk:9 - 	27.431129455566406	leisure park
# 2025-01-25 20:30:03.944 | INFO     | __main__:compute_similarities_topk:9 - 	27.381160736083984	building
# 2025-01-25 20:30:03.944 | INFO     | __main__:compute_similarities_topk:9 - 	27.381160736083984	building
# 2025-01-25 20:30:03.944 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.945 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.945 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.945 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.946 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.946 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.946 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.947 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.947 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.947 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.948 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.948 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.948 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.949 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.949 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.949 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.950 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.950 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.950 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.951 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.951 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.951 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.952 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.952 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.952 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.953 | INFO     | __main__:compute_similarities_topk:9 - 	26.968120574951172	leisure garden
# 2025-01-25 20:30:03.953 | INFO     | __main__:compute_similarities_topk:9 - 	26.76032257080078	highway unclassified noname surface asphalt service parking_aisle
# 2025-01-25 20:30:03.954 | INFO     | __main__:compute_similarities_topk:9 - 	26.21531105041504	amenity bicycle_parking check_date 2023-06-29
# 2025-01-25 20:30:03.954 | INFO     | __main__:compute_similarities_topk:9 - 	26.037982940673828	Museum Playground access customers leisure playground
# 2025-01-25 20:30:03.954 | INFO     | __main__:compute_similarities_topk:9 - 	26.015113830566406	highway unclassified bicycle designated noname surface asphalt oneway service parking_aisle
# 2025-01-25 20:30:03.954 | INFO     | __main__:compute_similarities_topk:9 - 	26.00775909423828	City of Yarra place municipality admin_level 6 boundary administrative population 98521 type boundary
# 2025-01-25 20:30:03.955 | INFO     | __main__:compute_similarities_topk:9 - 	25.917381286621094	amenity drinking_water check_date 2023-06-29 fountain bubbler
# 2025-01-25 20:30:03.955 | INFO     | __main__:compute_similarities_topk:9 - 	25.8033447265625	amenity drinking_water check_date 2022-10-04
# 2025-01-25 20:30:03.956 | INFO     | __main__:compute_similarities_topk:9 - 	25.745967864990234	Princes Street highway residential source Yahoo surface asphalt
# 2025-01-25 20:30:03.956 | INFO     | __main__:compute_similarities_topk:9 - 	25.710418701171875	building type multipolygon
# 2025-01-25 20:30:03.956 | INFO     | __main__:compute_similarities_topk:9 - 	25.593326568603516	amenity bicycle_parking check_date 2023-04-24
# 2025-01-25 20:30:03.957 | INFO     | __main__:compute_similarities_topk:9 - 	25.582136154174805	Princes Street highway residential source Yahoo lit surface asphalt
# 2025-01-25 20:30:03.957 | INFO     | __main__:compute_similarities_topk:9 - 	25.249755859375	source Vicmap Address landuse residential
# 2025-01-25 20:30:03.957 | INFO     | __main__:compute_similarities_topk:9 - 	25.24359893798828	Forest Gallery covered source nearmap leisure garden
# 2025-01-25 20:30:03.958 | INFO     | __main__:compute_similarities_topk:9 - 	25.004913330078125	source Vicmap Address building apartments
# 2025-01-25 20:30:03.958 | INFO     | __main__:compute_similarities_topk:9 - 	24.986482620239258	highway unclassified bicycle designated lit noname surface asphalt service parking_aisle
# 2025-01-25 20:30:03.958 | INFO     | __main__:compute_similarities_topk:9 - 	24.982078552246094	Richmond District Richmond boundary political type boundary political_division au_vic_la
# 2025-01-25 20:30:03.959 | INFO     | __main__:compute_similarities_topk:9 - 	24.869037628173828	Fitzroy place suburb admin_level 9 boundary administrative population 10445 postal_code 3065 type boundary
# 2025-01-25 20:30:03.959 | INFO     | __main__:compute_similarities_topk:9 - 	24.468185424804688	Carlton place suburb admin_level 9 boundary administrative population 19001 postal_code 3053 type boundary
# 2025-01-25 20:30:03.960 | INFO     | __main__:compute_similarities_topk:9 - 	24.38406753540039	Nicholson Street highway primary lit surface asphalt oneway lanes 2 maxspeed 60
# 2025-01-25 20:30:03.960 | INFO     | __main__:compute_similarities_topk:9 - 	24.38406753540039	Nicholson Street highway primary lit surface asphalt oneway lanes 2 maxspeed 60
# 2025-01-25 20:30:03.961 | INFO     | __main__:compute_similarities_topk:9 - 	24.239730834960938	amenity bicycle_parking check_date 2023-04-24 covered bicycle_parking stands
# 2025-01-25 20:30:03.961 | INFO     | __main__:compute_similarities_topk:9 - 	23.834636688232422	leisure garden layer 1
# 2025-01-25 20:30:03.962 | INFO     | __main__:compute_similarities_topk:9 - 	23.714813232421875	Commonwealth Bank amenity atm operator Commonwealth Bank brand Commonwealth Bank
# 2025-01-25 20:30:03.962 | INFO     | __main__:compute_similarities_topk:9 - 	23.67729949951172	Nicholson Street highway primary lit surface asphalt oneway lanes 2 maxspeed 40
# 2025-01-25 20:30:03.963 | INFO     | __main__:compute_similarities_topk:9 - 	23.67729949951172	Nicholson Street highway primary lit surface asphalt oneway lanes 2 maxspeed 40
# 2025-01-25 20:30:03.963 | INFO     | __main__:compute_similarities_topk:9 - 	23.658435821533203	amenity bench backrest source nearmap
# 2025-01-25 20:30:03.964 | INFO     | __main__:compute_similarities_topk:9 - 	23.658435821533203	amenity bench backrest source nearmap
# 2025-01-25 20:30:03.964 | INFO     | __main__:compute_similarities_topk:9 - 	23.658432006835938	amenity bench backrest source nearmap
# 2025-01-25 20:30:03.965 | INFO     | __main__:compute_similarities_topk:9 - 	23.658432006835938	amenity bench backrest source nearmap
# 2025-01-25 20:30:03.966 | INFO     | __main__:compute_similarities_topk:9 - 	23.19542694091797	highway tertiary_link surface asphalt
# 2025-01-25 20:30:03.966 | INFO     | __main__:compute_similarities_topk:9 - 	23.19542694091797	highway tertiary_link surface asphalt
# 2025-01-25 20:30:03.967 | INFO     | __main__:compute_similarities_topk:9 - 	23.14141273498535	Telstra amenity telephone operator Telstra
# 2025-01-25 20:30:03.967 | INFO     | __main__:compute_similarities_topk:9 - 	22.126949310302734	highway service service driveway
# 2025-01-25 20:30:03.968 | INFO     | __main__:compute_similarities_topk:9 - 	22.01078224182129	highway pedestrian noname surface asphalt
# 2025-01-25 20:30:03.968 | INFO     | __main__:compute_similarities_topk:9 - 	22.01078224182129	highway pedestrian noname surface asphalt
# 2025-01-25 20:30:03.969 | INFO     | __main__:compute_similarities_topk:9 - 	22.01078224182129	highway pedestrian noname surface asphalt
# 2025-01-25 20:30:03.969 | INFO     | __main__:compute_similarities_topk:9 - 	21.906124114990234	highway cycleway bicycle designated foot designated source nearmap surface asphalt
# 2025-01-25 20:30:03.970 | INFO     | __main__:compute_similarities_topk:9 - 	21.757476806640625	highway pedestrian noname
# 2025-01-25 20:30:03.970 | INFO     | __main__:compute_similarities_topk:9 - 	21.757476806640625	highway pedestrian noname
# 2025-01-25 20:30:03.971 | INFO     | __main__:compute_similarities_topk:9 - 	21.512310028076172	natural water layer 2
# 2025-01-25 20:30:03.971 | INFO     | __main__:compute_similarities_topk:9 - 	21.101741790771484	Queensberry Street highway tertiary source nearmap lit surface asphalt oneway lanes 2 maxspeed 50
# 2025-01-25 20:30:03.972 | INFO     | __main__:compute_similarities_topk:9 - 	20.849063873291016	highway service surface asphalt
# 2025-01-25 20:30:03.972 | INFO     | __main__:compute_similarities_topk:9 - 	20.634830474853516	building apartments
# 2025-01-25 20:30:03.973 | INFO     | __main__:compute_similarities_topk:9 - 	20.617916107177734	highway footway crossing marked bicycle designated surface asphalt footway crossing
# 2025-01-25 20:30:03.973 | INFO     | __main__:compute_similarities_topk:9 - 	20.452051162719727	source nearmap natural water layer 1
# 2025-01-25 20:30:03.973 | INFO     | __main__:compute_similarities_topk:9 - 	20.400806427001953	highway footway surface asphalt
# 2025-01-25 20:30:03.974 | INFO     | __main__:compute_similarities_topk:9 - 	20.364856719970703	Queensberry Street highway tertiary source nearmap;Bing;nearmap lit surface asphalt oneway lanes 2 maxspeed 50
# 2025-01-25 20:30:03.974 | INFO     | __main__:compute_similarities_topk:9 - 	20.3331298828125	highway pedestrian surface asphalt service laneway
# 2025-01-25 20:30:03.975 | INFO     | __main__:compute_similarities_topk:9 - 	20.310163497924805	highway crossing crossing unmarked kerb flush
# 2025-01-25 20:30:03.975 | INFO     | __main__:compute_similarities_topk:9 - 	20.268640518188477	highway service
# 2025-01-25 20:30:03.975 | INFO     | __main__:compute_similarities_topk:9 - 	20.246990203857422	highway footway crossing marked surface concrete footway crossing
# 2025-01-25 20:30:03.976 | INFO     | __main__:compute_similarities_topk:9 - 	20.071638107299805	landuse grass
# 2025-01-25 20:30:03.976 | INFO     | __main__:compute_similarities_topk:9 - 	20.071638107299805	landuse grass
# 2025-01-25 20:30:03.977 | INFO     | __main__:compute_similarities_topk:9 - 	20.071638107299805	landuse grass
# 2025-01-25 20:30:03.977 | INFO     | __main__:compute_similarities_topk:9 - 	20.071638107299805	landuse grass
# 2025-01-25 20:30:03.978 | INFO     | __main__:compute_similarities_topk:9 - 	20.071638107299805	landuse grass
# 2025-01-25 20:30:03.978 | INFO     | __main__:compute_similarities_topk:9 - 	20.071638107299805	landuse grass
# 2025-01-25 20:30:03.979 | INFO     | __main__:compute_similarities_topk:9 - 	20.071638107299805	landuse grass
# 2025-01-25 20:30:03.979 | INFO     | __main__:compute_similarities_topk:9 - 	19.879281997680664	highway crossing crossing traffic_signals tactile_paving button_operated
# 2025-01-25 20:30:03.979 | INFO     | __main__:compute_similarities_topk:9 - 	19.875017166137695	highway service source nearmap surface asphalt oneway
# 2025-01-25 20:30:03.979 | INFO     | __main__:compute_similarities_topk:9 - 	19.8541202545166	highway footway bicycle designated source nearmap surface asphalt footway sidewalk
# 2025-01-25 20:30:03.980 | INFO     | __main__:compute_similarities_topk:9 - 	19.672927856445312	highway crossing crossing traffic_signals tactile_paving button_operated foot designated
# 2025-01-25 20:30:03.980 | INFO     | __main__:compute_similarities_topk:9 - 	19.6680965423584	highway footway surface asphalt footway crossing
# 2025-01-25 20:30:03.981 | INFO     | __main__:compute_similarities_topk:9 - 	19.6680965423584	highway footway surface asphalt footway crossing
# 2025-01-25 20:30:03.981 | INFO     | __main__:compute_similarities_topk:9 - 	19.5889892578125	layer 1 landuse grass
# 2025-01-25 20:30:03.981 | INFO     | __main__:compute_similarities_topk:9 - 	19.5889892578125	layer 1 landuse grass
# 2025-01-25 20:30:03.982 | INFO     | __main__:compute_similarities_topk:9 - 	19.5889892578125	layer 1 landuse grass
# 2025-01-25 20:30:03.982 | INFO     | __main__:compute_similarities_topk:9 - 	19.5889892578125	layer 1 landuse grass
# 2025-01-25 20:30:03.982 | INFO     | __main__:compute_similarities_topk:9 - 	19.564184188842773	highway footway source nearmap surface asphalt footway sidewalk
# 2025-01-25 20:30:03.982 | INFO     | __main__:compute_similarities_topk:9 - 	19.556673049926758	highway traffic_signals
# 2025-01-25 20:30:03.983 | INFO     | __main__:compute_similarities_topk:9 - 	19.556673049926758	highway traffic_signals
# 2025-01-25 20:30:03.983 | INFO     | __main__:compute_similarities_topk:9 - 	19.556673049926758	highway traffic_signals
# 2025-01-25 20:30:03.984 | INFO     | __main__:compute_similarities_topk:9 - 	19.183940887451172	railway tram service crossover electrified contact_line frequency 0 gauge 1435 voltage 600
# 2025-01-25 20:30:03.984 | INFO     | __main__:compute_similarities_topk:9 - 	19.03142547607422	Nicholson Street source nearmap railway tram oneway electrified contact_line frequency 0 gauge 1435 voltage 600
# 2025-01-25 20:30:03.984 | INFO     | __main__:compute_similarities_topk:9 - 	19.03142547607422	Nicholson Street source nearmap railway tram oneway electrified contact_line frequency 0 gauge 1435 voltage 600
# 2025-01-25 20:30:03.985 | INFO     | __main__:compute_similarities_topk:9 - 	19.02886199951172	highway pedestrian lit
# 2025-01-25 20:30:03.985 | INFO     | __main__:compute_similarities_topk:9 - 	18.564170837402344	highway pedestrian source nearmap noname surface asphalt
# 2025-01-25 20:30:03.985 | INFO     | __main__:compute_similarities_topk:9 - 	18.564170837402344	highway pedestrian source nearmap noname surface asphalt
# 2025-01-25 20:30:03.985 | INFO     | __main__:compute_similarities_topk:9 - 	18.564170837402344	highway pedestrian source nearmap noname surface asphalt
# 2025-01-25 20:30:03.986 | INFO     | __main__:compute_similarities_topk:9 - 	18.564170837402344	highway pedestrian source nearmap noname surface asphalt
# 2025-01-25 20:30:03.986 | INFO     | __main__:compute_similarities_topk:9 - 	18.564170837402344	highway pedestrian source nearmap noname surface asphalt
# 2025-01-25 20:30:03.986 | INFO     | __main__:compute_similarities_topk:9 - 	18.564170837402344	highway pedestrian source nearmap noname surface asphalt
# 2025-01-25 20:30:03.987 | INFO     | __main__:compute_similarities_topk:9 - 	18.564170837402344	highway pedestrian source nearmap noname surface asphalt
# 2025-01-25 20:30:03.987 | INFO     | __main__:compute_similarities_topk:9 - 	18.564170837402344	highway pedestrian source nearmap noname surface asphalt
# 2025-01-25 20:30:03.987 | INFO     | __main__:compute_similarities_topk:9 - 	18.564170837402344	highway pedestrian source nearmap noname surface asphalt
# 2025-01-25 20:30:03.988 | INFO     | __main__:compute_similarities_topk:9 - 	18.452163696289062	highway pedestrian source nearmap lit noname surface asphalt
# 2025-01-25 20:30:03.988 | INFO     | __main__:compute_similarities_topk:9 - 	18.452163696289062	highway pedestrian source nearmap lit noname surface asphalt
# 2025-01-25 20:30:03.988 | INFO     | __main__:compute_similarities_topk:9 - 	18.452163696289062	highway pedestrian source nearmap lit noname surface asphalt
# 2025-01-25 20:30:03.989 | INFO     | __main__:compute_similarities_topk:9 - 	18.452163696289062	highway pedestrian source nearmap lit noname surface asphalt
# 2025-01-25 20:30:03.989 | INFO     | __main__:compute_similarities_topk:9 - 	18.452163696289062	highway pedestrian source nearmap lit noname surface asphalt
# 2025-01-25 20:30:03.990 | INFO     | __main__:compute_similarities_topk:9 - 	18.273330688476562	highway traffic_signals traffic_signals pedestrian_crossing
# 2025-01-25 20:30:03.990 | INFO     | __main__:compute_similarities_topk:9 - 	17.96446418762207	highway service source nearmap oneway
# 2025-01-25 20:30:03.990 | INFO     | __main__:compute_similarities_topk:9 - 	17.96446418762207	highway service source nearmap oneway
# 2025-01-25 20:30:03.991 | INFO     | __main__:compute_similarities_topk:9 - 	17.960041046142578	highway pedestrian type multipolygon area
# 2025-01-25 20:30:03.991 | INFO     | __main__:compute_similarities_topk:9 - 	17.83045196533203	highway pedestrian
# 2025-01-25 20:30:03.991 | INFO     | __main__:compute_similarities_topk:9 - 	17.83045196533203	highway pedestrian
# 2025-01-25 20:30:03.992 | INFO     | __main__:compute_similarities_topk:9 - 	17.83045196533203	highway pedestrian
# 2025-01-25 20:30:03.992 | INFO     | __main__:compute_similarities_topk:9 - 	17.83045196533203	highway pedestrian
# 2025-01-25 20:30:03.993 | INFO     | __main__:compute_similarities_topk:9 - 	17.82858657836914	highway pedestrian source nearmap noname
# 2025-01-25 20:30:03.993 | INFO     | __main__:compute_similarities_topk:9 - 	17.82858657836914	highway pedestrian source nearmap noname
# 2025-01-25 20:30:03.994 | INFO     | __main__:compute_similarities_topk:9 - 	17.81389808654785	highway footway source nearmap surface asphalt
# 2025-01-25 20:30:03.994 | INFO     | __main__:compute_similarities_topk:9 - 	17.35993003845215	highway pedestrian type multipolygon
# 2025-01-25 20:30:03.995 | INFO     | __main__:compute_similarities_topk:9 - 	17.193988800048828	highway crossing crossing zebra
# 2025-01-25 20:30:03.995 | INFO     | __main__:compute_similarities_topk:9 - 	16.92513656616211	highway pedestrian source nearmap,bing
# 2025-01-25 20:30:03.996 | INFO     | __main__:compute_similarities_topk:9 - 	14.394341468811035	highway service bicycle source nearmap
# 2025-01-25 20:30:03.996 | INFO     | __main__:compute_similarities_topk:9 - 	14.092538833618164	highway pedestrian source nearmap
# 2025-01-25 20:30:03.997 | INFO     | __main__:compute_similarities_topk:9 - 	14.092538833618164	highway pedestrian source nearmap
# 2025-01-25 20:30:03.997 | INFO     | __main__:compute_similarities_topk:9 - 	14.092538833618164	highway pedestrian source nearmap
# array([ 46,   1,  26,  27,  44,  49, 298,  43, 297, 436])

# %%
features.iloc[k_similar]
# Out:
#     element_type       osmid   highway traffic_signals:direction access  \
# 46          node  9106562132       nan                       nan    nan
# 1           node   368393200       nan                       nan    nan
# 26          node  4061250667  bus_stop                       nan    nan
# 27          node  4332324003       nan                       nan    nan
# 44          node  7248901076  bus_stop                       nan    nan
# 49          node  9307551791       nan                       nan    yes
# 298          way     4817074       nan                       nan    nan
# 43          node  6810298878       nan                       nan    nan
# 297          way     4817059       nan                       nan    nan
# 436     relation     6623509       nan                       nan    nan
#
#               amenity  fee          operator toilets:disposal unisex  ...  \
# 46                nan  nan               nan              nan    nan  ...
# 1              cinema  nan  Melbourne museum              nan    nan  ...
# 26                nan  nan               nan              nan    nan  ...
# 27   charging_station  nan  Museums Victoria              nan    nan  ...
# 44                nan  nan               nan              nan    nan  ...
# 49                nan  nan               nan              nan    nan  ...
# 298               nan  yes   Museum Victoria              nan    nan  ...
# 43                nan  nan               nan              nan    nan  ...
# 297               nan  nan               nan              nan    nan  ...
# 436               nan  nan               nan              nan    nan  ...
#
#     name:mk short_name political_division heritage heritage:operator  \
# 46      nan        nan                nan      nan               nan
# 1       nan        nan                nan      nan               nan
# 26      nan        nan                nan      nan               nan
# 27      nan        nan                nan      nan               nan
# 44      nan        nan                nan      nan               nan
# 49      nan        nan                nan      nan               nan
# 298     nan        nan                nan      nan               nan
# 43      nan        nan                nan      nan               nan
# 297     nan        nan                nan      nan               nan
# 436     nan        nan                nan        1               whc
#
#                        heritage:website area  \
# 46                                  nan  nan
# 1                                   nan  nan
# 26                                  nan  nan
# 27                                  nan  nan
# 44                                  nan  nan
# 49                                  nan  nan
# 298                                 nan  nan
# 43                                  nan  nan
# 297                                 nan  nan
# 436  http://whc.unesco.org/en/list/1131  nan
#
#                                               geometry    distance  \
# 46                      POINT (321559.646 5813927.545)  170.659614
# 1                       POINT (321343.567 5814046.274)  188.373535
# 26                      POINT (321243.477 5813954.530)  179.719018
# 27                      POINT (321463.713 5813962.011)  114.580080
# 44                      POINT (321211.629 5813902.092)  191.907516
# 49                      POINT (321592.650 5813874.406)  192.577146
# 298  POLYGON ((321505.691 5814023.082, 321459.066 5...  159.043248
# 43                      POINT (321503.096 5813888.150)  105.093724
# 297  POLYGON ((321415.382 5813963.959, 321416.338 5...   11.700249
# 436  MULTIPOLYGON (((321415.382 5813963.959, 321416...    3.048837
#
#                                              full_name
# 46              artwork_type sculpture tourism artwork
# 1    IMAX Melbourne amenity cinema operator Melbour...
# 26   Exhibition Building/Rathdowne Street highway b...
# 27   amenity charging_station operator Museums Vict...
# 44   Exhibition Building/Rathdowne Street highway b...
# 49   access historic monument inscription To Victor...
# 298  Melbourne Museum fee operator Museum Victoria ...
# 43   Royal Exhibition Building Opening historic mem...
# 297  Royal Exhibition Building source Vicmap Addres...
# 436  Royal Exhibition Building and Carlton Gardens ...
#
# [10 rows x 142 columns]

# %%
def get_top_k(case_id, k=10, model = msmarco_model, verbose=False):
    test_case = nominatim_output[str(case_id)]
    
    features = gpd.read_file('dataset/osm-poi-{0}-dist-{1}-features.geojson'.format(case_id, dist_threshold))
    cols = list(features.columns)
    if verbose:
        print(features.head())
        logger.info(cols)
    features['full_name'] = features.apply(lambda row: generate_textual_descriptions(row, cols), axis=1)
    
    feature_descriptions = list(features['full_name'])
    feature_embeddings = embed_texts(feature_descriptions, model=model)
    
    case_description = test_case['title'] + ' ' + test_case['summary']
    k_similar = compute_similarities_topk(case_description, feature_descriptions, feature_embeddings, model=model, verbose=verbose)
    return features.iloc[np.flip(k_similar)]

# %%
len(top_k_dfs)
# Out:
# 4392

# %%
case_id
# Out:
# 4391

# %%
top_k_df.
# Out:
#    element_type       osmid  highway source   surface leisure     sport  \
# 51          way  1105105836  footway    nan     paved     nan       nan
# 53          way  1105106176  footway    nan  concrete     nan       nan
# 50          way  1105105835  service    nan       nan     nan       nan
# 49          way  1105105834  service    nan       nan     nan       nan
# 48          way  1105105833  service    nan       nan     nan       nan
# 47          way  1105105832  service    nan       nan     nan       nan
# 34          way   277564665      nan    nan       nan     nan       nan
# 85          way  1171940509      nan    nan       nan   pitch  softball
# 84          way  1171940508      nan    nan       nan   pitch  softball
# 83          way  1171940507      nan    nan       nan   pitch  softball
#
#                                                 nodes name bicycle  ...  \
# 51  [ 668646878, 10112835040, 10112835039, 1011283...  nan     nan  ...
# 53  [ 10112832233, 11098668126, 10112832241, 10112...  nan     nan  ...
# 50          [ 10112835025, 10112835039, 10112835035 ]  nan     nan  ...
# 49          [ 10112835033, 10112835038, 10112835034 ]  nan     nan  ...
# 48  [ 10112835024, 10112835028, 10112835047, 10112...  nan     nan  ...
# 47  [ 10112835024, 978035608, 10112835033, 1011283...  nan     nan  ...
# 34  [ 2820691440, 10155904575, 10794945280, 107949...  nan     nan  ...
# 85  [ 10889194401, 10889194402, 10889194403, 10889...  nan     nan  ...
# 84  [ 10889194386, 10889194387, 10889194388, 10889...  nan     nan  ...
# 83  [ 10889194371, 10889194372, 10889194373, 10889...  nan     nan  ...
#
#           service  fee footway shelter_type  \
# 51            nan  nan     nan          nan
# 53            nan  nan     nan          nan
# 50  parking_aisle  nan     nan          nan
# 49  parking_aisle  nan     nan          nan
# 48  parking_aisle  nan     nan          nan
# 47  parking_aisle  nan     nan          nan
# 34            nan  nan     nan          nan
# 85            nan  nan     nan          nan
# 84            nan  nan     nan          nan
# 83            nan  nan     nan          nan
#
#                                              geometry  \
# 51  LINESTRING (145.05682 -37.65699, 145.05665 -37...
# 53  LINESTRING (145.05658 -37.65664, 145.05668 -37...
# 50  LINESTRING (145.05615 -37.65695, 145.05647 -37...
# 49  LINESTRING (145.05599 -37.65704, 145.05631 -37...
# 48  LINESTRING (145.05583 -37.65713, 145.05583 -37...
# 47  LINESTRING (145.05583 -37.65713, 145.05595 -37...
# 34  POLYGON ((145.05939 -37.65564, 145.05933 -37.6...
# 85  POLYGON ((145.05677 -37.65641, 145.05675 -37.6...
# 84  POLYGON ((145.05563 -37.65674, 145.05557 -37.6...
# 83  POLYGON ((145.05555 -37.65548, 145.05560 -37.6...
#
#                                 full_name      osm_id osm_type        lat  \
# 51          highway footway surface paved  1105105836      way -37.657301
# 53       highway footway surface concrete  1105106176      way -37.656814
# 50  highway service service parking_aisle  1105105835      way -37.657204
# 49  highway service service parking_aisle  1105105834      way -37.657308
# 48  highway service service parking_aisle  1105105833      way -37.657328
# 47  highway service service parking_aisle  1105105832      way -37.656905
# 34                           natural wood   277564665      way -37.655313
# 85           leisure pitch sport softball  1171940509      way -37.656364
# 84           leisure pitch sport softball  1171940508      way -37.656532
# 83           leisure pitch sport softball  1171940507      way -37.655700
#
#            lng
# 51  145.056369
# 53  145.056755
# 50  145.056434
# 49  145.056267
# 48  145.056424
# 47  145.056340
# 34  145.058038
# 85  145.056266
# 84  145.055199
# 83  145.055967
#
# [10 rows x 34 columns]

# %%
top_k_df_all = pd.concat(top_k_dfs)
top_k_df_all.to_csv(os.path.join(WRITE_DIR, 'poi_top10.csv'))
